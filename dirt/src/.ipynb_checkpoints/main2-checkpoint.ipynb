# %% [markdown]
# # インポート

# %%
import create_population
import create_population3
import preprocessing
from feature_engineering import FeatureCreator
from feature_engineering_prediction import PredictionFeatureCreator

import prediction
from train_lgbm_rank_niti_cross import Trainer_lightgbm_rank_niti_cv
from train_lgbm_rank_kaiki_cross import Trainer_lightgbm_rank_kaiki_cv
from train_lgbm_time_cross import Trainer_lightgbm_time_cv

from evaluation_lgbm_rank_niti_cross import Evaluator_lightgbm_rank_niti_cross

import pandas as pd


import condition_prediction


from train_lightgbm_rank_niti import Trainer_lightgbm_rank_niti
from train_lightgbm_time import Trainer_lightgbm_time
from train_lightgbm_rank_kaiki import Trainer_lightgbm_rank_kaiki

from evaluation_lightgbm_rank_niti import Evaluator_lightgbm_rank_niti
from evaluation_lightgbm_time_kaiki import Evaluator_lightgbm_time_kaiki
from evaluation_lightgbm_rank_kaiki import Evaluator_lightgbm_rank_kaiki
from evaluation_pop import Evaluator_pop

# %load_ext autoreload

# %%
# %autoreload

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # 学習母集団の作成
# - ここで何年までのデータを使うか設定してください
# - 2016-01-01から、2024-11-30まではスクレイピングしてあります
# - 特徴量が多いため、あまり年月が嵩むと処理が止まる恐れがあります

# %%
# population = create_population.create(from_="2016-01-01", to_="2023-12-31")
# population = create_population.create(from_="2020-01-01", to_="2023-12-31")
# population = create_population.create(from_="2016-01-01", to_="2023-12-31")
# #テスト用
# population = create_population.create(from_="2022-01-01", to_="2023-12-31")
population = create_population.create(from_="2016-01-01", to_="2024-11-30")

# %%
population
# Out:
#              race_id       date    horse_id
# 0       201606010101 2016-01-05  2013100513
# 1       201606010101 2016-01-05  2013102845
# 2       201606010101 2016-01-05  2013102932
# 3       201606010101 2016-01-05  2013103416
# 4       201606010101 2016-01-05  2013100107
# ...              ...        ...         ...
# 211703  202408070110 2024-11-30  2019102753
# 211704  202408070110 2024-11-30  2019101055
# 211705  202408070110 2024-11-30  2020104046
# 211706  202408070110 2024-11-30  2020103367
# 211707  202408070110 2024-11-30  2020107113
#
# [211805 rows x 3 columns]

# %% [markdown]
# # データ加工

# %%
#まとめて実行
# レース結果テーブルの前処理
results_preprocessed = preprocessing.process_results()
# 馬の過去成績テーブルの加工
horse_results_preprocessed = preprocessing.process_horse_results()
# レース情報テーブルの前処理
race_info_preprocessed = preprocessing.process_race_info()
# 騎手リーディングテーブルの前処理
jockey_leading_preprocessed = preprocessing.process_jockey_leading()
# 調教師リーディングテーブルの前処理
trainer_leading_preprocessed = preprocessing.process_trainer_leading()
# 血統テーブルの前処理
peds_preprocessed = preprocessing.process_peds()
# 種牡馬リーディングテーブルの前処理
sire_leading_preprocessed = preprocessing.process_sire_leading()
bms_leading_preprocessed = preprocessing.process_sire_leading(
    input_filename="bms_leading.csv",
    output_filename = "bms_leading.csv",
    id_col = "bms_id",
)
# 払い戻しテーブルの前処理_２度目をするならcsvファイルを消さないとダメ
return_tables_preprocessed = preprocessing.process_return_tables()
# Out:
# /Users/iniad/Documents/kenkyu_4/dirt/src/preprocessing.py:520: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["place_course_category"] = df["place_course_category"].fillna(-1).astype(int)

# %%
# 重複チェック
results_preprocessed.duplicated(subset=["race_id", "horse_id"]).sum()

# %%
# 欠損チェック
results_preprocessed.isnull().sum()

# %%
# 欠損チェック
horse_results_preprocessed.isnull().sum()

# %%
# 重複チェック
horse_results_preprocessed.duplicated(subset=["horse_id", "date"]).sum()

# %% [markdown]
# #  特徴量作成

# %%
fc = FeatureCreator()
features = fc.create_features()
# Out:
# agg_horse_n_races_relative:   0%|          | 0/4 [00:00<?, ?it/s]
# running agg_jockey()...
# running agg_jockey()...comp
# running agg_trainer()...
# running agg_trainer()...comp
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# pace_category_win_1:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_2:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_3:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_11()...comp
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_12()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_13()...comp
# agg_raceclass_rankdiff_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_14()...comp
# speed_index:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_15()...comp
# agg_horse_per_ground_state_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_grade:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_weather:   0%|          | 0/4 [00:00<?, ?it/s]
# running agg_sire()...
# running agg_sire()...comp
# running agg_bms()...
# running agg_bms()...comp
# merging all features...
# merging all features...comp

# %%
#もしもカーネルがリセットした場合、ここからfeatureをとる
features = pd.read_csv("../data/02_features/features.csv", sep="\t")

# %%
# 重複チェック
features.duplicated(subset=["race_id", "horse_id"]).sum()

# %%
#特徴量を変更した場合に実行、"config_lightgbm_niti_new.yaml"に特徴量リストが入る
list(features.columns)
import yaml
feature_cols = {
    "features": features.columns.drop(
        ["date","rank","rank_per_horse","time","nobori","corner_1","corner_2","corner_3","corner_4",
                        "corner_1_per_horse","corner_2_per_horse",
                        "corner_3_per_horse",
                        "corner_4_per_horse", "owner_id"]
    ).to_list()
}
print(feature_cols)
with open("config_lightgbm_niti_new.yaml","w") as file:
    yaml.dump(feature_cols,file
              )

# %% [markdown]
# # 学習
# - 特徴量にオッズを利用したもの、利用していないもの
# - rank列を二値分類で予測したもの、回帰で予測したもの、time列を予測したもの
# - ホールドアウト法、cv(クロスバリデーション)を利用したもの
# - その他、独自の特徴量のみを利用したものなど、さまざまな学習モデルを作成する段階です
# - config_filepath="config_lightgbm_kaiki_odds_removed.yaml"の部分を変更することで、特徴量やハイパーパラメータを変更できます
# - 好きな特徴量を選んで、学習させてください（保存先のファイル名の変更も忘れずに）

# %%
#オッズあり、ランク二値、ホールドアウト法
trainer = Trainer_lightgbm_rank_niti()
evaluation_df = trainer.run(
    valid_start_date="2021-01-01",
    test_start_date="2023-01-01"
)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.211354
# [200]	valid_0's binary_logloss: 0.20292
# [300]	valid_0's binary_logloss: 0.200737
# [400]	valid_0's binary_logloss: 0.199977
# [500]	valid_0's binary_logloss: 0.19963
# [600]	valid_0's binary_logloss: 0.199486
# [700]	valid_0's binary_logloss: 0.199449
# [800]	valid_0's binary_logloss: 0.199378
# [900]	valid_0's binary_logloss: 0.199361
# [1000]	valid_0's binary_logloss: 0.199297
# [1100]	valid_0's binary_logloss: 0.199271
# [1200]	valid_0's binary_logloss: 0.199302
# Early stopping, best iteration is:
# [1108]	valid_0's binary_logloss: 0.199254
#              race_id    horse_id  target  rank  tansho_odds  popularity  \
# 165338  202306010101  2020103575       1     1          1.8           1
# 165339  202306010101  2020107073       0     2          7.4           3
# 165340  202306010101  2020102562       0     3         36.1           6
# 165341  202306010101  2020106345       0     4          4.2           2
# 165342  202306010101  2020100039       0     5          7.9           4
# ...              ...         ...     ...   ...          ...         ...
# 210205  202408070110  2019104660       0    11         39.7          10
# 210206  202408070110  2019102753       0    12         66.4          12
# 210207  202408070110  2019101055       0    13        175.5          14
# 210208  202408070110  2020104046       0    14         28.9           9
# 210209  202408070110  2020103367       0    15         14.4           7
#
#         umaban      pred
# 165338      14  0.429738
# 165339       5  0.115963
# 165340       1  0.023907
# 165341      15  0.207785
# 165342       9  0.080743
# ...        ...       ...
# 210205       1  0.021887
# 210206      16  0.013492
# 210207       4  0.003355
# 210208       6  0.019303
# 210209       8  0.035913
#
# [41269 rows x 8 columns]
# -------------------- Metrics --------------------
# Log Loss: 0.1998
# Accuracy: 0.7321
# Precision: 0.1841
# Recall: 0.7992
# F1 Score: 0.2992
# ROC AUC: 0.8438
# test_df's binary_logloss: 0.1998221873110733

# %%
#オッズあり、ランク回帰、ホールドアウト法
trainer = Trainer_lightgbm_rank_kaiki()
evaluation_df = trainer.run(
    valid_start_date="2021-01-01",
    test_start_date="2023-01-01"
)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.58626
# [200]	valid_0's rmse: 3.44297
# [300]	valid_0's rmse: 3.40172
# [400]	valid_0's rmse: 3.37806
# [500]	valid_0's rmse: 3.36277
# [600]	valid_0's rmse: 3.3535
# [700]	valid_0's rmse: 3.34794
# [800]	valid_0's rmse: 3.34449
# [900]	valid_0's rmse: 3.34187
# [1000]	valid_0's rmse: 3.33965
# [1100]	valid_0's rmse: 3.3379
# [1200]	valid_0's rmse: 3.33668
# [1300]	valid_0's rmse: 3.33561
# [1400]	valid_0's rmse: 3.33446
# [1500]	valid_0's rmse: 3.33384
# [1600]	valid_0's rmse: 3.33309
# [1700]	valid_0's rmse: 3.3324
# [1800]	valid_0's rmse: 3.33177
# [1900]	valid_0's rmse: 3.33126
# [2000]	valid_0's rmse: 3.33092
# [2100]	valid_0's rmse: 3.3305
# [2200]	valid_0's rmse: 3.33021
# [2300]	valid_0's rmse: 3.33012
# [2400]	valid_0's rmse: 3.3299
# [2500]	valid_0's rmse: 3.32941
# [2600]	valid_0's rmse: 3.32922
# [2700]	valid_0's rmse: 3.3291
# Early stopping, best iteration is:
# [2650]	valid_0's rmse: 3.32904
#              race_id    horse_id  target  rank  tansho_odds  popularity  \
# 165338  202306010101  2020103575       1     1          1.8           1
# 165339  202306010101  2020107073       2     2          7.4           3
# 165340  202306010101  2020102562       3     3         36.1           6
# 165341  202306010101  2020106345       4     4          4.2           2
# 165342  202306010101  2020100039       5     5          7.9           4
# ...              ...         ...     ...   ...          ...         ...
# 210205  202408070110  2019104660      11    11         39.7          10
# 210206  202408070110  2019102753      12    12         66.4          12
# 210207  202408070110  2019101055      13    13        175.5          14
# 210208  202408070110  2020104046      14    14         28.9           9
# 210209  202408070110  2020103367      15    15         14.4           7
#
#         umaban       pred
# 165338      14   2.231237
# 165339       5   4.531735
# 165340       1   8.227034
# 165341      15   5.103581
# 165342       9   5.135676
# ...        ...        ...
# 210205       1   7.776127
# 210206      16  10.244311
# 210207       4   9.242807
# 210208       6  11.373761
# 210209       8  10.233460
#
# [41269 rows x 8 columns]
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# -------------------- Metrics --------------------
# RMSE: 3.2974
# 値が1に近いほど良いR²: 0.4062
# test_df's root_mean_squared_error: 3.2973834105259674

# %%
#オッズあり、time回帰、ホールドアウト法
trainer = Trainer_lightgbm_time()
evaluation_df = trainer.run(
    valid_start_date="2021-01-01",
    test_start_date="2023-01-01"
)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 7.79323
# [200]	valid_0's rmse: 3.12897
# [300]	valid_0's rmse: 1.67962
# [400]	valid_0's rmse: 1.34522
# [500]	valid_0's rmse: 1.28227
# [600]	valid_0's rmse: 1.26777
# [700]	valid_0's rmse: 1.25999
# [800]	valid_0's rmse: 1.25323
# [900]	valid_0's rmse: 1.25082
# [1000]	valid_0's rmse: 1.25025
# [1100]	valid_0's rmse: 1.24924
# [1200]	valid_0's rmse: 1.24886
# [1300]	valid_0's rmse: 1.24816
# [1400]	valid_0's rmse: 1.24841
# Early stopping, best iteration is:
# [1304]	valid_0's rmse: 1.24807
#              race_id    horse_id  target  rank  tansho_odds  popularity  \
# 165338  202306010101  2020103575    72.6     1          1.8           1
# 165339  202306010101  2020107073    72.9     2          7.4           3
# 165340  202306010101  2020102562    72.9     3         36.1           6
# 165341  202306010101  2020106345    73.4     4          4.2           2
# 165342  202306010101  2020100039    73.9     5          7.9           4
# ...              ...         ...     ...   ...          ...         ...
# 210205  202408070110  2019104660    72.7    11         39.7          10
# 210206  202408070110  2019102753    72.9    12         66.4          12
# 210207  202408070110  2019101055    73.0    13        175.5          14
# 210208  202408070110  2020104046    73.2    14         28.9           9
# 210209  202408070110  2020103367    74.3    15         14.4           7
#
#         umaban       pred
# 165338      14  72.488970
# 165339       5  72.997055
# 165340       1  74.104233
# 165341      15  73.337431
# 165342       9  73.204302
# ...        ...        ...
# 210205       1  71.393458
# 210206      16  72.264228
# 210207       4  71.868795
# 210208       6  72.425986
# 210209       8  72.185693
#
# [41269 rows x 8 columns]
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# -------------------- Metrics --------------------
# RMSE: 1.4223
# 値が1に近いほど良いR²: 0.9952
# test_df's root_mean_squared_error: 1.4223411168637716

# %%
# オッズと人気を特徴量から省いたランク、二値、ホールドアウト法
trainer = Trainer_lightgbm_rank_niti(config_filepath="config_lightgbm_niti_odds_removed.yaml")
evaluation_df = trainer.run(
    valid_start_date="2021-01-01",
    test_start_date="2023-01-01",
    importance_filename="importance_lightgbm_rank_niti_odds_removed",
    model_filename="model_lightgbm_rank_niti_odds_removed.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_odds_removed.csv"
)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.225791
# [200]	valid_0's binary_logloss: 0.218683
# [300]	valid_0's binary_logloss: 0.215817
# [400]	valid_0's binary_logloss: 0.214446
# [500]	valid_0's binary_logloss: 0.213588
# [600]	valid_0's binary_logloss: 0.213008
# [700]	valid_0's binary_logloss: 0.212612
# [800]	valid_0's binary_logloss: 0.212435
# [900]	valid_0's binary_logloss: 0.212218
# [1000]	valid_0's binary_logloss: 0.212083
# [1100]	valid_0's binary_logloss: 0.211986
# [1200]	valid_0's binary_logloss: 0.211959
# [1300]	valid_0's binary_logloss: 0.211938
# [1400]	valid_0's binary_logloss: 0.211922
# Early stopping, best iteration is:
# [1337]	valid_0's binary_logloss: 0.21189
#              race_id    horse_id  target  rank  tansho_odds  popularity  \
# 165338  202306010101  2020103575       1     1          1.8           1
# 165339  202306010101  2020107073       0     2          7.4           3
# 165340  202306010101  2020102562       0     3         36.1           6
# 165341  202306010101  2020106345       0     4          4.2           2
# 165342  202306010101  2020100039       0     5          7.9           4
# ...              ...         ...     ...   ...          ...         ...
# 210205  202408070110  2019104660       0    11         39.7          10
# 210206  202408070110  2019102753       0    12         66.4          12
# 210207  202408070110  2019101055       0    13        175.5          14
# 210208  202408070110  2020104046       0    14         28.9           9
# 210209  202408070110  2020103367       0    15         14.4           7
#
#         umaban      pred
# 165338      14  0.441291
# 165339       5  0.213038
# 165340       1  0.025907
# 165341      15  0.278405
# 165342       9  0.117964
# ...        ...       ...
# 210205       1  0.041689
# 210206      16  0.016442
# 210207       4  0.023217
# 210208       6  0.045023
# 210209       8  0.030610
#
# [41269 rows x 8 columns]
# -------------------- Metrics --------------------
# Log Loss: 0.2118
# Accuracy: 0.7241
# Precision: 0.1727
# Recall: 0.7535
# F1 Score: 0.2810
# ROC AUC: 0.8121
# test_df's binary_logloss: 0.21182939838130768

# %%
# オッズと人気を特徴量から省いた場合,time回帰,ホールドアウト法
trainer = Trainer_lightgbm_time(config_filepath="config_lightgbm_kaiki_odds_removed.yaml")
evaluation_df = trainer.run(
    valid_start_date="2021-01-01",
    test_start_date="2023-01-01",
    importance_filename="importance_lightgbm_time_odds_removed",
    model_filename="model_lightgbm_time_odds_removed.pkl",
    evaluation_filename="evaluation_lightgbm_time_odds_removed.csv"
)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 7.79022
# [200]	valid_0's rmse: 3.12551
# [300]	valid_0's rmse: 1.68012
# [400]	valid_0's rmse: 1.35183
# [500]	valid_0's rmse: 1.29045
# [600]	valid_0's rmse: 1.27796
# [700]	valid_0's rmse: 1.27113
# [800]	valid_0's rmse: 1.26689
# [900]	valid_0's rmse: 1.26364
# [1000]	valid_0's rmse: 1.26278
# [1100]	valid_0's rmse: 1.26215
# [1200]	valid_0's rmse: 1.26142
# [1300]	valid_0's rmse: 1.26085
# [1400]	valid_0's rmse: 1.26046
# [1500]	valid_0's rmse: 1.26034
# Early stopping, best iteration is:
# [1435]	valid_0's rmse: 1.2601
#              race_id    horse_id  target  rank  tansho_odds  popularity  \
# 165338  202306010101  2020103575    72.6     1          1.8           1
# 165339  202306010101  2020107073    72.9     2          7.4           3
# 165340  202306010101  2020102562    72.9     3         36.1           6
# 165341  202306010101  2020106345    73.4     4          4.2           2
# 165342  202306010101  2020100039    73.9     5          7.9           4
# ...              ...         ...     ...   ...          ...         ...
# 210205  202408070110  2019104660    72.7    11         39.7          10
# 210206  202408070110  2019102753    72.9    12         66.4          12
# 210207  202408070110  2019101055    73.0    13        175.5          14
# 210208  202408070110  2020104046    73.2    14         28.9           9
# 210209  202408070110  2020103367    74.3    15         14.4           7
#
#         umaban       pred
# 165338      14  72.415030
# 165339       5  72.942987
# 165340       1  74.194335
# 165341      15  73.468512
# 165342       9  73.216232
# ...        ...        ...
# 210205       1  71.362472
# 210206      16  72.194661
# 210207       4  71.670156
# 210208       6  72.150815
# 210209       8  72.252793
#
# [41269 rows x 8 columns]
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# -------------------- Metrics --------------------
# RMSE: 1.4328
# 値が1に近いほど良いR²: 0.9952
# test_df's root_mean_squared_error: 1.4327880162992623

# %%
# オッズと人気を特徴量から省いたランク、回帰、ホールドアウト法
trainer = Trainer_lightgbm_rank_kaiki(config_filepath="config_lightgbm_kaiki_odds_removed.yaml")
evaluation_df = trainer.run(
    valid_start_date="2022-01-01",
    test_start_date="2023-01-01",
    importance_filename="importance_lightgbm_rank_kaiki_odds_removed",
    model_filename="model_lightgbm_rank_kaiki_odds_removed.pkl",
    evaluation_filename="evaluation_lightgbm_rank_kaiki_odds_removed.csv"
)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 3.69697
# [200]	valid_0's rmse: 3.55283
# [300]	valid_0's rmse: 3.49967
# [400]	valid_0's rmse: 3.46828
# [500]	valid_0's rmse: 3.44754
# [600]	valid_0's rmse: 3.43337
# [700]	valid_0's rmse: 3.42326
# [800]	valid_0's rmse: 3.41621
# [900]	valid_0's rmse: 3.41063
# [1000]	valid_0's rmse: 3.40588
# [1100]	valid_0's rmse: 3.40223
# [1200]	valid_0's rmse: 3.39949
# [1300]	valid_0's rmse: 3.39684
# [1400]	valid_0's rmse: 3.39445
# [1500]	valid_0's rmse: 3.39257
# [1600]	valid_0's rmse: 3.39072
# [1700]	valid_0's rmse: 3.38912
# [1800]	valid_0's rmse: 3.38791
# [1900]	valid_0's rmse: 3.38682
# [2000]	valid_0's rmse: 3.38567
# [2100]	valid_0's rmse: 3.38445
# [2200]	valid_0's rmse: 3.38353
# [2300]	valid_0's rmse: 3.38269
# [2400]	valid_0's rmse: 3.38174
# [2500]	valid_0's rmse: 3.38133
# [2600]	valid_0's rmse: 3.38065
# [2700]	valid_0's rmse: 3.38018
# [2800]	valid_0's rmse: 3.37978
# [2900]	valid_0's rmse: 3.37923
# [3000]	valid_0's rmse: 3.37881
# [3100]	valid_0's rmse: 3.37851
# [3200]	valid_0's rmse: 3.3779
# [3300]	valid_0's rmse: 3.3776
# [3400]	valid_0's rmse: 3.37747
# [3500]	valid_0's rmse: 3.377
# [3600]	valid_0's rmse: 3.37685
# [3700]	valid_0's rmse: 3.37658
# [3800]	valid_0's rmse: 3.37637
# [3900]	valid_0's rmse: 3.37612
# [4000]	valid_0's rmse: 3.37586
# [4100]	valid_0's rmse: 3.37556
# [4200]	valid_0's rmse: 3.37542
# [4300]	valid_0's rmse: 3.37538
# [4400]	valid_0's rmse: 3.37517
# [4500]	valid_0's rmse: 3.37486
# [4600]	valid_0's rmse: 3.37472
# [4700]	valid_0's rmse: 3.37466
# [4800]	valid_0's rmse: 3.37463
# [4900]	valid_0's rmse: 3.37436
# Early stopping, best iteration is:
# [4897]	valid_0's rmse: 3.37433
#              race_id    horse_id  target  rank  tansho_odds  popularity  \
# 165338  202306010101  2020103575       1     1          1.8           1
# 165339  202306010101  2020107073       2     2          7.4           3
# 165340  202306010101  2020102562       3     3         36.1           6
# 165341  202306010101  2020106345       4     4          4.2           2
# 165342  202306010101  2020100039       5     5          7.9           4
# ...              ...         ...     ...   ...          ...         ...
# 210205  202408070110  2019104660      11    11         39.7          10
# 210206  202408070110  2019102753      12    12         66.4          12
# 210207  202408070110  2019101055      13    13        175.5          14
# 210208  202408070110  2020104046      14    14         28.9           9
# 210209  202408070110  2020103367      15    15         14.4           7
#
#         umaban       pred
# 165338      14   2.047289
# 165339       5   3.798886
# 165340       1   8.117971
# 165341      15   4.803322
# 165342       9   4.449628
# ...        ...        ...
# 210205       1   7.160119
# 210206      16   9.417381
# 210207       4   7.819584
# 210208       6   8.866319
# 210209       8  11.187757
#
# [41269 rows x 8 columns]
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# -------------------- Metrics --------------------
# RMSE: 3.3827
# 値が1に近いほど良いR²: 0.3751
# test_df's root_mean_squared_error: 3.382673505916357

# %%
# オッズと人気を特徴量から省いたランク、二値、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(config_filepath="config_lightgbm_niti_odds_removed.yaml")
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_odds_removed",
    model_filename="model_lightgbm_rank_niti_cv_odds_removed.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_odds_removed.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_odds_removed.pkl"
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.222529
# [200]	valid_0's binary_logloss: 0.216197
# [300]	valid_0's binary_logloss: 0.213996
# [400]	valid_0's binary_logloss: 0.213129
# [500]	valid_0's binary_logloss: 0.212645
# [600]	valid_0's binary_logloss: 0.212559
# [700]	valid_0's binary_logloss: 0.212529
# Early stopping, best iteration is:
# [669]	valid_0's binary_logloss: 0.212502
# -------------------- Metrics --------------------
# Accuracy: 0.7535
# Precision: 0.1791
# Recall: 0.7018
# F1 Score: 0.2854
# ROC AUC: 0.8046
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [700]	valid_0's binary_logloss: 0.216896
# [800]	valid_0's binary_logloss: 0.216171
# [900]	valid_0's binary_logloss: 0.21593
# [1000]	valid_0's binary_logloss: 0.215784
# [1100]	valid_0's binary_logloss: 0.215675
# [1200]	valid_0's binary_logloss: 0.215595
# [1300]	valid_0's binary_logloss: 0.215524
# Early stopping, best iteration is:
# [1288]	valid_0's binary_logloss: 0.21551
# -------------------- Metrics --------------------
# Accuracy: 0.7217
# Precision: 0.1667
# Recall: 0.7185
# F1 Score: 0.2706
# ROC AUC: 0.8026
# Training fold 3/5...
# Training until validation scores don't improve for 100 rounds
# [1300]	valid_0's binary_logloss: 0.21392
# [1400]	valid_0's binary_logloss: 0.213565
# [1500]	valid_0's binary_logloss: 0.213368
# [1600]	valid_0's binary_logloss: 0.213177
# [1700]	valid_0's binary_logloss: 0.21305
# [1800]	valid_0's binary_logloss: 0.21303
# Early stopping, best iteration is:
# [1754]	valid_0's binary_logloss: 0.212999
# -------------------- Metrics --------------------
# Accuracy: 0.7119
# Precision: 0.1665
# Recall: 0.7509
# F1 Score: 0.2726
# ROC AUC: 0.8099
# Training fold 4/5...

# %%
#全体のレースを学習した際、最後のブースト回数よりも多いか確認
import lightgbm as lgb
import pickle

from pathlib import Path
DATA_DIR = Path("..", "data")
INPUT_DIR = DATA_DIR / "02_features"
OUTPUT_DIR = DATA_DIR / "03_train"

# モデルの読み込み
with open(OUTPUT_DIR/"model_lightgbm_rank_niti_cv_full_odds_removed.pkl", "rb") as f:
    model = pickle.load(f)

# ブースト回数の取得
num_trees = model.num_trees()

print(f"ブースト回数（num_boost_round）: {num_trees}")

# %%
# オッズと人気を特徴量から省いたランク、回帰、クロスバリデーション
trainer = Trainer_lightgbm_rank_kaiki_cv(config_filepath="config_lightgbm_kaiki_odds_removed.yaml")
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_kaiki_cv_odds_removed",
    model_filename="model_lightgbm_rank_kaiki_cv_odds_removed.pkl",
    evaluation_filename="evaluation_lightgbm_rank_kaiki_cv_odds_removed.csv",
    final_model_filename = "model_lightgbm_rank_kaiki_cv_full_odds_removed.pkl"
)

# %%
# オッズと人気を特徴量から省いたランク、回帰、クロスバリデーション
trainer = Trainer_lightgbm_time_cv(config_filepath="config_lightgbm_kaiki_odds_removed.yaml")
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_time_cv_odds_removed",
    model_filename="model_lightgbm_time_cv_odds_removed.pkl",
    evaluation_filename="evaluation_lightgbm_time_cv_odds_removed.csv",
    final_model_filename = "model_lightgbm_time_cv_full_odds_removed.pkl"
)
# Out:
# Training fold 1/5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 1.066445 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 726850
# [LightGBM] [Info] Number of data points in the train set: 42042, number of used features: 3000
# [LightGBM] [Info] Start training from score 96.302174
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 7.64047
# [200]	valid_0's rmse: 3.10843
# [300]	valid_0's rmse: 1.72337
# [400]	valid_0's rmse: 1.42603
# [500]	valid_0's rmse: 1.38297
# [600]	valid_0's rmse: 1.38206
# Early stopping, best iteration is:
# [535]	valid_0's rmse: 1.38043
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# -------------------- Metrics --------------------
# RMSE: 1.3804
# 値が1に近いほど良いR²: 0.9955
# test_df's root_mean_squared_error: 1.3804334695305767
# Training fold 2/5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.166188 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 730615
# [LightGBM] [Info] Number of data points in the train set: 84084, number of used features: 3000
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's rmse: 1.34102
# [700]	valid_0's rmse: 1.32664
# [800]	valid_0's rmse: 1.32371
# [900]	valid_0's rmse: 1.32264
# [1000]	valid_0's rmse: 1.32067
# [1100]	valid_0's rmse: 1.31677
# [1200]	valid_0's rmse: 1.31508
# [1300]	valid_0's rmse: 1.31376
# [1400]	valid_0's rmse: 1.3117
# [1500]	valid_0's rmse: 1.31054
# [1600]	valid_0's rmse: 1.31001
# [1700]	valid_0's rmse: 1.30918
# [1800]	valid_0's rmse: 1.30902
# [1900]	valid_0's rmse: 1.30902
# [2000]	valid_0's rmse: 1.3086
# [2100]	valid_0's rmse: 1.30854
# Early stopping, best iteration is:
# [2039]	valid_0's rmse: 1.30845
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# -------------------- Metrics --------------------
# RMSE: 1.3085
# 値が1に近いほど良いR²: 0.9961
# test_df's root_mean_squared_error: 1.308453670940135
# Training fold 3/5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 3.153660 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 732797
# [LightGBM] [Info] Number of data points in the train set: 126126, number of used features: 3000
# Training until validation scores don't improve for 100 rounds
# [2100]	valid_0's rmse: 1.30775
# [2200]	valid_0's rmse: 1.29698
# [2300]	valid_0's rmse: 1.29313
# [2400]	valid_0's rmse: 1.29183
# [2500]	valid_0's rmse: 1.29171
# [2600]	valid_0's rmse: 1.29144
# [2700]	valid_0's rmse: 1.2912
# Early stopping, best iteration is:
# [2684]	valid_0's rmse: 1.29115
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# -------------------- Metrics --------------------
# RMSE: 1.2911
# 値が1に近いほど良いR²: 0.9961
# test_df's root_mean_squared_error: 1.2911477471023856
# Training fold 4/5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 4.218988 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 734122
# [LightGBM] [Info] Number of data points in the train set: 168168, number of used features: 3000
# Training until validation scores don't improve for 100 rounds
# [2700]	valid_0's rmse: 1.469
# [2800]	valid_0's rmse: 1.46325
# [2900]	valid_0's rmse: 1.46213
# [3000]	valid_0's rmse: 1.46074
# [3100]	valid_0's rmse: 1.4602
# [3200]	valid_0's rmse: 1.45972
# [3300]	valid_0's rmse: 1.45954
# [3400]	valid_0's rmse: 1.45968
# Early stopping, best iteration is:
# [3313]	valid_0's rmse: 1.45943
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/iniad/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# -------------------- Metrics --------------------
# RMSE: 1.4594
# 値が1に近いほど良いR²: 0.9950
# test_df's root_mean_squared_error: 1.4594275787708924
# Training final model using all data...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 5.281724 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 735041
# [LightGBM] [Info] Number of data points in the train set: 210210, number of used features: 3000
# Final model training completed.

# %% [markdown]
# # 精度評価
# - popは人気列にかけた場合の回収率、的中率です
# - topnはそのモデルが評価した上からn番目にかけた場合の的中回収です
# - 例えばtop4の馬単にかけた場合上から4つの馬をかけた、4*3=12通りの的中率、回収率を計算します
# - なので、馬単と馬連などの的中率は同じになりますが、回収率は変わります

# %%
#オッズあり、ランク、二値、ホールドアウト
evaluator = Evaluator_lightgbm_rank_niti()
summary_df_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti")
summary_df_gbm

# %%
# オッズあり、ランク、回帰、ホールドアウト
evaluator = Evaluator_lightgbm_rank_kaiki(evaluation_filename="evaluation_lightgbm_rank_kaiki.csv")
summary_df_noodds_time = evaluator.summarize_box_exp(exp_name="lightgbm_rank_kaiki")
summary_df_noodds_time

# %%
# オッズあり、タイム、回帰、ホールドアウト
evaluator = Evaluator_lightgbm_time_kaiki(evaluation_filename="evaluation_lightgbm_time.csv")
summary_df_time = evaluator.summarize_box_exp(exp_name="lightgbm_time")
summary_df_time

# %%
# オッズと人気を特徴量から省いた場合、ランク、二値、ホールドアウト
evaluator = Evaluator_lightgbm_rank_niti(evaluation_filename="evaluation_lightgbm_rank_niti_odds_removed.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_noodds")
summary_df_noodds_gbm

# %%
# オッズと人気を特徴量から省いた場合,ランク、回帰、ホールドアウト
evaluator = Evaluator_lightgbm_rank_kaiki(evaluation_filename="evaluation_lightgbm_rank_kaiki_odds_removed.csv")
summary_df_noodds_time = evaluator.summarize_box_exp(exp_name="lightgbm_rank_kaiki_noodds")
summary_df_noodds_time

# %%
# オッズと人気を特徴量から省いた場合,タイム、回帰、ホールドアウト
evaluator = Evaluator_lightgbm_time_kaiki(evaluation_filename="evaluation_lightgbm_time_odds_removed.csv")
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_time_noodds_top3.csv")
summary_df_noodds_time = evaluator.summarize_box_exp(exp_name="lightgbm_time_noodds")
summary_df_noodds_time
# Out:
#     topn bet_type  hitrate_lightgbm_time_noodds  \
# 0      1       単勝                      0.274817
# 1      1       複勝                      0.593604
# 2      2      ワイド                      0.266489
# 3      2       単勝                      0.441372
# 4      2       複勝                      0.804131
# 5      2       馬単                      0.119587
# 6      2       馬連                      0.119587
# 7      3      ワイド                      0.493671
# 8      3      三連単                      0.066289
# 9      3      三連複                      0.066289
# 10     3       単勝                      0.570620
# 11     3       複勝                      0.907728
# 12     3       馬単                      0.248834
# 13     3       馬連                      0.248834
# 14     4      ワイド                      0.654897
# 15     4      三連単                      0.170553
# 16     4      三連複                      0.170553
# 17     4       単勝                      0.659893
# 18     4       複勝                      0.953364
# 19     4       馬単                      0.373418
# 20     4       馬連                      0.373418
# 21     5      ワイド                      0.768155
# 22     5      三連単                      0.289807
# 23     5      三連複                      0.289807
# 24     5       単勝                      0.739174
# 25     5       複勝                      0.976349
# 26     5       馬単                      0.489340
# 27     5       馬連                      0.489340
#
#     returnrate_lightgbm_time_noodds  hitrate_pop  returnrate_pop
# 0                          0.890873     0.336775        0.792105
# 1                          0.907328     0.654231        0.861193
# 2                          1.016689     0.309127        0.812325
# 3                          0.867505     0.517655        0.763491
# 4                          0.894803     0.846769        0.839007
# 5                          0.945786     0.148235        0.740057
# 6                          0.963891     0.148235        0.768887
# 7                          0.975727     0.559294        0.829458
# 8                          1.076449     0.089274        0.716972
# 9                          1.155596     0.089274        0.832612
# 10                         0.864735     0.653231        0.778370
# 11                         0.893948     0.938708        0.841694
# 12                         0.865601     0.319121        0.763574
# 13                         0.871330     0.319121        0.789141
# 14                         0.958700     0.721852        0.821475
# 15                         0.958294     0.222851        0.780446
# 16                         1.042338     0.222851        0.841922
# 17                         0.823476     0.750167        0.781870
# 18                         0.878872     0.972019        0.825550
# 19                         0.848054     0.466023        0.762658
# 20                         0.849212     0.466023        0.778331
# 21                         0.968941     0.826449        0.813015
# 22                         1.029968     0.366422        0.751281
# 23                         1.063348     0.366422        0.806765
# 24                         0.864290     0.815789        0.769434
# 25                         0.884923     0.988008        0.812045
# 26                         0.868731     0.595603        0.754234
# 27                         0.860633     0.595603        0.771972

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(evaluation_filename="evaluation_lightgbm_rank_niti_cv_odds_removed.csv")
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_noodds_top3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_noodds")
summary_df_noodds_gbm

# %%
# オッズと人気を特徴量から省いた場合_ランク、回帰、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_kaiki(evaluation_filename="evaluation_lightgbm_rank_kaiki_cv_odds_removed.csv")
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_kaiki_cross_noodds_top3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_kaiki_cross_noodds")
summary_df_noodds_gbm

# %%
# オッズと人気を特徴量から省いた場合_time、回帰、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_time_kaiki(evaluation_filename="evaluation_lightgbm_time_cv_odds_removed.csv")
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_time_cross_noodds_top3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_time_cross_noodds")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_time_cross_noodds  \
# 0      1       単勝                            0.280727
# 1      1       複勝                            0.596187
# 2      2      ワイド                            0.269000
# 3      2       単勝                            0.446961
# 4      2       複勝                            0.806642
# 5      2       馬単                            0.122639
# 6      2       馬連                            0.122639
# 7      3      ワイド                            0.485543
# 8      3      三連単                            0.074479
# 9      3      三連複                            0.074479
# 10     3       単勝                            0.569689
# 11     3       複勝                            0.901173
# 12     3       馬単                            0.256826
# 13     3       馬連                            0.256826
# 14     4      ワイド                            0.648017
# 15     4      三連単                            0.174828
# 16     4      三連複                            0.174828
# 17     4       単勝                            0.658312
# 18     4       複勝                            0.950139
# 19     4       馬単                            0.378211
# 20     4       馬連                            0.378211
# 21     5      ワイド                            0.764927
# 22     5      三連単                            0.287799
# 23     5      三連複                            0.287799
# 24     5       単勝                            0.734402
# 25     5       複勝                            0.974756
# 26     5       馬単                            0.492883
# 27     5       馬連                            0.492883
#
#     returnrate_lightgbm_time_cross_noodds  hitrate_pop  returnrate_pop
# 0                                0.962841     0.328350        0.782365
# 1                                0.927634     0.644884        0.845162
# 2                                1.047955     0.309910        0.808898
# 3                                0.897762     0.520276        0.794428
# 4                                0.916717     0.847731        0.842042
# 5                                1.076220     0.148510        0.750680
# 6                                1.114117     0.148510        0.780217
# 7                                1.039734     0.555188        0.828473
# 8                                1.504768     0.087548        0.714827
# 9                                1.598057     0.087548        0.812944
# 10                               0.876209     0.652045        0.794435
# 11                               0.906753     0.932951        0.836016
# 12                               0.959528     0.313222        0.763918
# 13                               0.995160     0.313222        0.791600
# 14                               1.000565     0.713454        0.809162
# 15                               1.276946     0.213857        0.737010
# 16                               1.263119     0.213857        0.795826
# 17                               0.862224     0.745591        0.789862
# 18                               0.894924     0.967774        0.815399
# 19                               0.975628     0.456987        0.761549
# 20                               0.992197     0.456987        0.780983
# 21                               0.976992     0.822666        0.803854
# 22                               1.184401     0.349655        0.741587
# 23                               1.177675     0.349655        0.787476
# 24                               0.852676     0.814072        0.782977
# 25                               0.886776     0.985856        0.807127
# 26                               0.927980     0.580342        0.753644
# 27                               0.943271     0.580342        0.772613

# %% [markdown]
# # 予測当日の処理

# %% [markdown]
# ## 事前準備
# **当日出走馬が確定した時点**で実行できる

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
# 当日出走馬の過去成績テーブルの前処理_そのままで使えない未加工のデータを加工する
horse_results_preprocessed = preprocessing.process_horse_results(
    input_filename="horse_results_prediction.csv",
    output_filename="horse_results_prediction.csv"
)
horse_results_preprocessed

# %%
population = create_population.create(from_="2016-01-01", to_="2024-11-31")

# %%
# 当日出走馬の血統テーブルの前処理
peds_preprocessed = preprocessing.process_peds(
    input_filename="peds_prediction.csv",
    output_filename="peds_prediction.csv"
)
peds_preprocessed

# %%
pfc = PredictionFeatureCreator()
# 過去成績集計は事前に行うことができる
pfc.create_baselog()
pfc.agg_horse_n_races()
pfc.agg_horse_n_races_relative()
pfc.agg_horse_n_races_df

# %%
# レース結果テーブルの前処理
results_preprocessed = condition_prediction.process_results()
# レース情報テーブルの前処理
race_info_preprocessed = condition_prediction.process_race_info()
create_race_grade_preprocessed = condition_prediction.create_race_grade()

# %% [markdown]
# ## 当日の予測処理
# レース直前出走直前に実行する

# %%
#当日にやらないと、天気や馬場状態がわからないので、当日に実行してください、
# 特徴量の更新
features = pfc.create_features(
    race_id="202408060411",  # 予測するレースidを指定
    date_content_a = "2024年11月10日", #"%Y年%m月%d日"形式で該当レース当日の日付を入れてください    
    skip_agg_horse=True  # 事前に集計した場合はスキップできる
)

# %%
pfc.results

# %%
pfc.race_info

# %% [markdown]
# ### pred列は全て降順（大きい順）で表示されます
# ### 二値予測のrankはpred列が大きい順で評価がよく、回帰のrankとtimeは小さい順で評価が良いです
# ### 順番が逆になっているので気をつけてください

# %%
# 予測/オッズあり、ランク、二値、ホールドアウト
prediction.predict(features)

# %%
# オッズ除外モデルでの予測、ランク、二値、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_rank_niti_odds_removed.pkl",
    config_filepath="config_lightgbm_niti_odds_removed.yaml"
)

# %%
# オッズあり予測、ランク、二値、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_rank_kaiki.pkl",
    config_filepath="config_lightgbm_kaiki.yaml"
)

# %%
# オッズ除外モデルでの予測、ランク、回帰、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_rank_kaiki_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %%
# オッズありtimeモデルでの予測、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_time.pkl",
    config_filepath="config_lightgbm_kaiki.yaml"
)

# %%
# オッズ除外モデルでの予測、time、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_time_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %%
# オッズ除外モデルでの予測、ランク、二値、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_rank_niti_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_niti_odds_removed.yaml"
)

# %%
# オッズ除外モデルでの予測、ランク、回帰、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_rank_kaiki_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %%
# オッズ除外モデルでの予測、time、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_time_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)
