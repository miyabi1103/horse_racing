# %%
import create_population
import create_population3
import preprocessing
from feature_engineering import FeatureCreator
from feature_engineering_prediction import PredictionFeatureCreator

import prediction
from train_lgbm_rank_niti_cross import Trainer_lightgbm_rank_niti_cv
from train_lgbm_rank_kaiki_cross import Trainer_lightgbm_rank_kaiki_cv
from train_lgbm_time_cross import Trainer_lightgbm_time_cv

from evaluation_lgbm_rank_niti_cross import Evaluator_lightgbm_rank_niti_cross

import pandas as pd


import condition_prediction


from train_lightgbm_rank_niti import Trainer_lightgbm_rank_niti
from train_lightgbm_time import Trainer_lightgbm_time
from train_lightgbm_rank_kaiki import Trainer_lightgbm_rank_kaiki

from evaluation_lightgbm_rank_niti import Evaluator_lightgbm_rank_niti
from evaluation_lightgbm_time_kaiki import Evaluator_lightgbm_time_kaiki
from evaluation_lightgbm_rank_kaiki import Evaluator_lightgbm_rank_kaiki
from evaluation_pop import Evaluator_pop

# %load_ext autoreload

# %%
# %autoreload

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
population = create_population.create(from_="2016-01-01", to_="2024-11-30")

# %%
# 当日出走馬の過去成績テーブルの前処理_そのままで使えない未加工のデータを加工する
horse_results_preprocessed = preprocessing.process_horse_results(
    input_filename="horse_results_prediction.csv",
    output_filename="horse_results_prediction.csv"
)
horse_results_preprocessed

# 当日出走馬の血統テーブルの前処理
peds_preprocessed = preprocessing.process_peds(
    input_filename="peds_prediction.csv",
    output_filename="peds_prediction.csv"
)
peds_preprocessed

pfc = PredictionFeatureCreator()
# 過去成績集計は事前に行うことができる
pfc.create_baselog()
pfc.agg_horse_n_races()
pfc.agg_horse_n_races_relative()
pfc.agg_horse_n_races_df

# レース結果テーブルの前処理
results_preprocessed = condition_prediction.process_results()
# レース情報テーブルの前処理
race_info_preprocessed = condition_prediction.process_race_info()
create_race_grade_preprocessed = condition_prediction.create_race_grade()
# Out:
# agg_horse_n_races_relative:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ###　12/21 第1回目レース

# %%
# 特徴量の更新
features = pfc.create_features(
    race_id="202406050701",  # 予測するレースidを指定
    date_content_a = "2024年12月21日", #"%Y年%m月%d日"形式で該当レース当日の日付を入れてください    
    skip_agg_horse=True  # 事前に集計した場合はスキップできる
)

# %%
pfc.results

# %%
pfc.race_info

# %%
# オッズ除外モデルでの予測、time、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_time_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %%
# オッズ除外モデルでの予測、time、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_time_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %% [markdown]
# ###　12/21 第2回目レース

# %%
# 特徴量の更新
features = pfc.create_features(
    race_id="202406050702",  # 予測するレースidを指定
    date_content_a = "2024年12月21日", #"%Y年%m月%d日"形式で該当レース当日の日付を入れてください    
    skip_agg_horse=True  # 事前に集計した場合はスキップできる
)
# Out:
# fetching shutuba page html...
# fetching shutuba page html...comp
# 0    2023
# Name: date_year, dtype: int32
# running cross_features()...comp
# running agg_interval()...comp
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:641: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["place_course_category"] = df["place_course_category"].fillna(-1).astype(int)
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:823: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['goal_range', 'curve', 'goal_slope']] = df[['goal_range', 'curve', 'goal_slope']].fillna(-1).astype(int)
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# pace_category_win_1:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_2:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_3:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_11()...comp
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_12()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_13()...comp
# agg_raceclass_rankdiff_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_14()...comp
# speed_index:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_15()...comp
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_ground_state_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_grade:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_weather:   0%|          | 0/4 [00:00<?, ?it/s]
# running agg_jockey()...
# running agg_trainer()...
# running agg_sire()...
# running agg_bms()...
# running agg_bms()...comp
# merging all features...
# merging all features...comp
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:6373: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   features["goal_range_100"] = features["goal_range_100"].fillna(-1)

# %%
pfc.results
# Out:
#          race_id    horse_id  jockey_id  trainer_id  umaban  wakuban  \
# 0   202406050702  2022105255       1207        1008       1        1
# 1   202406050702  2022103895       1209        1201       2        1
# 2   202406050702  2022102994       1179         399       3        2
# 3   202406050702  2022105221       1160        1177       4        2
# 4   202406050702  2022105239       1214        1199       5        3
# 5   202406050702  2022105685       1140        1115       6        3
# 6   202406050702  2022103753       1170        1023       7        4
# 7   202406050702  2022104378       5386        1074       8        4
# 8   202406050702  2022106024       1203        1035       9        5
# 9   202406050702  2022104699       5625        1064      10        5
# 10  202406050702  2022101090       1143        1031      11        6
# 11  202406050702  2022106771       1158        1089      12        6
# 12  202406050702  2022105787       1150        1086      13        7
# 13  202406050702  2022107156       1162        1047      14        7
# 14  202406050702  2022103537       1091        1131      15        8
# 15  202406050702  2022105859       5626        1153      16        8
#
#     tansho_odds  popularity  impost  sex  age  weight  weight_diff  n_horses  \
# 0         156.4          15    52.0    1    2   520.0         -2.0        16
# 1          31.6           9    52.0    1    2   440.0          0.0        16
# 2           7.9           4    55.0    1    2   470.0         -8.0        16
# 3         214.9          16    55.0    1    2   474.0          2.0        16
# 4          87.9          12    52.0    1    2   418.0          2.0        16
# 5           9.6           6    55.0    1    2   492.0         -6.0        16
# 6           3.1           1    55.0    1    2   480.0         -4.0        16
# 7           9.0           5    55.0    1    2   456.0          0.0        16
# 8          97.4          13    52.0    1    2   440.0          0.0        16
# 9          24.9           8    55.0    1    2   446.0          0.0        16
# 10         70.1          11    55.0    1    2   498.0         -2.0        16
# 11        146.9          14    55.0    1    2   438.0          2.0        16
# 12         23.3           7    55.0    1    2   468.0        -10.0        16
# 13          4.1           2    55.0    1    2   470.0          0.0        16
# 14         34.6          10    55.0    1    2   454.0        -12.0        16
# 15          6.6           3    55.0    1    2   430.0          6.0        16
#
#     mean_age  median_age  mean_age_kirisute
# 0        2.0         2.0                  2
# 1        2.0         2.0                  2
# 2        2.0         2.0                  2
# 3        2.0         2.0                  2
# 4        2.0         2.0                  2
# 5        2.0         2.0                  2
# 6        2.0         2.0                  2
# 7        2.0         2.0                  2
# 8        2.0         2.0                  2
# 9        2.0         2.0                  2
# 10       2.0         2.0                  2
# 11       2.0         2.0                  2
# 12       2.0         2.0                  2
# 13       2.0         2.0                  2
# 14       2.0         2.0                  2
# 15       2.0         2.0                  2

# %%
pfc.race_info
# Out:
#         race_id  race_type  around  course_len  weather  ground_state  \
# 0  202406050702          0       0        1800        1             0
#
#    race_class  place  race_day_count  race_date_day_count  season  \
# 0           1      6               2             73875002       4
#
#    place_season  place_season_type  kaisai_race  kaisai_race_type  day  \
# 0            64                640            2                20    7
#
#    day_type  kaisai_count  kaisai_count_type  place_season_day_type  \
# 0        70             5                 50                  64070
#
#    day_condition  place_season_condition_type  \
# 0              2                         6420
#
#    place_season_condition_type_categori  place_course_category  \
# 0                                    -3                     -1
#
#    place_course_tough  goal_range  curve  goal_slope goal_range_100  \
# 0                  -1          -1     -1          -1            NaN
#
#    place_season_type_course_len  lap_type  age_season  race_grade  \
# 0                       6401800        -1          24          60
#
#    race_grade_scaled
# 0                1.0

# %%
# オッズ除外モデルでの予測、time、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_time_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)
# Out:
#          race_id  umaban  tansho_odds  popularity  mean_fukusho_rate_wakuban  \
# 11  202406050702      12        146.9          14                   0.207064
# 0   202406050702       1        156.4          15                   0.182594
# 10  202406050702      11         70.1          11                   0.207064
# 4   202406050702       5         87.9          12                   0.178354
# 3   202406050702       4        214.9          16                   0.196187
# 1   202406050702       2         31.6           9                   0.182594
# 12  202406050702      13         23.3           7                   0.242279
# 2   202406050702       3          7.9           4                   0.196187
# 8   202406050702       9         97.4          13                   0.219168
# 14  202406050702      15         34.6          10                   0.211853
# 5   202406050702       6          9.6           6                   0.178354
# 9   202406050702      10         24.9           8                   0.219168
# 15  202406050702      16          6.6           3                   0.211853
# 6   202406050702       7          3.1           1                   0.184862
# 7   202406050702       8          9.0           5                   0.184862
# 13  202406050702      14          4.1           2                   0.242279
#
#     mean_fukusho_rate_umaban  \
# 11                  0.222059
# 0                   0.180707
# 10                  0.221751
# 4                   0.195387
# 3                   0.211460
# 1                   0.200272
# 12                  0.228707
# 2                   0.203274
# 8                   0.193460
# 14                  0.197343
# 5                   0.171662
# 9                   0.229282
# 15                  0.193622
# 6                   0.174863
# 7                   0.223881
# 13                  0.216123
#
#     distance_place_type_ground_state_encoded_time_diff_mean_3races_cross_encoded_relative  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                           -1.430730
# 14                                          -1.084828
# 5                                            0.292428
# 9                                            0.350400
# 15                                          -0.077593
# 6                                           -0.149295
# 7                                            0.232692
# 13                                           1.866925
#
#     distance_place_type_ground_state_encoded_time_diff_min_3races_cross_encoded_relative  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                           -1.073960
# 14                                          -0.396411
# 5                                            0.095932
# 9                                            0.188848
# 15                                           0.410782
# 6                                           -1.262468
# 7                                            0.068168
# 13                                           1.969108
#
#     syunpatu_mean_3races_encoded  zizoku_mean_3races_encoded  \
# 11                           NaN                         NaN
# 0                            NaN                         NaN
# 10                           NaN                         NaN
# 4                            NaN                         NaN
# 3                            NaN                         NaN
# 1                            NaN                         NaN
# 12                           NaN                         NaN
# 2                            NaN                         NaN
# 8                       0.754071                   -0.288964
# 14                           NaN                         NaN
# 5                       1.035083                   -0.093813
# 9                       0.979826                    0.029167
# 15                      1.204545                    0.066667
# 6                       1.113684                   -0.165720
# 7                       0.949796                    0.132738
# 13                      1.166220                    0.123810
#
#     dominant_position_category  pace_category  ground_state_level  \
# 11                           2              2                 NaN
# 0                            2              2                 NaN
# 10                           2              2                 NaN
# 4                            2              2                 NaN
# 3                            2              2                 NaN
# 1                            2              2                 NaN
# 12                           2              2                 NaN
# 2                            2              2                 NaN
# 8                            3              2                 NaN
# 14                           4              2                 NaN
# 5                            2              2                 NaN
# 9                            3              2                 NaN
# 15                           4              2                 NaN
# 6                            2              2                 NaN
# 7                            2              2                 NaN
# 13                           3              2                 NaN
#
#     rentai_for_pace_category_n5_relative  \
# 11                                   NaN
# 0                                    NaN
# 10                                   NaN
# 4                                    NaN
# 3                                    NaN
# 1                                    NaN
# 12                                   NaN
# 2                                    NaN
# 8                                    NaN
# 14                                   NaN
# 5                                    NaN
# 9                                    NaN
# 15                                   NaN
# 6                                    NaN
# 7                                    NaN
# 13                                   NaN
#
#     score_pace_potision_mean_3races_per_score_raw_relative  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                           -1.099026
# 14                                          -1.099026
# 5                                           -0.759559
# 9                                           -0.335224
# 15                                           0.734098
# 6                                            0.785019
# 7                                            0.123057
# 13                                           1.650661
#
#     mean_5races_sum_relative  tenkai_combined_standardized  \
# 11                 -0.614366                      0.652495
# 0                  -0.614366                      0.652495
# 10                 -0.614366                      0.652495
# 4                  -0.614366                      0.652495
# 3                  -0.614366                      0.652495
# 1                  -0.614366                      0.652495
# 12                 -0.614366                      0.652495
# 2                  -0.614366                      0.652495
# 8                  -0.614366                     -1.478100
# 14                 -0.614366                     -1.371571
# 5                  -0.229824                      0.652495
# 9                   0.250853                     -1.478100
# 15                  1.462160                     -1.371571
# 6                   1.519841                      0.652495
# 7                   0.640202                      0.652495
# 13                  2.500423                     -1.478100
#
#     tenkai_all_combined_standardized  \
# 11                               NaN
# 0                                NaN
# 10                               NaN
# 4                                NaN
# 3                                NaN
# 1                                NaN
# 12                               NaN
# 2                                NaN
# 8                                NaN
# 14                               NaN
# 5                                NaN
# 9                                NaN
# 15                               NaN
# 6                                NaN
# 7                                NaN
# 13                               NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_plus_tenkai_combined_standardized  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                           -1.302140
# 14                                          -1.287563
# 5                                           -0.213123
# 9                                           -0.216949
# 15                                           0.143790
# 6                                            1.673243
# 7                                            0.673532
# 13                                           0.529210
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_plus_tenkai_combined_standardized  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                           -1.086765
# 14                                          -1.464951
# 5                                           -0.179701
# 9                                           -0.207908
# 15                                           0.287480
# 6                                            1.586183
# 7                                            0.996997
# 13                                           0.068666
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_plus_tenkai_all_combined_standardized  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                                 NaN
# 14                                                NaN
# 5                                                 NaN
# 9                                                 NaN
# 15                                                NaN
# 6                                                 NaN
# 7                                                 NaN
# 13                                                NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_plus_tenkai_all_combined_standardized  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                                 NaN
# 14                                                NaN
# 5                                                 NaN
# 9                                                 NaN
# 15                                                NaN
# 6                                                 NaN
# 7                                                 NaN
# 13                                                NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_px_tenkai_combined_standardized  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                           -0.479147
# 14                                          -0.421001
# 5                                            0.900310
# 9                                           -0.798615
# 15                                          -0.800238
# 6                                            1.455635
# 7                                            1.161332
# 13                                          -1.018276
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_px_tenkai_combined_standardized  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                           -0.540136
# 14                                          -0.368348
# 5                                            0.857461
# 9                                           -0.822987
# 15                                          -0.875950
# 6                                            1.425792
# 7                                            1.236168
# 13                                          -0.912000
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_px_tenkai_all_combined_standardized  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                                 NaN
# 14                                                NaN
# 5                                                 NaN
# 9                                                 NaN
# 15                                                NaN
# 6                                                 NaN
# 7                                                 NaN
# 13                                                NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_px_tenkai_all_combined_standardized  \
# 11                                                NaN
# 0                                                 NaN
# 10                                                NaN
# 4                                                 NaN
# 3                                                 NaN
# 1                                                 NaN
# 12                                                NaN
# 2                                                 NaN
# 8                                                 NaN
# 14                                                NaN
# 5                                                 NaN
# 9                                                 NaN
# 15                                                NaN
# 6                                                 NaN
# 7                                                 NaN
# 13                                                NaN
#
#     speed_index_mean_3races  nobori_index_mean_3races  speed_index_min_5races  \
# 11                      NaN                       NaN                     NaN
# 0                       NaN                       NaN                     NaN
# 10                      NaN                       NaN                     NaN
# 4                       NaN                       NaN                     NaN
# 3                       NaN                       NaN                     NaN
# 1                       NaN                       NaN                     NaN
# 12                      NaN                       NaN                     NaN
# 2                       NaN                       NaN                     NaN
# 8                125.705193                136.339939              111.102819
# 14                      NaN                       NaN                     NaN
# 5                142.010179                141.505129              133.254624
# 9                137.652020                140.258081              120.093862
# 15               119.951084                140.335029              119.951084
# 6                133.586283                138.044819              107.517942
# 7                143.569402                140.250161              132.380352
# 13               146.916084                142.411033              146.916084
#
#     nobori_index_min_5races  speed_index_mean_3races_relative  \
# 11                      NaN                               NaN
# 0                       NaN                               NaN
# 10                      NaN                               NaN
# 4                       NaN                               NaN
# 3                       NaN                               NaN
# 1                       NaN                               NaN
# 12                      NaN                               NaN
# 2                       NaN                               NaN
# 8                136.245687                         -1.005947
# 14                      NaN                               NaN
# 5                140.305129                          0.647144
# 9                137.811033                          0.205290
# 15               140.335029                         -1.589330
# 6                133.384508                         -0.206917
# 7                135.875407                          0.805227
# 13               142.411033                          1.144533
#
#     nobori_index_mean_3races_relative        pred
# 11                                NaN  121.077092
# 0                                 NaN  121.060942
# 10                                NaN  121.059448
# 4                                 NaN  120.926389
# 3                                 NaN  120.909110
# 1                                 NaN  120.880527
# 12                                NaN  120.579710
# 2                                 NaN  120.034753
# 8                           -1.718309  119.717033
# 14                                NaN  118.874913
# 5                            0.790421  118.113344
# 9                            0.184731  118.063855
# 15                           0.222104  117.707667
# 6                           -0.890250  117.634133
# 7                            0.180884  117.595975
# 13                           1.230419  117.374496

# %%
# オッズ除外モデルでの予測、time、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_time_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %% [markdown]
# ### 12/21 第4回目レース

# %%
# 特徴量の更新
features = pfc.create_features(
    race_id="202406050704",  # 予測するレースidを指定
    date_content_a = "2024年12月21日", #"%Y年%m月%d日"形式で該当レース当日の日付を入れてください    
    skip_agg_horse=True  # 事前に集計した場合はスキップできる
)
# Out:
# fetching shutuba page html...
# fetching shutuba page html...comp
# 0    2023
# Name: date_year, dtype: int32
# running cross_features()...comp
# running agg_interval()...comp
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:641: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["place_course_category"] = df["place_course_category"].fillna(-1).astype(int)
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:823: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['goal_range', 'curve', 'goal_slope']] = df[['goal_range', 'curve', 'goal_slope']].fillna(-1).astype(int)
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# pace_category_win_1:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_2:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_3:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_11()...comp
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_12()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_13()...comp
# agg_raceclass_rankdiff_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_14()...comp
# speed_index:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_15()...comp
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_ground_state_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_grade:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_weather:   0%|          | 0/4 [00:00<?, ?it/s]
# running agg_jockey()...
# running agg_trainer()...
# running agg_sire()...
# running agg_bms()...
# running agg_bms()...comp
# merging all features...
# merging all features...comp
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:6373: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   features["goal_range_100"] = features["goal_range_100"].fillna(-1)

# %%
pfc.results
# Out:
#          race_id    horse_id  jockey_id  trainer_id  umaban  wakuban  \
# 0   202406050704  2022106337       1209        1114       1        1
# 1   202406050704  2022105508       1117        1074       2        1
# 2   202406050704  2022105448       1140        1189       3        2
# 3   202406050704  2022107286       1206        1020       4        2
# 4   202406050704  2022101023       1075         405       5        3
# 5   202406050704  2022105823       5626        1179       6        3
# 6   202406050704  2022102486       1091        1056       7        4
# 7   202406050704  2022105979       1122        1097       8        4
# 8   202406050704  2022106785       5386        1094       9        5
# 9   202406050704  2022107159       1203        1124      10        5
# 10  202406050704  2022105901       1161        1047      11        6
# 11  202406050704  2022104062       1179        1133      12        6
# 12  202406050704  2022103375       1109        1190      13        7
# 13  202406050704  2022100195       1160        1177      14        7
# 14  202406050704  2022105647       1143         423      15        8
# 15  202406050704  2022103851       1162        1076      16        8
#
#     tansho_odds  popularity  impost  sex  age  weight  weight_diff  n_horses  \
# 0          54.5          13    53.0    0    2     NaN          NaN        16
# 1          72.6          15    56.0    0    2     NaN          NaN        16
# 2           7.5           3    56.0    0    2     NaN          NaN        16
# 3          35.5          10    52.0    0    2     NaN          NaN        16
# 4          44.3          12    56.0    0    2     NaN          NaN        16
# 5           2.3           1    56.0    0    2     NaN          NaN        16
# 6          26.2           7    56.0    0    2     NaN          NaN        16
# 7           5.3           2    56.0    0    2     NaN          NaN        16
# 8          19.5           6    56.0    0    2     NaN          NaN        16
# 9         112.5          16    53.0    0    2     NaN          NaN        16
# 10         42.4          11    55.0    1    2     NaN          NaN        16
# 11          8.3           4    56.0    0    2     NaN          NaN        16
# 12         28.3           8    56.0    0    2     NaN          NaN        16
# 13         10.1           5    56.0    0    2     NaN          NaN        16
# 14         55.0          14    56.0    0    2     NaN          NaN        16
# 15         29.8           9    56.0    0    2     NaN          NaN        16
#
#     mean_age  median_age  mean_age_kirisute
# 0        2.0         2.0                  2
# 1        2.0         2.0                  2
# 2        2.0         2.0                  2
# 3        2.0         2.0                  2
# 4        2.0         2.0                  2
# 5        2.0         2.0                  2
# 6        2.0         2.0                  2
# 7        2.0         2.0                  2
# 8        2.0         2.0                  2
# 9        2.0         2.0                  2
# 10       2.0         2.0                  2
# 11       2.0         2.0                  2
# 12       2.0         2.0                  2
# 13       2.0         2.0                  2
# 14       2.0         2.0                  2
# 15       2.0         2.0                  2

# %%
pfc.race_info
# Out:
#         race_id  race_type  around  course_len  weather  ground_state  \
# 0  202406050704          0       0        1800        1             0
#
#    race_class  place  race_day_count  race_date_day_count  season  \
# 0           1      6               4             73875004       4
#
#    place_season  place_season_type  kaisai_race  kaisai_race_type  day  \
# 0            64                640            4                40    7
#
#    day_type  kaisai_count  kaisai_count_type  place_season_day_type  \
# 0        70             5                 50                  64070
#
#    day_condition  place_season_condition_type  \
# 0              2                         6420
#
#    place_season_condition_type_categori  place_course_category  \
# 0                                    -3                     -1
#
#    place_course_tough  goal_range  curve  goal_slope goal_range_100  \
# 0                  -1          -1     -1          -1            NaN
#
#    place_season_type_course_len  lap_type  age_season  race_grade  \
# 0                       6401800        -1          24          60
#
#    race_grade_scaled
# 0                1.0

# %%
# オッズ除外モデルでの予測、time、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_time_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)
# Out:
#          race_id  umaban  tansho_odds  popularity  mean_fukusho_rate_wakuban  \
# 15  202406050704      16         29.8           9                   0.211853
# 14  202406050704      15         55.0          14                   0.211853
# 3   202406050704       4         35.5          10                   0.196187
# 9   202406050704      10        112.5          16                   0.219168
# 4   202406050704       5         44.3          12                   0.178354
# 12  202406050704      13         28.3           8                   0.242279
# 1   202406050704       2         72.6          15                   0.182594
# 0   202406050704       1         54.5          13                   0.182594
# 8   202406050704       9         19.5           6                   0.219168
# 13  202406050704      14         10.1           5                   0.242279
# 10  202406050704      11         42.4          11                   0.207064
# 6   202406050704       7         26.2           7                   0.184862
# 2   202406050704       3          7.5           3                   0.196187
# 11  202406050704      12          8.3           4                   0.207064
# 5   202406050704       6          2.3           1                   0.178354
# 7   202406050704       8          5.3           2                   0.184862
#
#     mean_fukusho_rate_umaban  \
# 15                  0.193622
# 14                  0.197343
# 3                   0.211460
# 9                   0.229282
# 4                   0.195387
# 12                  0.228707
# 1                   0.200272
# 0                   0.180707
# 8                   0.193460
# 13                  0.216123
# 10                  0.221751
# 6                   0.174863
# 2                   0.203274
# 11                  0.222059
# 5                   0.171662
# 7                   0.223881
#
#     distance_place_type_ground_state_encoded_time_diff_mean_3races_cross_encoded_relative  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                           -1.184963
# 4                                                 NaN
# 12                                          -1.168441
# 1                                           -1.251566
# 0                                            0.346685
# 8                                           -0.442081
# 13                                          -0.193140
# 10                                           0.492650
# 6                                           -0.692185
# 2                                            0.112741
# 11                                           1.363158
# 5                                            1.691854
# 7                                            0.925288
#
#     distance_place_type_ground_state_encoded_time_diff_min_3races_cross_encoded_relative  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                           -0.854059
# 4                                                 NaN
# 12                                          -0.778859
# 1                                           -0.854059
# 0                                            0.278540
# 8                                           -1.817941
# 13                                          -0.420304
# 10                                           0.723856
# 6                                           -0.348012
# 2                                            0.380169
# 11                                           1.374488
# 5                                            1.242423
# 7                                            1.073758
#
#     syunpatu_mean_3races_encoded  zizoku_mean_3races_encoded  \
# 15                           NaN                         NaN
# 14                           NaN                         NaN
# 3                            NaN                         NaN
# 9                       0.617647                   -0.145692
# 4                            NaN                         NaN
# 12                      0.235366                   -0.544309
# 1                       0.272222                   -0.430556
# 0                       0.878154                   -0.235134
# 8                       0.819599                   -0.527122
# 13                      0.508455                   -0.193659
# 10                      0.895455                   -0.024242
# 6                       0.311111                   -0.220833
# 2                       0.938462                   -0.060119
# 11                      1.283463                   -0.493196
# 5                       1.271930                   -0.053810
# 7                       0.970553                   -0.303066
#
#     dominant_position_category  pace_category  ground_state_level  \
# 15                           2              1                 NaN
# 14                           2              1                 NaN
# 3                            2              1                 NaN
# 9                            4              1                 NaN
# 4                            2              1                 NaN
# 12                           3              1                 NaN
# 1                            2              1                 NaN
# 0                            4              1                 NaN
# 8                            2              1                 NaN
# 13                           3              1                 NaN
# 10                           3              1                 NaN
# 6                            3              1                 NaN
# 2                            3              1                 NaN
# 11                           2              1                 NaN
# 5                            3              1                 NaN
# 7                            3              1                 NaN
#
#     rentai_for_pace_category_n5_relative  \
# 15                                   NaN
# 14                                   NaN
# 3                                    NaN
# 9                              -0.647150
# 4                                    NaN
# 12                                   NaN
# 1                                    NaN
# 0                              -0.647150
# 8                              -0.647150
# 13                                   NaN
# 10                             -0.647150
# 6                              -0.647150
# 2                              -0.647150
# 11                              1.016950
# 5                               1.849001
# 7                               1.016950
#
#     score_pace_potision_mean_3races_per_score_raw_relative  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                           -0.500269
# 4                                                 NaN
# 12                                          -0.500269
# 1                                           -0.500269
# 0                                           -0.500269
# 8                                           -0.084821
# 13                                          -0.500269
# 10                                          -0.500269
# 6                                           -0.500269
# 2                                            2.864860
# 11                                          -0.084821
# 5                                            0.995344
# 7                                           -0.188683
#
#     mean_5races_sum_relative  tenkai_combined_standardized  \
# 15                 -0.416547                      1.097334
# 14                 -0.416547                      1.097334
# 3                  -0.416547                      1.097334
# 9                  -0.416547                     -0.776764
# 4                  -0.416547                      1.097334
# 12                 -0.416547                     -0.875401
# 1                  -0.416547                      1.097334
# 0                  -0.416547                     -0.776764
# 8                   0.052802                      1.097334
# 13                 -0.416547                     -0.875401
# 10                 -0.416547                     -0.875401
# 6                  -0.416547                     -0.875401
# 2                   3.385180                     -0.875401
# 11                 -0.064536                      1.097334
# 5                   1.273109                     -0.875401
# 7                  -0.064536                     -0.875401
#
#     tenkai_all_combined_standardized  \
# 15                               NaN
# 14                               NaN
# 3                                NaN
# 9                                NaN
# 4                                NaN
# 12                               NaN
# 1                                NaN
# 0                                NaN
# 8                                NaN
# 13                               NaN
# 10                               NaN
# 6                                NaN
# 2                                NaN
# 11                               NaN
# 5                                NaN
# 7                                NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_plus_tenkai_combined_standardized  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                           -0.901350
# 4                                                 NaN
# 12                                          -1.085583
# 1                                           -0.382984
# 0                                           -0.505297
# 8                                            0.264058
# 13                                          -0.777515
# 10                                          -0.742213
# 6                                           -0.888860
# 2                                            1.646051
# 11                                           0.896672
# 5                                            1.311136
# 7                                            1.165884
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_plus_tenkai_combined_standardized  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                           -0.671279
# 4                                                 NaN
# 12                                          -1.154438
# 1                                           -0.635882
# 0                                           -0.228387
# 8                                            0.266068
# 13                                          -0.738661
# 10                                          -0.866454
# 6                                           -0.989447
# 2                                            1.136579
# 11                                           1.137853
# 5                                            1.548900
# 7                                            1.195148
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_plus_tenkai_all_combined_standardized  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                                 NaN
# 4                                                 NaN
# 12                                                NaN
# 1                                                 NaN
# 0                                                 NaN
# 8                                                 NaN
# 13                                                NaN
# 10                                                NaN
# 6                                                 NaN
# 2                                                 NaN
# 11                                                NaN
# 5                                                 NaN
# 7                                                 NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_plus_tenkai_all_combined_standardized  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                                 NaN
# 4                                                 NaN
# 12                                                NaN
# 1                                                 NaN
# 0                                                 NaN
# 8                                                 NaN
# 13                                                NaN
# 10                                                NaN
# 6                                                 NaN
# 2                                                 NaN
# 11                                                NaN
# 5                                                 NaN
# 7                                                 NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_px_tenkai_combined_standardized  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                           -0.126736
# 4                                                 NaN
# 12                                          -0.137520
# 1                                            1.271506
# 0                                           -0.265852
# 8                                            1.524037
# 13                                          -0.257754
# 10                                          -0.271532
# 6                                           -0.214298
# 2                                           -1.203634
# 11                                           1.770936
# 5                                           -1.072922
# 7                                           -1.016233
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_px_tenkai_combined_standardized  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                           -0.173522
# 4                                                 NaN
# 12                                          -0.040220
# 1                                            1.088267
# 0                                           -0.350556
# 8                                            1.488855
# 13                                          -0.224881
# 10                                          -0.168124
# 6                                           -0.113498
# 2                                           -1.057743
# 11                                           1.876046
# 5                                           -1.240869
# 7                                           -1.083755
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_px_tenkai_all_combined_standardized  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                                 NaN
# 4                                                 NaN
# 12                                                NaN
# 1                                                 NaN
# 0                                                 NaN
# 8                                                 NaN
# 13                                                NaN
# 10                                                NaN
# 6                                                 NaN
# 2                                                 NaN
# 11                                                NaN
# 5                                                 NaN
# 7                                                 NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_px_tenkai_all_combined_standardized  \
# 15                                                NaN
# 14                                                NaN
# 3                                                 NaN
# 9                                                 NaN
# 4                                                 NaN
# 12                                                NaN
# 1                                                 NaN
# 0                                                 NaN
# 8                                                 NaN
# 13                                                NaN
# 10                                                NaN
# 6                                                 NaN
# 2                                                 NaN
# 11                                                NaN
# 5                                                 NaN
# 7                                                 NaN
#
#     speed_index_mean_3races  nobori_index_mean_3races  speed_index_min_5races  \
# 15                      NaN                       NaN                     NaN
# 14                      NaN                       NaN                     NaN
# 3                       NaN                       NaN                     NaN
# 9                145.297180                143.700161              138.928626
# 4                       NaN                       NaN                     NaN
# 12               128.202896                140.433666              128.202896
# 1                123.817942                137.684508              123.817942
# 0                131.954624                136.338462              127.062193
# 8                140.152089                139.795222              129.535907
# 13               126.192884                140.670910              116.817942
# 10               148.693862                142.411033              148.693862
# 6                121.217942                139.084508              121.217942
# 2                128.692665                136.006951              128.692665
# 11               145.910179                141.405129              142.365735
# 5                140.380514                143.450161              134.832402
# 7                135.828608                141.225243              130.424796
#
#     nobori_index_min_5races  speed_index_mean_3races_relative  \
# 15                      NaN                               NaN
# 14                      NaN                               NaN
# 3                       NaN                               NaN
# 9                143.605129                          1.137578
# 4                       NaN                               NaN
# 12               140.433666                         -0.696601
# 1                137.684508                         -1.167097
# 0                135.005129                         -0.294049
# 8                137.475407                          0.585521
# 13               137.684508                         -0.912271
# 10               142.411033                          1.502034
# 6                139.084508                         -1.446071
# 2                136.006951                         -0.644050
# 11               140.105129                          1.203351
# 5                140.105129                          0.610031
# 7                137.475407                          0.121621
#
#     nobori_index_mean_3races_relative        pred
# 15                                NaN  121.426967
# 14                                NaN  121.164871
# 3                                 NaN  120.974554
# 9                            1.386911  120.828028
# 4                                 NaN  120.737712
# 12                           0.098540  120.233972
# 1                           -0.985782  119.875525
# 0                           -1.516690  119.170214
# 8                           -0.153275  119.071232
# 13                           0.192115  119.032101
# 10                           0.878454  119.021343
# 6                           -0.433594  118.735957
# 2                           -1.647444  117.796003
# 11                           0.481705  117.786248
# 5                            1.288306  117.162383
# 7                            0.410754  117.093719

# %%
# オッズ除外モデルでの予測、time、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_time_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %% [markdown]
# ### 12/21 第7回目レース

# %%
# 特徴量の更新
features = pfc.create_features(
    race_id="202406050707",  # 予測するレースidを指定
    date_content_a = "2024年12月21日", #"%Y年%m月%d日"形式で該当レース当日の日付を入れてください    
    skip_agg_horse=True  # 事前に集計した場合はスキップできる
)
# Out:
# fetching shutuba page html...
# fetching shutuba page html...comp
# 0    2023
# Name: date_year, dtype: int32
# running cross_features()...comp
# running agg_interval()...comp
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:641: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["place_course_category"] = df["place_course_category"].fillna(-1).astype(int)
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:823: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['goal_range', 'curve', 'goal_slope']] = df[['goal_range', 'curve', 'goal_slope']].fillna(-1).astype(int)
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# pace_category_win_1:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_2:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_3:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_11()...comp
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_12()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_13()...comp
# agg_raceclass_rankdiff_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_14()...comp
# speed_index:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_15()...comp
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_ground_state_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_grade:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_weather:   0%|          | 0/4 [00:00<?, ?it/s]
# running agg_jockey()...
# running agg_trainer()...
# running agg_sire()...
# running agg_bms()...
# running agg_bms()...comp
# merging all features...
# merging all features...comp
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:6373: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   features["goal_range_100"] = features["goal_range_100"].fillna(-1)

# %%
pfc.results
# Out:
#          race_id    horse_id  jockey_id  trainer_id  umaban  wakuban  \
# 0   202406050707  2022100837       1112        1084       1        1
# 1   202406050707  2022106689       1179        1159       2        1
# 2   202406050707  2022107203       1184        1156       3        2
# 3   202406050707  2022106698       1214        1076       4        2
# 4   202406050707  2022105965       1122        1151       5        3
# 5   202406050707  2022106405       1077        1063       6        3
# 6   202406050707  2022106500       1206        1174       7        4
# 7   202406050707  2022102790       1192        1167       8        4
# 8   202406050707  2022110001       1170        1071       9        5
# 9   202406050707  2022106418       5386        1035      10        5
# 10  202406050707  2022100216       1092        1094      11        6
# 11  202406050707  2022104533       1117         437      12        6
# 12  202406050707  2022102711        422        1169      13        7
# 13  202406050707  2022100618       1140        1195      14        7
# 14  202406050707  2022105598       1197        1059      15        8
# 15  202406050707  2022103959       1162        1106      16        8
#
#     tansho_odds  popularity  impost  sex  age  weight  weight_diff  n_horses  \
# 0          17.7           8    56.0    0    2     NaN          NaN        16
# 1           9.6           4    55.0    1    2     NaN          NaN        16
# 2          49.0          13    54.0    1    2     NaN          NaN        16
# 3          44.6          12    52.0    1    2     NaN          NaN        16
# 4           2.9           1    56.0    0    2     NaN          NaN        16
# 5         128.8          16    55.0    1    2     NaN          NaN        16
# 6          51.0          14    51.0    1    2     NaN          NaN        16
# 7           4.7           2    55.0    0    2     NaN          NaN        16
# 8          10.9           5    55.0    1    2     NaN          NaN        16
# 9          41.5          11    56.0    0    2     NaN          NaN        16
# 10         13.8           7    55.0    1    2     NaN          NaN        16
# 11         60.0          15    56.0    0    2     NaN          NaN        16
# 12         29.4          10    56.0    0    2     NaN          NaN        16
# 13          8.3           3    55.0    1    2     NaN          NaN        16
# 14         13.7           6    56.0    0    2     NaN          NaN        16
# 15         21.8           9    55.0    1    2     NaN          NaN        16
#
#     mean_age  median_age  mean_age_kirisute
# 0        2.0         2.0                  2
# 1        2.0         2.0                  2
# 2        2.0         2.0                  2
# 3        2.0         2.0                  2
# 4        2.0         2.0                  2
# 5        2.0         2.0                  2
# 6        2.0         2.0                  2
# 7        2.0         2.0                  2
# 8        2.0         2.0                  2
# 9        2.0         2.0                  2
# 10       2.0         2.0                  2
# 11       2.0         2.0                  2
# 12       2.0         2.0                  2
# 13       2.0         2.0                  2
# 14       2.0         2.0                  2
# 15       2.0         2.0                  2

# %%
pfc.race_info
# Out:
#         race_id  race_type  around  course_len  weather  ground_state  \
# 0  202406050707          0       0        1200        1             0
#
#    race_class  place  race_day_count  race_date_day_count  season  \
# 0           2      6               7             73875007       4
#
#    place_season  place_season_type  kaisai_race  kaisai_race_type  day  \
# 0            64                640            7                70    7
#
#    day_type  kaisai_count  kaisai_count_type  place_season_day_type  \
# 0        70             5                 50                  64070
#
#    day_condition  place_season_condition_type  \
# 0              2                         6420
#
#    place_season_condition_type_categori  place_course_category  \
# 0                                    -3                     -1
#
#    place_course_tough  goal_range  curve  goal_slope goal_range_100  \
# 0                  -1          -1     -1          -1            NaN
#
#    place_season_type_course_len  lap_type  age_season  race_grade  \
# 0                       6401200        -1          24          70
#
#    race_grade_scaled
# 0                2.0

# %%
# オッズ除外モデルでの予測、time、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_time_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)
# Out:
#          race_id  umaban  tansho_odds  popularity  mean_fukusho_rate_wakuban  \
# 0   202406050707       1         17.7           8                   0.174194
# 11  202406050707      12         60.0          15                   0.211510
# 6   202406050707       7         51.0          14                   0.176471
# 5   202406050707       6        128.8          16                   0.192982
# 2   202406050707       3         49.0          13                   0.179209
# 12  202406050707      13         29.4          10                   0.205970
# 10  202406050707      11         13.8           7                   0.211510
# 9   202406050707      10         41.5          11                   0.189940
# 15  202406050707      16         21.8           9                   0.208644
# 3   202406050707       4         44.6          12                   0.179209
# 8   202406050707       9         10.9           5                   0.189940
# 14  202406050707      15         13.7           6                   0.208644
# 1   202406050707       2          9.6           4                   0.174194
# 13  202406050707      14          8.3           3                   0.205970
# 4   202406050707       5          2.9           1                   0.192982
# 7   202406050707       8          4.7           2                   0.176471
#
#     mean_fukusho_rate_umaban  \
# 0                   0.188623
# 11                  0.239394
# 6                   0.154762
# 5                   0.209199
# 2                   0.174107
# 12                  0.198157
# 10                  0.181682
# 9                   0.203593
# 15                  0.189895
# 3                   0.194362
# 8                   0.183036
# 14                  0.207792
# 1                   0.158209
# 13                  0.218553
# 4                   0.177083
# 7                   0.206538
#
#     distance_place_type_ground_state_encoded_time_diff_mean_3races_cross_encoded_relative  \
# 0                                                 NaN
# 11                                                NaN
# 6                                           -2.036179
# 5                                           -0.420860
# 2                                           -0.397249
# 12                                          -0.690276
# 10                                          -1.081413
# 9                                            0.642129
# 15                                          -0.585676
# 3                                            0.337876
# 8                                           -0.147835
# 14                                           0.252014
# 1                                            0.118010
# 13                                           1.609116
# 4                                            0.734216
# 7                                            1.666128
#
#     distance_place_type_ground_state_encoded_time_diff_min_3races_cross_encoded_relative  \
# 0                                                 NaN
# 11                                                NaN
# 6                                           -0.691971
# 5                                            0.196772
# 2                                           -0.137439
# 12                                          -0.118113
# 10                                          -1.696623
# 9                                            0.369817
# 15                                          -1.701421
# 3                                            0.641264
# 8                                           -0.215896
# 14                                           0.259776
# 1                                           -0.242569
# 13                                           1.927221
# 4                                           -0.085428
# 7                                            1.494609
#
#     syunpatu_mean_3races_encoded  zizoku_mean_3races_encoded  \
# 0                            NaN                         NaN
# 11                           NaN                         NaN
# 6                       0.872759                   -0.125380
# 5                       0.672917                   -0.336979
# 2                       0.795000                    0.143730
# 12                      0.936774                   -0.139086
# 10                      0.853172                   -0.114166
# 9                       1.541392                   -0.561077
# 15                      0.273770                   -0.374716
# 3                       0.693891                   -0.464405
# 8                       1.117778                   -0.385787
# 14                      1.702356                   -0.392222
# 1                       1.090000                   -0.008904
# 13                      2.098593                   -0.793333
# 4                       1.040213                   -0.374007
# 7                       1.540561                   -0.557500
#
#     dominant_position_category  pace_category  ground_state_level  \
# 0                            2              4                 NaN
# 11                           2              4                 NaN
# 6                            2              4                 NaN
# 5                            3              4                 NaN
# 2                            2              4                 NaN
# 12                           2              4                 NaN
# 10                           2              4                 NaN
# 9                            2              4                 NaN
# 15                           2              4                 NaN
# 3                            2              4                 NaN
# 8                            2              4                 NaN
# 14                           1              4                 NaN
# 1                            3              4                 NaN
# 13                           2              4                 NaN
# 4                            2              4                 NaN
# 7                            2              4                 NaN
#
#     rentai_for_pace_category_n5_relative  \
# 0                                    NaN
# 11                                   NaN
# 6                                    NaN
# 5                                    NaN
# 2                                    NaN
# 12                                   NaN
# 10                                   NaN
# 9                                    NaN
# 15                                   NaN
# 3                                    NaN
# 8                                    NaN
# 14                                   NaN
# 1                                    NaN
# 13                                   NaN
# 4                                    NaN
# 7                                    NaN
#
#     score_pace_potision_mean_3races_per_score_raw_relative  \
# 0                                                 NaN
# 11                                                NaN
# 6                                           -1.205735
# 5                                           -1.205735
# 2                                            0.445149
# 12                                          -0.277113
# 10                                          -0.380293
# 9                                           -0.380293
# 15                                          -0.586653
# 3                                           -1.205735
# 8                                            1.765856
# 14                                          -0.380293
# 1                                            1.765856
# 13                                           0.651510
# 4                                            0.032428
# 7                                            0.961050
#
#     mean_5races_sum_relative  tenkai_combined_standardized  \
# 0                  -1.071764                      0.365963
# 11                 -1.071764                      0.365963
# 6                  -1.071764                      0.365963
# 5                  -1.071764                     -2.561738
# 2                   1.403558                      0.365963
# 12                 -0.196060                      0.365963
# 10                 -0.487961                      0.365963
# 9                  -0.604722                      0.365963
# 15                 -0.487961                      0.365963
# 3                  -0.254441                      0.365963
# 8                   1.730487                      0.365963
# 14                 -0.293361                      0.365963
# 1                   1.730487                     -2.561738
# 13                  0.679643                      0.365963
# 4                   0.095841                      0.365963
# 7                   0.971544                      0.365963
#
#     tenkai_all_combined_standardized  \
# 0                                NaN
# 11                               NaN
# 6                                NaN
# 5                                NaN
# 2                                NaN
# 12                               NaN
# 10                               NaN
# 9                                NaN
# 15                               NaN
# 3                                NaN
# 8                                NaN
# 14                               NaN
# 1                                NaN
# 13                               NaN
# 4                                NaN
# 7                                NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_plus_tenkai_combined_standardized  \
# 0                                                 NaN
# 11                                                NaN
# 6                                           -1.517024
# 5                                           -1.462848
# 2                                            0.370884
# 12                                           0.391747
# 10                                           0.049014
# 9                                           -0.234854
# 15                                          -0.168138
# 3                                           -1.316073
# 8                                            0.550418
# 14                                          -0.056738
# 1                                            0.007162
# 13                                           2.136794
# 4                                           -0.006391
# 7                                            1.256047
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_plus_tenkai_combined_standardized  \
# 0                                                 NaN
# 11                                                NaN
# 6                                           -2.051635
# 5                                           -1.918116
# 2                                            0.706950
# 12                                           0.114195
# 10                                           0.823173
# 9                                            0.637647
# 15                                          -0.408191
# 3                                           -0.598114
# 8                                            0.243373
# 14                                           0.633885
# 1                                           -0.233188
# 13                                           1.106416
# 4                                           -0.162809
# 7                                            1.106416
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_plus_tenkai_all_combined_standardized  \
# 0                                                 NaN
# 11                                                NaN
# 6                                                 NaN
# 5                                                 NaN
# 2                                                 NaN
# 12                                                NaN
# 10                                                NaN
# 9                                                 NaN
# 15                                                NaN
# 3                                                 NaN
# 8                                                 NaN
# 14                                                NaN
# 1                                                 NaN
# 13                                                NaN
# 4                                                 NaN
# 7                                                 NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_plus_tenkai_all_combined_standardized  \
# 0                                                 NaN
# 11                                                NaN
# 6                                                 NaN
# 5                                                 NaN
# 2                                                 NaN
# 12                                                NaN
# 10                                                NaN
# 9                                                 NaN
# 15                                                NaN
# 3                                                 NaN
# 8                                                 NaN
# 14                                                NaN
# 1                                                 NaN
# 13                                                NaN
# 4                                                 NaN
# 7                                                 NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_px_tenkai_combined_standardized  \
# 0                                                 NaN
# 11                                                NaN
# 6                                           -0.241612
# 5                                           -1.934149
# 2                                            0.460791
# 12                                           0.468553
# 10                                           0.341038
# 9                                            0.235424
# 15                                           0.260246
# 3                                           -0.166847
# 8                                            0.527587
# 14                                           0.301693
# 1                                           -2.481071
# 13                                           1.117804
# 4                                            0.320424
# 7                                            0.790119
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_px_tenkai_combined_standardized  \
# 0                                                 NaN
# 11                                                NaN
# 6                                           -0.342810
# 5                                           -1.989231
# 2                                            0.547048
# 12                                           0.355838
# 10                                           0.584539
# 9                                            0.524692
# 15                                           0.187328
# 3                                            0.126063
# 8                                            0.397508
# 14                                           0.523479
# 1                                           -2.532751
# 13                                           0.675907
# 4                                            0.266483
# 7                                            0.675907
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_px_tenkai_all_combined_standardized  \
# 0                                                 NaN
# 11                                                NaN
# 6                                                 NaN
# 5                                                 NaN
# 2                                                 NaN
# 12                                                NaN
# 10                                                NaN
# 9                                                 NaN
# 15                                                NaN
# 3                                                 NaN
# 8                                                 NaN
# 14                                                NaN
# 1                                                 NaN
# 13                                                NaN
# 4                                                 NaN
# 7                                                 NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_px_tenkai_all_combined_standardized  \
# 0                                                 NaN
# 11                                                NaN
# 6                                                 NaN
# 5                                                 NaN
# 2                                                 NaN
# 12                                                NaN
# 10                                                NaN
# 9                                                 NaN
# 15                                                NaN
# 3                                                 NaN
# 8                                                 NaN
# 14                                                NaN
# 1                                                 NaN
# 13                                                NaN
# 4                                                 NaN
# 7                                                 NaN
#
#     speed_index_mean_3races  nobori_index_mean_3races  speed_index_min_5races  \
# 0                       NaN                       NaN                     NaN
# 11                      NaN                       NaN                     NaN
# 6                134.072337                142.531221              132.565735
# 5                134.229002                141.339939              130.536152
# 2                142.745204                145.289657              141.694881
# 12               147.522970                148.223408              136.796408
# 10               136.170919                147.665922              110.184418
# 9                151.385793                145.693539              137.336152
# 15               141.749709                143.952052              137.278625
# 3                148.042613                150.486883              139.145725
# 8                150.808489                144.911721              143.862193
# 14               143.720562                141.222612              128.004973
# 1                153.477012                141.962879              153.477012
# 13               142.073052                135.804424              142.073052
# 4                152.619530                143.071540              143.120149
# 7                143.900956                136.875369              140.006385
#
#     nobori_index_min_5races  speed_index_mean_3races_relative  \
# 0                       NaN                               NaN
# 11                      NaN                               NaN
# 6                140.505129                         -1.588512
# 5                139.745687                         -1.564567
# 2                141.346314                         -0.262944
# 12               140.568560                          0.467294
# 10               141.235029                         -1.267763
# 9                137.946314                          1.057690
# 15               137.758913                         -0.415096
# 3                136.504629                          0.546716
# 8                142.746314                          0.969455
# 14               138.611033                         -0.113869
# 1                141.962879                          1.377314
# 13               135.804424                         -0.365676
# 4                141.585351                          1.246256
# 7                132.404424                         -0.086298
#
#     nobori_index_mean_3races_relative       pred
# 0                                 NaN  75.769405
# 11                                NaN  75.756864
# 6                           -0.238690  74.686960
# 5                           -0.531528  73.973953
# 2                            0.439382  73.615049
# 12                           1.160548  73.569040
# 10                           1.023509  73.535987
# 9                            0.538663  73.527503
# 15                           0.110575  73.473770
# 3                            1.716950  73.390193
# 8                            0.346478  72.973803
# 14                          -0.560369  72.967986
# 1                           -0.378398  72.740821
# 13                          -1.892253  72.714368
# 4                           -0.105870  72.703906
# 7                           -1.628996  72.500875

# %%
# オッズ除外モデルでの予測、time、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_time_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %% [markdown]
# ### 12/21 第8回目レース

# %%
# 特徴量の更新
features = pfc.create_features(
    race_id="202406050708",  # 予測するレースidを指定
    date_content_a = "2024年12月21日", #"%Y年%m月%d日"形式で該当レース当日の日付を入れてください    
    skip_agg_horse=True  # 事前に集計した場合はスキップできる
)
# Out:
# fetching shutuba page html...
# fetching shutuba page html...comp
# 0    2023
# Name: date_year, dtype: int32
# running cross_features()...comp
# running agg_interval()...comp
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:641: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["place_course_category"] = df["place_course_category"].fillna(-1).astype(int)
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:823: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['goal_range', 'curve', 'goal_slope']] = df[['goal_range', 'curve', 'goal_slope']].fillna(-1).astype(int)
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# pace_category_win_1:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_2:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_3:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_11()...comp
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_12()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_13()...comp
# agg_raceclass_rankdiff_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_14()...comp
# speed_index:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_15()...comp
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_ground_state_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_grade:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_weather:   0%|          | 0/4 [00:00<?, ?it/s]
# running agg_jockey()...
# running agg_trainer()...
# running agg_sire()...
# running agg_bms()...
# running agg_bms()...comp
# merging all features...
# merging all features...comp
# /Users/iniad/Documents/kenkyu_4/dirt/src/feature_engineering_prediction.py:6373: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   features["goal_range_100"] = features["goal_range_100"].fillna(-1)

# %%
pfc.results
# Out:
#          race_id    horse_id  jockey_id  trainer_id  umaban  wakuban  \
# 0   202406050708  2020103438       1108        1063       1        1
# 1   202406050708  2021101776       1184        1156       2        1
# 2   202406050708  2021104276       1075        1027       3        2
# 3   202406050708  2021105974       1170        1038       4        2
# 4   202406050708  2020103900       1197        1112       5        3
# 5   202406050708  2021103894       1192        1077       6        3
# 6   202406050708  2021103513       5386        1086       7        4
# 7   202406050708  2021103535        422        1156       8        4
# 8   202406050708  2020103530       1043        1079       9        5
# 9   202406050708  2021106064       1092        1026      10        5
# 10  202406050708  2021102617        726        1081      11        6
# 11  202406050708  2019100097       1214        1035      12        6
# 12  202406050708  2020106979       1183        1089      13        7
# 13  202406050708  2021105779       1140        1202      14        7
# 14  202406050708  2019105338       1179        1070      15        8
# 15  202406050708  2021102516       5626        1043      16        8
#
#     tansho_odds  popularity  impost  sex  age  weight  weight_diff  n_horses  \
# 0          78.0          15    56.0    1    4     NaN          NaN        16
# 1          67.7          12    56.0    0    3     NaN          NaN        16
# 2           7.3           4    57.0    0    3     NaN          NaN        16
# 3           5.6           2    55.0    1    3     NaN          NaN        16
# 4          18.2           9    56.0    1    4     NaN          NaN        16
# 5          16.5           8    54.0    1    3     NaN          NaN        16
# 6          13.1           7    55.0    1    3     NaN          NaN        16
# 7          31.6          11    57.0    0    3     NaN          NaN        16
# 8           8.3           5    56.0    1    4     NaN          NaN        16
# 9          19.0          10    57.0    0    3     NaN          NaN        16
# 10         76.3          13    55.0    1    3     NaN          NaN        16
# 11         77.5          14    53.0    1    5     NaN          NaN        16
# 12         89.6          16    56.0    0    4     NaN          NaN        16
# 13          4.5           1    57.0    0    3     NaN          NaN        16
# 14         10.1           6    58.0    2    5     NaN          NaN        16
# 15          6.1           3    55.0    1    3     NaN          NaN        16
#
#     mean_age  median_age  mean_age_kirisute
# 0        3.5         3.0                  3
# 1        3.5         3.0                  3
# 2        3.5         3.0                  3
# 3        3.5         3.0                  3
# 4        3.5         3.0                  3
# 5        3.5         3.0                  3
# 6        3.5         3.0                  3
# 7        3.5         3.0                  3
# 8        3.5         3.0                  3
# 9        3.5         3.0                  3
# 10       3.5         3.0                  3
# 11       3.5         3.0                  3
# 12       3.5         3.0                  3
# 13       3.5         3.0                  3
# 14       3.5         3.0                  3
# 15       3.5         3.0                  3

# %%
pfc.race_info
# Out:
#         race_id  race_type  around  course_len  weather  ground_state  \
# 0  202406050708          0       0        1200        1             0
#
#    race_class  place  race_day_count  race_date_day_count  season  \
# 0           2      6               8             73875008       4
#
#    place_season  place_season_type  kaisai_race  kaisai_race_type  day  \
# 0            64                640            8                80    7
#
#    day_type  kaisai_count  kaisai_count_type  place_season_day_type  \
# 0        70             5                 50                  64070
#
#    day_condition  place_season_condition_type  \
# 0              2                         6420
#
#    place_season_condition_type_categori  place_course_category  \
# 0                                    -3                     -1
#
#    place_course_tough  goal_range  curve  goal_slope goal_range_100  \
# 0                  -1          -1     -1          -1            NaN
#
#    place_season_type_course_len  lap_type  age_season  race_grade  \
# 0                       6401200        -1          34          70
#
#    race_grade_scaled
# 0                2.0

# %%
# オッズ除外モデルでの予測、time、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_time_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)
# Out:
#          race_id  umaban  tansho_odds  popularity  mean_fukusho_rate_wakuban  \
# 8   202406050708       9          8.3           5                   0.189940
# 7   202406050708       8         31.6          11                   0.176471
# 0   202406050708       1         78.0          15                   0.174194
# 4   202406050708       5         18.2           9                   0.192982
# 11  202406050708      12         77.5          14                   0.211510
# 1   202406050708       2         67.7          12                   0.174194
# 10  202406050708      11         76.3          13                   0.211510
# 12  202406050708      13         89.6          16                   0.205970
# 9   202406050708      10         19.0          10                   0.189940
# 5   202406050708       6         16.5           8                   0.192982
# 6   202406050708       7         13.1           7                   0.176471
# 15  202406050708      16          6.1           3                   0.208644
# 3   202406050708       4          5.6           2                   0.179209
# 13  202406050708      14          4.5           1                   0.205970
# 2   202406050708       3          7.3           4                   0.179209
# 14  202406050708      15         10.1           6                   0.208644
#
#     mean_fukusho_rate_umaban  \
# 8                   0.183036
# 7                   0.206538
# 0                   0.188623
# 4                   0.177083
# 11                  0.239394
# 1                   0.158209
# 10                  0.181682
# 12                  0.198157
# 9                   0.203593
# 5                   0.209199
# 6                   0.154762
# 15                  0.189895
# 3                   0.194362
# 13                  0.218553
# 2                   0.174107
# 14                  0.207792
#
#     distance_place_type_ground_state_encoded_time_diff_mean_3races_cross_encoded_relative  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                           -2.138160
# 4                                           -0.970280
# 11                                          -1.034185
# 1                                           -0.154062
# 10                                          -0.203047
# 12                                          -0.321534
# 9                                           -0.890836
# 5                                            1.111432
# 6                                            0.390427
# 15                                           1.141224
# 3                                            0.724765
# 13                                           0.302579
# 2                                            0.841693
# 14                                           1.199984
#
#     distance_place_type_ground_state_encoded_time_diff_min_3races_cross_encoded_relative  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                           -2.654071
# 4                                           -0.987051
# 11                                          -0.338297
# 1                                            0.019867
# 10                                           0.215126
# 12                                          -0.389391
# 9                                           -0.800467
# 5                                            1.183901
# 6                                            0.300785
# 15                                           0.984434
# 3                                            0.551350
# 13                                           0.551350
# 2                                            0.805351
# 14                                           0.557114
#
#     syunpatu_mean_3races_encoded  zizoku_mean_3races_encoded  \
# 8                            NaN                         NaN
# 7                            NaN                         NaN
# 0                       0.632276                   -0.401350
# 4                       1.389892                   -0.168572
# 11                      0.772293                   -0.583069
# 1                       1.198540                   -0.115910
# 10                      1.335602                   -0.738759
# 12                      0.449882                   -0.281333
# 9                            NaN                   -1.016667
# 5                       2.235714                   -0.238077
# 6                       1.271695                    0.474028
# 15                      1.877433                    0.199792
# 3                       2.459891                    0.289632
# 13                      1.415824                   -0.281457
# 2                       2.520510                   -0.027381
# 14                      2.943618                   -0.158611
#
#     dominant_position_category  pace_category  ground_state_level  \
# 8                            2              2                 NaN
# 7                            2              2                 NaN
# 0                            2              2                 NaN
# 4                            2              2                 NaN
# 11                           2              2                 NaN
# 1                            3              2                 NaN
# 10                           2              2                 NaN
# 12                           3              2                 NaN
# 9                            2              2                 NaN
# 5                            2              2                 NaN
# 6                            2              2                 NaN
# 15                           3              2                 NaN
# 3                            3              2                 NaN
# 13                           4              2                 NaN
# 2                            2              2                 NaN
# 14                           2              2                 NaN
#
#     rentai_for_pace_category_n5_relative  \
# 8                                    NaN
# 7                                    NaN
# 0                              -0.333333
# 4                              -0.333333
# 11                             -0.333333
# 1                                    NaN
# 10                             -0.333333
# 12                             -0.333333
# 9                                    NaN
# 5                               2.666667
# 6                              -0.333333
# 15                                   NaN
# 3                              -0.333333
# 13                                   NaN
# 2                                    NaN
# 14                             -0.333333
#
#     score_pace_potision_mean_3races_per_score_raw_relative  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                           -0.638384
# 4                                           -0.245532
# 11                                          -0.638384
# 1                                           -0.638384
# 10                                          -0.638384
# 12                                          -0.638384
# 9                                           -0.343745
# 5                                           -0.245532
# 6                                           -0.638384
# 15                                           2.190148
# 3                                            2.190148
# 13                                           0.775882
# 2                                           -0.245532
# 14                                          -0.245532
#
#     mean_5races_sum_relative  tenkai_combined_standardized  \
# 8                  -0.730446                      0.652598
# 7                  -0.730446                      0.652598
# 0                  -0.730446                      0.652598
# 4                  -0.019478                      0.652598
# 11                 -0.730446                      0.652598
# 1                  -0.730446                     -1.456809
# 10                 -0.493456                      0.652598
# 12                 -0.730446                     -1.456809
# 9                  -0.286091                      0.652598
# 5                   0.392884                      0.652598
# 6                  -0.730446                      0.652598
# 15                  1.829040                     -1.456809
# 3                   1.829040                     -1.456809
# 13                  2.018631                     -1.351338
# 2                  -0.137972                      0.652598
# 14                 -0.019478                      0.652598
#
#     tenkai_all_combined_standardized  \
# 8                                NaN
# 7                                NaN
# 0                                NaN
# 4                                NaN
# 11                               NaN
# 1                                NaN
# 10                               NaN
# 12                               NaN
# 9                                NaN
# 5                                NaN
# 6                                NaN
# 15                               NaN
# 3                                NaN
# 13                               NaN
# 2                                NaN
# 14                               NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_plus_tenkai_combined_standardized  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                           -1.082082
# 4                                           -0.070423
# 11                                          -0.888110
# 1                                           -1.558572
# 10                                          -0.545627
# 12                                          -1.498807
# 9                                            0.537870
# 5                                            0.590652
# 6                                            0.722441
# 15                                           1.132085
# 3                                            1.112979
# 13                                          -0.305984
# 2                                            0.392849
# 14                                           1.460728
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_plus_tenkai_combined_standardized  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                           -1.088907
# 4                                            0.045499
# 11                                          -0.630529
# 1                                           -0.975476
# 10                                          -1.071176
# 12                                          -1.506814
# 9                                           -0.748656
# 5                                            1.003224
# 6                                            0.701005
# 15                                           1.249042
# 3                                            1.233246
# 13                                           0.049641
# 2                                            0.428512
# 14                                           1.311389
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_plus_tenkai_all_combined_standardized  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                                 NaN
# 4                                                 NaN
# 11                                                NaN
# 1                                                 NaN
# 10                                                NaN
# 12                                                NaN
# 9                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 15                                                NaN
# 3                                                 NaN
# 13                                                NaN
# 2                                                 NaN
# 14                                                NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_plus_tenkai_all_combined_standardized  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                                 NaN
# 4                                                 NaN
# 11                                                NaN
# 1                                                 NaN
# 10                                                NaN
# 12                                                NaN
# 9                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 15                                                NaN
# 3                                                 NaN
# 13                                                NaN
# 2                                                 NaN
# 14                                                NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_px_tenkai_combined_standardized  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                            0.431603
# 4                                            0.657013
# 11                                           0.474823
# 1                                           -0.983779
# 10                                           0.551132
# 12                                          -0.997095
# 9                                            0.792548
# 5                                            0.804308
# 6                                            0.833673
# 15                                          -1.583289
# 3                                           -1.579032
# 13                                          -1.160312
# 2                                            0.760236
# 14                                           0.998172
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_px_tenkai_combined_standardized  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                            0.327666
# 4                                            0.695767
# 11                                           0.476404
# 1                                           -0.923285
# 10                                           0.333420
# 12                                          -0.750873
# 9                                            0.438074
# 5                                            1.006537
# 6                                            0.908471
# 15                                          -1.645115
# 3                                           -1.639989
# 13                                          -1.153662
# 2                                            0.820051
# 14                                           1.106533
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_px_tenkai_all_combined_standardized  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                                 NaN
# 4                                                 NaN
# 11                                                NaN
# 1                                                 NaN
# 10                                                NaN
# 12                                                NaN
# 9                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 15                                                NaN
# 3                                                 NaN
# 13                                                NaN
# 2                                                 NaN
# 14                                                NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_px_tenkai_all_combined_standardized  \
# 8                                                 NaN
# 7                                                 NaN
# 0                                                 NaN
# 4                                                 NaN
# 11                                                NaN
# 1                                                 NaN
# 10                                                NaN
# 12                                                NaN
# 9                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 15                                                NaN
# 3                                                 NaN
# 13                                                NaN
# 2                                                 NaN
# 14                                                NaN
#
#     speed_index_mean_3races  nobori_index_mean_3races  speed_index_min_5races  \
# 8                       NaN                       NaN                     NaN
# 7                       NaN                       NaN                     NaN
# 0                143.558338                146.453758              134.494006
# 4                164.993136                152.691829              157.160623
# 11               149.693206                153.105011              148.910352
# 1                163.202314                153.998196              139.676846
# 10               152.348845                142.764531              142.228626
# 12               134.325239                142.670440              131.521853
# 9                126.206385                134.604424              126.206385
# 5                166.209393                147.940765              166.209393
# 6                142.280708                149.486883              130.952024
# 15               149.315442                149.976911              134.709393
# 3                148.800547                151.744863              141.362791
# 13               148.019425                152.993838              146.276059
# 2                148.859393                154.590765              139.636152
# 14               164.204081                157.518195              153.534759
#
#     nobori_index_min_5races  speed_index_mean_3races_relative  \
# 8                       NaN                               NaN
# 7                       NaN                               NaN
# 0                138.066493                         -0.561400
# 4                148.793957                          1.265818
# 11               152.669256                         -0.038431
# 1                140.505129                          1.113158
# 10               141.834191                          0.187950
# 12               141.345687                         -1.348479
# 9                134.604424                         -2.040574
# 5                147.940765                          1.369498
# 6                147.633001                         -0.670312
# 15               148.046912                         -0.070634
# 3                148.833001                         -0.114526
# 13               152.646912                         -0.181113
# 2                144.034191                         -0.109510
# 14               156.640765                          1.198554
#
#     nobori_index_mean_3races_relative       pred
# 8                                 NaN  75.195717
# 7                                 NaN  75.124757
# 0                           -0.474257  73.878794
# 4                            0.556361  73.842534
# 11                           0.624624  73.820001
# 1                            0.772191  73.567994
# 10                          -1.083769  73.331654
# 12                          -1.099314  72.882233
# 9                           -2.431934  72.773805
# 5                           -0.228582  72.772891
# 6                            0.026859  72.469258
# 15                           0.107818  72.451842
# 3                            0.399909  72.353966
# 13                           0.606257  72.314269
# 2                            0.870092  72.284072
# 14                           1.353745  72.210922

# %%
# オッズ除外モデルでの予測、time、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_time_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)
