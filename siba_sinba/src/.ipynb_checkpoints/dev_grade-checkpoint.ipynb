# %%
import create_population
import preprocessing
from feature_engineering import FeatureCreator
from feature_engineering_prediction import PredictionFeatureCreator

import prediction

import pandas as pd


import html5lib

from train_lightgbm_rank_niti import Trainer_lightgbm_rank_niti
from train_lightgbm_time import Trainer_lightgbm_time
from train_lightgbm_rank_kaiki import Trainer_lightgbm_rank_kaiki


from evaluation_lightgbm_rank_niti import Evaluator_lightgbm_rank_niti
from evaluation_lightgbm_time_kaiki import Evaluator_lightgbm_time_kaiki
from evaluation_lightgbm_rank_kaiki import Evaluator_lightgbm_rank_kaiki
from evaluation_pop import Evaluator_pop

# %load_ext autoreload

# %%
# %autoreload

# %%
population = create_population.create(from_="2023-01-01", to_="2023-12-31")

# %%
population
# Out:
#             race_id       date    horse_id
# 0      202306010101 2023-01-05  2020103575
# 1      202306010101 2023-01-05  2020107073
# 2      202306010101 2023-01-05  2020102562
# 3      202306010101 2023-01-05  2020106345
# 4      202306010101 2023-01-05  2020100039
# ...             ...        ...         ...
# 46207  202309050912 2023-12-28  2017104873
# 46208  202309050912 2023-12-28  2019100653
# 46209  202309050912 2023-12-28  2017106240
# 46210  202309050912 2023-12-28  2018103205
# 46211  202309050912 2023-12-28  2017102603
#
# [46212 rows x 3 columns]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1000)
pd.reset_option('display.precision')
pd.reset_option('display.float_format')

# %%
import json
from pathlib import Path


import re

import pandas as pd
import numpy as np
import ast
COMMON_DATA_DIR = Path("..", "..", "common", "data")
RAWDF_DIR = COMMON_DATA_DIR / "rawdf"
MAPPING_DIR = COMMON_DATA_DIR / "mapping"
POPULATION_DIR = Path("..", "data", "00_population")
OUTPUT_DIR = Path("..", "data", "01_preprocessed")
OUTPUT_DIR.mkdir(exist_ok=True, parents=True)

# カテゴリ変数を数値に変換するためのマッピング
with open(MAPPING_DIR / "sex.json", "r") as f:
    sex_mapping = json.load(f)
with open(MAPPING_DIR / "race_type.json", "r") as f:
    race_type_mapping = json.load(f)
with open(MAPPING_DIR / "around.json", "r") as f:
    around_mapping = json.load(f)
with open(MAPPING_DIR / "weather.json", "r") as f:
    weather_mapping = json.load(f)
with open(MAPPING_DIR / "ground_state.json", "r") as f:
    ground_state_mapping = json.load(f)
with open(MAPPING_DIR / "race_class.json", "r") as f:
    race_class_mapping = json.load(f)
with open(MAPPING_DIR / "place.json", "r") as f:
    place_mapping = json.load(f)

# %% [markdown]
# ### preproでレース平均年齢、中央値、平均年齢切り捨て、切り捨て+季節のカテゴリを作成

# %%
#切り捨て+季節のみ、futureで行う
population_dir = POPULATION_DIR
populaton_filename = "population.csv"
input_dir = RAWDF_DIR
output_dir = OUTPUT_DIR
input_filename= "results.csv"
output_filename = "results.csv"
sex_mapping = sex_mapping

# %%
population = pd.read_csv(population_dir / populaton_filename, sep="\t")

# df = pd.read_csv(input_dir / input_filename, sep="\t").query(
#     "race_id in @population['race_id']"
# )
# `race_id`のリストを作成
population_race_ids = population['race_id'].tolist()

# クエリでリストを直接使用
df = pd.read_csv(input_dir / input_filename, sep="\t").query(
    "race_id in @population_race_ids"
)


df["rank"] = pd.to_numeric(df["着順"], errors="coerce")
df.dropna(subset=["rank"], inplace=True)
df["rank"] = df["rank"].astype(int)

# 時間を秒に変換
df["time"] = pd.to_datetime(df["タイム"], format="%M:%S.%f", errors="coerce")
df.dropna(subset=["time"], inplace=True)
df["time"] = (
    df["time"].dt.minute * 60
    + df["time"].dt.second
    + df["time"].dt.microsecond / 1000000
)
df["time"] = df["time"].astype(float)


# その他の列を整形
df["nobori"] = df["上り"].astype(float)
df["umaban"] = df["馬番"].astype(int)
df["tansho_odds"] = df["単勝"].astype(float)
df["popularity"] = df["人気"].astype(int)
df["impost"] = df["斤量"].astype(float)
df["wakuban"] = df["枠番"].astype(int)
df["sex"] = df["性齢"].str[0].map(sex_mapping)
df["age"] = df["性齢"].str[1:].astype(int)
df["weight"] = df["馬体重"].str.extract(r"(\d+)").astype(int)
df["weight_diff"] = df["馬体重"].str.extract(r"\((.+)\)").astype(int)
df["n_horses"] = df.groupby("race_id")["race_id"].transform("count")

# コーナー通過順を分割して列を作成
corner_cols = df['通過'].str.split('-', expand=True)
corner_cols.columns = [f'corner_{i+1}' for i in range(corner_cols.shape[1])]
# オブジェクト型のデータを整数型に変換する
corner_cols = corner_cols.apply(pd.to_numeric, errors='coerce').astype('Int64')  
# nullable int型を指定


# # time列の相対化
# tmp_df = df.groupby("race_id")["time"]
# df["time_relative"] = ((df["time"] - tmp_df.transform("mean")) / tmp_df.transform("std"))
# tmp_df = df.groupby("race_id")["rank"]
# df["rank_relative"] = ((df["rank"] - tmp_df.transform("mean")) / tmp_df.transform("std"))


# 元のデータフレームと結合
result_df = pd.concat([df, corner_cols], axis=1)
# NoneをNaNに置き換え
result_df = result_df.where(pd.notnull(result_df), np.nan)
df = result_df

# rank / n_horses の特徴量を作成（欠損値を含む行はNaNに設定）
df["rank_per_horse"] = df["rank"].where(df["rank"].notna(), np.nan) / df["n_horses"].where(df["n_horses"].notna(), np.nan)

# corner_1 / n_horses の特徴量を作成（欠損値を含む行はNaNに設定）
df["corner_1_per_horse"] = df["corner_1"].where(df["corner_1"].notna(), np.nan) / df["n_horses"].where(df["n_horses"].notna(), np.nan)

df["corner_2_per_horse"] = df["corner_2"].where(df["corner_2"].notna(), np.nan) / df["n_horses"].where(df["n_horses"].notna(), np.nan)
df["corner_3_per_horse"] = df["corner_3"].where(df["corner_3"].notna(), np.nan) / df["n_horses"].where(df["n_horses"].notna(), np.nan)
df["corner_4_per_horse"] = df["corner_4"].where(df["corner_4"].notna(), np.nan) / df["n_horses"].where(df["n_horses"].notna(), np.nan)
# NoneをNaNに置き換え
df = df.where(pd.notnull(df), np.nan)   
result_df = df

# for col in corner_cols.columns:
#     # ここでは result_df を使う
#     tmp_df = result_df.groupby("race_id")[col]
#     result_df[f"{col}_relative"] = ((result_df[col] - tmp_df.transform("mean")) / tmp_df.transform("std"))
# result_df = result_df.apply(lambda col: col.apply(lambda x: np.nan if pd.isna(x) else x))

        

# データが着順に並んでいることによるリーク防止のため、各レースを馬番順にソートする
result_df = result_df.sort_values(["race_id", "umaban"])

# %%
result_df
# Out:
#              race_id 着順  枠番  馬番         馬名  性齢    斤量    騎手     タイム     着差  \
# 362306  202301010101  5   1   1   ウィスピースノー  牝2  55.0  吉田隼人  1:10.3    1/2
# 362307  202301010101  6   2   2    ロードスタウト  牡2  55.0  鮫島克駿  1:10.7  2.1/2
# 362308  202301010101  7   3   3    コミックガール  牝2  53.0  佐々木大  1:10.9  1.1/4
# 362305  202301010101  4   4   4  デビルシズカチャン  牝2  55.0  ルメール  1:10.2  1.1/2
# 362302  202301010101  1   5   5    サトミノキラリ  牡2  55.0  横山武史  1:09.5    NaN
# ...              ... ..  ..  ..        ...  ..   ...   ...     ...    ...
# 368104  202310030812  1   6   8  ジューンレインボー  牝4  53.0  田口貫太  2:40.0    NaN
# 368109  202310030812  6   7   9   アマートカヴァロ  牡3  55.0  藤岡康太  2:42.6  3.1/2
# 368107  202310030812  4   7  10  ルージュサクシード  牝3  50.0  今村聖奈  2:41.8  1.1/2
# 368105  202310030812  2   8  11  シリンガバルガリス  セ3  55.0   幸英明  2:40.9      5
# 368108  202310030812  5   8  12    ハナビマンカイ  セ6  58.0  国分優作  2:42.0      1
#
#           単勝   人気       馬体重       調教師    horse_id  jockey_id  owner_id  \
# 362306  23.9  5.0  434(-10)  [西] 今野貞一  2021100648       1095    281008
# 362307  61.8  7.0   454(-6)  [西] 中村直也  2021100159       1157    170800
# 362308  18.8  4.0   404(-2)  [東] 上原佑紀  2021100265       1197    320803
# 362305  16.6  3.0   450(+2)  [西] 武幸四郎  2021105553       5339    680031
# 362302   1.2  1.0   452(-4)  [東] 鈴木伸尋  2021101429       1170    425031
# ...      ...  ...       ...       ...         ...        ...       ...
# 368104   3.5  1.0   442(-2)   [西] 武英智  2019102542       1208     17803
# 368109  15.2  8.0    468(0)  [西] 笹田和秀  2020103754       1116    651031
# 368107  23.1  9.0   458(+6)  [西] 松永幹夫  2020100400       1193    180800
# 368105   5.0  3.0   486(-6)  [西] 松永幹夫  2020103663        732    226800
# 368108  14.1  7.0  420(-16)  [西] 坂口智康  2017104623       1125     37803
#
#         trainer_id ﾀｲﾑ指数           通過    上り  調教ﾀｲﾑ  厩舎ｺﾒﾝﾄ  備考           馬主  \
# 362306        1128    **          8-8  34.5    NaN     NaN NaN        水上ふじ子
# 362307        1186    **          5-6  35.1    NaN     NaN NaN    ロードホースクラブ
# 362308        1192    **          5-6  35.3    NaN     NaN NaN         古賀禎彦
# 362305        1160    **          3-3  34.9    NaN     NaN NaN  カカムーチョレーシング
# 362302        1026    **          2-2  34.3    NaN     NaN NaN         田代洋己
# ...            ...   ...          ...   ...    ...     ...  ..          ...
# 368104        1161    **      4-4-2-1  36.5    NaN     NaN NaN          吉川潤
# 368109        1104    **      7-7-9-6  38.4    NaN     NaN NaN         猪又晶介
# 368107        1092    **  11-11-12-10  36.9    NaN     NaN NaN   東京ホースレーシング
# 368105        1092    **      5-5-2-2  37.3    NaN     NaN NaN    サンデーレーシング
# 368108        1170    **      7-7-6-7  38.2    NaN     NaN NaN       廣崎利洋ＨＤ
#
#         賞金(万円)  rank   time  nobori  umaban  tansho_odds  popularity  impost  \
# 362306    55.0     5   70.3    34.5       1         23.9           5    55.0
# 362307     NaN     6   70.7    35.1       2         61.8           7    55.0
# 362308     NaN     7   70.9    35.3       3         18.8           4    53.0
# 362305    83.0     4   70.2    34.9       4         16.6           3    55.0
# 362302   550.0     1   69.5    34.3       5          1.2           1    55.0
# ...        ...   ...    ...     ...     ...          ...         ...     ...
# 368104   800.0     1  160.0    36.5       8          3.5           1    53.0
# 368109     NaN     6  162.6    38.4       9         15.2           8    55.0
# 368107   120.0     4  161.8    36.9      10         23.1           9    50.0
# 368105   320.0     2  160.9    37.3      11          5.0           3    55.0
# 368108    80.0     5  162.0    38.2      12         14.1           7    58.0
#
#         wakuban  sex  age  weight  weight_diff  n_horses  corner_1  corner_2  \
# 362306        1    1    2     434          -10         8         8         8
# 362307        2    0    2     454           -6         8         5         6
# 362308        3    1    2     404           -2         8         5         6
# 362305        4    1    2     450            2         8         3         3
# 362302        5    0    2     452           -4         8         2         2
# ...         ...  ...  ...     ...          ...       ...       ...       ...
# 368104        6    1    4     442           -2        12         4         4
# 368109        7    0    3     468            0        12         7         7
# 368107        7    1    3     458            6        12        11        11
# 368105        8    2    3     486           -6        12         5         5
# 368108        8    2    6     420          -16        12         7         7
#
#         corner_3  corner_4  rank_per_horse  corner_1_per_horse  \
# 362306      <NA>      <NA>        0.625000                 1.0
# 362307      <NA>      <NA>        0.750000               0.625
# 362308      <NA>      <NA>        0.875000               0.625
# 362305      <NA>      <NA>        0.500000               0.375
# 362302      <NA>      <NA>        0.125000                0.25
# ...          ...       ...             ...                 ...
# 368104         2         1        0.083333            0.333333
# 368109         9         6        0.500000            0.583333
# 368107        12        10        0.333333            0.916667
# 368105         2         2        0.166667            0.416667
# 368108         6         7        0.416667            0.583333
#
#         corner_2_per_horse  corner_3_per_horse  corner_4_per_horse
# 362306                 1.0                <NA>                <NA>
# 362307                0.75                <NA>                <NA>
# 362308                0.75                <NA>                <NA>
# 362305               0.375                <NA>                <NA>
# 362302                0.25                <NA>                <NA>
# ...                    ...                 ...                 ...
# 368104            0.333333            0.166667            0.083333
# 368109            0.583333                0.75                 0.5
# 368107            0.916667                 1.0            0.833333
# 368105            0.416667            0.166667            0.166667
# 368108            0.583333                 0.5            0.583333
#
# [45902 rows x 48 columns]

# %%
"""
レース平均年齢、中央値、平均年齢切り捨て
"""
import pandas as pd

# 1. race_idごとの年齢の平均、中央値、平均（小数点以下切り捨て）を計算
race_age_stats = result_df.groupby('race_id').agg(
    mean_age=('age', 'mean'),
    median_age=('age', 'median'),
    mean_age_kirisute=('age', lambda x: int(x.mean()))  # 小数点以下切り捨て
).reset_index()

# 2. result_dfに統合（merge）し、_xや_yを回避する
result_df = result_df.merge(
    race_age_stats, 
    on='race_id', 
    how='left', 
    suffixes=('', '_drop')  # _drop を付けることで重複を回避
)

# 不要な列を削除（この場合は、"age_drop" などの列があれば削除する）
result_df = result_df.loc[:, ~result_df.columns.str.endswith('_drop')]

# 確認
result_df.tail(100)
# Out:
#             race_id  着順  枠番  馬番         馬名  性齢    斤量    騎手     タイム     着差  \
# 45802  202310030806  12   1   2    アオイリキマル  牡3  53.0  大久保友  1:47.4      3
# 45803  202310030806  16   2   3      ヒュプノス  牡3  56.0  水口優也  1:51.8  2.1/2
# 45804  202310030806   6   2   4      ヴォランテ  牡3  53.0  川端海翼  1:46.6     クビ
# 45805  202310030806   7   3   5    モズマワシゲリ  牡3  56.0  団野大成  1:46.8  1.1/2
# 45806  202310030806  15   3   6       ホペロア  牡3  56.0  岩田望来  1:51.4      大
# 45807  202310030806   1   4   7    ヘヴンズタイム  牡3  53.0  田口貫太  1:46.0    NaN
# 45808  202310030806   4   4   8    セザンワールド  牡3  56.0  国分優作  1:46.5  1.3/4
# 45809  202310030806  10   5   9     リードブロー  牡3  56.0  藤岡康太  1:46.9     ハナ
# 45810  202310030806  11   5  10  ジャスティンボルト  牡3  56.0  坂井瑠星  1:46.9     クビ
# 45811  202310030806  13   6  11  サンライズプラーナ  牡3  56.0  国分恭介  1:48.7      8
# 45812  202310030806   5   6  12  ホッコーソムニウム  牡3  56.0  松山弘平  1:46.5     ハナ
# 45813  202310030806  14   7  13     タイトニット  牡3  56.0  松若風馬  1:49.4      4
# 45814  202310030806   2   7  14  セブンスストリート  牡3  56.0  和田竜二  1:46.0     ハナ
# 45815  202310030806   3   8  15  メイショウホウセン  牡3  55.0  角田大河  1:46.2  1.1/4
# 45816  202310030806   8   8  16  メイショウランザン  牡3  56.0  太宰啓介  1:46.9     クビ
# 45817  202310030807   5   1   1     ゴルトリッチ  牡3  56.0  坂井瑠星  1:08.6    1/2
# 45818  202310030807  15   1   2  メイショウヒゾッコ  牝5  56.0  太宰啓介  1:09.0    アタマ
# 45819  202310030807  12   2   3    フィルムスコア  牝5  56.0  藤懸貴志  1:08.9     クビ
# 45820  202310030807  11   2   4     スカプラリオ  牝3  54.0   田中健  1:08.9    アタマ
# 45821  202310030807   9   3   5      ヒトヨギリ  牝5  55.0  角田大河  1:08.8    1/2
# 45822  202310030807  16   3   6        マイド  牡3  56.0  団野大成  1:09.1     クビ
# 45823  202310030807  14   4   7   アントニオヒロキ  牡3  55.0  秋山稔樹  1:09.0    1/2
# 45824  202310030807  18   4   8     モノセーラス  牝3  54.0  松若風馬  1:10.0      5
# 45825  202310030807  13   5   9    ニシノコウダイ  牡3  53.0  田口貫太  1:08.9     ハナ
# 45826  202310030807   8   5  10   メイケイバートン  牡4  58.0  岩田望来  1:08.7     クビ
# 45827  202310030807   4   6  11   ダイヤモンドフジ  牡4  58.0  国分恭介  1:08.5    3/4
# 45828  202310030807  10   6  12   バーニングパワー  牝5  56.0   酒井学  1:08.9    1/2
# 45829  202310030807   6   7  13     テンジュイン  牝6  56.0  和田竜二  1:08.7    1/2
# 45830  202310030807   7   7  14    ヨウシタンレイ  牝3  51.0  今村聖奈  1:08.7     ハナ
# 45831  202310030807   3   7  15        ダミエ  牡3  56.0  藤岡康太  1:08.4    アタマ
# 45832  202310030807  17   8  16   ニシノベストワン  牡3  56.0   幸英明  1:09.2    3/4
# 45833  202310030807   2   8  17  シンプリーオーサム  牡3  56.0  西村淳也  1:08.3      1
# 45834  202310030807   1   8  18   トーホウフランゴ  牝3  51.0  永島まな  1:08.2    NaN
# 45835  202310030808   8   1   1   タイキエクセロン  牡4  58.0  坂井瑠星  0:58.8     ハナ
# 45836  202310030808  12   2   2    モズメルベイユ  牝3  54.0  西村淳也  0:59.3    1/2
# 45837  202310030808   3   3   3        フェリ  牝3  54.0   田中健  0:58.1    アタマ
# 45838  202310030808   2   4   4   ストリンジェンド  牡3  56.0  松山弘平  0:58.1  1.3/4
# 45839  202310030808   4   4   5  アインシュペンナー  牝4  56.0  国分恭介  0:58.2     クビ
# 45840  202310030808   6   5   6      ルワンジュ  牡4  58.0  岩田望来  0:58.5  1.1/4
# 45841  202310030808   9   5   7   ザモウコダマシイ  牝5  56.0  藤懸貴志  0:58.9    3/4
# 45842  202310030808  11   6   8   プレシャスアロー  牝3  54.0  藤岡康太  0:59.2     クビ
# 45843  202310030808   5   6   9       モーデン  牡5  54.0  河原田菜  0:58.3    1/2
# 45844  202310030808   1   7  10  メイショウカゼマチ  牡3  53.0  西塚洸二  0:57.8    NaN
# 45845  202310030808  10   7  11  タイガークリスエス  牡4  55.0  田口貫太  0:59.1  1.1/4
# 45846  202310030808   7   8  12    ヤマイチエスポ  牝4  53.0  川端海翼  0:58.8  1.3/4
# 45847  202310030808  13   8  13  アルティジャナーレ  牝3  51.0  永島まな  0:59.8      3
# 45848  202310030809   9   1   1  アスクキングコング  セ5  58.0  川須栄彦  1:08.8  1.1/4
# 45849  202310030809  11   1   2  サウンドブライアン  牡5  58.0  松山弘平  1:08.9     クビ
# 45850  202310030809  15   2   3     ジュストコル  牡5  58.0  松若風馬  1:09.3    1/2
# 45851  202310030809   8   2   4       イラーレ  牝4  56.0   幸英明  1:08.6     クビ
# 45852  202310030809  13   3   5  メイショウハボタン  牝5  56.0  泉谷楓真  1:08.9     ハナ
# 45853  202310030809  10   3   6   ミルトクレイモー  牡3  56.0  岩田望来  1:08.8     ハナ
# 45854  202310030809   5   4   7  フチサンメルチャン  牡6  58.0   小牧太  1:08.5    1/2
# 45855  202310030809  12   4   8  カンチェンジュンガ  牡3  56.0  藤岡康太  1:08.9    アタマ
# 45856  202310030809   7   5   9  アルムファーツリー  牝5  56.0  団野大成  1:08.6    1/2
# 45857  202310030809  14   5  10   インプロバイザー  牡4  58.0  角田大河  1:09.2      2
# 45858  202310030809  16   6  11    ウインバグース  牡4  58.0  和田竜二  1:09.5  1.1/4
# 45859  202310030809   3   6  12    エテルナメンテ  牝4  56.0  長岡禎仁  1:08.4      1
# 45860  202310030809  17   7  13    イールテソーロ  牝4  56.0  永島まな  1:10.3      5
# 45861  202310030809   2   7  14   プレジールミノル  牡5  58.0   荻野極  1:08.2     クビ
# 45862  202310030809   6   8  15    ダンツイノーバ  牝6  56.0  秋山真一  1:08.5    アタマ
# 45863  202310030809   4   8  16  メイショウイジゲン  牡5  58.0  国分恭介  1:08.4     ハナ
# 45864  202310030809   1   8  17    ロードラスター  牡5  58.0  西村淳也  1:08.2    NaN
# 45865  202310030810   8   1   1      ダッチマン  セ6  58.0  川須栄彦  1:45.7  1.1/2
# 45866  202310030810   6   2   2   コパノリッチマン  牡6  58.0  松若風馬  1:45.1     クビ
# 45867  202310030810  10   2   3    グットディール  セ4  58.0  坂井瑠星  1:46.0    3/4
# 45868  202310030810   7   3   4      モズマゾク  牡5  58.0  長岡禎仁  1:45.5  2.1/2
# 45869  202310030810   1   3   5    リキサントライ  牡5  58.0  松山弘平  1:44.8    NaN
# 45870  202310030810   9   4   6      ムエックス  牡5  58.0  国分優作  1:45.8    1/2
# 45871  202310030810   5   4   7    カシノブレンド  セ7  58.0  秋山稔樹  1:45.0    3/4
# 45872  202310030810  15   5   8   ケイサンフリーゼ  牝5  56.0  太宰啓介  1:49.2  1.1/2
# 45873  202310030810   2   5   9   メイショウミカワ  牡5  58.0  西村淳也  1:44.9     クビ
# 45874  202310030810  11   6  10   リバプールタウン  牡8  58.0  角田大河  1:46.4  2.1/2
# 45875  202310030810   4   6  11     ラズルダズル  牡6  58.0   幸英明  1:44.9     ハナ
# 45876  202310030810   3   7  12  レッドエランドール  セ6  58.0   酒井学  1:44.9     ハナ
# 45877  202310030810  14   7  13  サウンドウォリアー  牡5  58.0  岩田望来  1:48.9      大
# 45878  202310030810  12   8  14  ロードインファイト  牡6  58.0  藤岡康太  1:46.4     クビ
# 45879  202310030810  13   8  15    ストームゾーン  牡4  58.0  団野大成  1:46.8  2.1/2
# 45880  202310030811  10   1   1  テイエムチュララン  牝2  55.0  太宰啓介  1:09.4    1/2
# 45881  202310030811   5   2   2    フォルテローザ  牝2  55.0  団野大成  1:09.0    1/2
# 45882  202310030811   7   3   3    セイウンデセオ  牝2  55.0  今村聖奈  1:09.1     クビ
# 45883  202310030811   8   4   4    ドナヴィーナス  牝2  55.0  川島信二  1:09.1     ハナ
# 45884  202310030811   3   5   5  キャンシーエンゼル  牝2  55.0  松山弘平  1:08.9  1.1/2
# 45885  202310030811   6   6   6  パッシングシャワー  牡2  55.0  西村淳也  1:09.1    1/2
# 45886  202310030811   4   7   7    ビッグドリーム  牡2  55.0   幸英明  1:08.9     クビ
# 45887  202310030811   9   7   8   メイプルギャング  牡2  55.0  角田大河  1:09.3  1.1/4
# 45888  202310030811   2   8   9    ミルテンベルク  牡2  55.0  藤岡康太  1:08.6    アタマ
# 45889  202310030811   1   8  10   アスクワンタイム  牡2  55.0  岩田望来  1:08.6    NaN
# 45890  202310030812   8   1   1      リヴァーレ  牝3  53.0  太宰啓介  2:42.9  1.1/4
# 45891  202310030812  10   2   2   アウローラシエル  牡3  55.0  和田竜二  2:43.6    3/4
# 45892  202310030812   7   3   3  メイショウイッシン  牡3  52.0  永島まな  2:42.7     クビ
# 45893  202310030812  11   4   4   ハイグッドエース  牡4  55.0  西塚洸二  2:43.7    3/4
# 45894  202310030812  12   5   5    コスモフランメ  牝3  52.0  角田大河  2:44.1  2.1/2
# 45895  202310030812   3   5   6   ドゥヴァンスマン  牡3  55.0  坂井瑠星  2:41.6      4
# 45896  202310030812   9   6   7   シュアーウィナー  牡5  55.0  川端海翼  2:43.5  3.1/2
# 45897  202310030812   1   6   8  ジューンレインボー  牝4  53.0  田口貫太  2:40.0    NaN
# 45898  202310030812   6   7   9   アマートカヴァロ  牡3  55.0  藤岡康太  2:42.6  3.1/2
# 45899  202310030812   4   7  10  ルージュサクシード  牝3  50.0  今村聖奈  2:41.8  1.1/2
# 45900  202310030812   2   8  11  シリンガバルガリス  セ3  55.0   幸英明  2:40.9      5
# 45901  202310030812   5   8  12    ハナビマンカイ  セ6  58.0  国分優作  2:42.0      1
#
#           単勝    人気       馬体重       調教師    horse_id  jockey_id  owner_id  \
# 45802  199.8  16.0    500(0)  [西] 清水久詞  2020101895       1194    443033
# 45803  128.5  15.0    488(0)  [西] 吉田直弘  2020106159       1133    368803
# 45804   85.8  14.0   452(+4)  [西] 羽月友彦  2020100593       1195    875006
# 45805   16.5   7.0   500(+4)  [西] 鮫島一歩  2020102261       1180      5803
# 45806   19.7   8.0   512(+2)  [西] 友道康夫  2020103557       1174    858800
# 45807   12.9   6.0   486(+2)  [西] 北出成人  2020105624       1208    788800
# 45808    7.9   4.0    482(0)  [西] 畑端省吾  2020106051       1125    523009
# 45809   28.2   9.0   522(-2)  [西] 安田翔伍  2020103657       1116    506800
# 45810    3.5   1.0    532(0)  [西] 友道康夫  2020103624       1163    195031
# 45811   30.2  11.0   538(+6)  [西] 牧浦充徳  2020101534       1124    399803
# 45812   44.9  12.0   480(-4)  [西] 長谷川浩  2020101379       1126     57803
# 45813   47.5  13.0    542(0)  [西] 今野貞一  2020102750       1154    415800
# 45814    6.8   3.0  454(+12)  [西] 吉岡辰弥  2020101594       1018    272008
# 45815    4.4   2.0    496(0)  [西] 千田輝彦  2020106182       1199    523005
# 45816   29.7  10.0   452(+2)  [西] 松永幹夫  2020106905       1037    523005
# 45817   24.4  11.0   488(+4)  [西] 牧浦充徳  2020101195       1163    427030
# 45818   32.4  12.0   428(+4)   [西] 石橋守  2018106200       1037    523005
# 45819   62.3  14.0   458(+2)   [西] 平田修  2018103063       1138    482002
# 45820   18.3   9.0   456(-4)  [西] 佐々木晶  2020104825       1114    336030
# 45821   45.8  13.0   472(-2)  [西] 中竹和也  2018110113       1199    819031
# 45822   19.9  10.0   456(-4)  [西] 野中賢二  2020101879       1180    318803
# 45823  128.8  17.0   452(+2)  [西] 北出成人  2020100784       1181     87803
# 45824  161.2  18.0   408(-2)  [西] 中村直也  2020106644       1154    601031
# 45825    8.0   4.0  482(-10)  [西] 長谷川浩  2020105484       1208    897009
# 45826    9.4   6.0   456(-2)  [西] 中竹和也  2019104818       1174      4800
# 45827    6.9   2.0    438(0)   [西] 宮本博  2019109096       1124    148800
# 45828  112.6  16.0   486(-2)  [西] 鮫島一歩  2018103200       1034    895002
# 45829   65.9  15.0   460(-6)  [西] 千田輝彦  2017101991       1018    471033
# 45830    7.9   3.0  474(+10)  [西] 松永昌博  2020103969       1193    545008
# 45831   12.8   7.0   458(-4)  [西] 武幸四郎  2020103270       1116      2803
# 45832   16.3   8.0    464(0)  [西] 新谷功一  2020106561        732    897009
# 45833    8.0   5.0   538(+2)  [西] 吉岡辰弥  2020100725       1171    851009
# 45834    4.2   1.0   436(+2)  [西] 高橋康之  2020101763       1187    965800
# 45835    4.3   2.0    506(0)  [西] 西園翔太  2019103996       1163    536800
# 45836   37.7  13.0   436(+3)  [西] 杉山佳明  2020102257       1171      5803
# 45837   17.9   7.0   490(+4)  [西] 佐々木晶  2020105156       1114    547800
# 45838    2.6   1.0   468(-4)  [西] 音無秀孝  2020102702       1126    486800
# 45839   28.4  11.0   452(+4)  [西] 牧田和弥  2019102274       1124    875006
# 45840   26.8  10.0  498(+14)  [西] 千田輝彦  2019105798       1174    854800
# 45841   15.6   6.0   452(-2)  [西] 坂口智康  2018104367       1138    625008
# 45842   19.8   9.0  512(-14)  [西] 藤岡健一  2020104166       1116    348803
# 45843   31.6  12.0   478(-6)  [西] 大橋勇樹  2018100442       1204    188800
# 45844    8.3   3.0    446(0)  [西] 角田晃一  2020106534       1200    523005
# 45845   10.3   4.0   494(+6)  [西] 大橋勇樹  2019102292       1208     49033
# 45846   13.9   5.0   472(-2)  [西] 中尾秀正  2019100288       1195    698033
# 45847   19.6   8.0   454(+4)  [西] 茶木太樹  2020104947       1187    346803
# 45848   46.6  10.0   460(+6)  [西] 梅田智之  2018104534       1128     37803
# 45849   60.5  13.0   484(+4)   [西] 村山明  2018103902       1126    168006
# 45850   47.3  11.0   502(-8)  [西] 大久保龍  2018110001       1154    758005
# 45851   12.8   6.0  462(+20)  [西] 北出成人  2019100666        732    788800
# 45852   66.8  15.0   472(-2)   [西] 本田優  2018106455       1182    523005
# 45853    2.2   1.0   506(+4)  [西] 中村直也  2020100815       1174    695033
# 45854  120.5  17.0   470(+2)  [西] 大橋勇樹  2017100922        894    117030
# 45855    5.7   2.0   470(+6)  [西] 庄野靖志  2020101503       1116    331007
# 45856   22.3   8.0   460(-4)  [西] 川村禎彦  2018101964       1180    899030
# 45857   10.2   4.0   470(-6)  [西] 音無秀孝  2019104498       1199    879033
# 45858   11.5   5.0   484(+8)  [西] 西園正都  2019100210       1018    494800
# 45859   59.7  12.0   458(+4)  [東] 小島茂之  2019101917       1142      3060
# 45860   61.9  14.0   474(+4)  [東] 加藤和宏  2019109146       1187     89803
# 45861   43.9   9.0   496(-8)  [西] 北出成人  2018104322       1160    265008
# 45862   16.2   7.0   462(-2)    [西] 谷潔  2017103020       1019    248005
# 45863   82.0  16.0   452(-6)  [西] 牧浦充徳  2018106391       1124    523005
# 45864    8.5   3.0   514(+6)  [西] 千田輝彦  2018102585       1171    170800
# 45865   30.4   9.0   468(+4)  [西] 音無秀孝  2017106012       1128    975030
# 45866   41.4  13.0    512(0)   [西] 村山明  2017104137       1154    966007
# 45867    6.0   4.0  492(-10)  [西] 須貝尚介  2019105446       1163    271008
# 45868   24.1   8.0  496(+10)  [西] 杉山佳明  2018101075       1142      5803
# 45869    5.0   2.0   496(-8)   [西] 緒方努  2018101796       1126    572800
# 45870   37.9  12.0   502(-6)  [西] 大根田裕  2018101007       1125    646030
# 45871   92.3  15.0    458(0)  [東] 蛯名利弘  2016100297       1181    514009
# 45872   37.5  11.0  484(-10)  [西] 畑端省吾  2018102270       1037    208033
# 45873    5.4   3.0    510(0)  [西] 千田輝彦  2018106458       1171    523005
# 45874   54.7  14.0   494(+4)   [西] 石橋守  2015101320       1199    768006
# 45875    6.8   5.0   468(-2)  [西] 茶木太樹  2017105602        732    226800
# 45876   14.6   7.0  492(-12)  [西] 田中克典  2017104972       1034    180800
# 45877    4.9   1.0  502(+10)  [西] 高橋康之  2018104591       1174    168006
# 45878   35.3  10.0   444(+4)  [西] 野中賢二  2017102389       1116    170800
# 45879   12.6   6.0    514(0)  [西] 上村洋行  2019104496       1180    808800
# 45880   22.4   7.0    482(0)  [西] 畑端省吾  2021109157       1037    356002
# 45881   35.3   8.0   420(-6)  [西] 斉藤崇史  2021105706       1180    358803
# 45882   48.3   9.0  474(+14)  [西] 吉村圭司  2021100248       1193    897009
# 45883   16.4   6.0   448(+4)  [西] 庄野靖志  2021100782       1062    440006
# 45884    6.5   4.0   446(+4)  [西] 鈴木孝志  2021106615       1126    788800
# 45885    4.9   3.0   476(-2)  [西] 安田翔伍  2021110033       1171      3060
# 45886    3.5   1.0   518(+2)  [西] 西園正都  2021100899        732    646030
# 45887   58.1  10.0   458(-2)  [西] 中竹和也  2021110063       1199    944030
# 45888    4.1   2.0  474(+14)   [西] 武英智  2021105771       1116    486800
# 45889    7.1   5.0    438(0)  [西] 梅田智之  2021102315       1174    539002
# 45890   62.8  11.0   394(+2)  [西] 松永幹夫  2020105644       1037    866006
# 45891    9.8   5.0   496(+8)  [西] 森田直行  2020101781       1018    665033
# 45892   13.9   6.0  458(+12)  [西] 藤原英昭  2020106455       1187    523005
# 45893   37.2  10.0   440(-2)  [西] 大根田裕  2019106647       1200    142006
# 45894    6.2   4.0   442(+6)    [西] 宮徹  2020103324       1199    716800
# 45895    4.8   2.0    470(0)  [西] 矢作芳人  2020102716       1163    808800
# 45896  125.6  12.0   470(-4)  [西] 安田隆行  2018106584       1195    721008
# 45897    3.5   1.0   442(-2)   [西] 武英智  2019102542       1208     17803
# 45898   15.2   8.0    468(0)  [西] 笹田和秀  2020103754       1116    651031
# 45899   23.1   9.0   458(+6)  [西] 松永幹夫  2020100400       1193    180800
# 45900    5.0   3.0   486(-6)  [西] 松永幹夫  2020103663        732    226800
# 45901   14.1   7.0  420(-16)  [西] 坂口智康  2017104623       1125     37803
#
#        trainer_id ﾀｲﾑ指数           通過    上り  調教ﾀｲﾑ  厩舎ｺﾒﾝﾄ  備考  \
# 45802        1110    **      4-3-3-5  39.3    NaN     NaN NaN
# 45803        1101    **  12-12-14-15  42.6    NaN     NaN NaN
# 45804        1091    **      7-7-6-5  38.2    NaN     NaN NaN
# 45805        1046    **   10-10-11-8  38.0    NaN     NaN NaN
# 45806        1061    **  13-13-14-16  42.2    NaN     NaN NaN
# 45807        1078    **      2-2-2-2  38.1    NaN     NaN NaN
# 45808        1188    **      9-9-8-8  37.9    NaN     NaN NaN
# 45809        1164    **   11-11-8-11  38.3    NaN     NaN NaN
# 45810        1061    **      7-7-8-8  38.3    NaN     NaN NaN
# 45811        1113    **  15-15-14-14  39.4    NaN     NaN NaN
# 45812        1173    **      3-3-3-2  38.5    NaN     NaN NaN
# 45813        1128    **  15-15-12-13  40.4    NaN     NaN NaN
# 45814        1176    **      4-5-3-2  37.9    NaN     NaN NaN
# 45815        1120    **      6-6-6-5  37.9    NaN     NaN NaN
# 45816        1092    **  13-13-12-12  37.9    NaN     NaN NaN
# 45817        1113    **        17-15  33.6    NaN     NaN NaN
# 45818        1140    **        14-13  34.4    NaN     NaN NaN
# 45819        1082    **          2-2  35.4    NaN     NaN NaN
# 45820         429    **          1-1  35.5    NaN     NaN NaN
# 45821        1039    **          3-3  34.9    NaN     NaN NaN
# 45822        1098    **          7-7  35.0    NaN     NaN NaN
# 45823        1078    **        14-15  34.4    NaN     NaN NaN
# 45824        1186    **        18-18  34.9    NaN     NaN NaN
# 45825        1173    **          3-3  35.1    NaN     NaN NaN
# 45826        1039    **          9-7  34.4    NaN     NaN NaN
# 45827        1073    **          3-3  34.7    NaN     NaN NaN
# 45828        1046    **        14-15  34.4    NaN     NaN NaN
# 45829        1120    **          7-7  34.7    NaN     NaN NaN
# 45830        1083    **         9-13  34.4    NaN     NaN NaN
# 45831        1160    **         9-11  34.1    NaN     NaN NaN
# 45832        1172    **        13-11  34.8    NaN     NaN NaN
# 45833        1176    **          3-6  34.5    NaN     NaN NaN
# 45834        1135    **          9-7  34.0    NaN     NaN NaN
# 45835        1196    **         10-8  35.5    NaN     NaN NaN
# 45836        1178    **         10-8  36.0    NaN     NaN NaN
# 45837         429    **          2-2  35.5    NaN     NaN NaN
# 45838        1002    **          5-4  35.3    NaN     NaN NaN
# 45839        1123    **          3-3  35.5    NaN     NaN NaN
# 45840        1120    **          7-7  35.4    NaN     NaN NaN
# 45841        1170    **         9-12  35.7    NaN     NaN NaN
# 45842        1062    **         7-11  36.1    NaN     NaN NaN
# 45843        1065    **          5-6  35.5    NaN     NaN NaN
# 45844        1121    **          1-1  35.5    NaN     NaN NaN
# 45845        1065    **          3-4  36.4    NaN     NaN NaN
# 45846        1069    **         10-8  35.5    NaN     NaN NaN
# 45847        1181    **        10-13  36.5    NaN     NaN NaN
# 45848        1084    **         7-10  35.1    NaN     NaN NaN
# 45849        1107    **        11-13  34.9    NaN     NaN NaN
# 45850        1058    **          7-7  35.6    NaN     NaN NaN
# 45851        1078    **        14-10  34.5    NaN     NaN NaN
# 45852        1099    **          7-7  35.2    NaN     NaN NaN
# 45853        1186    **          4-4  35.3    NaN     NaN NaN
# 45854        1065    **         10-4  34.7    NaN     NaN NaN
# 45855        1087    **        11-13  34.9    NaN     NaN NaN
# 45856        1003    **        16-16  34.2    NaN     NaN NaN
# 45857        1002    **          2-2  35.9    NaN     NaN NaN
# 45858        1028    **          2-2  36.2    NaN     NaN NaN
# 45859        1068    **        16-16  34.1    NaN     NaN NaN
# 45860        1077    **          4-7  36.8    NaN     NaN NaN
# 45861        1078    **          1-1  35.0    NaN     NaN NaN
# 45862         431    **        11-10  34.6    NaN     NaN NaN
# 45863        1113    **          6-4  34.8    NaN     NaN NaN
# 45864        1120    **        14-13  34.1    NaN     NaN NaN
# 45865        1002    **  12-11-11-10  38.0    NaN     NaN NaN
# 45866        1107    **  12-11-11-10  37.3    NaN     NaN NaN
# 45867        1105    **      4-4-4-3  38.7    NaN     NaN NaN
# 45868        1178    **      9-8-9-6  37.9    NaN     NaN NaN
# 45869        1193    **      9-8-6-3  37.4    NaN     NaN NaN
# 45870        1032    **      7-7-6-6  38.3    NaN     NaN NaN
# 45871        1131    **  15-15-15-13  36.8    NaN     NaN NaN
# 45872        1188    **     4-4-6-13  41.8    NaN     NaN NaN
# 45873        1120    **      2-2-2-2  37.9    NaN     NaN NaN
# 45874        1140    **   11-11-9-10  38.8    NaN     NaN NaN
# 45875        1181    **   14-14-11-6  37.2    NaN     NaN NaN
# 45876        1180    **      1-1-1-1  38.0    NaN     NaN NaN
# 45877        1135    **   8-10-11-15  41.1    NaN     NaN NaN
# 45878        1098    **      2-2-2-3  39.4    NaN     NaN NaN
# 45879        1168    **      4-4-4-6  39.5    NaN     NaN NaN
# 45880        1188    **        10-10  34.9    NaN     NaN NaN
# 45881        1151    **          8-8  34.9    NaN     NaN NaN
# 45882        1130    **          6-5  35.1    NaN     NaN NaN
# 45883        1087    **          1-1  35.8    NaN     NaN NaN
# 45884        1111    **          3-3  35.2    NaN     NaN NaN
# 45885        1164    **          4-5  35.2    NaN     NaN NaN
# 45886        1028    **          4-3  35.1    NaN     NaN NaN
# 45887        1039    **          2-2  35.8    NaN     NaN NaN
# 45888        1161    **          6-5  34.6    NaN     NaN NaN
# 45889        1084    **          8-8  34.4    NaN     NaN NaN
# 45890        1092    **    11-11-8-7  38.8    NaN     NaN NaN
# 45891        1142    **      3-3-4-5  39.9    NaN     NaN NaN
# 45892        1055    **      1-1-1-3  39.3    NaN     NaN NaN
# 45893        1032    **      2-2-4-7  40.0    NaN     NaN NaN
# 45894        1018    **  10-10-10-12  39.6    NaN     NaN NaN
# 45895        1075    **      7-7-6-4  37.8    NaN     NaN NaN
# 45896         438    **    5-5-10-11  38.9    NaN     NaN NaN
# 45897        1161    **      4-4-2-1  36.5    NaN     NaN NaN
# 45898        1104    **      7-7-9-6  38.4    NaN     NaN NaN
# 45899        1092    **  11-11-12-10  36.9    NaN     NaN NaN
# 45900        1092    **      5-5-2-2  37.3    NaN     NaN NaN
# 45901        1170    **      7-7-6-7  38.2    NaN     NaN NaN
#
#                           馬主  賞金(万円)  rank   time  nobori  umaban  \
# 45802                   新谷幸義     NaN    12  107.4    39.3       2
# 45803       ウエスト．フォレスト．ステイブル     NaN    16  111.8    42.6       3
# 45804                   永田和彦     NaN     6  106.6    38.2       4
# 45805             キャピタル・システム     NaN     7  106.8    38.0       5
# 45806                   大塚亮一     NaN    15  111.4    42.2       6
# 45807                 ノースヒルズ   550.0     1  106.0    38.1       7
# 45808                   瀬山孝一    83.0     4  106.5    37.9       8
# 45809               シルクレーシング     NaN    10  106.9    38.3       9
# 45810                   三木正浩     NaN    11  106.9    38.3      10
# 45811                 ライフハウス     NaN    13  108.7    39.4      11
# 45812                   北幸商事    55.0     5  106.5    38.5      12
# 45813               社台レースホース     NaN    14  109.4    40.4      13
# 45814                  下河辺隆行   220.0     2  106.0    37.9      14
# 45815                   松本好雄   140.0     3  106.2    37.9      15
# 45816                   松本好雄     NaN     8  106.9    37.9      16
# 45817                   前原敏行    80.0     5   68.6    33.6       1
# 45818                   松本好雄     NaN    15   69.0    34.4       2
# 45819                   水上行雄     NaN    12   68.9    35.4       3
# 45820                  小林竜太郎     NaN    11   68.9    35.5       4
# 45821                   森田和豊     NaN     9   68.8    34.9       5
# 45822           ニッシンホールディングス     NaN    16   69.1    35.0       6
# 45823  ＨｉｍＲｏｃｋＲａｃｉｎｇホールディングス     NaN    14   69.0    34.4       7
# 45824                     辻助     NaN    18   70.0    34.9       8
# 45825                   西山茂行     NaN    13   68.9    35.1       9
# 45826                  名古屋競馬     NaN     8   68.7    34.4      10
# 45827               グリーンファーム   120.0     4   68.5    34.7      11
# 45828                  長谷川光司     NaN    10   68.9    34.4      12
# 45829                   中村政夫     NaN     6   68.7    34.7      13
# 45830                  中内田克二     NaN     7   68.7    34.4      14
# 45831                 キーファーズ   200.0     3   68.4    34.1      15
# 45832                   西山茂行     NaN    17   69.2    34.8      16
# 45833                   岡田牧雄   320.0     2   68.3    34.5      17
# 45834                   東豊物産   800.0     1   68.2    34.0      18
# 45835                 大樹ファーム     NaN     8   58.8    35.5       1
# 45836             キャピタル・システム     NaN    12   59.3    36.0       2
# 45837        ヒダカ・ブリーダーズ・ユニオン   200.0     3   58.1    35.5       3
# 45838              キャロットファーム   320.0     2   58.1    35.3       4
# 45839                   永田和彦   120.0     4   58.2    35.5       5
# 45840     ノルマンディーサラブレッドレーシング     NaN     6   58.5    35.4       6
# 45841                   廣崎智子     NaN     9   58.9    35.7       7
# 45842          ゴールドアップ・カンパニー     NaN    11   59.2    36.1       8
# 45843              ＹＧＧホースクラブ    80.0     5   58.3    35.5       9
# 45844                   松本好雄   800.0     1   57.8    35.5      10
# 45845                   伊藤和夫     NaN    10   59.1    36.4      11
# 45846                    森和久     NaN     7   58.8    35.5      12
# 45847             吉澤ホールディングス     NaN    13   59.8    36.5      13
# 45848                 廣崎利洋ＨＤ     NaN     9   68.8    35.1       1
# 45849                   増田雄一     NaN    11   68.9    34.9       2
# 45850                   吉田照哉     NaN    15   69.3    35.6       3
# 45851                 ノースヒルズ     NaN     8   68.6    34.5       4
# 45852                   松本好雄     NaN    13   68.9    35.2       5
# 45853                   永山勝敏     NaN    10   68.8    35.3       6
# 45854                    中西功   155.0     5   68.5    34.7       7
# 45855                   幅田昌伸     NaN    12   68.9    34.9       8
# 45856                  崎川美枝子     NaN     7   68.6    34.2       9
# 45857                   江馬由将     NaN    14   69.2    35.9      10
# 45858                    ウイン     NaN    16   69.5    36.2      11
# 45859                 ゴドルフィン   395.3     3   68.4    34.1      12
# 45860          了徳寺健二ホールディングス     NaN    17   70.3    36.8      13
# 45861                    吉岡實   630.6     2   68.2    35.0      14
# 45862                   山元哲二     NaN     6   68.5    34.6      15
# 45863                   松本好雄   230.0     4   68.4    34.8      16
# 45864              ロードホースクラブ  1587.1     1   68.2    34.1      17
# 45865                   小田切光     NaN     8  105.7    38.0       1
# 45866                   小林祥晃     NaN     6  105.1    37.3       2
# 45867                   安原浩司     NaN    10  106.0    38.7       3
# 45868             キャピタル・システム     NaN     7  105.5    37.9       4
# 45869                ハイパワー商事  1871.5     1  104.8    37.4       5
# 45870                    中辻明     NaN     9  105.8    38.3       6
# 45871                    柏木務   184.0     5  105.0    36.8       7
# 45872                   中西桂子     NaN    15  109.2    41.8       8
# 45873                   松本好雄   749.0     2  104.9    37.9       9
# 45874                    薪浦亨     NaN    11  106.4    38.8      10
# 45875              サンデーレーシング   280.0     4  104.9    37.2      11
# 45876             東京ホースレーシング   464.5     3  104.9    38.0      12
# 45877                   増田雄一     NaN    14  108.9    41.1      13
# 45878              ロードホースクラブ     NaN    12  106.4    39.4      14
# 45879                Ｇ１レーシング     NaN    13  106.8    39.5      15
# 45880                   竹園正繼     NaN    10   69.4    34.9       1
# 45881               ホシノレーシング   310.0     5   69.0    34.9       2
# 45882                   西山茂行     NaN     7   69.1    35.1       3
# 45883                   山田貢一     NaN     8   69.1    35.8       4
# 45884                 ノースヒルズ   785.2     3   68.9    35.2       5
# 45885                 ゴドルフィン     NaN     6   69.1    35.2       6
# 45886                    中辻明   470.0     4   68.9    35.1       7
# 45887                    加藤誠     NaN     9   69.3    35.8       8
# 45888              キャロットファーム  1210.4     2   68.6    34.6       9
# 45889                   廣崎利洋  3136.4     1   68.6    34.4      10
# 45890                   寺田寿男     NaN     8  162.9    38.8       1
# 45891                   高橋正雄     NaN    10  163.6    39.9       2
# 45892                   松本好雄     NaN     7  162.7    39.3       3
# 45893                   服部新平     NaN    11  163.7    40.0       4
# 45894             ビッグレッドファーム     NaN    12  164.1    39.6       5
# 45895                Ｇ１レーシング   200.0     3  161.6    37.8       6
# 45896                   久保博文     NaN     9  163.5    38.9       7
# 45897                    吉川潤   800.0     1  160.0    36.5       8
# 45898                   猪又晶介     NaN     6  162.6    38.4       9
# 45899             東京ホースレーシング   120.0     4  161.8    36.9      10
# 45900              サンデーレーシング   320.0     2  160.9    37.3      11
# 45901                 廣崎利洋ＨＤ    80.0     5  162.0    38.2      12
#
#        tansho_odds  popularity  impost  wakuban  sex  age  weight  \
# 45802        199.8          16    53.0        1    0    3     500
# 45803        128.5          15    56.0        2    0    3     488
# 45804         85.8          14    53.0        2    0    3     452
# 45805         16.5           7    56.0        3    0    3     500
# 45806         19.7           8    56.0        3    0    3     512
# 45807         12.9           6    53.0        4    0    3     486
# 45808          7.9           4    56.0        4    0    3     482
# 45809         28.2           9    56.0        5    0    3     522
# 45810          3.5           1    56.0        5    0    3     532
# 45811         30.2          11    56.0        6    0    3     538
# 45812         44.9          12    56.0        6    0    3     480
# 45813         47.5          13    56.0        7    0    3     542
# 45814          6.8           3    56.0        7    0    3     454
# 45815          4.4           2    55.0        8    0    3     496
# 45816         29.7          10    56.0        8    0    3     452
# 45817         24.4          11    56.0        1    0    3     488
# 45818         32.4          12    56.0        1    1    5     428
# 45819         62.3          14    56.0        2    1    5     458
# 45820         18.3           9    54.0        2    1    3     456
# 45821         45.8          13    55.0        3    1    5     472
# 45822         19.9          10    56.0        3    0    3     456
# 45823        128.8          17    55.0        4    0    3     452
# 45824        161.2          18    54.0        4    1    3     408
# 45825          8.0           4    53.0        5    0    3     482
# 45826          9.4           6    58.0        5    0    4     456
# 45827          6.9           2    58.0        6    0    4     438
# 45828        112.6          16    56.0        6    1    5     486
# 45829         65.9          15    56.0        7    1    6     460
# 45830          7.9           3    51.0        7    1    3     474
# 45831         12.8           7    56.0        7    0    3     458
# 45832         16.3           8    56.0        8    0    3     464
# 45833          8.0           5    56.0        8    0    3     538
# 45834          4.2           1    51.0        8    1    3     436
# 45835          4.3           2    58.0        1    0    4     506
# 45836         37.7          13    54.0        2    1    3     436
# 45837         17.9           7    54.0        3    1    3     490
# 45838          2.6           1    56.0        4    0    3     468
# 45839         28.4          11    56.0        4    1    4     452
# 45840         26.8          10    58.0        5    0    4     498
# 45841         15.6           6    56.0        5    1    5     452
# 45842         19.8           9    54.0        6    1    3     512
# 45843         31.6          12    54.0        6    0    5     478
# 45844          8.3           3    53.0        7    0    3     446
# 45845         10.3           4    55.0        7    0    4     494
# 45846         13.9           5    53.0        8    1    4     472
# 45847         19.6           8    51.0        8    1    3     454
# 45848         46.6          10    58.0        1    2    5     460
# 45849         60.5          13    58.0        1    0    5     484
# 45850         47.3          11    58.0        2    0    5     502
# 45851         12.8           6    56.0        2    1    4     462
# 45852         66.8          15    56.0        3    1    5     472
# 45853          2.2           1    56.0        3    0    3     506
# 45854        120.5          17    58.0        4    0    6     470
# 45855          5.7           2    56.0        4    0    3     470
# 45856         22.3           8    56.0        5    1    5     460
# 45857         10.2           4    58.0        5    0    4     470
# 45858         11.5           5    58.0        6    0    4     484
# 45859         59.7          12    56.0        6    1    4     458
# 45860         61.9          14    56.0        7    1    4     474
# 45861         43.9           9    58.0        7    0    5     496
# 45862         16.2           7    56.0        8    1    6     462
# 45863         82.0          16    58.0        8    0    5     452
# 45864          8.5           3    58.0        8    0    5     514
# 45865         30.4           9    58.0        1    2    6     468
# 45866         41.4          13    58.0        2    0    6     512
# 45867          6.0           4    58.0        2    2    4     492
# 45868         24.1           8    58.0        3    0    5     496
# 45869          5.0           2    58.0        3    0    5     496
# 45870         37.9          12    58.0        4    0    5     502
# 45871         92.3          15    58.0        4    2    7     458
# 45872         37.5          11    56.0        5    1    5     484
# 45873          5.4           3    58.0        5    0    5     510
# 45874         54.7          14    58.0        6    0    8     494
# 45875          6.8           5    58.0        6    0    6     468
# 45876         14.6           7    58.0        7    2    6     492
# 45877          4.9           1    58.0        7    0    5     502
# 45878         35.3          10    58.0        8    0    6     444
# 45879         12.6           6    58.0        8    0    4     514
# 45880         22.4           7    55.0        1    1    2     482
# 45881         35.3           8    55.0        2    1    2     420
# 45882         48.3           9    55.0        3    1    2     474
# 45883         16.4           6    55.0        4    1    2     448
# 45884          6.5           4    55.0        5    1    2     446
# 45885          4.9           3    55.0        6    0    2     476
# 45886          3.5           1    55.0        7    0    2     518
# 45887         58.1          10    55.0        7    0    2     458
# 45888          4.1           2    55.0        8    0    2     474
# 45889          7.1           5    55.0        8    0    2     438
# 45890         62.8          11    53.0        1    1    3     394
# 45891          9.8           5    55.0        2    0    3     496
# 45892         13.9           6    52.0        3    0    3     458
# 45893         37.2          10    55.0        4    0    4     440
# 45894          6.2           4    52.0        5    1    3     442
# 45895          4.8           2    55.0        5    0    3     470
# 45896        125.6          12    55.0        6    0    5     470
# 45897          3.5           1    53.0        6    1    4     442
# 45898         15.2           8    55.0        7    0    3     468
# 45899         23.1           9    50.0        7    1    3     458
# 45900          5.0           3    55.0        8    2    3     486
# 45901         14.1           7    58.0        8    2    6     420
#
#        weight_diff  n_horses  corner_1  corner_2  corner_3  corner_4  \
# 45802            0        16         4         3         3         5
# 45803            0        16        12        12        14        15
# 45804            4        16         7         7         6         5
# 45805            4        16        10        10        11         8
# 45806            2        16        13        13        14        16
# 45807            2        16         2         2         2         2
# 45808            0        16         9         9         8         8
# 45809           -2        16        11        11         8        11
# 45810            0        16         7         7         8         8
# 45811            6        16        15        15        14        14
# 45812           -4        16         3         3         3         2
# 45813            0        16        15        15        12        13
# 45814           12        16         4         5         3         2
# 45815            0        16         6         6         6         5
# 45816            2        16        13        13        12        12
# 45817            4        18        17        15      <NA>      <NA>
# 45818            4        18        14        13      <NA>      <NA>
# 45819            2        18         2         2      <NA>      <NA>
# 45820           -4        18         1         1      <NA>      <NA>
# 45821           -2        18         3         3      <NA>      <NA>
# 45822           -4        18         7         7      <NA>      <NA>
# 45823            2        18        14        15      <NA>      <NA>
# 45824           -2        18        18        18      <NA>      <NA>
# 45825          -10        18         3         3      <NA>      <NA>
# 45826           -2        18         9         7      <NA>      <NA>
# 45827            0        18         3         3      <NA>      <NA>
# 45828           -2        18        14        15      <NA>      <NA>
# 45829           -6        18         7         7      <NA>      <NA>
# 45830           10        18         9        13      <NA>      <NA>
# 45831           -4        18         9        11      <NA>      <NA>
# 45832            0        18        13        11      <NA>      <NA>
# 45833            2        18         3         6      <NA>      <NA>
# 45834            2        18         9         7      <NA>      <NA>
# 45835            0        13        10         8      <NA>      <NA>
# 45836            3        13        10         8      <NA>      <NA>
# 45837            4        13         2         2      <NA>      <NA>
# 45838           -4        13         5         4      <NA>      <NA>
# 45839            4        13         3         3      <NA>      <NA>
# 45840           14        13         7         7      <NA>      <NA>
# 45841           -2        13         9        12      <NA>      <NA>
# 45842          -14        13         7        11      <NA>      <NA>
# 45843           -6        13         5         6      <NA>      <NA>
# 45844            0        13         1         1      <NA>      <NA>
# 45845            6        13         3         4      <NA>      <NA>
# 45846           -2        13        10         8      <NA>      <NA>
# 45847            4        13        10        13      <NA>      <NA>
# 45848            6        17         7        10      <NA>      <NA>
# 45849            4        17        11        13      <NA>      <NA>
# 45850           -8        17         7         7      <NA>      <NA>
# 45851           20        17        14        10      <NA>      <NA>
# 45852           -2        17         7         7      <NA>      <NA>
# 45853            4        17         4         4      <NA>      <NA>
# 45854            2        17        10         4      <NA>      <NA>
# 45855            6        17        11        13      <NA>      <NA>
# 45856           -4        17        16        16      <NA>      <NA>
# 45857           -6        17         2         2      <NA>      <NA>
# 45858            8        17         2         2      <NA>      <NA>
# 45859            4        17        16        16      <NA>      <NA>
# 45860            4        17         4         7      <NA>      <NA>
# 45861           -8        17         1         1      <NA>      <NA>
# 45862           -2        17        11        10      <NA>      <NA>
# 45863           -6        17         6         4      <NA>      <NA>
# 45864            6        17        14        13      <NA>      <NA>
# 45865            4        15        12        11        11        10
# 45866            0        15        12        11        11        10
# 45867          -10        15         4         4         4         3
# 45868           10        15         9         8         9         6
# 45869           -8        15         9         8         6         3
# 45870           -6        15         7         7         6         6
# 45871            0        15        15        15        15        13
# 45872          -10        15         4         4         6        13
# 45873            0        15         2         2         2         2
# 45874            4        15        11        11         9        10
# 45875           -2        15        14        14        11         6
# 45876          -12        15         1         1         1         1
# 45877           10        15         8        10        11        15
# 45878            4        15         2         2         2         3
# 45879            0        15         4         4         4         6
# 45880            0        10        10        10      <NA>      <NA>
# 45881           -6        10         8         8      <NA>      <NA>
# 45882           14        10         6         5      <NA>      <NA>
# 45883            4        10         1         1      <NA>      <NA>
# 45884            4        10         3         3      <NA>      <NA>
# 45885           -2        10         4         5      <NA>      <NA>
# 45886            2        10         4         3      <NA>      <NA>
# 45887           -2        10         2         2      <NA>      <NA>
# 45888           14        10         6         5      <NA>      <NA>
# 45889            0        10         8         8      <NA>      <NA>
# 45890            2        12        11        11         8         7
# 45891            8        12         3         3         4         5
# 45892           12        12         1         1         1         3
# 45893           -2        12         2         2         4         7
# 45894            6        12        10        10        10        12
# 45895            0        12         7         7         6         4
# 45896           -4        12         5         5        10        11
# 45897           -2        12         4         4         2         1
# 45898            0        12         7         7         9         6
# 45899            6        12        11        11        12        10
# 45900           -6        12         5         5         2         2
# 45901          -16        12         7         7         6         7
#
#        rank_per_horse  corner_1_per_horse  corner_2_per_horse  \
# 45802        0.750000                0.25              0.1875
# 45803        1.000000                0.75                0.75
# 45804        0.375000              0.4375              0.4375
# 45805        0.437500               0.625               0.625
# 45806        0.937500              0.8125              0.8125
# 45807        0.062500               0.125               0.125
# 45808        0.250000              0.5625              0.5625
# 45809        0.625000              0.6875              0.6875
# 45810        0.687500              0.4375              0.4375
# 45811        0.812500              0.9375              0.9375
# 45812        0.312500              0.1875              0.1875
# 45813        0.875000              0.9375              0.9375
# 45814        0.125000                0.25              0.3125
# 45815        0.187500               0.375               0.375
# 45816        0.500000              0.8125              0.8125
# 45817        0.277778            0.944444            0.833333
# 45818        0.833333            0.777778            0.722222
# 45819        0.666667            0.111111            0.111111
# 45820        0.611111            0.055556            0.055556
# 45821        0.500000            0.166667            0.166667
# 45822        0.888889            0.388889            0.388889
# 45823        0.777778            0.777778            0.833333
# 45824        1.000000                 1.0                 1.0
# 45825        0.722222            0.166667            0.166667
# 45826        0.444444                 0.5            0.388889
# 45827        0.222222            0.166667            0.166667
# 45828        0.555556            0.777778            0.833333
# 45829        0.333333            0.388889            0.388889
# 45830        0.388889                 0.5            0.722222
# 45831        0.166667                 0.5            0.611111
# 45832        0.944444            0.722222            0.611111
# 45833        0.111111            0.166667            0.333333
# 45834        0.055556                 0.5            0.388889
# 45835        0.615385            0.769231            0.615385
# 45836        0.923077            0.769231            0.615385
# 45837        0.230769            0.153846            0.153846
# 45838        0.153846            0.384615            0.307692
# 45839        0.307692            0.230769            0.230769
# 45840        0.461538            0.538462            0.538462
# 45841        0.692308            0.692308            0.923077
# 45842        0.846154            0.538462            0.846154
# 45843        0.384615            0.384615            0.461538
# 45844        0.076923            0.076923            0.076923
# 45845        0.769231            0.230769            0.307692
# 45846        0.538462            0.769231            0.615385
# 45847        1.000000            0.769231                 1.0
# 45848        0.529412            0.411765            0.588235
# 45849        0.647059            0.647059            0.764706
# 45850        0.882353            0.411765            0.411765
# 45851        0.470588            0.823529            0.588235
# 45852        0.764706            0.411765            0.411765
# 45853        0.588235            0.235294            0.235294
# 45854        0.294118            0.588235            0.235294
# 45855        0.705882            0.647059            0.764706
# 45856        0.411765            0.941176            0.941176
# 45857        0.823529            0.117647            0.117647
# 45858        0.941176            0.117647            0.117647
# 45859        0.176471            0.941176            0.941176
# 45860        1.000000            0.235294            0.411765
# 45861        0.117647            0.058824            0.058824
# 45862        0.352941            0.647059            0.588235
# 45863        0.235294            0.352941            0.235294
# 45864        0.058824            0.823529            0.764706
# 45865        0.533333                 0.8            0.733333
# 45866        0.400000                 0.8            0.733333
# 45867        0.666667            0.266667            0.266667
# 45868        0.466667                 0.6            0.533333
# 45869        0.066667                 0.6            0.533333
# 45870        0.600000            0.466667            0.466667
# 45871        0.333333                 1.0                 1.0
# 45872        1.000000            0.266667            0.266667
# 45873        0.133333            0.133333            0.133333
# 45874        0.733333            0.733333            0.733333
# 45875        0.266667            0.933333            0.933333
# 45876        0.200000            0.066667            0.066667
# 45877        0.933333            0.533333            0.666667
# 45878        0.800000            0.133333            0.133333
# 45879        0.866667            0.266667            0.266667
# 45880        1.000000                 1.0                 1.0
# 45881        0.500000                 0.8                 0.8
# 45882        0.700000                 0.6                 0.5
# 45883        0.800000                 0.1                 0.1
# 45884        0.300000                 0.3                 0.3
# 45885        0.600000                 0.4                 0.5
# 45886        0.400000                 0.4                 0.3
# 45887        0.900000                 0.2                 0.2
# 45888        0.200000                 0.6                 0.5
# 45889        0.100000                 0.8                 0.8
# 45890        0.666667            0.916667            0.916667
# 45891        0.833333                0.25                0.25
# 45892        0.583333            0.083333            0.083333
# 45893        0.916667            0.166667            0.166667
# 45894        1.000000            0.833333            0.833333
# 45895        0.250000            0.583333            0.583333
# 45896        0.750000            0.416667            0.416667
# 45897        0.083333            0.333333            0.333333
# 45898        0.500000            0.583333            0.583333
# 45899        0.333333            0.916667            0.916667
# 45900        0.166667            0.416667            0.416667
# 45901        0.416667            0.583333            0.583333
#
#        corner_3_per_horse  corner_4_per_horse  mean_age  median_age  \
# 45802              0.1875              0.3125  3.000000         3.0
# 45803               0.875              0.9375  3.000000         3.0
# 45804               0.375              0.3125  3.000000         3.0
# 45805              0.6875                 0.5  3.000000         3.0
# 45806               0.875                 1.0  3.000000         3.0
# 45807               0.125               0.125  3.000000         3.0
# 45808                 0.5                 0.5  3.000000         3.0
# 45809                 0.5              0.6875  3.000000         3.0
# 45810                 0.5                 0.5  3.000000         3.0
# 45811               0.875               0.875  3.000000         3.0
# 45812              0.1875               0.125  3.000000         3.0
# 45813                0.75              0.8125  3.000000         3.0
# 45814              0.1875               0.125  3.000000         3.0
# 45815               0.375              0.3125  3.000000         3.0
# 45816                0.75                0.75  3.000000         3.0
# 45817                <NA>                <NA>  3.722222         3.0
# 45818                <NA>                <NA>  3.722222         3.0
# 45819                <NA>                <NA>  3.722222         3.0
# 45820                <NA>                <NA>  3.722222         3.0
# 45821                <NA>                <NA>  3.722222         3.0
# 45822                <NA>                <NA>  3.722222         3.0
# 45823                <NA>                <NA>  3.722222         3.0
# 45824                <NA>                <NA>  3.722222         3.0
# 45825                <NA>                <NA>  3.722222         3.0
# 45826                <NA>                <NA>  3.722222         3.0
# 45827                <NA>                <NA>  3.722222         3.0
# 45828                <NA>                <NA>  3.722222         3.0
# 45829                <NA>                <NA>  3.722222         3.0
# 45830                <NA>                <NA>  3.722222         3.0
# 45831                <NA>                <NA>  3.722222         3.0
# 45832                <NA>                <NA>  3.722222         3.0
# 45833                <NA>                <NA>  3.722222         3.0
# 45834                <NA>                <NA>  3.722222         3.0
# 45835                <NA>                <NA>  3.692308         4.0
# 45836                <NA>                <NA>  3.692308         4.0
# 45837                <NA>                <NA>  3.692308         4.0
# 45838                <NA>                <NA>  3.692308         4.0
# 45839                <NA>                <NA>  3.692308         4.0
# 45840                <NA>                <NA>  3.692308         4.0
# 45841                <NA>                <NA>  3.692308         4.0
# 45842                <NA>                <NA>  3.692308         4.0
# 45843                <NA>                <NA>  3.692308         4.0
# 45844                <NA>                <NA>  3.692308         4.0
# 45845                <NA>                <NA>  3.692308         4.0
# 45846                <NA>                <NA>  3.692308         4.0
# 45847                <NA>                <NA>  3.692308         4.0
# 45848                <NA>                <NA>  4.588235         5.0
# 45849                <NA>                <NA>  4.588235         5.0
# 45850                <NA>                <NA>  4.588235         5.0
# 45851                <NA>                <NA>  4.588235         5.0
# 45852                <NA>                <NA>  4.588235         5.0
# 45853                <NA>                <NA>  4.588235         5.0
# 45854                <NA>                <NA>  4.588235         5.0
# 45855                <NA>                <NA>  4.588235         5.0
# 45856                <NA>                <NA>  4.588235         5.0
# 45857                <NA>                <NA>  4.588235         5.0
# 45858                <NA>                <NA>  4.588235         5.0
# 45859                <NA>                <NA>  4.588235         5.0
# 45860                <NA>                <NA>  4.588235         5.0
# 45861                <NA>                <NA>  4.588235         5.0
# 45862                <NA>                <NA>  4.588235         5.0
# 45863                <NA>                <NA>  4.588235         5.0
# 45864                <NA>                <NA>  4.588235         5.0
# 45865            0.733333            0.666667  5.533333         5.0
# 45866            0.733333            0.666667  5.533333         5.0
# 45867            0.266667                 0.2  5.533333         5.0
# 45868                 0.6                 0.4  5.533333         5.0
# 45869                 0.4                 0.2  5.533333         5.0
# 45870                 0.4                 0.4  5.533333         5.0
# 45871                 1.0            0.866667  5.533333         5.0
# 45872                 0.4            0.866667  5.533333         5.0
# 45873            0.133333            0.133333  5.533333         5.0
# 45874                 0.6            0.666667  5.533333         5.0
# 45875            0.733333                 0.4  5.533333         5.0
# 45876            0.066667            0.066667  5.533333         5.0
# 45877            0.733333                 1.0  5.533333         5.0
# 45878            0.133333                 0.2  5.533333         5.0
# 45879            0.266667                 0.4  5.533333         5.0
# 45880                <NA>                <NA>  2.000000         2.0
# 45881                <NA>                <NA>  2.000000         2.0
# 45882                <NA>                <NA>  2.000000         2.0
# 45883                <NA>                <NA>  2.000000         2.0
# 45884                <NA>                <NA>  2.000000         2.0
# 45885                <NA>                <NA>  2.000000         2.0
# 45886                <NA>                <NA>  2.000000         2.0
# 45887                <NA>                <NA>  2.000000         2.0
# 45888                <NA>                <NA>  2.000000         2.0
# 45889                <NA>                <NA>  2.000000         2.0
# 45890            0.666667            0.583333  3.583333         3.0
# 45891            0.333333            0.416667  3.583333         3.0
# 45892            0.083333                0.25  3.583333         3.0
# 45893            0.333333            0.583333  3.583333         3.0
# 45894            0.833333                 1.0  3.583333         3.0
# 45895                 0.5            0.333333  3.583333         3.0
# 45896            0.833333            0.916667  3.583333         3.0
# 45897            0.166667            0.083333  3.583333         3.0
# 45898                0.75                 0.5  3.583333         3.0
# 45899                 1.0            0.833333  3.583333         3.0
# 45900            0.166667            0.166667  3.583333         3.0
# 45901                 0.5            0.583333  3.583333         3.0
#
#        mean_age_kirisute
# 45802                  3
# 45803                  3
# 45804                  3
# 45805                  3
# 45806                  3
# 45807                  3
# 45808                  3
# 45809                  3
# 45810                  3
# 45811                  3
# 45812                  3
# 45813                  3
# 45814                  3
# 45815                  3
# 45816                  3
# 45817                  3
# 45818                  3
# 45819                  3
# 45820                  3
# 45821                  3
# 45822                  3
# 45823                  3
# 45824                  3
# 45825                  3
# 45826                  3
# 45827                  3
# 45828                  3
# 45829                  3
# 45830                  3
# 45831                  3
# 45832                  3
# 45833                  3
# 45834                  3
# 45835                  3
# 45836                  3
# 45837                  3
# 45838                  3
# 45839                  3
# 45840                  3
# 45841                  3
# 45842                  3
# 45843                  3
# 45844                  3
# 45845                  3
# 45846                  3
# 45847                  3
# 45848                  4
# 45849                  4
# 45850                  4
# 45851                  4
# 45852                  4
# 45853                  4
# 45854                  4
# 45855                  4
# 45856                  4
# 45857                  4
# 45858                  4
# 45859                  4
# 45860                  4
# 45861                  4
# 45862                  4
# 45863                  4
# 45864                  4
# 45865                  5
# 45866                  5
# 45867                  5
# 45868                  5
# 45869                  5
# 45870                  5
# 45871                  5
# 45872                  5
# 45873                  5
# 45874                  5
# 45875                  5
# 45876                  5
# 45877                  5
# 45878                  5
# 45879                  5
# 45880                  2
# 45881                  2
# 45882                  2
# 45883                  2
# 45884                  2
# 45885                  2
# 45886                  2
# 45887                  2
# 45888                  2
# 45889                  2
# 45890                  3
# 45891                  3
# 45892                  3
# 45893                  3
# 45894                  3
# 45895                  3
# 45896                  3
# 45897                  3
# 45898                  3
# 45899                  3
# 45900                  3
# 45901                  3

# %%
#futre_修正、馬場状態
# レース結果テーブルの前処理
results_preprocessed = preprocessing.process_results()
# 馬の過去成績テーブルの加工
horse_results_preprocessed = preprocessing.process_horse_results()
# レース情報テーブルの前処理
race_info_preprocessed = preprocessing.process_race_info()

# %%
from pathlib import Path

from tqdm.notebook import tqdm
import json
import re
from pathlib import Path

import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from tqdm.notebook import tqdm
from webdriver_manager.chrome import ChromeDriverManager
from io import StringIO 

DATA_DIR = Path("..", "data")
POPULATION_DIR = DATA_DIR / "00_population"
INPUT_DIR = DATA_DIR / "01_preprocessed"
OUTPUT_DIR = DATA_DIR / "02_features"
OUTPUT_DIR.mkdir(exist_ok=True, parents=True)

population_dir = POPULATION_DIR
poplation_filename = "population.csv"
input_dir = INPUT_DIR
results_filename = "results.csv"
race_info_filename = "race_info.csv"
horse_results_filename = "horse_results.csv"
jockey_leading_filename = "jockey_leading.csv"
trainer_leading_filename = "trainer_leading.csv"
peds_filename = "peds.csv"
sire_leading_filename = "sire_leading.csv"
output_dir = OUTPUT_DIR
output_filename = "features.csv"

population = pd.read_csv(population_dir / poplation_filename, sep="\t")
results = pd.read_csv(input_dir / results_filename, sep="\t")
race_info = pd.read_csv(input_dir / race_info_filename, sep="\t")
horse_results = pd.read_csv(input_dir / horse_results_filename, sep="\t")
jockey_leading = pd.read_csv(input_dir / jockey_leading_filename, sep="\t")
trainer_leading = pd.read_csv(
    input_dir / trainer_leading_filename, sep="\t"
)
peds = pd.read_csv(input_dir / peds_filename, sep="\t")
sire_leading = pd.read_csv(input_dir / sire_leading_filename, sep="\t")
output_dir = output_dir
output_filename = output_filename
agg_horse_per_group_cols_dfs = {}

# %%
df = (
    results[["race_id", "horse_id","mean_age_kirisute"]]
    .merge(race_info[["race_id", "race_type", "season","race_class"]], on="race_id")
)

# %%
df
# Out:
#             race_id    horse_id  mean_age_kirisute  race_type  season  \
# 0      202301010101  2021100648                  2          1       2
# 1      202301010101  2021100159                  2          1       2
# 2      202301010101  2021100265                  2          1       2
# 3      202301010101  2021105553                  2          1       2
# 4      202301010101  2021101429                  2          1       2
# ...             ...         ...                ...        ...     ...
# 45897  202310030812  2019102542                  3          1       3
# 45898  202310030812  2020103754                  3          1       3
# 45899  202310030812  2020100400                  3          1       3
# 45900  202310030812  2020103663                  3          1       3
# 45901  202310030812  2017104623                  3          1       3
#
#        race_class
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 45897           2
# 45898           2
# 45899           2
# 45900           2
# 45901           2
#
# [45902 rows x 6 columns]

# %%
df
# Out:
#             race_id    horse_id  mean_age_kirisute  race_type  season  \
# 0      202301010101  2021100648                  2          1       2
# 1      202301010101  2021100159                  2          1       2
# 2      202301010101  2021100265                  2          1       2
# 3      202301010101  2021105553                  2          1       2
# 4      202301010101  2021101429                  2          1       2
# ...             ...         ...                ...        ...     ...
# 45897  202310030812  2019102542                  3          1       3
# 45898  202310030812  2020103754                  3          1       3
# 45899  202310030812  2020100400                  3          1       3
# 45900  202310030812  2020103663                  3          1       3
# 45901  202310030812  2017104623                  3          1       3
#
#        race_class        date  age_season
# 0               1  2023-07-22          22
# 1               1  2023-07-22          22
# 2               1  2023-07-22          22
# 3               1  2023-07-22          22
# 4               1  2023-07-22          22
# ...           ...         ...         ...
# 45897           2  2023-09-03          33
# 45898           2  2023-09-03          33
# 45899           2  2023-09-03          33
# 45900           2  2023-09-03          33
# 45901           2  2023-09-03          33
#
# [45902 rows x 8 columns]

# %%
"""

dfに新たな列、race_gradeを作成して欲しい
作成ルールは以下の通りである
'age_season'の条件に引っかかった場合、それを優先すること
次点で"race_class"の条件にかかっても、'age_season'がある方を優先して変換すること


"race_class"列が0は55

"race_class"列が1は60

"race_class"列が2は70
2歳それ以外は68（20<='age_season'<30かつ、2<="race_class"列<5の行）
2歳G2,G3,OPは73（20<='age_season'<30かつ、5<="race_class"列<8の行）

"race_class"列が3は79
2歳G1は79（20<='age_season'<30かつ、8<="race_class"の行）
3歳春OPは80（30<='age_season'<33かつ、4<="race_class"列<6の行）
3歳春G2.G3は81（30<='age_season'<33かつ、6<="race_class"列<8の行）

"race_class"列が4は85
3歳春G1は86（30<='age_season'<33かつ、8<="race_class"の行）
3歳秋G2,G3は86（33<='age_season'<40かつ、5<="race_class"列<8の行）

"race_class"列が5は89
3歳秋G1は91（33<='age_season'<40かつ、8<="race_class"の行）

"race_class"列が6は92

"race_class"列が7は94

"race_class"列が8は98




これらを小さく（1/10 - 5）した列

G1 8	100
G2 7	95
G3 6	92
オープン5	89
1600万4	86
２勝クラス3	80
１勝クラス2	70
未勝利1	60
新馬0	55


クラス	芝	ダート
未勝利	６５（-１５）	６０（-２０）
500万下
Ｇ１を除く２歳ＯＰ	７５（-５）	７２（-８）
1000万下
２歳Ｇ１
Ｇ１を除く３歳春ＯＰ	８３（３）	８３（３）
1600万下
３歳春Ｇ１
３歳秋重賞	８８（８）	９０（１０）
ＯＰ（ただしダート重賞を除く）
３歳秋Ｇ１	９３（１３）	９５（１５）
ダート重賞（３歳を除く）	－	１００（２０）
古馬Ｇ１	９８（１８）	１０５（２５）
"""
# "mean_age_kirisute"と"season"を文字列に変換して結合し、int型に変換して新しい列 "age_season" を作成
df['age_season'] = (df['mean_age_kirisute'].astype(str) + df['season'].astype(str)).astype(int)

# race_gradeの作成
def calculate_race_grade(row):
    age_season = row['age_season']
    race_class = row['race_class']

    # 'age_season' に基づく条件を優先してチェック
    if 20 <= age_season < 30:
        if 2 <= race_class < 5:
            return 68
        elif 5 <= race_class < 8:
            return 73
        elif 8 <= race_class:
            return 78
    elif 30 <= age_season < 33:
        if 4 <= race_class < 6:
            return 80
        elif 6 <= race_class < 8:
            return 82
        elif 8 <= race_class:
            return 85
    elif 33 <= age_season < 40:
        if 5 <= race_class < 8:
            return 86
        elif 8 <= race_class:
            return 92
    
    if race_class == 0:
        return 55
    elif race_class == 1:
        return 60
    elif race_class == 2:
        return 70
    elif race_class == 3:
        return 79
    elif race_class == 4:
        return 85
    elif race_class == 5:
        return 89
    elif race_class == 6:
        return 91
    elif race_class == 7:
        return 94
    elif race_class == 8:
        return 98
    else:
        return np.nan  

# race_grade列を作成
df['race_grade'] = df.apply(calculate_race_grade, axis=1)

#race_grade_scaledの作成
df['race_grade_scaled'] = df['race_grade'] / 10 - 5

race_info[['age_season', 'race_grade', 'race_grade_scaled']] = df[['age_season', 'race_grade', 'race_grade_scaled']]

# %%
race_info
# Out:
#            race_id        date  race_type  around  course_len  weather  \
# 0     202306010101  2023-01-05          0       0        1200        1
# 1     202306010102  2023-01-05          0       0        1800        1
# 2     202306010103  2023-01-05          0       0        1800        1
# 3     202306010104  2023-01-05          0       0        1800        1
# 4     202306010105  2023-01-05          1       0        1600        1
# ...            ...         ...        ...     ...         ...      ...
# 3324  202309050908  2023-12-28          0       0        1400        1
# 3325  202309050909  2023-12-28          0       0        1800        1
# 3326  202309050910  2023-12-28          1       0        2000        1
# 3327  202309050911  2023-12-28          0       0        1800        1
# 3328  202309050912  2023-12-28          1       0        1200        1
#
#       ground_state  race_class  place  season  place_season  \
# 0                0           1      6       4            64
# 1                0           1      6       4            64
# 2                0           0      6       4            64
# 3                0           2      6       4            64
# 4                0           1      6       4            64
# ...            ...         ...    ...     ...           ...
# 3324             0           2      9       4            94
# 3325             0           3      9       4            94
# 3326             0           3      9       4            94
# 3327             0           5      9       4            94
# 3328             0           4      9       4            94
#
#       place_season_type  kaisai_race  kaisai_race_type  day  day_type  \
# 0                   640            1                10    1        10
# 1                   640            2                20    1        10
# 2                   640            3                30    1        10
# 3                   640            4                40    1        10
# 4                   641            5                51    1        11
# ...                 ...          ...               ...  ...       ...
# 3324                940            8                80    9        90
# 3325                940            9                90    9        90
# 3326                941           10               101    9        91
# 3327                940           11               110    9        90
# 3328                941           12               121    9        91
#
#       kaisai_count  kaisai_count_type  place_season_day_type  day_condition  \
# 0                1                 10                  64010              1
# 1                1                 10                  64010              1
# 2                1                 10                  64010              1
# 3                1                 10                  64010              1
# 4                1                 11                  64011              1
# ...            ...                ...                    ...            ...
# 3324             5                 50                  94090              2
# 3325             5                 50                  94090              2
# 3326             5                 51                  94091              2
# 3327             5                 50                  94090              2
# 3328             5                 51                  94091              2
#
#       place_season_condition_type  place_season_condition_type_categori  \
# 0                            6410                                    -3
# 1                            6410                                    -3
# 2                            6410                                    -3
# 3                            6410                                    -3
# 4                            6411                                     3
# ...                           ...                                   ...
# 3324                         9420                                    -2
# 3325                         9420                                    -2
# 3326                         9421                                     2
# 3327                         9420                                    -2
# 3328                         9421                                     2
#
#       place_course_category  place_course_tough  goal_range  curve  \
# 0                        -1                  -1         NaN    NaN
# 1                        -1                  -1         NaN    NaN
# 2                        -1                  -1         NaN    NaN
# 3                        -1                  -1         NaN    NaN
# 4                       602                   1       310.0    5.0
# ...                     ...                 ...         ...    ...
# 3324                     -1                  -1         NaN    NaN
# 3325                     -1                  -1         NaN    NaN
# 3326                    901                   1       356.5    5.0
# 3327                     -1                  -1         NaN    NaN
# 3328                    901                   1       356.5    5.0
#
#       goal_slope  place_season_type_course_len  lap_type  race_day_count  \
# 0            NaN                       6401200        -1               1
# 1            NaN                       6401800        -1               2
# 2            NaN                       6401800        -1               3
# 3            NaN                       6401800        -1               4
# 4            3.0                       6411600         4               5
# ...          ...                           ...       ...             ...
# 3324         NaN                       9401400        -1               8
# 3325         NaN                       9401800        -1               9
# 3326         3.0                       9412000        -1              10
# 3327         NaN                       9401800        -1              11
# 3328         3.0                       9411200         3              12
#
#       race_date_day_count  goal_range_100  age_season  race_grade  \
# 0                73803501             NaN          22          60
# 1                73803502             NaN          22          60
# 2                73803503             NaN          22          60
# 3                73803504             NaN          22          60
# 4                73803505           3.100          22          60
# ...                   ...             ...         ...         ...
# 3324             73839208             NaN          22          60
# 3325             73839209             NaN          22          60
# 3326             73839210           3.565          22          60
# 3327             73839211             NaN          22          60
# 3328             73839212           3.565          22          60
#
#       race_grade_scaled
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 3324                1.0
# 3325                1.0
# 3326                1.0
# 3327                1.0
# 3328                1.0
#
# [3329 rows x 35 columns]

# %%
horse_results
# Out:
#           horse_id  rank_per_horse        date  rank  prize  rank_diff  \
# 0       2011106610        1.000000  2023-12-10   8.0    0.0        3.9
# 1       2011106610        1.000000  2023-11-11   8.0    0.0        1.6
# 2       2011106610        1.000000  2023-10-29   9.0    0.0        2.3
# 3       2011106610        1.000000  2023-10-07  11.0    0.0        1.8
# 4       2011106610        0.900000  2023-09-18   9.0    0.0        2.7
# ...            ...             ...         ...   ...    ...        ...
# 130271  2021102427        0.571429  2024-04-06   8.0    0.0        2.3
# 130272  2021102427        0.928571  2023-12-28  13.0    0.0        2.5
# 130273  2021103807        1.000000  2024-02-24  11.0    0.0        3.4
# 130274  2021103807        0.785714  2024-01-13  11.0    0.0        2.1
# 130275  2021103807        1.000000  2023-12-28  14.0    0.0        3.1
#
#         umaban  wakuban  weather  race_type  course_len  ground_state  \
# 0            1        1        1          1        2400             0
# 1            7        7        2          1        1600             0
# 2            2        2        1          1        1800             0
# 3           10        8        1          1        1600             0
# 4            3        3        1          1        1600             0
# ...        ...      ...      ...        ...         ...           ...
# 130271      12        7        2          0        1800             2
# 130272       7        5        1          1        1800             0
# 130273       1        1        2          0        1800             2
# 130274       2        2        1          0        1800             0
# 130275      13        8        1          1        1800             0
#
#         race_class  n_horses   time  time_courselen  nobori  win  rentai  \
# 0                3       8.0  151.9        0.063292    36.4    0       0
# 1                3       8.0   96.1        0.060062    34.7    0       0
# 2                5       9.0  110.2        0.061222    34.9    0       0
# 3                5      11.0   95.8        0.059875    34.4    0       0
# 4                3      10.0   94.5        0.059062    35.0    0       0
# ...            ...       ...    ...             ...     ...  ...     ...
# 130271           1      14.0  117.5        0.065278    39.6    0       0
# 130272           0      14.0  110.0        0.061111    36.0    0       0
# 130273           1      11.0  118.9        0.066056    43.0    0       0
# 130274           1      14.0  117.9        0.065500    40.8    0       0
# 130275           0      14.0  110.6        0.061444    37.0    0       0
#
#         show  place  corner_1_per_horse  corner_2_per_horse  \
# 0          0      9            1.000000            1.000000
# 1          0      5            0.750000            0.750000
# 2          0      8            0.777778            0.777778
# 3          0      8            0.909091            0.909091
# 4          0      9            0.900000            0.900000
# ...      ...    ...                 ...                 ...
# 130271     0      6            0.571429            0.642857
# 130272     0      9            0.642857            0.642857
# 130273     0      9            0.090909            0.090909
# 130274     0      8            1.000000            0.857143
# 130275     0      9            0.214286            0.214286
#
#         corner_3_per_horse  corner_4_per_horse  race_position  pace_diff  \
# 0                 1.000000            0.875000              4       -4.5
# 1                      NaN                 NaN              4       -1.0
# 2                      NaN                 NaN              4       -3.1
# 3                      NaN                 NaN              4       -2.5
# 4                      NaN                 NaN              4       -1.5
# ...                    ...                 ...            ...        ...
# 130271            0.428571            0.500000              3       -1.1
# 130272                 NaN                 NaN              3       -1.9
# 130273            0.090909            0.181818              1        2.9
# 130274            0.642857            0.571429              3        4.0
# 130275                 NaN                 NaN              2       -1.9
#
#         pace_category  corner_1  corner_2  corner_3  corner_4  pace_1  pace_2
# 0                 4.0         8       8.0       8.0       7.0    38.2    33.7
# 1                 3.0         6       6.0       NaN       NaN    35.9    34.9
# 2                 4.0         7       7.0       NaN       NaN    36.5    33.4
# 3                 4.0        10      10.0       NaN       NaN    36.0    33.5
# 4                 4.0         9       9.0       NaN       NaN    34.7    33.2
# ...               ...       ...       ...       ...       ...     ...     ...
# 130271            4.0         8       9.0       6.0       7.0    39.1    38.0
# 130272            4.0         9       9.0       NaN       NaN    36.0    34.1
# 130273            1.0         1       1.0       1.0       2.0    36.8    39.7
# 130274            1.0        14      12.0       9.0       8.0    35.8    39.8
# 130275            4.0         3       3.0       NaN       NaN    36.0    34.1
#
# [130276 rows x 34 columns]

# %%
"""
ホースリザルトは、シーズンデータ入れなくてもいいかも
年齢は入ってるからそれで


dfに新たな列、race_gradeを作成して欲しい
作成ルールは以下の通りである
'age_season'の条件に引っかかった場合、それを優先すること
次点で"race_class"の条件にかかっても、'age_season'がある方を優先して変換すること


"race_class"列が0は55

"race_class"列が1は60

"race_class"列が2は70
2歳それ以外は68（20<='age_season'<30かつ、2<="race_class"列<5の行）
2歳G2,G3,OPは73（20<='age_season'<30かつ、5<="race_class"列<8の行）

"race_class"列が3は79
2歳G1は79（20<='age_season'<30かつ、8<="race_class"の行）
3歳春OPは80（30<='age_season'<33かつ、4<="race_class"列<6の行）
3歳春G2.G3は81（30<='age_season'<33かつ、6<="race_class"列<8の行）

"race_class"列が4は85
3歳春G1は86（30<='age_season'<33かつ、8<="race_class"の行）
3歳秋G2,G3は86（33<='age_season'<40かつ、5<="race_class"列<8の行）

"race_class"列が5は89
3歳秋G1は91（33<='age_season'<40かつ、8<="race_class"の行）

"race_class"列が6は92

"race_class"列が7は94

"race_class"列が8は98




これらを小さく（1/10 - 5）した列

G1 8	100
G2 7	95
G3 6	92
オープン5	89
1600万4	86
２勝クラス3	80
１勝クラス2	70
未勝利1	60
新馬0	55


クラス	芝	ダート
未勝利	６５（-１５）	６０（-２０）
500万下
Ｇ１を除く２歳ＯＰ	７５（-５）	７２（-８）
1000万下
２歳Ｇ１
Ｇ１を除く３歳春ＯＰ	８３（３）	８３（３）
1600万下
３歳春Ｇ１
３歳秋重賞	８８（８）	９０（１０）
ＯＰ（ただしダート重賞を除く）
３歳秋Ｇ１	９３（１３）	９５（１５）
ダート重賞（３歳を除く）	－	１００（２０）
古馬Ｇ１	９８（１８）	１０５（２５）
"""
# race_gradeの作成
def calculate_race_grade(row):
    race_class = row['race_class']
    
    if race_class == 0:
        return 55
    elif race_class == 1:
        return 60
    elif race_class == 2:
        return 70
    elif race_class == 3:
        return 79
    elif race_class == 4:
        return 85
    elif race_class == 5:
        return 89
    elif race_class == 6:
        return 91
    elif race_class == 7:
        return 94
    elif race_class == 8:
        return 98
    else:
        return np.nan  

# race_grade列を作成
df['race_grade'] = df.apply(calculate_race_grade, axis=1
#race_grade_scaledの作成
df['race_grade_scaled'] = df['race_grade'] / 10 - 5
horse_results[['race_grade', 'race_grade_scaled']] = df[['race_grade', 'race_grade_scaled']]

# %%
horse_results
# Out:
#           horse_id  rank_per_horse        date  rank  prize  rank_diff  \
# 0       2011106610        1.000000  2023-12-10   8.0    0.0        3.9
# 1       2011106610        1.000000  2023-11-11   8.0    0.0        1.6
# 2       2011106610        1.000000  2023-10-29   9.0    0.0        2.3
# 3       2011106610        1.000000  2023-10-07  11.0    0.0        1.8
# 4       2011106610        0.900000  2023-09-18   9.0    0.0        2.7
# ...            ...             ...         ...   ...    ...        ...
# 130271  2021102427        0.571429  2024-04-06   8.0    0.0        2.3
# 130272  2021102427        0.928571  2023-12-28  13.0    0.0        2.5
# 130273  2021103807        1.000000  2024-02-24  11.0    0.0        3.4
# 130274  2021103807        0.785714  2024-01-13  11.0    0.0        2.1
# 130275  2021103807        1.000000  2023-12-28  14.0    0.0        3.1
#
#         umaban  wakuban  weather  race_type  course_len  ground_state  \
# 0            1        1        1          1        2400             0
# 1            7        7        2          1        1600             0
# 2            2        2        1          1        1800             0
# 3           10        8        1          1        1600             0
# 4            3        3        1          1        1600             0
# ...        ...      ...      ...        ...         ...           ...
# 130271      12        7        2          0        1800             2
# 130272       7        5        1          1        1800             0
# 130273       1        1        2          0        1800             2
# 130274       2        2        1          0        1800             0
# 130275      13        8        1          1        1800             0
#
#         race_class  n_horses   time  time_courselen  nobori  win  rentai  \
# 0                3       8.0  151.9        0.063292    36.4    0       0
# 1                3       8.0   96.1        0.060062    34.7    0       0
# 2                5       9.0  110.2        0.061222    34.9    0       0
# 3                5      11.0   95.8        0.059875    34.4    0       0
# 4                3      10.0   94.5        0.059062    35.0    0       0
# ...            ...       ...    ...             ...     ...  ...     ...
# 130271           1      14.0  117.5        0.065278    39.6    0       0
# 130272           0      14.0  110.0        0.061111    36.0    0       0
# 130273           1      11.0  118.9        0.066056    43.0    0       0
# 130274           1      14.0  117.9        0.065500    40.8    0       0
# 130275           0      14.0  110.6        0.061444    37.0    0       0
#
#         show  place  corner_1_per_horse  corner_2_per_horse  \
# 0          0      9            1.000000            1.000000
# 1          0      5            0.750000            0.750000
# 2          0      8            0.777778            0.777778
# 3          0      8            0.909091            0.909091
# 4          0      9            0.900000            0.900000
# ...      ...    ...                 ...                 ...
# 130271     0      6            0.571429            0.642857
# 130272     0      9            0.642857            0.642857
# 130273     0      9            0.090909            0.090909
# 130274     0      8            1.000000            0.857143
# 130275     0      9            0.214286            0.214286
#
#         corner_3_per_horse  corner_4_per_horse  race_position  pace_diff  \
# 0                 1.000000            0.875000              4       -4.5
# 1                      NaN                 NaN              4       -1.0
# 2                      NaN                 NaN              4       -3.1
# 3                      NaN                 NaN              4       -2.5
# 4                      NaN                 NaN              4       -1.5
# ...                    ...                 ...            ...        ...
# 130271            0.428571            0.500000              3       -1.1
# 130272                 NaN                 NaN              3       -1.9
# 130273            0.090909            0.181818              1        2.9
# 130274            0.642857            0.571429              3        4.0
# 130275                 NaN                 NaN              2       -1.9
#
#         pace_category  corner_1  corner_2  corner_3  corner_4  pace_1  pace_2  \
# 0                 4.0         8       8.0       8.0       7.0    38.2    33.7
# 1                 3.0         6       6.0       NaN       NaN    35.9    34.9
# 2                 4.0         7       7.0       NaN       NaN    36.5    33.4
# 3                 4.0        10      10.0       NaN       NaN    36.0    33.5
# 4                 4.0         9       9.0       NaN       NaN    34.7    33.2
# ...               ...       ...       ...       ...       ...     ...     ...
# 130271            4.0         8       9.0       6.0       7.0    39.1    38.0
# 130272            4.0         9       9.0       NaN       NaN    36.0    34.1
# 130273            1.0         1       1.0       1.0       2.0    36.8    39.7
# 130274            1.0        14      12.0       9.0       8.0    35.8    39.8
# 130275            4.0         3       3.0       NaN       NaN    36.0    34.1
#
#         race_grade  race_grade_scaled
# 0             60.0                1.0
# 1             60.0                1.0
# 2             60.0                1.0
# 3             60.0                1.0
# 4             60.0                1.0
# ...            ...                ...
# 130271         NaN                NaN
# 130272         NaN                NaN
# 130273         NaN                NaN
# 130274         NaN                NaN
# 130275         NaN                NaN
#
# [130276 rows x 36 columns]
