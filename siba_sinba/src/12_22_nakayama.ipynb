# %%
import create_population
import create_population3
import preprocessing
from feature_engineering import FeatureCreator
from feature_engineering_prediction import PredictionFeatureCreator

import prediction
from train_lgbm_rank_niti_cross import Trainer_lightgbm_rank_niti_cv
from train_lgbm_rank_kaiki_cross import Trainer_lightgbm_rank_kaiki_cv
from train_lgbm_time_cross import Trainer_lightgbm_time_cv

from evaluation_lgbm_rank_niti_cross import Evaluator_lightgbm_rank_niti_cross

import pandas as pd


import condition_prediction


from train_lightgbm_rank_niti import Trainer_lightgbm_rank_niti
from train_lightgbm_time import Trainer_lightgbm_time
from train_lightgbm_rank_kaiki import Trainer_lightgbm_rank_kaiki

from evaluation_lightgbm_rank_niti import Evaluator_lightgbm_rank_niti
from evaluation_lightgbm_time_kaiki import Evaluator_lightgbm_time_kaiki
from evaluation_lightgbm_rank_kaiki import Evaluator_lightgbm_rank_kaiki
from evaluation_pop import Evaluator_pop

# %load_ext autoreload

# %%
# %autoreload

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
population = create_population.create(from_="2016-01-01", to_="2024-11-30")

# %%
# 当日出走馬の過去成績テーブルの前処理_そのままで使えない未加工のデータを加工する
horse_results_preprocessed = preprocessing.process_horse_results(
    input_filename="horse_results_prediction.csv",
    output_filename="horse_results_prediction.csv"
)
horse_results_preprocessed

# 当日出走馬の血統テーブルの前処理
peds_preprocessed = preprocessing.process_peds(
    input_filename="peds_prediction.csv",
    output_filename="peds_prediction.csv"
)
peds_preprocessed

pfc = PredictionFeatureCreator()
# 過去成績集計は事前に行うことができる
pfc.create_baselog()
pfc.agg_horse_n_races()
pfc.agg_horse_n_races_relative()
pfc.agg_horse_n_races_df

# レース結果テーブルの前処理
results_preprocessed = condition_prediction.process_results()
# レース情報テーブルの前処理
race_info_preprocessed = condition_prediction.process_race_info()
create_race_grade_preprocessed = condition_prediction.create_race_grade()
# Out:
# agg_horse_n_races_relative:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ###　12/22 第6回目レース

# %%
# 特徴量の更新
features = pfc.create_features(
    race_id="202406050806",  # 予測するレースidを指定
    date_content_a = "2024年12月22日", #"%Y年%m月%d日"形式で該当レース当日の日付を入れてください    
    skip_agg_horse=True  # 事前に集計した場合はスキップできる
)
# Out:
# fetching shutuba page html...
# fetching shutuba page html...comp
# 0    2023
# Name: date_year, dtype: int32
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# pace_category_win_1:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_2:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_3:   0%|          | 0/4 [00:00<?, ?it/s]
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_11()...comp
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_12()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_goal_slope_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_stamina_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_13()...comp
# agg_raceclass_rankdiff_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_14()...comp
# speed_index:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_15()...comp
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_ground_state_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_grade:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_type:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place_len:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_race_place:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_horse_per_weather:   0%|          | 0/4 [00:00<?, ?it/s]
# running agg_jockey()...
# running agg_trainer()...
# running agg_sire()...
# running agg_bms()...
# running agg_bms()...comp
# merging all features...
# merging all features...comp

# %%
pfc.results
# Out:
#          race_id    horse_id  jockey_id  trainer_id  umaban  wakuban  \
# 0   202406050806  2022101259       5386        1201       1        1
# 1   202406050806  2022106213       1122        1097       2        2
# 2   202406050806  2022102452       1158        1079       3        2
# 3   202406050806  2022100628       1170        1192       4        3
# 4   202406050806  2022107182       5366        1070       5        3
# 5   202406050806  2022101030       1109        1174       6        4
# 6   202406050806  2022102480       1143        1125       7        4
# 7   202406050806  2022104092       5626        1103       8        5
# 8   202406050806  2022103018       1117        1027       9        5
# 9   202406050806  2022103206       1150         399      10        6
# 10  202406050806  2022105537        733        1125      11        6
# 11  202406050806  2022100462       1179        1195      12        7
# 12  202406050806  2022103871       1162        1035      13        7
# 13  202406050806  2022104911       5339        1115      14        8
# 14  202406050806  2022103577       1192        1094      15        8
#
#     tansho_odds  popularity  impost  sex  age  weight  weight_diff  n_horses  \
# 0          13.9           5    55.0    1    2     NaN          NaN        15
# 1           6.1           3    55.0    1    2     NaN          NaN        15
# 2          72.7          14    56.0    0    2     NaN          NaN        15
# 3          21.7           8    55.0    1    2     NaN          NaN        15
# 4           2.9           1    56.0    0    2     NaN          NaN        15
# 5          78.5          15    55.0    1    2     NaN          NaN        15
# 6          61.7          13    56.0    0    2     NaN          NaN        15
# 7           8.2           4    56.0    0    2     NaN          NaN        15
# 8          57.1          12    55.0    1    2     NaN          NaN        15
# 9          19.1           7    55.0    1    2     NaN          NaN        15
# 10         44.1          10    56.0    0    2     NaN          NaN        15
# 11         18.9           6    56.0    0    2     NaN          NaN        15
# 12         51.3          11    56.0    0    2     NaN          NaN        15
# 13          3.7           2    55.0    1    2     NaN          NaN        15
# 14         27.6           9    55.0    0    2     NaN          NaN        15
#
#     mean_age  median_age  mean_age_kirisute
# 0        2.0         2.0                  2
# 1        2.0         2.0                  2
# 2        2.0         2.0                  2
# 3        2.0         2.0                  2
# 4        2.0         2.0                  2
# 5        2.0         2.0                  2
# 6        2.0         2.0                  2
# 7        2.0         2.0                  2
# 8        2.0         2.0                  2
# 9        2.0         2.0                  2
# 10       2.0         2.0                  2
# 11       2.0         2.0                  2
# 12       2.0         2.0                  2
# 13       2.0         2.0                  2
# 14       2.0         2.0                  2

# %%
pfc.race_info
# Out:
#         race_id  race_type  around  course_len  weather  ground_state  \
# 0  202406050806          1       0        1600        1             0
#
#    race_class  place  race_day_count  race_date_day_count  season  \
# 0           0      6               6             73875106       4
#
#    place_season  place_season_type  kaisai_race  kaisai_race_type  day  \
# 0            64                641            6                61    8
#
#    day_type  kaisai_count  kaisai_count_type  place_season_day_type  \
# 0        81             5                 51                  64081
#
#    day_condition  place_season_condition_type  \
# 0              2                         6421
#
#    place_season_condition_type_categori  place_course_category  \
# 0                                     2                    602
#
#    place_course_tough  goal_range  curve  goal_slope  goal_range_100  \
# 0                   1         310      5           3             3.1
#
#    place_season_type_course_len  lap_type  age_season  race_grade  \
# 0                       6411600         4          24          55
#
#    race_grade_scaled
# 0                0.5

# %%
# オッズ除外モデルでの予測、time、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_time_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)
# Out:
# [LightGBM] [Fatal] The number of features in data (195) is not the same as it was in training data (3066).
# You can set ``predict_disable_shape_check=true`` to discard this error, but please be aware what you are doing.
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# Cell In[9], line 2
#       1 # オッズ除外モデルでの予測、time、ホールドアウト
# ----> 2 prediction.predict(
#       3     features,
#       4     model_filename="model_lightgbm_time_odds_removed.pkl",
#       5     config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
#       6 )
#
# File ~/Documents/kenkyu_4/siba_sinba/src/prediction.py:61, in predict(features, model_dir, model_filename, config_filepath)
#      20     model = pickle.load(f)
#      21 prediction_df = features[[
#      22     "race_id",
#      23     "umaban",
#    (...)
#      59
#      60                          ]].copy()
# ---> 61 prediction_df["pred"] = model.predict(features[feature_cols])
#      62 return prediction_df.sort_values("pred", ascending=False)
#
# File ~/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/lightgbm/basic.py:4748, in Booster.predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features, **kwargs)
#    4746     else:
#    4747         num_iteration = -1
# -> 4748 return predictor.predict(
#    4749     data=data,
#    4750     start_iteration=start_iteration,
#    4751     num_iteration=num_iteration,
#    4752     raw_score=raw_score,
#    4753     pred_leaf=pred_leaf,
#    4754     pred_contrib=pred_contrib,
#    4755     data_has_header=data_has_header,
#    4756     validate_features=validate_features,
#    4757 )
#
# File ~/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/lightgbm/basic.py:1185, in _InnerPredictor.predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features)
#    1178     preds, nrow = self.__pred_for_csc(
#    1179         csc=data,
#    1180         start_iteration=start_iteration,
#    1181         num_iteration=num_iteration,
#    1182         predict_type=predict_type,
#    1183     )
#    1184 elif isinstance(data, np.ndarray):
# -> 1185     preds, nrow = self.__pred_for_np2d(
#    1186         mat=data,
#    1187         start_iteration=start_iteration,
#    1188         num_iteration=num_iteration,
#    1189         predict_type=predict_type,
#    1190     )
#    1191 elif _is_pyarrow_table(data):
#    1192     preds, nrow = self.__pred_for_pyarrow_table(
#    1193         table=data,
#    1194         start_iteration=start_iteration,
#    1195         num_iteration=num_iteration,
#    1196         predict_type=predict_type,
#    1197     )
#
# File ~/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/lightgbm/basic.py:1344, in _InnerPredictor.__pred_for_np2d(self, mat, start_iteration, num_iteration, predict_type)
#    1342     return preds, nrow
#    1343 else:
# -> 1344     return self.__inner_predict_np2d(
#    1345         mat=mat,
#    1346         start_iteration=start_iteration,
#    1347         num_iteration=num_iteration,
#    1348         predict_type=predict_type,
#    1349         preds=None,
#    1350     )
#
# File ~/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/lightgbm/basic.py:1290, in _InnerPredictor.__inner_predict_np2d(self, mat, start_iteration, num_iteration, predict_type, preds)
#    1288     raise ValueError("Wrong length of pre-allocated predict array")
#    1289 out_num_preds = ctypes.c_int64(0)
# -> 1290 _safe_call(
#    1291     _LIB.LGBM_BoosterPredictForMat(
#    1292         self._handle,
#    1293         ptr_data,
#    1294         ctypes.c_int(type_ptr_data),
#    1295         ctypes.c_int32(mat.shape[0]),
#    1296         ctypes.c_int32(mat.shape[1]),
#    1297         ctypes.c_int(_C_API_IS_ROW_MAJOR),
#    1298         ctypes.c_int(predict_type),
#    1299         ctypes.c_int(start_iteration),
#    1300         ctypes.c_int(num_iteration),
#    1301         _c_str(self.pred_parameter),
#    1302         ctypes.byref(out_num_preds),
#    1303         preds.ctypes.data_as(ctypes.POINTER(ctypes.c_double)),
#    1304     )
#    1305 )
#    1306 if n_preds != out_num_preds.value:
#    1307     raise ValueError("Wrong length for predict results")
#
# File ~/miniconda3/envs/kenkyu4/lib/python3.11/site-packages/lightgbm/basic.py:296, in _safe_call(ret)
#     288 """Check the return value from C API call.
#     289
#     290 Parameters
#    (...)
#     293     The return value from C API calls.
#     294 """
#     295 if ret != 0:
# --> 296     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
#
# LightGBMError: The number of features in data (195) is not the same as it was in training data (3066).
# You can set ``predict_disable_shape_check=true`` to discard this error, but please be aware what you are doing.

# %%
# オッズ除外モデルでの予測、time、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_time_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)
# Out:
#          race_id  umaban  tansho_odds  popularity  mean_fukusho_rate_wakuban  \
# 14  202406050806      13         51.3          11                   0.190132
# 10  202406050806       7         61.7          13                   0.229974
# 11  202406050806      15         27.6           9                   0.191038
# 9   202406050806      11         44.1          10                   0.182266
# 1   202406050806       6         78.5          15                   0.229974
# 2   202406050806       3         72.7          14                   0.245810
# 4   202406050806       9         57.1          12                   0.203026
# 7   202406050806      12         18.9           6                   0.190132
# 3   202406050806       8          8.2           4                   0.203026
# 5   202406050806       1         13.9           5                   0.240175
# 13  202406050806       4         21.7           8                   0.212824
# 8   202406050806      10         19.1           7                   0.182266
# 12  202406050806      14          3.7           2                   0.191038
# 6   202406050806       5          2.9           1                   0.212824
# 0   202406050806       2          6.1           3                   0.245810
#
#     mean_fukusho_rate_umaban  \
# 14                  0.178886
# 10                  0.211137
# 11                  0.161972
# 9                   0.154450
# 1                   0.230769
# 2                   0.266204
# 4                   0.188995
# 7                   0.183562
# 3                   0.215777
# 5                   0.236111
# 13                  0.244804
# 8                   0.210127
# 12                  0.180921
# 6                   0.208817
# 0                   0.273148
#
#     distance_place_type_ground_state_encoded_time_diff_mean_3races_cross_encoded_relative  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     distance_place_type_ground_state_encoded_time_diff_min_3races_cross_encoded_relative  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     syunpatu_mean_3races_encoded  zizoku_mean_3races_encoded  \
# 14                           NaN                         NaN
# 10                           NaN                         NaN
# 11                           NaN                         NaN
# 9                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 4                            NaN                         NaN
# 7                            NaN                         NaN
# 3                            NaN                         NaN
# 5                            NaN                         NaN
# 13                           NaN                         NaN
# 8                            NaN                         NaN
# 12                           NaN                         NaN
# 6                            NaN                         NaN
# 0                            NaN                         NaN
#
#     dominant_position_category  pace_category  ground_state_level  \
# 14                           2              4                   2
# 10                           2              4                   2
# 11                           2              4                   2
# 9                            2              4                   2
# 1                            2              4                   2
# 2                            2              4                   2
# 4                            2              4                   2
# 7                            2              4                   2
# 3                            2              4                   2
# 5                            2              4                   2
# 13                           2              4                   2
# 8                            2              4                   2
# 12                           2              4                   2
# 6                            2              4                   2
# 0                            2              4                   2
#
#     rentai_for_pace_category_n5_relative  \
# 14                                   NaN
# 10                                   NaN
# 11                                   NaN
# 9                                    NaN
# 1                                    NaN
# 2                                    NaN
# 4                                    NaN
# 7                                    NaN
# 3                                    NaN
# 5                                    NaN
# 13                                   NaN
# 8                                    NaN
# 12                                   NaN
# 6                                    NaN
# 0                                    NaN
#
#     score_pace_potision_mean_3races_per_score_raw_relative  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     mean_5races_sum_relative  tenkai_combined_standardized  \
# 14                       NaN                           NaN
# 10                       NaN                           NaN
# 11                       NaN                           NaN
# 9                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 4                        NaN                           NaN
# 7                        NaN                           NaN
# 3                        NaN                           NaN
# 5                        NaN                           NaN
# 13                       NaN                           NaN
# 8                        NaN                           NaN
# 12                       NaN                           NaN
# 6                        NaN                           NaN
# 0                        NaN                           NaN
#
#     tenkai_all_combined_standardized  \
# 14                               NaN
# 10                               NaN
# 11                               NaN
# 9                                NaN
# 1                                NaN
# 2                                NaN
# 4                                NaN
# 7                                NaN
# 3                                NaN
# 5                                NaN
# 13                               NaN
# 8                                NaN
# 12                               NaN
# 6                                NaN
# 0                                NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_plus_tenkai_combined_standardized  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_plus_tenkai_combined_standardized  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_plus_tenkai_all_combined_standardized  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_plus_tenkai_all_combined_standardized  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_px_tenkai_combined_standardized  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_px_tenkai_combined_standardized  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     race_grade_rank_diff_sum_mean_3races_grade_rankdiff_score_px_tenkai_all_combined_standardized  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     race_grade_rank_diff_multi_mean_3races_grade_rankdiff_score_px_tenkai_all_combined_standardized  \
# 14                                                NaN
# 10                                                NaN
# 11                                                NaN
# 9                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 13                                                NaN
# 8                                                 NaN
# 12                                                NaN
# 6                                                 NaN
# 0                                                 NaN
#
#     speed_index_mean_3races  nobori_index_mean_3races  speed_index_min_5races  \
# 14                      NaN                       NaN                     NaN
# 10                      NaN                       NaN                     NaN
# 11                      NaN                       NaN                     NaN
# 9                       NaN                       NaN                     NaN
# 1                       NaN                       NaN                     NaN
# 2                       NaN                       NaN                     NaN
# 4                       NaN                       NaN                     NaN
# 7                       NaN                       NaN                     NaN
# 3                       NaN                       NaN                     NaN
# 5                       NaN                       NaN                     NaN
# 13                      NaN                       NaN                     NaN
# 8                       NaN                       NaN                     NaN
# 12                      NaN                       NaN                     NaN
# 6                       NaN                       NaN                     NaN
# 0                       NaN                       NaN                     NaN
#
#     nobori_index_min_5races  speed_index_mean_3races_relative  \
# 14                      NaN                               NaN
# 10                      NaN                               NaN
# 11                      NaN                               NaN
# 9                       NaN                               NaN
# 1                       NaN                               NaN
# 2                       NaN                               NaN
# 4                       NaN                               NaN
# 7                       NaN                               NaN
# 3                       NaN                               NaN
# 5                       NaN                               NaN
# 13                      NaN                               NaN
# 8                       NaN                               NaN
# 12                      NaN                               NaN
# 6                       NaN                               NaN
# 0                       NaN                               NaN
#
#     nobori_index_mean_3races_relative       pred
# 14                                NaN  97.585938
# 10                                NaN  97.432837
# 11                                NaN  97.301673
# 9                                 NaN  97.236479
# 1                                 NaN  97.179028
# 2                                 NaN  97.145943
# 4                                 NaN  97.103323
# 7                                 NaN  96.848596
# 3                                 NaN  96.708708
# 5                                 NaN  96.689785
# 13                                NaN  96.595708
# 8                                 NaN  96.543668
# 12                                NaN  96.435689
# 6                                 NaN  96.384233
# 0                                 NaN  96.383939

# %% [markdown]
# ###　12/21 第n回目レース

# %%
# 特徴量の更新
features = pfc.create_features(
    race_id="202408060411",  # 予測するレースidを指定
    date_content_a = "2024年12月21日", #"%Y年%m月%d日"形式で該当レース当日の日付を入れてください    
    skip_agg_horse=True  # 事前に集計した場合はスキップできる
)

# %%
pfc.results

# %%
pfc.race_info

# %%
# オッズ除外モデルでの予測、time、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_time_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %%
# オッズ除外モデルでの予測、time、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_time_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %% [markdown]
# ### 12/21 第n回目レース

# %%
# 特徴量の更新
features = pfc.create_features(
    race_id="202408060411",  # 予測するレースidを指定
    date_content_a = "2024年12月21日", #"%Y年%m月%d日"形式で該当レース当日の日付を入れてください    
    skip_agg_horse=True  # 事前に集計した場合はスキップできる
)

# %%
pfc.results

# %%
pfc.race_info

# %%
# オッズ除外モデルでの予測、time、ホールドアウト
prediction.predict(
    features,
    model_filename="model_lightgbm_time_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)

# %%
# オッズ除外モデルでの予測、time、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_time_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)
