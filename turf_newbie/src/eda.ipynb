# %% [markdown]
# # 探索的データ分析(EDA)

# %% [markdown]
# ## 1. データの概要を把握する分析
# - データの分布を確認
#     - 欠損値
#     - 外れ値
#     - 偏り
#     - カテゴリ数
# - 目的変数との相関を確認

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import create_population
import create_population3
import preprocessing
from feature_engineering import FeatureCreator
from feature_engineering_prediction import PredictionFeatureCreator

import prediction

import pandas as pd
# %load_ext autoreload

# %%
# %autoreload
# Out:
# UsageError: Line magic function `%autoreload` not found.

# %%
# population = create_population.create(from_="2016-01-01", to_="2023-12-31")
population = create_population.create(from_="2016-01-01", to_="2023-12-31")

# %%
# レース結果テーブルの前処理
results_preprocessed = preprocessing.process_results()
# 馬の過去成績テーブルの加工
horse_results_preprocessed = preprocessing.process_horse_results()
# レース情報テーブルの前処理
race_info_preprocessed = preprocessing.process_race_info()
# 騎手リーディングテーブルの前処理
jockey_leading_preprocessed = preprocessing.process_jockey_leading()
# 調教師リーディングテーブルの前処理
trainer_leading_preprocessed = preprocessing.process_trainer_leading()
# 血統テーブルの前処理
peds_preprocessed = preprocessing.process_peds()
# 種牡馬リーディングテーブルの前処理
sire_leading_preprocessed = preprocessing.process_sire_leading()
fc = FeatureCreator()
features = fc.create_features()
# 重複チェック
features.duplicated(subset=["race_id", "horse_id"]).sum()
# Out:
# agg_horse_n_races_relative:   0%|          | 0/5 [00:00<?, ?it/s]
# running agg_jockey()...
# running agg_jockey()...comp
# running agg_trainer()...
# running agg_trainer()...comp
# agg_horse_per_course_len:   0%|          | 0/5 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_horse_per_ground_state_race_type:   0%|          | 0/5 [00:00<?, ?it/s]
# agg_horse_per_race_class:   0%|          | 0/5 [00:00<?, ?it/s]
# agg_horse_per_race_type:   0%|          | 0/5 [00:00<?, ?it/s]
# agg_horse_per_race_place_len:   0%|          | 0/5 [00:00<?, ?it/s]
# agg_horse_per_weather:   0%|          | 0/5 [00:00<?, ?it/s]
# running agg_sire()...
# running agg_sire()...comp
# merging all features...
# merging all features...comp
# np.int64(0)

# %%
df = pd.read_csv("../data/02_features/features.csv", sep="\t")

# %%
df.head()
# Out:
#         race_id        date    horse_id  jockey_id  trainer_id  owner_id  \
# 0  202206010101  2022-01-05  2019103610       1192        1020    897009
# 1  202206010101  2022-01-05  2019100855       1179        1088    125008
# 2  202206010101  2022-01-05  2019103542       1009        1089    546800
# 3  202206010101  2022-01-05  2019104288       1119        1132     64803
# 4  202206010101  2022-01-05  2019101003       5212        1109    427030
#
#    rank  time  nobori  umaban  ...  win_mean_10races_per_weather_relative  \
# 0     1  72.5    37.6      15  ...                                    NaN
# 1     2  72.5    37.7      10  ...                                    NaN
# 2     3  72.5    37.3       4  ...                                    NaN
# 3     4  72.8    37.2       2  ...                                    NaN
# 4     5  73.2    38.0      16  ...                                    NaN
#
#    win_max_10races_per_weather_relative  win_min_10races_per_weather_relative  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#    show_mean_10races_per_weather_relative  \
# 0                                1.283881
# 1                               -0.385164
# 2                               -0.385164
# 3                               -0.385164
# 4                               -0.385164
#
#    show_max_10races_per_weather_relative  \
# 0                               2.253203
# 1                              -0.409673
# 2                              -0.409673
# 3                              -0.409673
# 4                              -0.409673
#
#    show_min_10races_per_weather_relative  sire_n_races_relative  \
# 0                               -0.27735                    NaN
# 1                               -0.27735                    NaN
# 2                               -0.27735                    NaN
# 3                               -0.27735                    NaN
# 4                               -0.27735                    NaN
#
#    sire_n_wins_relative  sire_winrate_relative  sire_course_len_diff_relative
# 0                   NaN                    NaN                            NaN
# 1                   NaN                    NaN                            NaN
# 2                   NaN                    NaN                            NaN
# 3                   NaN                    NaN                            NaN
# 4                   NaN                    NaN                            NaN
#
# [5 rows x 1583 columns]

# %%
df.tail()
# Out:
#             race_id        date    horse_id  jockey_id  trainer_id  owner_id  \
# 94108  202309050912  2023-12-28  2017104873       1154         425    758005
# 94109  202309050912  2023-12-28  2019100653       1138        1158    950006
# 94110  202309050912  2023-12-28  2017106240       1018        1178    258033
# 94111  202309050912  2023-12-28  2018103205       1112         428    629800
# 94112  202309050912  2023-12-28  2017102603       1144        1050    356002
#
#        rank  time  nobori  umaban  ...  win_mean_10races_per_weather_relative  \
# 94108    12  69.5    33.6      11  ...                              -1.437777
# 94109    13  69.5    34.2      15  ...                              -0.444167
# 94110    14  69.6    34.5       7  ...                              -0.642889
# 94111    15  69.8    34.9      16  ...                              -0.642889
# 94112    16  70.4    34.4      14  ...                               0.151999
#
#        win_max_10races_per_weather_relative  \
# 94108                             -2.561738
# 94109                              0.365963
# 94110                              0.365963
# 94111                              0.365963
# 94112                              0.365963
#
#        win_min_10races_per_weather_relative  \
# 94108                                   NaN
# 94109                                   NaN
# 94110                                   NaN
# 94111                                   NaN
# 94112                                   NaN
#
#        show_mean_10races_per_weather_relative  \
# 94108                               -0.991184
# 94109                               -1.380550
# 94110                               -0.472029
# 94111                               -0.991184
# 94112                               -0.991184
#
#        show_max_10races_per_weather_relative  \
# 94108                                    NaN
# 94109                                    NaN
# 94110                                    NaN
# 94111                                    NaN
# 94112                                    NaN
#
#        show_min_10races_per_weather_relative  sire_n_races_relative  \
# 94108                                    NaN                    NaN
# 94109                                    NaN                    NaN
# 94110                                    NaN                    NaN
# 94111                                    NaN                    NaN
# 94112                                    NaN                    NaN
#
#        sire_n_wins_relative  sire_winrate_relative  \
# 94108                   NaN                    NaN
# 94109                   NaN                    NaN
# 94110                   NaN                    NaN
# 94111                   NaN                    NaN
# 94112                   NaN                    NaN
#
#        sire_course_len_diff_relative
# 94108                            NaN
# 94109                            NaN
# 94110                            NaN
# 94111                            NaN
# 94112                            NaN
#
# [5 rows x 1583 columns]

# %% [markdown]
# ### データの分布を確認する

# %%
# 目的変数
df["target"] = (df["rank"] == 1).astype(int)

# %%
df["target"].value_counts()
# Out:
# target
# 0    87194
# 1     6919
# Name: count, dtype: int64

# %%
df["target"].mean()
# Out:
# np.float64(0.07351800495149448)

# %%
#説明変数

# %%
# 年間レース数・出馬数など
df["year"] = pd.to_datetime(df["date"]).dt.year
df["year"].head()
# Out:
# 0    2022
# 1    2022
# 2    2022
# 3    2022
# 4    2022
# Name: year, dtype: int32

# %%
#年間ごとのレース数、馬の数、ジョッキー、トレーナーなど
df.groupby("year")[["race_id", "horse_id", "jockey_id", "trainer_id"]].nunique()
# Out:
#       race_id  horse_id  jockey_id  trainer_id
# year
# 2022     3456     11497        196         230
# 2023     3456     11664        198         234

# %%
df["race_id"].value_counts()
# Out:
# race_id
# 201805020404    18
# 202004020105    18
# 202010011111    18
# 201807030307    18
# 202010011103    18
#                 ..
# 202008010606     5
# 202009050409     5
# 202302020205     5
# 202207010608     4
# 201907030504     4
# Name: count, Length: 20729, dtype: int64

# %%
#何頭だてのレースがどれくらいあるか
df["race_id"].value_counts().value_counts()
# Out:
# count
# 16    6116
# 15    2657
# 14    2101
# 13    1691
# 12    1686
# 11    1505
# 10    1239
# 18    1238
# 9      956
# 8      688
# 17     431
# 7      281
# 6       99
# 5       39
# 4        2
# Name: count, dtype: int64

# %%
sns.barplot(df["race_id"].value_counts().value_counts())
# Out:
# <Axes: xlabel='count', ylabel='count'>

# %%
sns.set
#綺麗に整えてくれる
# Out:
# <function seaborn.rcmod.set(*args, **kwargs)>

# %%
sns.barplot(df["race_id"].value_counts().value_counts())
# Out:
# <Axes: xlabel='count', ylabel='count'>

# %%
agg_df = df["race_id"].value_counts().to_frame().reset_index()
agg_df
# Out:
#             race_id  count
# 0      201805020404     18
# 1      202004020105     18
# 2      202010011111     18
# 3      201807030307     18
# 4      202010011103     18
# ...             ...    ...
# 20724  202008010606      5
# 20725  202009050409      5
# 20726  202302020205      5
# 20727  202207010608      4
# 20728  201907030504      4
#
# [20729 rows x 2 columns]

# %%
sns.countplot(data=agg_df, x="count")
# Out:
# <Axes: xlabel='count', ylabel='count'>

# %%
# 基本の型＿テンプレ＿
sns.hogehogeplot(data=df, x="列名", y="列名")

# %%
df.head()
# Out:
#         race_id        date    horse_id  jockey_id  trainer_id  owner_id  \
# 0  201806010101  2018-01-06  2015104603       5386        1109    928030
# 1  201806010101  2018-01-06  2015106010       1085         421    775002
# 2  201806010101  2018-01-06  2015105549       1075         417    629800
# 3  201806010101  2018-01-06  2015103961       1122        1118    669033
# 4  201806010101  2018-01-06  2015103269       1077        1116    866800
#
#    rank  umaban  wakuban  tansho_odds  ...  \
# 0     1      15        8          2.0  ...
# 1     2       3        2          6.7  ...
# 2     3       6        3          7.6  ...
# 3     4       9        5         48.5  ...
# 4     5      10        5         61.9  ...
#
#    win_min_20races_per_race_type_relative  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    show_mean_20races_per_race_type_relative  \
# 0                                  1.189258
# 1                                  0.997883
# 2                                  0.505776
# 3                                 -0.724490
# 4                                 -0.724490
#
#    show_max_20races_per_race_type_relative  \
# 0                                 1.132843
# 1                                 1.132843
# 2                                 1.132843
# 3                                -0.809174
# 4                                -0.809174
#
#    show_min_20races_per_race_type_relative  sire_n_races_relative  \
# 0                                -0.288675              -0.118795
# 1                                -0.288675              -0.662675
# 2                                -0.288675              -0.267646
# 3                                -0.288675              -0.336347
# 4                                -0.288675               0.024331
#
#    sire_n_wins_relative  sire_winrate_relative  sire_course_len_diff_relative  \
# 0             -0.340453              -0.285466                       0.470337
# 1             -0.961026              -1.319551                       0.377336
# 2             -0.478358              -0.394098                      -0.469773
# 3             -0.202548               0.307962                      -0.154100
# 4             -0.409406              -0.534589                      -0.345948
#
#    target  year
# 0       1  2018
# 1       0  2018
# 2       0  2018
# 3       0  2018
# 4       0  2018
#
# [5 rows x 545 columns]

# %%
#同じ馬が何回走っているのか
agg_df = df["horse_id"].value_counts().to_frame().reset_index()
agg_df.rename(columns={"count": "id_count"}, inplace=True)
sns.countplot(data=agg_df, x="id_count")
# Out:
# <Axes: xlabel='id_count', ylabel='count'>

# %%
plt.figure(figsize=(20, 5))
sns.countplot(data=agg_df, x="id_count")
# Out:
# <Axes: xlabel='id_count', ylabel='count'>

# %%
plt.figure(figsize=(5, 10))
sns.countplot(data=agg_df, y="id_count")
# Out:
# <Axes: xlabel='count', ylabel='id_count'>

# %%
#機種がどんくらい出るのか
agg_df = df["jockey_id"].value_counts().rename("id_count").to_frame().reset_index()
agg_df
# Out:
#      jockey_id  id_count
# 0         1157      1757
# 1         1018      1746
# 2         1126      1677
# 3          732      1677
# 4         1091      1663
# ..         ...       ...
# 223       5624         1
# 224       5488         1
# 225       5229         1
# 226       5329         1
# 227       5580         1
#
# [228 rows x 2 columns]

# %%
sns.countplot(data=agg_df, x="id_count")
# Out:
# <Axes: xlabel='id_count', ylabel='count'>

# %%
agg_df
# Out:
#      jockey_id  id_count
# 0         1126      5274
# 1         1018      5166
# 2          732      5066
# 3         1170      4430
# 4         1157      4388
# ..         ...       ...
# 315        409         1
# 316       5456         1
# 317       5598         1
# 318       5444         1
# 319       5491         1
#
# [320 rows x 2 columns]

# %%
# 箱ひげ図
sns.boxplot(data=agg_df, x="id_count")
# Out:
# <Axes: xlabel='id_count'>

# %% [markdown]
# 75パーセンタイル値 + 1.5 * IQR（箱の長さ）

# %%
#id_countの統計量
agg_df["id_count"].describe()
# Out:
# count     228.000000
# mean      412.776316
# std       476.241728
# min         1.000000
# 25%        10.750000
# 50%       187.000000
# 75%       713.750000
# max      1757.000000
# Name: id_count, dtype: float64

# %%
# ヒストグラム: データをいくつかの範囲（ビン）に分けて、その範囲内のデータの個数を棒グラフの形で表したもの
#単勝オッズの範囲
sns.histplot(data=df, x="tansho_odds")
# Out:
# <Axes: xlabel='tansho_odds', ylabel='Count'>

# %%
sns.histplot(data=df, x="tansho_odds", bins=10)
# Out:
# <Axes: xlabel='tansho_odds', ylabel='Count'>

# %%
sns.histplot(data=df, x="tansho_odds", bins=1000)
# Out:
# <Axes: xlabel='tansho_odds', ylabel='Count'>

# %% [markdown]
# （発展）：デフォルトではFreedman-Diaconis ruleと呼ばれる手法でビンの数が決められている
#
# https://github.com/mwaskom/seaborn/blob/b4e5f8d261d6d5524a00b7dd35e00a40e4855872/seaborn/distributions.py#L2375

# %%
# 目的変数との相関＿枠番ごとの勝率＿
df["wakuban"]
# Out:
# 0         8
# 1         2
# 2         3
# 3         5
# 4         5
#          ..
# 284763    6
# 284764    8
# 284765    4
# 284766    8
# 284767    7
# Name: wakuban, Length: 284768, dtype: int64

# %%
df["target"]
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284763    0
# 284764    0
# 284765    0
# 284766    0
# 284767    0
# Name: target, Length: 284768, dtype: int64

# %% [markdown]
# ### 目的変数との相関を確認する

# %%
# 目的変数との相関＿枠番ごとの勝率＿
#　棒は95%の信頼区間
sns.barplot(df, x="wakuban", y="target")
# Out:
# <Axes: xlabel='wakuban', ylabel='target'>

# %% [markdown]
# {
#     "ダ": 0,
#     "芝": 1,
#     "障": 2
# }

# %%
df["race_type"].value_counts(dropna=False)
# dropna=Falseで欠損値を含める
# Out:
# race_type
# 0    142155
# 1    134040
# 2      8573
# Name: count, dtype: int64

# %%
# 目的変数との相関＿枠番ごとの勝率＿レースタイプごと
#レースデータが少ないと標準誤差が大きい
sns.barplot(df, x="wakuban", y="target", hue="race_type")
# Out:
# <Axes: xlabel='wakuban', ylabel='target'>

# %%
sns.barplot(df, hue="wakuban", y="target", x="race_type")
# Out:
# <Axes: xlabel='race_type', ylabel='target'>

# %% [markdown]
# ダートは外枠有利、芝は内枠有利（だが、そこまで有意な差ではない）

# %%
# 馬体重
df["weight"]
# Out:
# 0         462
# 1         478
# 2         442
# 3         464
# 4         456
#          ...
# 284763    512
# 284764    498
# 284765    508
# 284766    472
# 284767    490
# Name: weight, Length: 284768, dtype: int64

# %%
#離散的なデータをプロットしてくれる
sns.histplot(df, x="weight")
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %%
sns.histplot(df, x="weight", discrete=True)
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %%
sns.barplot(df, x="target", y="weight")
# Out:
# <Axes: xlabel='target', ylabel='weight'>

# %%
#＿目的変数との相関
sns.violinplot(df, x="target", y="weight")
# Out:
# <Axes: xlabel='target', ylabel='weight'>

# %%
sns.histplot(df, x="weight", discrete=True, hue="target")
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %%
# 2重軸
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

sns.histplot(
    df.query("target == 0"),
    x="weight",
    discrete=True,
    ax=ax1,
    label="target:0"
)
ax1.legend(loc="upper left")
sns.histplot(
    df.query("target == 1"),
    x="weight",
    discrete=True,
    ax=ax2,
    color="red",
    label="target:1"
)
ax2.legend()

# %%
# 2重軸
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

sns.histplot(
    df.query("target == 0"),
    x="weight",
    discrete=True,
    ax=ax1,
    label="target:0"
)
ax1.legend(loc="upper left")
ax1.set_ylabel("count(target:0)")

sns.histplot(
    df.query("target == 1"),
    x="weight",
    discrete=True,
    ax=ax2,
    color="red",
    label="target:1"
)
ax2.legend()
ax2.set_ylabel("count(target:1)")
# Out:
# Text(0, 0.5, 'count(target:1)')

# %%
# 連続値 x 連続値の可視化
sns.scatterplot(data=df, x="rank_mean_10races_relative", y="tansho_odds")
# Out:
# <Axes: xlabel='rank_mean_10races_relative', ylabel='tansho_odds'>

# %%
sns.displot(data=df, x="rank_mean_10races_relative", y="tansho_odds")

# %%
# 体重変化
df["weight_diff"]
# Out:
# 0          0
# 1          4
# 2         12
# 3          8
# 4         10
#           ..
# 284763     4
# 284764    10
# 284765     2
# 284766    -4
# 284767    14
# Name: weight_diff, Length: 284768, dtype: int64

# %%
sns.histplot(df, x="weight_diff", discrete=True)
# Out:
# <Axes: xlabel='weight_diff', ylabel='Count'>

# %%
# 体重変化が+の方が勝率が高そう
sns.barplot(df, x="target", y="weight_diff")
# Out:
# <Axes: xlabel='target', ylabel='weight_diff'>

# %%
# 「馬の過去成績」の欠損率
df["rank_3races"].isnull().mean()
# Out:
# 0.09870139903359929

# %%
from feature_engineering import FeatureCreator

fc = FeatureCreator()
fc.create_baselog()

# %%
#それぞれの馬にどれだけのデータが使われているのか
n_races = fc.baselog[["race_id", "horse_id"]].value_counts().to_frame()
n_races
# Out:
#                          count
# race_id      horse_id
# 202206030810 2013103671     74
# 202309050610 2014100555     74
# 202309040201 2013103941     73
# 202305050310 2014100555     73
# 202209010411 2013103671     73
# ...                        ...
# 202305040303 2021104068      1
#              2021101640      1
# 202205020904 2019110041      1
# 202305040302 2021106800      1
# 202201010101 2020100678      1
#
# [85316 rows x 1 columns]

# %%
sns.histplot(n_races, x="count", discrete=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
#中央値として、過去8レースを紐づけると全部になりそう
#windowサイズとされているので
n_races["count"].describe()
# Out:
# count    258813.000000
# mean         11.025057
# std          10.315446
# min           1.000000
# 25%           3.000000
# 50%           8.000000
# 75%          16.000000
# max         122.000000
# Name: count, dtype: float64

# %% [markdown]
# window_size: 中央値くらいに設定すると良いらしい？

# %% [markdown]
# ## 仮説を検証する分析

# %% [markdown]
# ## 内枠・外枠の検証
# - 芝は内枠有利だが、ダートは外枠有利
# - 直線はコースが荒れていない外枠有利
# - 馬場が整っている開催前半は内枠有利
# - 雨の日など、馬場状態が悪い時には外枠有利
# - ゲートから最初のコーナーまでの距離が短い方が内枠有利
#     - コースによって異なる

# %% [markdown]
# {
#     "右": 0,
#     "左": 1,
#     "直": 2
# }

# %%
df["around"].value_counts(dropna=False)
# Out:
# around
# 0.0    55986
# 1.0    34722
# NaN     2693
# 2.0      712
# Name: count, dtype: int64

# %%
sns.barplot(df, x="around", y="target", hue="wakuban")
# Out:
# <Axes: xlabel='around', ylabel='target'>

# %% [markdown]
# around x wakubanの特徴量は入れたい

# %% [markdown]
# {
#     "良": 0,
#     "重": 1,
#     "稍": 2,
#     "不": 3,
#     "稍重": 2,
#     "不良": 3
# }

# %%
sns.barplot(df, x="ground_state", y="target", hue="wakuban")
# Out:
# <Axes: xlabel='ground_state', ylabel='target'>

# %% [markdown]
# ## 出走間隔

# %%
fc.baselog
# Out:
#               race_id        date    horse_id  date_horse  rank  prize  \
# 1523411  202309050903  2023-12-28  2021102811  2023-12-23  17.0    0.0
# 1523347  202309050903  2023-12-28  2021105731  2023-12-23  12.0    0.0
# 1523405  202309050903  2023-12-28  2021105018  2023-12-23  14.0    0.0
# 1523388  202309050903  2023-12-28  2021104215  2023-12-23  14.0    0.0
# 1511977  202306050704  2023-12-23  2021103822  2023-12-17   9.0    0.0
# ...               ...         ...         ...         ...   ...    ...
# 244868   202206030711  2022-04-16  2011101125  2013-11-16   8.0    0.0
# 244869   202206030711  2022-04-16  2011101125  2013-10-19  11.0    0.0
# 799332   202206050710  2022-12-24  2011101125  2013-10-19  11.0    0.0
# 647847   202205040509  2022-10-16  2011101125  2013-10-19  11.0    0.0
# 169314   202209010908  2022-03-12  2011101125  2013-10-19  11.0    0.0
#
#          rank_diff  weather  race_type  course_len  ...  win  rentai  show  \
# 1523411        3.3      1.0          1        1400  ...    0       0     0
# 1523347        1.6      1.0          1        1800  ...    0       0     0
# 1523405        3.3      1.0          0        1200  ...    0       0     0
# 1523388        2.0      1.0          1        1800  ...    0       0     0
# 1511977        4.2      1.0          0        1800  ...    0       0     0
# ...            ...      ...        ...         ...  ...  ...     ...   ...
# 244868         1.8      1.0          1        2000  ...    0       0     0
# 244869         0.8      1.0          1        1800  ...    0       0     0
# 799332         0.8      1.0          1        1800  ...    0       0     0
# 647847         0.8      1.0          1        1800  ...    0       0     0
# 169314         0.8      1.0          1        1800  ...    0       0     0
#
#          place  corner_1  corner_2  corner_3  corner_4  pase_1  pase_2
# 1523411    9.0        13      15.0       NaN       NaN    34.8    34.8
# 1523347    9.0         6       8.0       NaN       NaN    35.4    34.4
# 1523405    9.0        10      12.0       NaN       NaN    35.6    38.0
# 1523388    9.0        14      14.0       NaN       NaN    35.4    34.4
# 1511977    6.0        14      14.0      12.0      13.0    38.3    40.6
# ...        ...       ...       ...       ...       ...     ...     ...
# 244868     5.0        12      12.0      12.0       NaN    37.1    34.4
# 244869     5.0        15      14.0      11.0       NaN    38.0    34.4
# 799332     5.0        15      14.0      11.0       NaN    38.0    34.4
# 647847     5.0        15      14.0      11.0       NaN    38.0    34.4
# 169314     5.0        15      14.0      11.0       NaN    38.0    34.4
#
# [859138 rows x 25 columns]

# %%
fc.baselog.groupby(["race_id", "horse_id", "date"])["date_horse"].max()
# Out:
# race_id       horse_id    date
# 201801010101  2016101840  2018-07-28    2018-07-21
#               2016102801  2018-07-28    2018-07-15
#               2016103821  2018-07-28    2018-07-15
#               2016103985  2018-07-28    2018-07-22
#               2016104880  2018-07-28    2018-07-08
#                                            ...
# 202310030812  2020103324  2023-09-03    2023-08-26
#               2020103663  2023-09-03    2023-06-04
#               2020103754  2023-09-03    2023-08-06
#               2020105644  2023-09-03    2023-08-06
#               2020106455  2023-09-03    2023-08-13
# Name: date_horse, Length: 258813, dtype: object

# %%
latest_df = (
    fc.baselog
    .groupby(["race_id", "horse_id", "date"])["date_horse"]
    .max()
    .to_frame()
    .reset_index()
)

# %%
latest_df
# Out:
#              race_id    horse_id        date  date_horse
# 0       201801010101  2016101840  2018-07-28  2018-07-21
# 1       201801010101  2016102801  2018-07-28  2018-07-15
# 2       201801010101  2016103821  2018-07-28  2018-07-15
# 3       201801010101  2016103985  2018-07-28  2018-07-22
# 4       201801010101  2016104880  2018-07-28  2018-07-08
# ...              ...         ...         ...         ...
# 258808  202310030812  2020103324  2023-09-03  2023-08-26
# 258809  202310030812  2020103663  2023-09-03  2023-06-04
# 258810  202310030812  2020103754  2023-09-03  2023-08-06
# 258811  202310030812  2020105644  2023-09-03  2023-08-06
# 258812  202310030812  2020106455  2023-09-03  2023-08-13
#
# [258813 rows x 4 columns]

# %%
#出走間隔の表（土日開催なので一週間単位で）
latest_df["interval"] = (
    pd.to_datetime(latest_df["date"]) - pd.to_datetime(latest_df["date_horse"])
).dt.days

# %%
sns.histplot(latest_df, x="interval", discrete=True)
# Out:
# <Axes: xlabel='interval', ylabel='Count'>

# %%
latest_df["interval"] = latest_df["interval"] // 7

# %%
sns.histplot(latest_df, x="interval", discrete=True)
# Out:
# <Axes: xlabel='interval', ylabel='Count'>

# %%
latest_df["interval"].value_counts()
# Out:
# interval
# 3      43693
# 2      40796
# 4      26431
# 1      16278
# 5      14821
#        ...
# 117        1
# 100        1
# 157        1
# 112        1
# 104        1
# Name: count, Length: 128, dtype: int64

# %%
#targetを表に紐づける
df2 = latest_df.merge(
    df[["race_id", "horse_id", "target"]],
    on=["race_id", "horse_id"]
)

# %%
#データ数が多いので30で絞る
#標準誤差が大きい
sns.barplot(df2.query("interval < 30"), x="interval", y="target")
# Out:
# <Axes: xlabel='interval', ylabel='target'>

# %% [markdown]
# 出走間隔は入れたい

# %% [markdown]
# ## 夏は牝馬

# %% [markdown]
# {
#     "牡": 0,
#     "牝": 1,
#     "セ": 2
# }

# %%
df["sex"]
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 94108    0
# 94109    1
# 94110    0
# 94111    0
# 94112    0
# Name: sex, Length: 94113, dtype: int64

# %%
#月毎の雄雌の勝敗
df["month"] = pd.to_datetime(df["date"]).dt.month
df["month"].value_counts(sort=False)
# Out:
# month
# 1     8551
# 2     8116
# 3     7405
# 4     8577
# 5     8043
# 6     7099
# 7     8701
# 8     7205
# 9     6572
# 10    8452
# 11    7266
# 12    8126
# Name: count, dtype: int64

# %%
sns.barplot(df, x="month", y="target", hue="sex")
# Out:
# <Axes: xlabel='month', ylabel='target'>

# %% [markdown]
# {
#     "牡": 0,
#     "牝": 1,
#     "セ": 2
# }

# %% [markdown]
# 季節 x 性別も入れたい

# %%
#カテゴリの比較と、時系列の比較もしたい場合
sns.lineplot(df, x="month", y="target", hue="sex", marker="x")
# Out:
# <Axes: xlabel='month', ylabel='target'>

# %%
mix_races = df.groupby("race_id")[["sex"]].nunique().query("sex == 2").index

# %%
sns.lineplot(
    df.query("race_id in @mix_races"),
    x="month",
    y="target",
    hue="sex",
    marker="."
)
# Out:
# <Axes: xlabel='month', ylabel='target'>

# %% [markdown]
# ## 【深堀分析】競馬場ごとの枠順有利/不利

# %%
sns.countplot(df, x="place")
# Out:
# <Axes: xlabel='place', ylabel='count'>

# %% [markdown]
# {
#     "札幌": 1,
#     "函館": 2,
#     "福島": 3,
#     "新潟": 4,
#     "東京": 5,
#     "中山": 6,
#     "中京": 7,
#     "京都": 8,
#     "阪神": 9,
#     "小倉": 10
# }

# %%
# 1着だとぶれが大きいので
df["target"] = (df["rank"] <= 3).astype(int)

# %%
df2 = df[["race_type", "course_len", "place", "target", "wakuban"]].dropna().astype(int)
df2["race_type_course_len"] = df2["race_type"].astype(str) + "_" + df2["course_len"].astype(str)
df2["type_count"] = df2.groupby(["place", "race_type_course_len"])["wakuban"].transform("count")
df2 = df2.query("type_count >= 1000")

# %%
# 札幌競馬場
plt.figure(figsize=(20, 5))
sns.barplot(
    df2.query("place == 1"),
    x="race_type_course_len",
    y="target",
    hue="wakuban"
)
# Out:
# <Axes: xlabel='race_type_course_len', ylabel='target'>

# %%
# 函館競馬場
plt.figure(figsize=(20, 5))
sns.barplot(
    df2.query("place == 2"),
    x="race_type_course_len",
    y="target",
    hue="wakuban"
)
# Out:
# <Axes: xlabel='race_type_course_len', ylabel='target'>

# %%
# 福島競馬場
plt.figure(figsize=(20, 5))
sns.barplot(
    df2.query("place == 3"),
    x="race_type_course_len",
    y="target",
    hue="wakuban"
)
# Out:
# <Axes: xlabel='race_type_course_len', ylabel='target'>

# %%
# 新潟競馬場
plt.figure(figsize=(20, 5))
sns.barplot(
    df2.query("place == 4"),
    x="race_type_course_len",
    y="target",
    hue="wakuban"
)
# Out:
# <Axes: xlabel='race_type_course_len', ylabel='target'>

# %%
# 東京競馬場
plt.figure(figsize=(20, 5))
sns.barplot(
    df2.query("place == 5"),
    x="race_type_course_len",
    y="target",
    hue="wakuban"
)
# Out:
# <Axes: xlabel='race_type_course_len', ylabel='target'>

# %%
# 中山競馬場
plt.figure(figsize=(20, 5))
sns.barplot(
    df2.query("place == 6"),
    x="race_type_course_len",
    y="target",
    hue="wakuban"
)
# Out:
# <Axes: xlabel='race_type_course_len', ylabel='target'>

# %%
# 中京競馬場
plt.figure(figsize=(20, 5))
sns.barplot(
    df2.query("place == 7"),
    x="race_type_course_len",
    y="target",
    hue="wakuban"
)
# Out:
# <Axes: xlabel='race_type_course_len', ylabel='target'>

# %%
# 京都競馬場
plt.figure(figsize=(20, 5))
sns.barplot(
    df2.query("place == 8"),
    x="race_type_course_len",
    y="target",
    hue="wakuban"
)
# Out:
# <Axes: xlabel='race_type_course_len', ylabel='target'>

# %% [markdown]
# {
#     "札幌": 1,
#     "函館": 2,
#     "福島": 3,
#     "新潟": 4,
#     "東京": 5,
#     "中山": 6,
#     "中京": 7,
#     "京都": 8,
#     "阪神": 9,
#     "小倉": 10
# }

# %%
# 阪神競馬場
plt.figure(figsize=(20, 5))
sns.barplot(
    df2.query("place == 9"),
    x="race_type_course_len",
    y="target",
    hue="wakuban"
)
# Out:
# <Axes: xlabel='race_type_course_len', ylabel='target'>

# %%
# 小倉競馬場
plt.figure(figsize=(20, 5))
sns.barplot(
    df2.query("place == 10"),
    x="race_type_course_len",
    y="target",
    hue="wakuban"
)
# Out:
# <Axes: xlabel='race_type_course_len', ylabel='target'>

# %%
df
# Out:
#              race_id        date    horse_id  jockey_id  trainer_id  owner_id  \
# 0       201606010101  2016-01-05  2013100513        689        1094    674004
# 1       201606010101  2016-01-05  2013102845       1122        1089    281008
# 2       201606010101  2016-01-05  2013102932        733        1103    978800
# 3       201606010101  2016-01-05  2013103416       1127        1043    129005
# 4       201606010101  2016-01-05  2013100107        684         415    270006
# ...              ...         ...         ...        ...         ...       ...
# 379457  202309050912  2023-12-28  2017104873       1154         425    758005
# 379458  202309050912  2023-12-28  2019100653       1138        1158    950006
# 379459  202309050912  2023-12-28  2017106240       1018        1178    258033
# 379460  202309050912  2023-12-28  2018103205       1112         428    629800
# 379461  202309050912  2023-12-28  2017102603       1144        1050    356002
#
#         rank  rank_per_horse  time  nobori  ...  \
# 0          1          0.0625  73.2    38.6  ...
# 1          2          0.1250  73.2    38.4  ...
# 2          3          0.1875  73.3    38.5  ...
# 3          4          0.2500  73.3    38.9  ...
# 4          5          0.3125  73.7    38.6  ...
# ...      ...             ...   ...     ...  ...
# 379457    12          0.7500  69.5    33.6  ...
# 379458    13          0.8125  69.5    34.2  ...
# 379459    14          0.8750  69.6    34.5  ...
# 379460    15          0.9375  69.8    34.9  ...
# 379461    16          1.0000  70.4    34.4  ...
#
#         win_mean_10races_per_weather_relative  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 379457                              -1.437777
# 379458                              -0.444167
# 379459                              -0.642889
# 379460                              -0.642889
# 379461                               0.151999
#
#         win_max_10races_per_weather_relative  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 379457                             -2.561738
# 379458                              0.365963
# 379459                              0.365963
# 379460                              0.365963
# 379461                              0.365963
#
#         win_min_10races_per_weather_relative  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 379457                                   NaN
# 379458                                   NaN
# 379459                                   NaN
# 379460                                   NaN
# 379461                                   NaN
#
#         show_mean_10races_per_weather_relative  \
# 0                                     0.675199
# 1                                     0.076500
# 2                                     1.273898
# 3                                     0.076500
# 4                                     0.475633
# ...                                        ...
# 379457                               -0.991184
# 379458                               -1.380550
# 379459                               -0.472029
# 379460                               -0.991184
# 379461                               -0.991184
#
#         show_max_10races_per_weather_relative  \
# 0                                    0.677003
# 1                                    0.677003
# 2                                    0.677003
# 3                                    0.677003
# 4                                    0.677003
# ...                                       ...
# 379457                                    NaN
# 379458                                    NaN
# 379459                                    NaN
# 379460                                    NaN
# 379461                                    NaN
#
#         show_min_10races_per_weather_relative  sire_n_races_relative  \
# 0                                   -0.552771                    NaN
# 1                                   -0.552771                    NaN
# 2                                    1.658312                    NaN
# 3                                   -0.552771                    NaN
# 4                                   -0.552771                    NaN
# ...                                       ...                    ...
# 379457                                    NaN               1.299880
# 379458                                    NaN              -0.532798
# 379459                                    NaN              -0.241709
# 379460                                    NaN              -0.663492
# 379461                                    NaN               2.345427
#
#         sire_n_wins_relative  sire_winrate_relative  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# ...                      ...                    ...
# 379457              1.269922               0.160283
# 379458             -0.616819              -0.501468
# 379459             -0.616819              -0.876060
# 379460             -0.674873              -0.425169
# 379461              2.285860               0.181466
#
#         sire_course_len_diff_relative
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 379457                      -0.807546
# 379458                       0.108645
# 379459                       0.319818
# 379460                       0.055911
# 379461                      -0.262155
#
# [379462 rows x 2680 columns]

# %%
#枠番ごとのタイム
#馬番ごとのタイム
#レースランクごとのタイム
#天気ごとのタイム
#馬場状態ごとのタイム
#性別ごとのタイム
#直線コースごとのタイム

#これらを調べてtimeどのくらい+するか考える

# "target" 列を作成（time を整数型に変換）
df["target"] = df["time"].astype(int)

# 必要な列を選択して、データを整理
df2 = df[["race_type", "course_len", "place", "target", "wakuban","umaban","race_class","weather","ground_state","sex","around"]].dropna().astype(int)

# race_type と course_len の組み合わせ列を作成
df2["race_type_course_len"] = df2["race_type"].astype(str) + "_" + df2["course_len"].astype(str)


# plt.figure(figsize=(20, 5))
# ax = sns.barplot(
#     data=df2_grouped,
#     x="race_type_course_len",
#     y="target",
#     hue="wakuban",  # 枠番ごとに色分け
#     palette="viridis"  # 好みのカラーパレットに変更可能
# )


# plt.title("wakuban_mean_sapporo", fontsize=16)
# plt.xlabel("race_type+course_len", fontsize=12)
# plt.ylabel("target", fontsize=12)
# plt.legend(title="wakuban", fontsize=10)
# plt.show()

# %%
# 札幌競馬場
# 枠番ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 1")  # 札幌競馬場のみを対象
    .groupby(["race_type_course_len", "wakuban"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="wakuban",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_08e88_row0_col0, #T_08e88_row4_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_08e88_row0_col1, #T_08e88_row0_col2, #T_08e88_row0_col4, #T_08e88_row1_col0, #T_08e88_row1_col6, #T_08e88_row1_col7, #T_08e88_row4_col5, #T_08e88_row5_col3, #T_08e88_row6_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_08e88_row0_col3, #T_08e88_row1_col3, #T_08e88_row7_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_08e88_row0_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_08e88_row0_col6 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_08e88_row0_col7 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_08e88_row0_col8, #T_08e88_row2_col2, #T_08e88_row2_col5, #T_08e88_row2_col7, #T_08e88_row4_col1, #T_08e88_row5_col4, #T_08e88_row6_col0, #T_08e88_row6_col3, #T_08e88_row6_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_08e88_row1_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_08e88_row1_col2, #T_08e88_row7_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_08e88_row1_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_08e88_row1_col5, #T_08e88_row6_col5 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_08e88_row1_col8 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_08e88_row2_col0, #T_08e88_row3_col0 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_08e88_row2_col1, #T_08e88_row6_col7 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_08e88_row2_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_08e88_row2_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_08e88_row2_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_08e88_row2_col8 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_08e88_row3_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_08e88_row3_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_08e88_row3_col3, #T_08e88_row4_col3, #T_08e88_row4_col6 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_08e88_row3_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_08e88_row3_col5 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_08e88_row3_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_08e88_row3_col7 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_08e88_row3_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_08e88_row4_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_08e88_row4_col4 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_08e88_row4_col7, #T_08e88_row4_col8 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_08e88_row5_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_08e88_row5_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_08e88_row5_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_08e88_row5_col5, #T_08e88_row7_col8 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_08e88_row5_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_08e88_row5_col7 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_08e88_row5_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_08e88_row6_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_08e88_row6_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_08e88_row6_col4 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_08e88_row7_col0, #T_08e88_row7_col7 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_08e88_row7_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_08e88_row7_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_08e88_row7_col5 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_08e88_row7_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_08e88">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_08e88_level0_col0" class="col_heading level0 col0" >0_1000</th>
#       <th id="T_08e88_level0_col1" class="col_heading level0 col1" >0_1700</th>
#       <th id="T_08e88_level0_col2" class="col_heading level0 col2" >0_2400</th>
#       <th id="T_08e88_level0_col3" class="col_heading level0 col3" >1_1000</th>
#       <th id="T_08e88_level0_col4" class="col_heading level0 col4" >1_1200</th>
#       <th id="T_08e88_level0_col5" class="col_heading level0 col5" >1_1500</th>
#       <th id="T_08e88_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_08e88_level0_col7" class="col_heading level0 col7" >1_2000</th>
#       <th id="T_08e88_level0_col8" class="col_heading level0 col8" >1_2600</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >wakuban</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08e88_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_08e88_row0_col0" class="data row0 col0" >59.76</td>
#       <td id="T_08e88_row0_col1" class="data row0 col1" >107.99</td>
#       <td id="T_08e88_row0_col2" class="data row0 col2" >158.88</td>
#       <td id="T_08e88_row0_col3" class="data row0 col3" >57.00</td>
#       <td id="T_08e88_row0_col4" class="data row0 col4" >69.95</td>
#       <td id="T_08e88_row0_col5" class="data row0 col5" >90.29</td>
#       <td id="T_08e88_row0_col6" class="data row0 col6" >110.39</td>
#       <td id="T_08e88_row0_col7" class="data row0 col7" >122.70</td>
#       <td id="T_08e88_row0_col8" class="data row0 col8" >162.76</td>
#     </tr>
#     <tr>
#       <th id="T_08e88_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_08e88_row1_col0" class="data row1 col0" >60.01</td>
#       <td id="T_08e88_row1_col1" class="data row1 col1" >107.86</td>
#       <td id="T_08e88_row1_col2" class="data row1 col2" >158.00</td>
#       <td id="T_08e88_row1_col3" class="data row1 col3" >57.00</td>
#       <td id="T_08e88_row1_col4" class="data row1 col4" >69.77</td>
#       <td id="T_08e88_row1_col5" class="data row1 col5" >90.40</td>
#       <td id="T_08e88_row1_col6" class="data row1 col6" >110.39</td>
#       <td id="T_08e88_row1_col7" class="data row1 col7" >122.84</td>
#       <td id="T_08e88_row1_col8" class="data row1 col8" >163.21</td>
#     </tr>
#     <tr>
#       <th id="T_08e88_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_08e88_row2_col0" class="data row2 col0" >59.91</td>
#       <td id="T_08e88_row2_col1" class="data row2 col1" >107.89</td>
#       <td id="T_08e88_row2_col2" class="data row2 col2" >156.88</td>
#       <td id="T_08e88_row2_col3" class="data row2 col3" >58.00</td>
#       <td id="T_08e88_row2_col4" class="data row2 col4" >69.94</td>
#       <td id="T_08e88_row2_col5" class="data row2 col5" >90.19</td>
#       <td id="T_08e88_row2_col6" class="data row2 col6" >110.23</td>
#       <td id="T_08e88_row2_col7" class="data row2 col7" >122.55</td>
#       <td id="T_08e88_row2_col8" class="data row2 col8" >163.50</td>
#     </tr>
#     <tr>
#       <th id="T_08e88_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_08e88_row3_col0" class="data row3 col0" >59.91</td>
#       <td id="T_08e88_row3_col1" class="data row3 col1" >107.71</td>
#       <td id="T_08e88_row3_col2" class="data row3 col2" >157.88</td>
#       <td id="T_08e88_row3_col3" class="data row3 col3" >57.50</td>
#       <td id="T_08e88_row3_col4" class="data row3 col4" >69.77</td>
#       <td id="T_08e88_row3_col5" class="data row3 col5" >90.33</td>
#       <td id="T_08e88_row3_col6" class="data row3 col6" >110.15</td>
#       <td id="T_08e88_row3_col7" class="data row3 col7" >122.77</td>
#       <td id="T_08e88_row3_col8" class="data row3 col8" >162.98</td>
#     </tr>
#     <tr>
#       <th id="T_08e88_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_08e88_row4_col0" class="data row4 col0" >59.76</td>
#       <td id="T_08e88_row4_col

# %%
# 枠番ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 5")#東京  
    .groupby(["race_type_course_len", "wakuban"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="wakuban",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_6a79a_row0_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_6a79a_row0_col1 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_6a79a_row0_col2, #T_6a79a_row6_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_6a79a_row0_col3 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_6a79a_row0_col4 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_6a79a_row0_col5, #T_6a79a_row0_col6, #T_6a79a_row0_col7, #T_6a79a_row0_col8, #T_6a79a_row1_col1, #T_6a79a_row2_col2, #T_6a79a_row2_col12, #T_6a79a_row2_col14, #T_6a79a_row3_col4, #T_6a79a_row3_col10, #T_6a79a_row4_col9, #T_6a79a_row5_col10, #T_6a79a_row5_col13, #T_6a79a_row7_col0, #T_6a79a_row7_col3, #T_6a79a_row7_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6a79a_row0_col9 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_6a79a_row0_col10 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_6a79a_row0_col11 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_6a79a_row0_col12 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_6a79a_row0_col13, #T_6a79a_row4_col13, #T_6a79a_row7_col13 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_6a79a_row0_col14 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_6a79a_row1_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_6a79a_row1_col2, #T_6a79a_row3_col2 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_6a79a_row1_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_6a79a_row1_col4 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_6a79a_row1_col5 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_6a79a_row1_col6 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_6a79a_row1_col7 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_6a79a_row1_col8 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_6a79a_row1_col9 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_6a79a_row1_col10 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_6a79a_row1_col11 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_6a79a_row1_col12, #T_6a79a_row1_col13, #T_6a79a_row2_col0, #T_6a79a_row3_col11, #T_6a79a_row3_col14, #T_6a79a_row4_col7, #T_6a79a_row4_col8, #T_6a79a_row4_col10, #T_6a79a_row5_col3, #T_6a79a_row5_col4, #T_6a79a_row6_col5, #T_6a79a_row6_col9, #T_6a79a_row7_col1, #T_6a79a_row7_col2, #T_6a79a_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6a79a_row1_col14 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6a79a_row2_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_6a79a_row2_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_6a79a_row2_col4 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_6a79a_row2_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_6a79a_row2_col6 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_6a79a_row2_col7, #T_6a79a_row5_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_6a79a_row2_col8, #T_6a79a_row3_col8 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_6a79a_row2_col9 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_6a79a_row2_col10, #T_6a79a_row5_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6a79a_row2_col11, #T_6a79a_row3_col0, #T_6a79a_row6_col11 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6a79a_row2_col13, #T_6a79a_row6_col13 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_6a79a_row3_col1, #T_6a79a_row4_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6a79a_row3_col3 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_6a79a_row3_col5 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_6a79a_row3_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_6a79a_row3_col7, #T_6a79a_row7_col12 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_6a79a_row3_col9 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_6a79a_row3_col12 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_6a79a_row3_col13 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_6a79a_row4_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_6a79a_row4_col1 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_6a79a_row4_col3, #T_6a79a_row6_col10 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_6a79a_row4_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_6a79a_row4_col5 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_6a79a_row4_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_6a79a_row4_col11, #T_6a79a_row5_col11 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_6a79a_row4_col12 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_6a79a_row4_col14 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_6a79a_row5_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_6a79a_row5_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_6a79a_row5_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_6a79a_row5_col6 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_6a79a_row5_col7 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_6a79a_row5_col9 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_6a79a_row5_col12 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_6a79a_row5_col14 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_6a79a_row6_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_6a79a_row6_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_6a79a_row6_col3 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_6a79a_row6_col4 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_6a79a_row6_col6 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_6a79a_row6_col7 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_6a79a_row6_col8 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_6a79a_row6_col12 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_6a79a_row6_col14 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_6a79a_row7_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_6a79a_row7_col5 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_6a79a_row7_col7 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_6a79a_row7_col8, #T_6a79a_row7_col14 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_6a79a_row7_col9 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_6a79a_row7_col10 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a79a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_6a79a_level0_col0" class="col_heading level0 col0" >0_1300</th>
#       <th id="T_6a79a_level0_col1" class="col_heading level0 col1" >0_1400</th>
#       <th id="T_6a79a_level0_col2" class="col_heading level0 col2" >0_1600</th>
#       <th id="T_6a79a_level0_col3" class="col_heading level0 col3" >0_2100</th>
#       <th id="T_6a79a_level0_col4" class="col_heading level0 col4" >1_1400</th>
#       <th id="T_6a79a_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_6a79a_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_6a79a_level0_col7" class="col_heading level0 col7" >1_2000</th>
#       <th id="T_6a79a_level0_col8" class="col_heading level0 col8" >1_2300</th>
#       <th id="T_6a79a_level0_col9" class="col_heading level0 col9" >1_2400</th>
#       <th id="T_6a79a_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_6a79a_level0_col11" class="col_heading level0 col11" >1_3400</th>
#       <th id="T_6a79a_level0_col12" class="col_heading level0 col12" >2_3000</th>
#       <th id="T_6a79a_level0_col13" class="col_heading level0 col13" >2_3100</th>
#       <th id="T_6a79a_level0_col14" class="col_heading level0 col14" >2_3110</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >wakuban</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th

# %%
# 枠番ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 6")#中山  
    .groupby(["race_type_course_len", "wakuban"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="wakuban",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_dc3a3_row0_col0 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_dc3a3_row0_col1 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_dc3a3_row0_col2, #T_dc3a3_row0_col9, #T_dc3a3_row1_col1, #T_dc3a3_row1_col4, #T_dc3a3_row1_col6, #T_dc3a3_row1_col7, #T_dc3a3_row1_col8, #T_dc3a3_row1_col16, #T_dc3a3_row2_col0, #T_dc3a3_row2_col11, #T_dc3a3_row2_col12, #T_dc3a3_row2_col17, #T_dc3a3_row3_col3, #T_dc3a3_row4_col14, #T_dc3a3_row5_col6, #T_dc3a3_row5_col10, #T_dc3a3_row5_col13, #T_dc3a3_row6_col15, #T_dc3a3_row7_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dc3a3_row0_col3 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_dc3a3_row0_col4 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_dc3a3_row0_col5 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_dc3a3_row0_col6 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_dc3a3_row0_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_dc3a3_row0_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_dc3a3_row0_col10, #T_dc3a3_row1_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_dc3a3_row0_col11, #T_dc3a3_row0_col15, #T_dc3a3_row0_col16, #T_dc3a3_row1_col3, #T_dc3a3_row2_col3, #T_dc3a3_row2_col4, #T_dc3a3_row2_col13, #T_dc3a3_row3_col6, #T_dc3a3_row3_col9, #T_dc3a3_row3_col12, #T_dc3a3_row4_col10, #T_dc3a3_row5_col5, #T_dc3a3_row5_col7, #T_dc3a3_row5_col8, #T_dc3a3_row6_col0, #T_dc3a3_row6_col1, #T_dc3a3_row6_col2, #T_dc3a3_row6_col17, #T_dc3a3_row7_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dc3a3_row0_col12 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_dc3a3_row0_col13 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_dc3a3_row0_col14 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_dc3a3_row0_col17, #T_dc3a3_row6_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_dc3a3_row1_col0 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_dc3a3_row1_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_dc3a3_row1_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_dc3a3_row1_col9, #T_dc3a3_row3_col0 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_dc3a3_row1_col11 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_dc3a3_row1_col12, #T_dc3a3_row3_col2, #T_dc3a3_row5_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_dc3a3_row1_col13 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_dc3a3_row1_col14, #T_dc3a3_row1_col17 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_dc3a3_row1_col15 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_dc3a3_row2_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_dc3a3_row2_col2, #T_dc3a3_row6_col7 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_dc3a3_row2_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_dc3a3_row2_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_dc3a3_row2_col7 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_dc3a3_row2_col8 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_dc3a3_row2_col9 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_dc3a3_row2_col10 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_dc3a3_row2_col14, #T_dc3a3_row4_col11 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_dc3a3_row2_col15 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_dc3a3_row2_col16 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_dc3a3_row3_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_dc3a3_row3_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_dc3a3_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_dc3a3_row3_col7, #T_dc3a3_row4_col7 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_dc3a3_row3_col8 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_dc3a3_row3_col10 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_dc3a3_row3_col11 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_dc3a3_row3_col13 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_dc3a3_row3_col14, #T_dc3a3_row4_col9, #T_dc3a3_row4_col12 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_dc3a3_row3_col15 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_dc3a3_row3_col16 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_dc3a3_row3_col17 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_dc3a3_row4_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_dc3a3_row4_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_dc3a3_row4_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_dc3a3_row4_col3 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_dc3a3_row4_col4 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_dc3a3_row4_col5 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_dc3a3_row4_col6 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_dc3a3_row4_col8 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_dc3a3_row4_col13 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_dc3a3_row4_col15 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_dc3a3_row4_col16 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_dc3a3_row4_col17 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_dc3a3_row5_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_dc3a3_row5_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_dc3a3_row5_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_dc3a3_row5_col4, #T_dc3a3_row7_col17 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_dc3a3_row5_col9 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_dc3a3_row5_col11, #T_dc3a3_row6_col10 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_dc3a3_row5_col12 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_dc3a3_row5_col14 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_dc3a3_row5_col15 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_dc3a3_row5_col16 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_dc3a3_row5_col17 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_dc3a3_row6_col3, #T_dc3a3_row7_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_dc3a3_row6_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_dc3a3_row6_col5, #T_dc3a3_row6_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_dc3a3_row6_col9 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_dc3a3_row6_col11 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_dc3a3_row6_col12, #T_dc3a3_row7_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_dc3a3_row6_col13 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_dc3a3_row6_col14 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_dc3a3_row6_col16 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_dc3a3_row7_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_dc3a3_row7_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_dc3a3_row7_col3 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_dc3a3_row7_col4 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_dc3a3_row7_col6 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_dc3a3_row7_col7 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_dc3a3_row7_col8 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_dc3a3_row7_col9 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_dc3a3_row7_col11 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_dc3a3_row7_col12 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_dc3a3_row7_col13 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_dc3a3_row7_col15 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_dc3a3_row7_col16 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# </style>
# <table id="T_dc3a3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_dc3a3_level0_col0" class="col_heading level0 col0" >0_1200</th>
#       <th id="T_dc3a3_level0_col1" class="col_heading level0 col1" >0_1800</th>
#       <th id="T_dc3a3_level0_col2" class="col_heading level0 col2" >0_2400</th>
#       <th id="T_dc3a3_level0_col3" class="col_heading level0 col3" >0_2500</th>

# %%
# 馬番ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 5")#東京  
    .groupby(["race_type_course_len", "umaban"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="umaban",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_ea220_row0_col0, #T_ea220_row8_col14 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_ea220_row0_col1, #T_ea220_row2_col5, #T_ea220_row3_col1, #T_ea220_row4_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_ea220_row0_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_ea220_row0_col3 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_ea220_row0_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_ea220_row0_col5, #T_ea220_row1_col6, #T_ea220_row4_col8 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_ea220_row0_col6, #T_ea220_row2_col9, #T_ea220_row10_col7 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_ea220_row0_col7, #T_ea220_row0_col8, #T_ea220_row1_col1, #T_ea220_row2_col6, #T_ea220_row2_col12, #T_ea220_row3_col5, #T_ea220_row4_col2, #T_ea220_row6_col3, #T_ea220_row7_col14, #T_ea220_row12_col13, #T_ea220_row14_col10, #T_ea220_row14_col11, #T_ea220_row15_col0, #T_ea220_row16_col4, #T_ea220_row16_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ea220_row0_col9, #T_ea220_row5_col2, #T_ea220_row10_col12, #T_ea220_row15_col4 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_ea220_row0_col10, #T_ea220_row3_col10 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_ea220_row0_col11, #T_ea220_row2_col11, #T_ea220_row3_col11, #T_ea220_row5_col11, #T_ea220_row6_col11 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_ea220_row0_col12, #T_ea220_row17_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_ea220_row0_col13, #T_ea220_row7_col13 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_ea220_row0_col14, #T_ea220_row1_col10, #T_ea220_row5_col10, #T_ea220_row12_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_ea220_row1_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ea220_row1_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_ea220_row1_col3, #T_ea220_row2_col3 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_ea220_row1_col4 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_ea220_row1_col5, #T_ea220_row12_col8 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_ea220_row1_col7, #T_ea220_row5_col7 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_ea220_row1_col8, #T_ea220_row10_col8, #T_ea220_row11_col8 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_ea220_row1_col9 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_ea220_row1_col11, #T_ea220_row4_col11, #T_ea220_row10_col11, #T_ea220_row12_col11 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ea220_row1_col12 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ea220_row1_col13, #T_ea220_row9_col13 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ea220_row1_col14, #T_ea220_row7_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_ea220_row2_col0, #T_ea220_row15_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ea220_row2_col1, #T_ea220_row8_col7, #T_ea220_row10_col6 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_ea220_row2_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_ea220_row2_col4 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_ea220_row2_col7, #T_ea220_row10_col3, #T_ea220_row17_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_ea220_row2_col8, #T_ea220_row5_col9 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_ea220_row2_col10, #T_ea220_row6_col10, #T_ea220_row7_col5, #T_ea220_row11_col10 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_ea220_row2_col13 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ea220_row2_col14 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_ea220_row3_col0, #T_ea220_row9_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_ea220_row3_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_ea220_row3_col3, #T_ea220_row4_col5 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_ea220_row3_col4, #T_ea220_row6_col2, #T_ea220_row14_col4 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_ea220_row3_col6 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_ea220_row3_col7, #T_ea220_row4_col9, #T_ea220_row6_col7, #T_ea220_row14_col9 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_ea220_row3_col8 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_ea220_row3_col9, #T_ea220_row7_col7, #T_ea220_row9_col8 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_ea220_row3_col12, #T_ea220_row13_col9 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_ea220_row3_col13, #T_ea220_row8_col13 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_ea220_row3_col14, #T_ea220_row4_col6 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_ea220_row4_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ea220_row4_col3, #T_ea220_row4_col12, #T_ea220_row7_col0, #T_ea220_row9_col4, #T_ea220_row11_col12, #T_ea220_row11_col13, #T_ea220_row13_col1, #T_ea220_row13_col5, #T_ea220_row13_col8, #T_ea220_row13_col14, #T_ea220_row15_col2, #T_ea220_row15_col11, #T_ea220_row16_col10, #T_ea220_row17_col6, #T_ea220_row17_col7, #T_ea220_row17_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ea220_row4_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ea220_row4_col7, #T_ea220_row14_col7, #T_ea220_row15_col6 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_ea220_row4_col10, #T_ea220_row6_col14 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_ea220_row4_col13, #T_ea220_row10_col13 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_ea220_row4_col14 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ea220_row5_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ea220_row5_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ea220_row5_col3, #T_ea220_row11_col5 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_ea220_row5_col4, #T_ea220_row5_col12 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_ea220_row5_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_ea220_row5_col6 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_ea220_row5_col8 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_ea220_row5_col13 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_ea220_row5_col14 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_ea220_row6_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_ea220_row6_col1, #T_ea220_row14_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_ea220_row6_col4, #T_ea220_row8_col4, #T_ea220_row12_col0, #T_ea220_row16_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_ea220_row6_col5, #T_ea220_row9_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_ea220_row6_col6 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_ea220_row6_col8, #T_ea220_row7_col8 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_ea220_row6_col9 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_ea220_row6_col12, #T_ea220_row9_col6 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_ea220_row6_col13, #T_ea220_row11_col1, #T_ea220_row13_col2, #T_ea220_row15_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_ea220_row7_col1, #T_ea220_row10_col9, #T_ea220_row10_col10, #T_ea220_row12_col10 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_ea220_row7_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_ea220_row7_col4, #T_ea220_row9_col7, #T_ea220_row14_col6, #T_ea220_row15_col9 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_ea220_row7_col6 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_ea220_row7_col9 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_ea220_row7_col10, #T_ea220_row10_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_ea220_row7_col11 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ea220_row7_col12, #T_ea220_row8_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_ea220_row8_col0, #T_ea220_row8_col11, #T_ea220_row11_col11 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_ea220_row8_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_ea220_row8_col3 {
#   background-color: #88abfd;
#   c

# %%
# レースランクごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 6")#中山
    .groupby(["race_type_course_len", "umaban"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="umaban",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_3def5_row0_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_3def5_row0_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_3def5_row0_col2, #T_3def5_row3_col16, #T_3def5_row7_col10, #T_3def5_row7_col12, #T_3def5_row9_col17, #T_3def5_row11_col4, #T_3def5_row11_col14, #T_3def5_row11_col15, #T_3def5_row12_col13, #T_3def5_row13_col11, #T_3def5_row14_col7, #T_3def5_row14_col8, #T_3def5_row15_col0, #T_3def5_row15_col1, #T_3def5_row15_col3, #T_3def5_row15_col5, #T_3def5_row15_col6, #T_3def5_row15_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3def5_row0_col3, #T_3def5_row3_col3, #T_3def5_row4_col8, #T_3def5_row8_col17, #T_3def5_row13_col3 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_3def5_row0_col4, #T_3def5_row0_col17, #T_3def5_row2_col13, #T_3def5_row3_col5, #T_3def5_row4_col6, #T_3def5_row8_col7, #T_3def5_row9_col1, #T_3def5_row10_col7, #T_3def5_row10_col12, #T_3def5_row11_col0, #T_3def5_row11_col9, #T_3def5_row11_col13, #T_3def5_row12_col11, #T_3def5_row12_col14, #T_3def5_row12_col15, #T_3def5_row14_col3, #T_3def5_row15_col2, #T_3def5_row15_col7, #T_3def5_row15_col10, #T_3def5_row15_col16, #T_3def5_row17_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3def5_row0_col5, #T_3def5_row7_col9 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_3def5_row0_col6, #T_3def5_row0_col15 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_3def5_row0_col7, #T_3def5_row6_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_3def5_row0_col8, #T_3def5_row7_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_3def5_row0_col9, #T_3def5_row12_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_3def5_row0_col10 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_3def5_row0_col11 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_3def5_row0_col12, #T_3def5_row13_col15 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_3def5_row0_col13, #T_3def5_row9_col5 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_3def5_row0_col14, #T_3def5_row1_col13, #T_3def5_row3_col14, #T_3def5_row8_col15, #T_3def5_row13_col13 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_3def5_row0_col16, #T_3def5_row2_col6, #T_3def5_row2_col16 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_3def5_row1_col0, #T_3def5_row1_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_3def5_row1_col1, #T_3def5_row10_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_3def5_row1_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_3def5_row1_col3, #T_3def5_row2_col7, #T_3def5_row6_col3, #T_3def5_row7_col7, #T_3def5_row9_col16 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_3def5_row1_col4 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_3def5_row1_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_3def5_row1_col7, #T_3def5_row4_col7, #T_3def5_row5_col7, #T_3def5_row7_col4, #T_3def5_row11_col7, #T_3def5_row12_col3, #T_3def5_row12_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_3def5_row1_col8 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_3def5_row1_col9, #T_3def5_row3_col6, #T_3def5_row3_col13, #T_3def5_row5_col9, #T_3def5_row5_col13, #T_3def5_row8_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_3def5_row1_col10 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_3def5_row1_col11, #T_3def5_row2_col1, #T_3def5_row3_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_3def5_row1_col12, #T_3def5_row8_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_3def5_row1_col14, #T_3def5_row9_col2, #T_3def5_row9_col14, #T_3def5_row12_col12, #T_3def5_row13_col14 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_3def5_row1_col15, #T_3def5_row5_col12, #T_3def5_row7_col14 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_3def5_row1_col16 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_3def5_row1_col17 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_3def5_row2_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_3def5_row2_col2, #T_3def5_row2_col10 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_3def5_row2_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_3def5_row2_col4, #T_3def5_row4_col13 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_3def5_row2_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_3def5_row2_col8, #T_3def5_row6_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_3def5_row2_col9 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_3def5_row2_col11 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_3def5_row2_col12, #T_3def5_row13_col12 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_3def5_row2_col14, #T_3def5_row4_col14, #T_3def5_row6_col13, #T_3def5_row6_col15 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_3def5_row2_col15, #T_3def5_row14_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_3def5_row2_col17, #T_3def5_row3_col8, #T_3def5_row12_col8 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_3def5_row3_col0, #T_3def5_row9_col13, #T_3def5_row13_col9 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_3def5_row3_col1, #T_3def5_row3_col15, #T_3def5_row4_col17, #T_3def5_row8_col14 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_3def5_row3_col4, #T_3def5_row3_col17 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_3def5_row3_col7, #T_3def5_row9_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_3def5_row3_col9, #T_3def5_row5_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_3def5_row3_col10, #T_3def5_row6_col10 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_3def5_row3_col11, #T_3def5_row10_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_3def5_row3_col12 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_3def5_row4_col0, #T_3def5_row4_col15 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_3def5_row4_col1, #T_3def5_row7_col17 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_3def5_row4_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_3def5_row4_col3, #T_3def5_row10_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_3def5_row4_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_3def5_row4_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_3def5_row4_col9 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_3def5_row4_col10, #T_3def5_row6_col14 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_3def5_row4_col11, #T_3def5_row14_col10 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_3def5_row4_col12, #T_3def5_row9_col12 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_3def5_row4_col16, #T_3def5_row10_col11 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_3def5_row5_col0, #T_3def5_row10_col14, #T_3def5_row10_col15 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_3def5_row5_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_3def5_row5_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_3def5_row5_col3, #T_3def5_row10_col3, #T_3def5_row12_col16 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_3def5_row5_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_3def5_row5_col5, #T_3def5_row12_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_3def5_row5_col8 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_3def5_row5_col10 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_3def5_row5_col11 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_3def5_row5_col14 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_3def5_row5_col15, #T_3def5_row9_col15 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_3def5_row5_col16 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_3def5_row5_col17 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_3def5_row6_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_3def5_row6_col2, #T_3def5_row7_col15 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_3def5_row6_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_3def5_row6_col5, #T_3def5_

# %%
# レースランクごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 5")#東京  
    .groupby(["race_type_course_len", "race_class"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="race_class",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_8daef_row0_col0, #T_8daef_row0_col1, #T_8daef_row0_col2, #T_8daef_row0_col4, #T_8daef_row0_col5, #T_8daef_row0_col6, #T_8daef_row0_col7, #T_8daef_row1_col3, #T_8daef_row1_col8, #T_8daef_row1_col9, #T_8daef_row3_col10, #T_8daef_row7_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8daef_row0_col3, #T_8daef_row0_col8, #T_8daef_row0_col9, #T_8daef_row0_col10, #T_8daef_row0_col14, #T_8daef_row1_col10, #T_8daef_row1_col14, #T_8daef_row2_col10, #T_8daef_row2_col14, #T_8daef_row3_col8, #T_8daef_row3_col14, #T_8daef_row4_col8, #T_8daef_row4_col10, #T_8daef_row4_col14, #T_8daef_row5_col8, #T_8daef_row5_col10, #T_8daef_row6_col0, #T_8daef_row6_col3, #T_8daef_row6_col4, #T_8daef_row6_col7, #T_8daef_row6_col8, #T_8daef_row6_col9, #T_8daef_row6_col10, #T_8daef_row7_col0, #T_8daef_row7_col1, #T_8daef_row7_col2, #T_8daef_row7_col3, #T_8daef_row7_col8, #T_8daef_row8_col0, #T_8daef_row8_col1, #T_8daef_row8_col3, #T_8daef_row8_col4, #T_8daef_row8_col6, #T_8daef_row8_col8, #T_8daef_row8_col10, #T_8daef_row8_col14 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_8daef_row0_col11, #T_8daef_row0_col12, #T_8daef_row0_col13, #T_8daef_row1_col11, #T_8daef_row1_col12, #T_8daef_row1_col13, #T_8daef_row2_col8, #T_8daef_row2_col11, #T_8daef_row2_col12, #T_8daef_row2_col13, #T_8daef_row3_col11, #T_8daef_row3_col12, #T_8daef_row3_col13, #T_8daef_row4_col0, #T_8daef_row4_col11, #T_8daef_row4_col12, #T_8daef_row4_col13, #T_8daef_row5_col3, #T_8daef_row5_col11, #T_8daef_row5_col12, #T_8daef_row5_col13, #T_8daef_row5_col14, #T_8daef_row6_col1, #T_8daef_row6_col11, #T_8daef_row6_col12, #T_8daef_row6_col13, #T_8daef_row7_col4, #T_8daef_row7_col6, #T_8daef_row7_col10, #T_8daef_row7_col11, #T_8daef_row7_col12, #T_8daef_row7_col13, #T_8daef_row8_col2, #T_8daef_row8_col5, #T_8daef_row8_col7, #T_8daef_row8_col9, #T_8daef_row8_col11, #T_8daef_row8_col12, #T_8daef_row8_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8daef_row1_col0 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_8daef_row1_col1 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_8daef_row1_col2 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_8daef_row1_col4 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_8daef_row1_col5 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_8daef_row1_col6 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_8daef_row1_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_8daef_row2_col0, #T_8daef_row3_col2, #T_8daef_row7_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_8daef_row2_col1, #T_8daef_row2_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_8daef_row2_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_8daef_row2_col4 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_8daef_row2_col5, #T_8daef_row5_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_8daef_row2_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_8daef_row2_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_8daef_row2_col9 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_8daef_row3_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_8daef_row3_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_8daef_row3_col3 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_8daef_row3_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_8daef_row3_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_8daef_row3_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_8daef_row3_col7 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_8daef_row3_col9 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_8daef_row4_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_8daef_row4_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_8daef_row4_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_8daef_row4_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_8daef_row4_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_8daef_row4_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_8daef_row4_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_8daef_row4_col9 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_8daef_row5_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_8daef_row5_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_8daef_row5_col2, #T_8daef_row6_col14 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_8daef_row5_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_8daef_row5_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_8daef_row5_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_8daef_row5_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_8daef_row6_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_8daef_row6_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_8daef_row6_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_8daef_row7_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_8daef_row7_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8daef">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_8daef_level0_col0" class="col_heading level0 col0" >0_1300</th>
#       <th id="T_8daef_level0_col1" class="col_heading level0 col1" >0_1400</th>
#       <th id="T_8daef_level0_col2" class="col_heading level0 col2" >0_1600</th>
#       <th id="T_8daef_level0_col3" class="col_heading level0 col3" >0_2100</th>
#       <th id="T_8daef_level0_col4" class="col_heading level0 col4" >1_1400</th>
#       <th id="T_8daef_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_8daef_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_8daef_level0_col7" class="col_heading level0 col7" >1_2000</th>
#       <th id="T_8daef_level0_col8" class="col_heading level0 col8" >1_2300</th>
#       <th id="T_8daef_level0_col9" class="col_heading level0 col9" >1_2400</th>
#       <th id="T_8daef_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_8daef_level0_col11" class="col_heading level0 col11" >1_3400</th>
#       <th id="T_8daef_level0_col12" class="col_heading level0 col12" >2_3000</th>
#       <th id="T_8daef_level0_col13" class="col_heading level0 col13" >2_3100</th>
#       <th id="T_8daef_level0_col14" class="col_heading level0 col14" >2_3110</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >race_class</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8daef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8daef_row0_col0" class="data row0 col0" >81.23</td>
#       <td id="T_8daef_row0_col1" class="data row0 col1" >88.31</td>
#       <td id="T_8daef_row0_col2" class="data row0 col2" >101.50</td>
#       <td id="T_8daef_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_8daef_row0_col4" class="data row0 col4" >84.28</td>
#       <td id="T_8daef_row0_col5" class="data row0 col5" >97.33</td>
#       <td id="T_8daef_row0_col6" class="data row0 col6" >110.70</td>
#       <td id="T_8daef_row0_col7" class="data row0 col7" >123.92</td>
#       <td id="T_8daef_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_8daef_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_8daef_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_8daef_row0_col11" class="d

# %%
# 枠番ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 6")#中山 
    .groupby(["race_type_course_len", "race_class"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="race_class",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_793b2_row0_col0, #T_793b2_row0_col1, #T_793b2_row0_col4, #T_793b2_row0_col5, #T_793b2_row0_col6, #T_793b2_row0_col8, #T_793b2_row1_col9, #T_793b2_row2_col2, #T_793b2_row2_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_793b2_row0_col2, #T_793b2_row0_col9, #T_793b2_row0_col10, #T_793b2_row1_col2, #T_793b2_row1_col10, #T_793b2_row4_col2, #T_793b2_row5_col9, #T_793b2_row6_col2, #T_793b2_row6_col9, #T_793b2_row6_col10, #T_793b2_row7_col0, #T_793b2_row7_col1, #T_793b2_row7_col2, #T_793b2_row7_col4, #T_793b2_row8_col0, #T_793b2_row8_col1, #T_793b2_row8_col2, #T_793b2_row8_col5, #T_793b2_row8_col6, #T_793b2_row8_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_793b2_row0_col3, #T_793b2_row0_col7, #T_793b2_row0_col11, #T_793b2_row0_col12, #T_793b2_row0_col13, #T_793b2_row0_col14, #T_793b2_row0_col15, #T_793b2_row0_col16, #T_793b2_row0_col17, #T_793b2_row1_col3, #T_793b2_row1_col7, #T_793b2_row1_col11, #T_793b2_row1_col12, #T_793b2_row1_col13, #T_793b2_row1_col14, #T_793b2_row1_col15, #T_793b2_row1_col16, #T_793b2_row1_col17, #T_793b2_row2_col3, #T_793b2_row2_col7, #T_793b2_row2_col11, #T_793b2_row2_col12, #T_793b2_row2_col13, #T_793b2_row2_col14, #T_793b2_row2_col15, #T_793b2_row2_col16, #T_793b2_row2_col17, #T_793b2_row3_col2, #T_793b2_row3_col3, #T_793b2_row3_col7, #T_793b2_row3_col11, #T_793b2_row3_col12, #T_793b2_row3_col13, #T_793b2_row3_col14, #T_793b2_row3_col15, #T_793b2_row3_col16, #T_793b2_row3_col17, #T_793b2_row4_col3, #T_793b2_row4_col7, #T_793b2_row4_col11, #T_793b2_row4_col12, #T_793b2_row4_col13, #T_793b2_row4_col14, #T_793b2_row4_col15, #T_793b2_row4_col16, #T_793b2_row4_col17, #T_793b2_row5_col3, #T_793b2_row5_col7, #T_793b2_row5_col11, #T_793b2_row5_col12, #T_793b2_row5_col13, #T_793b2_row5_col14, #T_793b2_row5_col15, #T_793b2_row5_col16, #T_793b2_row5_col17, #T_793b2_row6_col0, #T_793b2_row6_col1, #T_793b2_row6_col3, #T_793b2_row6_col5, #T_793b2_row6_col7, #T_793b2_row6_col11, #T_793b2_row6_col12, #T_793b2_row6_col13, #T_793b2_row6_col14, #T_793b2_row6_col15, #T_793b2_row6_col16, #T_793b2_row6_col17, #T_793b2_row7_col3, #T_793b2_row7_col6, #T_793b2_row7_col7, #T_793b2_row7_col8, #T_793b2_row7_col9, #T_793b2_row7_col11, #T_793b2_row7_col12, #T_793b2_row7_col13, #T_793b2_row7_col14, #T_793b2_row7_col15, #T_793b2_row7_col16, #T_793b2_row7_col17, #T_793b2_row8_col3, #T_793b2_row8_col4, #T_793b2_row8_col7, #T_793b2_row8_col10, #T_793b2_row8_col11, #T_793b2_row8_col12, #T_793b2_row8_col13, #T_793b2_row8_col14, #T_793b2_row8_col15, #T_793b2_row8_col16, #T_793b2_row8_col17 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_793b2_row1_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_793b2_row1_col1 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_793b2_row1_col4, #T_793b2_row4_col10 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_793b2_row1_col5 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_793b2_row1_col6 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_793b2_row1_col8 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_793b2_row2_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_793b2_row2_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_793b2_row2_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_793b2_row2_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_793b2_row2_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_793b2_row2_col8, #T_793b2_row3_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_793b2_row2_col9 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_793b2_row3_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_793b2_row3_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_793b2_row3_col5 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_793b2_row3_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_793b2_row3_col8, #T_793b2_row5_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_793b2_row3_col9 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_793b2_row3_col10 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_793b2_row4_col0, #T_793b2_row5_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_793b2_row4_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_793b2_row4_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_793b2_row4_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_793b2_row4_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_793b2_row4_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_793b2_row4_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_793b2_row5_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_793b2_row5_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_793b2_row5_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_793b2_row5_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_793b2_row5_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_793b2_row5_col10 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_793b2_row6_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_793b2_row6_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_793b2_row6_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_793b2_row7_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_793b2_row7_col10 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_793b2_row8_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_793b2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_793b2_level0_col0" class="col_heading level0 col0" >0_1200</th>
#       <th id="T_793b2_level0_col1" class="col_heading level0 col1" >0_1800</th>
#       <th id="T_793b2_level0_col2" class="col_heading level0 col2" >0_2400</th>
#       <th id="T_793b2_level0_col3" class="col_heading level0 col3" >0_2500</th>
#       <th id="T_793b2_level0_col4" class="col_heading level0 col4" >1_1200</th>
#       <th id="T_793b2_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_793b2_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_793b2_level0_col7" class="col_heading level0 col7" >1_2</th>
#       <th id="T_793b2_level0_col8" class="col_heading level0 col8" >1_2000</th>
#       <th id="T_793b2_level0_col9" class="col_heading level0 col9" >1_2200</th>
#       <th id="T_793b2_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_793b2_level0_col11" class="col_heading level0 col11" >2_2880</th>
#       <th id="T_793b2_level0_col12" class="col_heading level0 col12" >2_3200</th>
#       <th id="T_793b2_level0_col13" class="col_heading level0 col13" >2_3210</th>
#       <th id="T_793b2_level0_col14" class="col_heading level0 col14" >2_3350</th>
#       <th id="T_793b2_level0_col15" class="col_heading level0 col15" >2_3570</th>
#       <th id="T_793b2_level0_col16" class="col_heading level0 col16" >2_4100</th>
#       <th id="T_793b2_level0_col17" class="col_heading level0 col17" >2_4250</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >race_class</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_793b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_793b2_row0_col0" class="data row

# %%
# 天気ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 5")#東京  
    .groupby(["race_type_course_len", "weather"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="weather",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_9491e_row0_col0, #T_9491e_row0_col1, #T_9491e_row0_col2, #T_9491e_row0_col3, #T_9491e_row0_col4, #T_9491e_row0_col5, #T_9491e_row1_col7, #T_9491e_row1_col11, #T_9491e_row1_col12, #T_9491e_row1_col14, #T_9491e_row2_col6, #T_9491e_row2_col8, #T_9491e_row2_col9, #T_9491e_row2_col10, #T_9491e_row2_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9491e_row0_col6, #T_9491e_row1_col0, #T_9491e_row1_col1, #T_9491e_row1_col2, #T_9491e_row1_col3, #T_9491e_row1_col8, #T_9491e_row1_col10, #T_9491e_row1_col13, #T_9491e_row2_col11, #T_9491e_row2_col14, #T_9491e_row3_col4, #T_9491e_row3_col5, #T_9491e_row3_col7, #T_9491e_row3_col9, #T_9491e_row3_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9491e_row0_col7 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_9491e_row0_col8 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_9491e_row0_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_9491e_row0_col10, #T_9491e_row0_col11, #T_9491e_row0_col13, #T_9491e_row0_col14, #T_9491e_row3_col8, #T_9491e_row3_col10, #T_9491e_row3_col11, #T_9491e_row3_col13, #T_9491e_row3_col14 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9491e_row0_col12 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_9491e_row1_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_9491e_row1_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_9491e_row1_col6, #T_9491e_row2_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_9491e_row1_col9 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_9491e_row2_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_9491e_row2_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_9491e_row2_col2 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_9491e_row2_col3 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_9491e_row2_col4 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_9491e_row2_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_9491e_row2_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_9491e_row3_col0 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_9491e_row3_col1 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_9491e_row3_col2 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_9491e_row3_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_9491e_row3_col6 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9491e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_9491e_level0_col0" class="col_heading level0 col0" >0_1300</th>
#       <th id="T_9491e_level0_col1" class="col_heading level0 col1" >0_1400</th>
#       <th id="T_9491e_level0_col2" class="col_heading level0 col2" >0_1600</th>
#       <th id="T_9491e_level0_col3" class="col_heading level0 col3" >0_2100</th>
#       <th id="T_9491e_level0_col4" class="col_heading level0 col4" >1_1400</th>
#       <th id="T_9491e_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_9491e_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_9491e_level0_col7" class="col_heading level0 col7" >1_2000</th>
#       <th id="T_9491e_level0_col8" class="col_heading level0 col8" >1_2300</th>
#       <th id="T_9491e_level0_col9" class="col_heading level0 col9" >1_2400</th>
#       <th id="T_9491e_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_9491e_level0_col11" class="col_heading level0 col11" >1_3400</th>
#       <th id="T_9491e_level0_col12" class="col_heading level0 col12" >2_3000</th>
#       <th id="T_9491e_level0_col13" class="col_heading level0 col13" >2_3100</th>
#       <th id="T_9491e_level0_col14" class="col_heading level0 col14" >2_3110</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >weather</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9491e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9491e_row0_col0" class="data row0 col0" >78.53</td>
#       <td id="T_9491e_row0_col1" class="data row0 col1" >85.09</td>
#       <td id="T_9491e_row0_col2" class="data row0 col2" >97.50</td>
#       <td id="T_9491e_row0_col3" class="data row0 col3" >131.66</td>
#       <td id="T_9491e_row0_col4" class="data row0 col4" >81.76</td>
#       <td id="T_9491e_row0_col5" class="data row0 col5" >94.61</td>
#       <td id="T_9491e_row0_col6" class="data row0 col6" >109.91</td>
#       <td id="T_9491e_row0_col7" class="data row0 col7" >122.44</td>
#       <td id="T_9491e_row0_col8" class="data row0 col8" >140.15</td>
#       <td id="T_9491e_row0_col9" class="data row0 col9" >147.29</td>
#       <td id="T_9491e_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_9491e_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_9491e_row0_col12" class="data row0 col12" >213.38</td>
#       <td id="T_9491e_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_9491e_row0_col14" class="data row0 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9491e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9491e_row1_col0" class="data row1 col0" >80.06</td>
#       <td id="T_9491e_row1_col1" class="data row1 col1" >86.12</td>
#       <td id="T_9491e_row1_col2" class="data row1 col2" >98.93</td>
#       <td id="T_9491e_row1_col3" class="data row1 col3" >133.47</td>
#       <td id="T_9491e_row1_col4" class="data row1 col4" >82.20</td>
#       <td id="T_9491e_row1_col5" class="data row1 col5" >94.93</td>
#       <td id="T_9491e_row1_col6" class="data row1 col6" >108.31</td>
#       <td id="T_9491e_row1_col7" class="data row1 col7" >120.80</td>
#       <td id="T_9491e_row1_col8" class="data row1 col8" >141.35</td>
#       <td id="T_9491e_row1_col9" class="data row1 col9" >146.58</td>
#       <td id="T_9491e_row1_col10" class="data row1 col10" >152.04</td>
#       <td id="T_9491e_row1_col11" class="data row1 col11" >211.56</td>
#       <td id="T_9491e_row1_col12" class="data row1 col12" >208.09</td>
#       <td id="T_9491e_row1_col13" class="data row1 col13" >212.58</td>
#       <td id="T_9491e_row1_col14" class="data row1 col14" >207.92</td>
#     </tr>
#     <tr>
#       <th id="T_9491e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9491e_row2_col0" class="data row2 col0" >79.58</td>
#       <td id="T_9491e_row2_col1" class="data row2 col1" >85.71</td>
#       <td id="T_9491e_row2_col2" class="data row2 col2" >98.74</td>
#       <td id="T_9491e_row2_col3" class="data row2 col3" >132.86</td>
#       <td id="T_9491e_row2_col4" class="data row2 col4" >82.34</td>
#       <td id="T_9491e_row2_col5" class="data row2 col5" >94.94</td>
#       <td id="T_9491e_row2_col6" class="data row2 col6" >107.98</td>
#       <td id="T_9491e_row2_col7" class="data row2 col7" >121.28</td>
#       <td id="T_9491e_row2_col8" class="data row2 col8" >140.08</td>
#       <td id="T_9491e_row2_col9" class="data row2 col9" >146.17</td>
#       <td id="T_9491e_row2_col10" class="data row2 col10" >151.31</td>
#       <td id="T_9491e_row2_col11" class="data row2 col11" >212.20</td>
#       <td id="T_9491e_row2_col12" class="data row2 col12" >208.63</td>
#       <td id="T_9491e_row2_col13" class="data row2 col13" >208.18</td>
#       <td id="T_9491e_row2_col14" class="data row2 col14" >210.89</td>
#     </tr>
#     <tr>
#       <th id="T_9491e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9491e_row3_col0" class="data row3 col0" >79.70</td>
#       <

# %%
# 天気ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 6")#東京  
    .groupby(["race_type_course_len", "weather"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="weather",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_3a979_row0_col0, #T_3a979_row0_col1, #T_3a979_row0_col12, #T_3a979_row0_col16, #T_3a979_row1_col4, #T_3a979_row1_col5, #T_3a979_row1_col6, #T_3a979_row1_col8, #T_3a979_row1_col9, #T_3a979_row1_col10, #T_3a979_row1_col11, #T_3a979_row1_col12, #T_3a979_row1_col14, #T_3a979_row1_col16, #T_3a979_row2_col3, #T_3a979_row2_col7, #T_3a979_row2_col12, #T_3a979_row2_col13, #T_3a979_row2_col15, #T_3a979_row2_col16, #T_3a979_row2_col17, #T_3a979_row3_col12, #T_3a979_row3_col16, #T_3a979_row4_col12, #T_3a979_row4_col16, #T_3a979_row5_col2, #T_3a979_row5_col12, #T_3a979_row5_col16 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3a979_row0_col2, #T_3a979_row0_col3, #T_3a979_row0_col17, #T_3a979_row1_col13, #T_3a979_row3_col3, #T_3a979_row3_col7, #T_3a979_row3_col13, #T_3a979_row3_col15, #T_3a979_row4_col1, #T_3a979_row4_col3, #T_3a979_row4_col4, #T_3a979_row4_col5, #T_3a979_row4_col6, #T_3a979_row4_col7, #T_3a979_row4_col9, #T_3a979_row4_col10, #T_3a979_row4_col13, #T_3a979_row4_col14, #T_3a979_row4_col15, #T_3a979_row4_col17, #T_3a979_row5_col0, #T_3a979_row5_col3, #T_3a979_row5_col5, #T_3a979_row5_col7, #T_3a979_row5_col8, #T_3a979_row5_col9, #T_3a979_row5_col10, #T_3a979_row5_col11, #T_3a979_row5_col13, #T_3a979_row5_col14, #T_3a979_row5_col15, #T_3a979_row5_col17 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_3a979_row0_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_3a979_row0_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_3a979_row0_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_3a979_row0_col7, #T_3a979_row0_col10, #T_3a979_row0_col13, #T_3a979_row0_col15, #T_3a979_row1_col3, #T_3a979_row3_col0, #T_3a979_row3_col4, #T_3a979_row3_col5, #T_3a979_row3_col6, #T_3a979_row3_col8, #T_3a979_row3_col9, #T_3a979_row3_col11, #T_3a979_row3_col14, #T_3a979_row3_col17, #T_3a979_row4_col2, #T_3a979_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3a979_row0_col8 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_3a979_row0_col9 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_3a979_row0_col11 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_3a979_row0_col14 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_3a979_row1_col0 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_3a979_row1_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_3a979_row1_col2 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_3a979_row1_col7, #T_3a979_row2_col10 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_3a979_row1_col15, #T_3a979_row2_col11 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_3a979_row1_col17 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_3a979_row2_col0 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_3a979_row2_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_3a979_row2_col2 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_3a979_row2_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_3a979_row2_col5 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_3a979_row2_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_3a979_row2_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_3a979_row2_col9 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_3a979_row2_col14 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_3a979_row3_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_3a979_row3_col2 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_3a979_row3_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_3a979_row4_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_3a979_row4_col8 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_3a979_row4_col11 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_3a979_row5_col4 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_3a979_row5_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# </style>
# <table id="T_3a979">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_3a979_level0_col0" class="col_heading level0 col0" >0_1200</th>
#       <th id="T_3a979_level0_col1" class="col_heading level0 col1" >0_1800</th>
#       <th id="T_3a979_level0_col2" class="col_heading level0 col2" >0_2400</th>
#       <th id="T_3a979_level0_col3" class="col_heading level0 col3" >0_2500</th>
#       <th id="T_3a979_level0_col4" class="col_heading level0 col4" >1_1200</th>
#       <th id="T_3a979_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_3a979_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_3a979_level0_col7" class="col_heading level0 col7" >1_2</th>
#       <th id="T_3a979_level0_col8" class="col_heading level0 col8" >1_2000</th>
#       <th id="T_3a979_level0_col9" class="col_heading level0 col9" >1_2200</th>
#       <th id="T_3a979_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_3a979_level0_col11" class="col_heading level0 col11" >2_2880</th>
#       <th id="T_3a979_level0_col12" class="col_heading level0 col12" >2_3200</th>
#       <th id="T_3a979_level0_col13" class="col_heading level0 col13" >2_3210</th>
#       <th id="T_3a979_level0_col14" class="col_heading level0 col14" >2_3350</th>
#       <th id="T_3a979_level0_col15" class="col_heading level0 col15" >2_3570</th>
#       <th id="T_3a979_level0_col16" class="col_heading level0 col16" >2_4100</th>
#       <th id="T_3a979_level0_col17" class="col_heading level0 col17" >2_4250</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >weather</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a979_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a979_row0_col0" class="data row0 col0" >72.27</td>
#       <td id="T_3a979_row0_col1" class="data row0 col1" >115.78</td>
#       <td id="T_3a979_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_3a979_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_3a979_row0_col4" class="data row0 col4" >70.14</td>
#       <td id="T_3a979_row0_col5" class="data row0 col5" >96.54</td>
#       <td id="T_3a979_row0_col6" class="data row0 col6" >110.92</td>
#       <td id="T_3a979_row0_col7" class="data row0 col7" >233.27</td>
#       <td id="T_3a979_row0_col8" class="data row0 col8" >124.15</td>
#       <td id="T_3a979_row0_col9" class="data row0 col9" >138.90</td>
#       <td id="T_3a979_row0_col10" class="data row0 col10" >156.69</td>
#       <td id="T_3a979_row0_col11" class="data row0 col11" >199.44</td>
#       <td id="T_3a979_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_3a979_row0_col13" class="data row0 col13" >230.43</td>
#       <td id="T_3a979_row0_col14" class="data row0 col14" >226.30</td>
#       <td id="T_3a979_row0_col15" class="data row0 col15" >245.64</td>
#       <td id="T_3a979_row0_col16" class="data row0 col16" >nan</td>
#       <td id="T_3a979_row0_col17" class="data row0 col17" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a979_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a979_row1_col0" class="data row1 col0" >72.81</td>
#       <td id="T_3a979_row1_col1" class="data row1 col1" >116.42</td>
#       <td id="T_3a979_row1_col2" class="data row1 col2" >157.04</td>
#       <td id="T_3a979_row1_col3" class="data row1 col3" >164.89</

# %%
# 馬場状態ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 5")#東京  
    .groupby(["race_type_course_len", "ground_state"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="ground_state",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_ecbb8_row0_col0, #T_ecbb8_row0_col1, #T_ecbb8_row0_col2, #T_ecbb8_row0_col3, #T_ecbb8_row1_col12, #T_ecbb8_row1_col14, #T_ecbb8_row3_col4, #T_ecbb8_row3_col5, #T_ecbb8_row3_col6, #T_ecbb8_row3_col7, #T_ecbb8_row3_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ecbb8_row0_col4, #T_ecbb8_row0_col5, #T_ecbb8_row0_col6, #T_ecbb8_row0_col8, #T_ecbb8_row0_col9, #T_ecbb8_row0_col10, #T_ecbb8_row0_col11, #T_ecbb8_row0_col12, #T_ecbb8_row0_col13, #T_ecbb8_row0_col14, #T_ecbb8_row1_col0, #T_ecbb8_row1_col1, #T_ecbb8_row1_col2, #T_ecbb8_row1_col3, #T_ecbb8_row1_col7, #T_ecbb8_row1_col8, #T_ecbb8_row1_col10, #T_ecbb8_row1_col11, #T_ecbb8_row1_col13, #T_ecbb8_row2_col8, #T_ecbb8_row2_col10, #T_ecbb8_row2_col11, #T_ecbb8_row2_col13, #T_ecbb8_row3_col8, #T_ecbb8_row3_col10, #T_ecbb8_row3_col11, #T_ecbb8_row3_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ecbb8_row0_col7 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ecbb8_row1_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ecbb8_row1_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_ecbb8_row1_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ecbb8_row1_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ecbb8_row2_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_ecbb8_row2_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_ecbb8_row2_col2 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_ecbb8_row2_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_ecbb8_row2_col4, #T_ecbb8_row2_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_ecbb8_row2_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_ecbb8_row2_col7, #T_ecbb8_row3_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_ecbb8_row2_col9 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_ecbb8_row2_col12 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_ecbb8_row2_col14 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_ecbb8_row3_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ecbb8_row3_col1 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_ecbb8_row3_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ecbb8_row3_col12 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_ecbb8_row3_col14 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ecbb8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_ecbb8_level0_col0" class="col_heading level0 col0" >0_1300</th>
#       <th id="T_ecbb8_level0_col1" class="col_heading level0 col1" >0_1400</th>
#       <th id="T_ecbb8_level0_col2" class="col_heading level0 col2" >0_1600</th>
#       <th id="T_ecbb8_level0_col3" class="col_heading level0 col3" >0_2100</th>
#       <th id="T_ecbb8_level0_col4" class="col_heading level0 col4" >1_1400</th>
#       <th id="T_ecbb8_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_ecbb8_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_ecbb8_level0_col7" class="col_heading level0 col7" >1_2000</th>
#       <th id="T_ecbb8_level0_col8" class="col_heading level0 col8" >1_2300</th>
#       <th id="T_ecbb8_level0_col9" class="col_heading level0 col9" >1_2400</th>
#       <th id="T_ecbb8_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_ecbb8_level0_col11" class="col_heading level0 col11" >1_3400</th>
#       <th id="T_ecbb8_level0_col12" class="col_heading level0 col12" >2_3000</th>
#       <th id="T_ecbb8_level0_col13" class="col_heading level0 col13" >2_3100</th>
#       <th id="T_ecbb8_level0_col14" class="col_heading level0 col14" >2_3110</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ground_state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecbb8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ecbb8_row0_col0" class="data row0 col0" >79.99</td>
#       <td id="T_ecbb8_row0_col1" class="data row0 col1" >86.30</td>
#       <td id="T_ecbb8_row0_col2" class="data row0 col2" >99.14</td>
#       <td id="T_ecbb8_row0_col3" class="data row0 col3" >133.82</td>
#       <td id="T_ecbb8_row0_col4" class="data row0 col4" >82.07</td>
#       <td id="T_ecbb8_row0_col5" class="data row0 col5" >94.84</td>
#       <td id="T_ecbb8_row0_col6" class="data row0 col6" >108.16</td>
#       <td id="T_ecbb8_row0_col7" class="data row0 col7" >120.87</td>
#       <td id="T_ecbb8_row0_col8" class="data row0 col8" >141.00</td>
#       <td id="T_ecbb8_row0_col9" class="data row0 col9" >146.39</td>
#       <td id="T_ecbb8_row0_col10" class="data row0 col10" >151.77</td>
#       <td id="T_ecbb8_row0_col11" class="data row0 col11" >211.87</td>
#       <td id="T_ecbb8_row0_col12" class="data row0 col12" >207.79</td>
#       <td id="T_ecbb8_row0_col13" class="data row0 col13" >210.48</td>
#       <td id="T_ecbb8_row0_col14" class="data row0 col14" >208.39</td>
#     </tr>
#     <tr>
#       <th id="T_ecbb8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ecbb8_row1_col0" class="data row1 col0" >79.03</td>
#       <td id="T_ecbb8_row1_col1" class="data row1 col1" >84.90</td>
#       <td id="T_ecbb8_row1_col2" class="data row1 col2" >97.35</td>
#       <td id="T_ecbb8_row1_col3" class="data row1 col3" >131.59</td>
#       <td id="T_ecbb8_row1_col4" class="data row1 col4" >83.59</td>
#       <td id="T_ecbb8_row1_col5" class="data row1 col5" >96.97</td>
#       <td id="T_ecbb8_row1_col6" class="data row1 col6" >108.81</td>
#       <td id="T_ecbb8_row1_col7" class="data row1 col7" >120.61</td>
#       <td id="T_ecbb8_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_ecbb8_row1_col9" class="data row1 col9" >146.73</td>
#       <td id="T_ecbb8_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_ecbb8_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_ecbb8_row1_col12" class="data row1 col12" >215.56</td>
#       <td id="T_ecbb8_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_ecbb8_row1_col14" class="data row1 col14" >214.58</td>
#     </tr>
#     <tr>
#       <th id="T_ecbb8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ecbb8_row2_col0" class="data row2 col0" >79.86</td>
#       <td id="T_ecbb8_row2_col1" class="data row2 col1" >85.64</td>
#       <td id="T_ecbb8_row2_col2" class="data row2 col2" >98.74</td>
#       <td id="T_ecbb8_row2_col3" class="data row2 col3" >132.66</td>
#       <td id="T_ecbb8_row2_col4" class="data row2 col4" >82.80</td>
#       <td id="T_ecbb8_row2_col5" class="data row2 col5" >95.61</td>
#       <td id="T_ecbb8_row2_col6" class="data row2 col6" >108.93</td>
#       <td id="T_ecbb8_row2_col7" class="data row2 col7" >122.10</td>
#       <td id="T_ecbb8_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_ecbb8_row2_col9" class="data row2 col9" >147.97</td>
#       <td id="T_ecbb8_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_ecbb8_row2_col11" class="data row2 col11" >nan</td>
#       <td id="T_ecbb8_row2_col12" class="data row2 col12" >209.42</td>
#       <td id="T_ecbb8_row2_col13" class="data row2 col13" >nan</td>
#       <td id="T_ecbb8_row2_col14" class="data row2 col14" >211.60</td>
#     </tr>
#     <tr>
#       <th id="T_ecbb8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ecbb8_row3_col0" class="data row3 col0" >79.25</td>
#       <td id="T_ecbb8_row3_col1" class="data row3 col1" >85.45</

# %%
# 馬場状態ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 6")#東京  
    .groupby(["race_type_course_len", "ground_state"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="ground_state",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_ebe66_row0_col0, #T_ebe66_row0_col1, #T_ebe66_row0_col2, #T_ebe66_row1_col14, #T_ebe66_row2_col7, #T_ebe66_row2_col12, #T_ebe66_row2_col15, #T_ebe66_row2_col16, #T_ebe66_row3_col4, #T_ebe66_row3_col5, #T_ebe66_row3_col6, #T_ebe66_row3_col8, #T_ebe66_row3_col9, #T_ebe66_row3_col10, #T_ebe66_row3_col11, #T_ebe66_row3_col13, #T_ebe66_row3_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ebe66_row0_col3, #T_ebe66_row0_col4, #T_ebe66_row0_col5, #T_ebe66_row0_col6, #T_ebe66_row0_col7, #T_ebe66_row0_col8, #T_ebe66_row0_col9, #T_ebe66_row0_col10, #T_ebe66_row0_col11, #T_ebe66_row0_col12, #T_ebe66_row0_col13, #T_ebe66_row0_col15, #T_ebe66_row0_col16, #T_ebe66_row0_col17, #T_ebe66_row1_col0, #T_ebe66_row1_col3, #T_ebe66_row2_col3, #T_ebe66_row2_col14, #T_ebe66_row3_col0, #T_ebe66_row3_col1, #T_ebe66_row3_col2, #T_ebe66_row3_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ebe66_row0_col14 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ebe66_row1_col1, #T_ebe66_row2_col17 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ebe66_row1_col2 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_ebe66_row1_col4, #T_ebe66_row2_col10 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_ebe66_row1_col5 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ebe66_row1_col6 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ebe66_row1_col7, #T_ebe66_row1_col12, #T_ebe66_row1_col13, #T_ebe66_row1_col15, #T_ebe66_row1_col16, #T_ebe66_row3_col7, #T_ebe66_row3_col12, #T_ebe66_row3_col14, #T_ebe66_row3_col15, #T_ebe66_row3_col16 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ebe66_row1_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ebe66_row1_col9 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_ebe66_row1_col10 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_ebe66_row1_col11 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_ebe66_row1_col17 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ebe66_row2_col0 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_ebe66_row2_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_ebe66_row2_col2 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_ebe66_row2_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_ebe66_row2_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_ebe66_row2_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ebe66_row2_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_ebe66_row2_col9 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_ebe66_row2_col11 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ebe66_row2_col13 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# </style>
# <table id="T_ebe66">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_ebe66_level0_col0" class="col_heading level0 col0" >0_1200</th>
#       <th id="T_ebe66_level0_col1" class="col_heading level0 col1" >0_1800</th>
#       <th id="T_ebe66_level0_col2" class="col_heading level0 col2" >0_2400</th>
#       <th id="T_ebe66_level0_col3" class="col_heading level0 col3" >0_2500</th>
#       <th id="T_ebe66_level0_col4" class="col_heading level0 col4" >1_1200</th>
#       <th id="T_ebe66_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_ebe66_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_ebe66_level0_col7" class="col_heading level0 col7" >1_2</th>
#       <th id="T_ebe66_level0_col8" class="col_heading level0 col8" >1_2000</th>
#       <th id="T_ebe66_level0_col9" class="col_heading level0 col9" >1_2200</th>
#       <th id="T_ebe66_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_ebe66_level0_col11" class="col_heading level0 col11" >2_2880</th>
#       <th id="T_ebe66_level0_col12" class="col_heading level0 col12" >2_3200</th>
#       <th id="T_ebe66_level0_col13" class="col_heading level0 col13" >2_3210</th>
#       <th id="T_ebe66_level0_col14" class="col_heading level0 col14" >2_3350</th>
#       <th id="T_ebe66_level0_col15" class="col_heading level0 col15" >2_3570</th>
#       <th id="T_ebe66_level0_col16" class="col_heading level0 col16" >2_4100</th>
#       <th id="T_ebe66_level0_col17" class="col_heading level0 col17" >2_4250</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ground_state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebe66_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ebe66_row0_col0" class="data row0 col0" >72.89</td>
#       <td id="T_ebe66_row0_col1" class="data row0 col1" >116.64</td>
#       <td id="T_ebe66_row0_col2" class="data row0 col2" >157.44</td>
#       <td id="T_ebe66_row0_col3" class="data row0 col3" >164.85</td>
#       <td id="T_ebe66_row0_col4" class="data row0 col4" >69.15</td>
#       <td id="T_ebe66_row0_col5" class="data row0 col5" >95.49</td>
#       <td id="T_ebe66_row0_col6" class="data row0 col6" >109.40</td>
#       <td id="T_ebe66_row0_col7" class="data row0 col7" >227.05</td>
#       <td id="T_ebe66_row0_col8" class="data row0 col8" >122.79</td>
#       <td id="T_ebe66_row0_col9" class="data row0 col9" >135.51</td>
#       <td id="T_ebe66_row0_col10" class="data row0 col10" >154.68</td>
#       <td id="T_ebe66_row0_col11" class="data row0 col11" >197.53</td>
#       <td id="T_ebe66_row0_col12" class="data row0 col12" >216.25</td>
#       <td id="T_ebe66_row0_col13" class="data row0 col13" >217.82</td>
#       <td id="T_ebe66_row0_col14" class="data row0 col14" >226.35</td>
#       <td id="T_ebe66_row0_col15" class="data row0 col15" >242.78</td>
#       <td id="T_ebe66_row0_col16" class="data row0 col16" >284.89</td>
#       <td id="T_ebe66_row0_col17" class="data row0 col17" >293.50</td>
#     </tr>
#     <tr>
#       <th id="T_ebe66_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ebe66_row1_col0" class="data row1 col0" >72.06</td>
#       <td id="T_ebe66_row1_col1" class="data row1 col1" >114.87</td>
#       <td id="T_ebe66_row1_col2" class="data row1 col2" >156.44</td>
#       <td id="T_ebe66_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_ebe66_row1_col4" class="data row1 col4" >70.20</td>
#       <td id="T_ebe66_row1_col5" class="data row1 col5" >96.63</td>
#       <td id="T_ebe66_row1_col6" class="data row1 col6" >111.09</td>
#       <td id="T_ebe66_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_ebe66_row1_col8" class="data row1 col8" >123.81</td>
#       <td id="T_ebe66_row1_col9" class="data row1 col9" >138.70</td>
#       <td id="T_ebe66_row1_col10" class="data row1 col10" >156.34</td>
#       <td id="T_ebe66_row1_col11" class="data row1 col11" >200.61</td>
#       <td id="T_ebe66_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_ebe66_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_ebe66_row1_col14" class="data row1 col14" >230.23</td>
#       <td id="T_ebe66_row1_col15" class="data row1 col15" >nan</td>
#       <td id="T_ebe66_row1_col16" class="data row1 col16" >nan</td>
#       <td id="T_ebe66_row1_col17" class="data row1 col17" >298.10</td>
#     </tr>
#     <tr>
#       <th id="T_ebe66_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ebe66_row2_col0" class="data row2 col0" >72.86</td>
#       <td id="T_ebe66_row2_col1" class

# %%
# 性別ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 5")#東京  
    .groupby(["race_type_course_len", "sex"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="sex",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_82c8f_row0_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_82c8f_row0_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_82c8f_row0_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_82c8f_row0_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_82c8f_row0_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_82c8f_row0_col5 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_82c8f_row0_col6 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_82c8f_row0_col7 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_82c8f_row0_col8 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_82c8f_row0_col9, #T_82c8f_row1_col10, #T_82c8f_row1_col14, #T_82c8f_row2_col0, #T_82c8f_row2_col1, #T_82c8f_row2_col2, #T_82c8f_row2_col3, #T_82c8f_row2_col4, #T_82c8f_row2_col5, #T_82c8f_row2_col6, #T_82c8f_row2_col7, #T_82c8f_row2_col8, #T_82c8f_row2_col11, #T_82c8f_row2_col12, #T_82c8f_row2_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_82c8f_row0_col10 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_82c8f_row0_col11 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_82c8f_row0_col12 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_82c8f_row0_col13, #T_82c8f_row1_col0, #T_82c8f_row1_col1, #T_82c8f_row1_col2, #T_82c8f_row1_col3, #T_82c8f_row1_col4, #T_82c8f_row1_col5, #T_82c8f_row1_col6, #T_82c8f_row1_col7, #T_82c8f_row1_col8, #T_82c8f_row1_col11, #T_82c8f_row1_col12, #T_82c8f_row2_col9, #T_82c8f_row2_col10, #T_82c8f_row2_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_82c8f_row0_col14 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_82c8f_row1_col9 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_82c8f_row1_col13 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_82c8f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_82c8f_level0_col0" class="col_heading level0 col0" >0_1300</th>
#       <th id="T_82c8f_level0_col1" class="col_heading level0 col1" >0_1400</th>
#       <th id="T_82c8f_level0_col2" class="col_heading level0 col2" >0_1600</th>
#       <th id="T_82c8f_level0_col3" class="col_heading level0 col3" >0_2100</th>
#       <th id="T_82c8f_level0_col4" class="col_heading level0 col4" >1_1400</th>
#       <th id="T_82c8f_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_82c8f_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_82c8f_level0_col7" class="col_heading level0 col7" >1_2000</th>
#       <th id="T_82c8f_level0_col8" class="col_heading level0 col8" >1_2300</th>
#       <th id="T_82c8f_level0_col9" class="col_heading level0 col9" >1_2400</th>
#       <th id="T_82c8f_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_82c8f_level0_col11" class="col_heading level0 col11" >1_3400</th>
#       <th id="T_82c8f_level0_col12" class="col_heading level0 col12" >2_3000</th>
#       <th id="T_82c8f_level0_col13" class="col_heading level0 col13" >2_3100</th>
#       <th id="T_82c8f_level0_col14" class="col_heading level0 col14" >2_3110</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82c8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82c8f_row0_col0" class="data row0 col0" >79.66</td>
#       <td id="T_82c8f_row0_col1" class="data row0 col1" >85.67</td>
#       <td id="T_82c8f_row0_col2" class="data row0 col2" >98.64</td>
#       <td id="T_82c8f_row0_col3" class="data row0 col3" >133.15</td>
#       <td id="T_82c8f_row0_col4" class="data row0 col4" >82.24</td>
#       <td id="T_82c8f_row0_col5" class="data row0 col5" >94.86</td>
#       <td id="T_82c8f_row0_col6" class="data row0 col6" >108.37</td>
#       <td id="T_82c8f_row0_col7" class="data row0 col7" >121.09</td>
#       <td id="T_82c8f_row0_col8" class="data row0 col8" >141.01</td>
#       <td id="T_82c8f_row0_col9" class="data row0 col9" >146.70</td>
#       <td id="T_82c8f_row0_col10" class="data row0 col10" >151.72</td>
#       <td id="T_82c8f_row0_col11" class="data row0 col11" >211.98</td>
#       <td id="T_82c8f_row0_col12" class="data row0 col12" >209.05</td>
#       <td id="T_82c8f_row0_col13" class="data row0 col13" >210.50</td>
#       <td id="T_82c8f_row0_col14" class="data row0 col14" >209.13</td>
#     </tr>
#     <tr>
#       <th id="T_82c8f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_82c8f_row1_col0" class="data row1 col0" >80.13</td>
#       <td id="T_82c8f_row1_col1" class="data row1 col1" >86.47</td>
#       <td id="T_82c8f_row1_col2" class="data row1 col2" >99.21</td>
#       <td id="T_82c8f_row1_col3" class="data row1 col3" >133.91</td>
#       <td id="T_82c8f_row1_col4" class="data row1 col4" >82.42</td>
#       <td id="T_82c8f_row1_col5" class="data row1 col5" >95.37</td>
#       <td id="T_82c8f_row1_col6" class="data row1 col6" >108.38</td>
#       <td id="T_82c8f_row1_col7" class="data row1 col7" >121.18</td>
#       <td id="T_82c8f_row1_col8" class="data row1 col8" >141.24</td>
#       <td id="T_82c8f_row1_col9" class="data row1 col9" >146.81</td>
#       <td id="T_82c8f_row1_col10" class="data row1 col10" >151.50</td>
#       <td id="T_82c8f_row1_col11" class="data row1 col11" >212.43</td>
#       <td id="T_82c8f_row1_col12" class="data row1 col12" >210.28</td>
#       <td id="T_82c8f_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_82c8f_row1_col14" class="data row1 col14" >206.00</td>
#     </tr>
#     <tr>
#       <th id="T_82c8f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_82c8f_row2_col0" class="data row2 col0" >79.10</td>
#       <td id="T_82c8f_row2_col1" class="data row2 col1" >85.18</td>
#       <td id="T_82c8f_row2_col2" class="data row2 col2" >98.07</td>
#       <td id="T_82c8f_row2_col3" class="data row2 col3" >132.56</td>
#       <td id="T_82c8f_row2_col4" class="data row2 col4" >82.09</td>
#       <td id="T_82c8f_row2_col5" class="data row2 col5" >94.14</td>
#       <td id="T_82c8f_row2_col6" class="data row2 col6" >107.62</td>
#       <td id="T_82c8f_row2_col7" class="data row2 col7" >120.50</td>
#       <td id="T_82c8f_row2_col8" class="data row2 col8" >139.75</td>
#       <td id="T_82c8f_row2_col9" class="data row2 col9" >147.63</td>
#       <td id="T_82c8f_row2_col10" class="data row2 col10" >152.12</td>
#       <td id="T_82c8f_row2_col11" class="data row2 col11" >210.57</td>
#       <td id="T_82c8f_row2_col12" class="data row2 col12" >208.81</td>
#       <td id="T_82c8f_row2_col13" class="data row2 col13" >210.40</td>
#       <td id="T_82c8f_row2_col14" class="data row2 col14" >210.06</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 性別ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 6")#東京  
    .groupby(["race_type_course_len", "sex"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="sex",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_fdeed_row0_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_fdeed_row0_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_fdeed_row0_col2, #T_fdeed_row0_col3, #T_fdeed_row0_col10, #T_fdeed_row0_col12, #T_fdeed_row0_col13, #T_fdeed_row1_col7, #T_fdeed_row2_col0, #T_fdeed_row2_col1, #T_fdeed_row2_col4, #T_fdeed_row2_col5, #T_fdeed_row2_col6, #T_fdeed_row2_col8, #T_fdeed_row2_col9, #T_fdeed_row2_col11, #T_fdeed_row2_col14, #T_fdeed_row2_col15, #T_fdeed_row2_col16, #T_fdeed_row2_col17 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fdeed_row0_col4 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_fdeed_row0_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_fdeed_row0_col6 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_fdeed_row0_col7, #T_fdeed_row0_col16, #T_fdeed_row0_col17, #T_fdeed_row1_col0, #T_fdeed_row1_col1, #T_fdeed_row1_col2, #T_fdeed_row1_col4, #T_fdeed_row1_col5, #T_fdeed_row1_col6, #T_fdeed_row1_col8, #T_fdeed_row1_col9, #T_fdeed_row1_col11, #T_fdeed_row1_col13, #T_fdeed_row1_col14, #T_fdeed_row1_col15, #T_fdeed_row2_col3, #T_fdeed_row2_col10, #T_fdeed_row2_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fdeed_row0_col8 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_fdeed_row0_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_fdeed_row0_col11 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_fdeed_row0_col14 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_fdeed_row0_col15, #T_fdeed_row2_col13 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_fdeed_row1_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_fdeed_row1_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_fdeed_row1_col12, #T_fdeed_row1_col16, #T_fdeed_row1_col17 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_fdeed_row2_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_fdeed_row2_col7 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fdeed">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_fdeed_level0_col0" class="col_heading level0 col0" >0_1200</th>
#       <th id="T_fdeed_level0_col1" class="col_heading level0 col1" >0_1800</th>
#       <th id="T_fdeed_level0_col2" class="col_heading level0 col2" >0_2400</th>
#       <th id="T_fdeed_level0_col3" class="col_heading level0 col3" >0_2500</th>
#       <th id="T_fdeed_level0_col4" class="col_heading level0 col4" >1_1200</th>
#       <th id="T_fdeed_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_fdeed_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_fdeed_level0_col7" class="col_heading level0 col7" >1_2</th>
#       <th id="T_fdeed_level0_col8" class="col_heading level0 col8" >1_2000</th>
#       <th id="T_fdeed_level0_col9" class="col_heading level0 col9" >1_2200</th>
#       <th id="T_fdeed_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_fdeed_level0_col11" class="col_heading level0 col11" >2_2880</th>
#       <th id="T_fdeed_level0_col12" class="col_heading level0 col12" >2_3200</th>
#       <th id="T_fdeed_level0_col13" class="col_heading level0 col13" >2_3210</th>
#       <th id="T_fdeed_level0_col14" class="col_heading level0 col14" >2_3350</th>
#       <th id="T_fdeed_level0_col15" class="col_heading level0 col15" >2_3570</th>
#       <th id="T_fdeed_level0_col16" class="col_heading level0 col16" >2_4100</th>
#       <th id="T_fdeed_level0_col17" class="col_heading level0 col17" >2_4250</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdeed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fdeed_row0_col0" class="data row0 col0" >72.47</td>
#       <td id="T_fdeed_row0_col1" class="data row0 col1" >116.13</td>
#       <td id="T_fdeed_row0_col2" class="data row0 col2" >156.86</td>
#       <td id="T_fdeed_row0_col3" class="data row0 col3" >164.74</td>
#       <td id="T_fdeed_row0_col4" class="data row0 col4" >69.33</td>
#       <td id="T_fdeed_row0_col5" class="data row0 col5" >95.54</td>
#       <td id="T_fdeed_row0_col6" class="data row0 col6" >110.08</td>
#       <td id="T_fdeed_row0_col7" class="data row0 col7" >228.84</td>
#       <td id="T_fdeed_row0_col8" class="data row0 col8" >123.08</td>
#       <td id="T_fdeed_row0_col9" class="data row0 col9" >136.20</td>
#       <td id="T_fdeed_row0_col10" class="data row0 col10" >155.06</td>
#       <td id="T_fdeed_row0_col11" class="data row0 col11" >198.01</td>
#       <td id="T_fdeed_row0_col12" class="data row0 col12" >216.13</td>
#       <td id="T_fdeed_row0_col13" class="data row0 col13" >222.28</td>
#       <td id="T_fdeed_row0_col14" class="data row0 col14" >227.44</td>
#       <td id="T_fdeed_row0_col15" class="data row0 col15" >243.56</td>
#       <td id="T_fdeed_row0_col16" class="data row0 col16" >286.27</td>
#       <td id="T_fdeed_row0_col17" class="data row0 col17" >298.74</td>
#     </tr>
#     <tr>
#       <th id="T_fdeed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fdeed_row1_col0" class="data row1 col0" >73.10</td>
#       <td id="T_fdeed_row1_col1" class="data row1 col1" >116.92</td>
#       <td id="T_fdeed_row1_col2" class="data row1 col2" >157.50</td>
#       <td id="T_fdeed_row1_col3" class="data row1 col3" >165.00</td>
#       <td id="T_fdeed_row1_col4" class="data row1 col4" >69.60</td>
#       <td id="T_fdeed_row1_col5" class="data row1 col5" >96.07</td>
#       <td id="T_fdeed_row1_col6" class="data row1 col6" >110.11</td>
#       <td id="T_fdeed_row1_col7" class="data row1 col7" >227.20</td>
#       <td id="T_fdeed_row1_col8" class="data row1 col8" >123.44</td>
#       <td id="T_fdeed_row1_col9" class="data row1 col9" >136.75</td>
#       <td id="T_fdeed_row1_col10" class="data row1 col10" >155.11</td>
#       <td id="T_fdeed_row1_col11" class="data row1 col11" >199.28</td>
#       <td id="T_fdeed_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_fdeed_row1_col13" class="data row1 col13" >235.00</td>
#       <td id="T_fdeed_row1_col14" class="data row1 col14" >232.00</td>
#       <td id="T_fdeed_row1_col15" class="data row1 col15" >248.00</td>
#       <td id="T_fdeed_row1_col16" class="data row1 col16" >nan</td>
#       <td id="T_fdeed_row1_col17" class="data row1 col17" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fdeed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fdeed_row2_col0" class="data row2 col0" >72.03</td>
#       <td id="T_fdeed_row2_col1" class="data row2 col1" >115.37</td>
#       <td id="T_fdeed_row2_col2" class="data row2 col2" >157.07</td>
#       <td id="T_fdeed_row2_col3" class="data row2 col3" >167.00</td>
#       <td id="T_fdeed_row2_col4" class="data row2 col4" >69.11</td>
#       <td id="T_fdeed_row2_col5" class="data row2 col5" >95.21</td>
#       <td id="T_fdeed_row2_col6" class="data row2 col6" >109.05</td>
#       <td id="T_fdeed_row2_col7" class="data row2 col7" >228.69</td>
#       <td id="T_fdeed_row2_col8" class="data row2 col8" >122.47</td>
#       <td id="T_fdeed_row2_col9" class="data row2 col9" >135.95</td>
#       <td id="T_fdeed_row2_col10" class="data row2 col10" >155.35</td>
#       <td id="T_fdeed_row2_col11" class="data row2 col11" >197.86<

# %%
# レース形状ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 5")#東京  
    .groupby(["race_type_course_len", "around"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="around",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_62f2f_row0_col0, #T_62f2f_row0_col1, #T_62f2f_row0_col2, #T_62f2f_row0_col3, #T_62f2f_row0_col4, #T_62f2f_row0_col5, #T_62f2f_row0_col6, #T_62f2f_row0_col7, #T_62f2f_row0_col8, #T_62f2f_row0_col9, #T_62f2f_row0_col10, #T_62f2f_row0_col11, #T_62f2f_row0_col12, #T_62f2f_row0_col13, #T_62f2f_row0_col14, #T_62f2f_row1_col0, #T_62f2f_row1_col1, #T_62f2f_row1_col2, #T_62f2f_row1_col3, #T_62f2f_row1_col4, #T_62f2f_row1_col5, #T_62f2f_row1_col6, #T_62f2f_row1_col7, #T_62f2f_row1_col8, #T_62f2f_row1_col9, #T_62f2f_row1_col10, #T_62f2f_row1_col11, #T_62f2f_row1_col12, #T_62f2f_row1_col13, #T_62f2f_row1_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_62f2f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_62f2f_level0_col0" class="col_heading level0 col0" >0_1300</th>
#       <th id="T_62f2f_level0_col1" class="col_heading level0 col1" >0_1400</th>
#       <th id="T_62f2f_level0_col2" class="col_heading level0 col2" >0_1600</th>
#       <th id="T_62f2f_level0_col3" class="col_heading level0 col3" >0_2100</th>
#       <th id="T_62f2f_level0_col4" class="col_heading level0 col4" >1_1400</th>
#       <th id="T_62f2f_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_62f2f_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_62f2f_level0_col7" class="col_heading level0 col7" >1_2000</th>
#       <th id="T_62f2f_level0_col8" class="col_heading level0 col8" >1_2300</th>
#       <th id="T_62f2f_level0_col9" class="col_heading level0 col9" >1_2400</th>
#       <th id="T_62f2f_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_62f2f_level0_col11" class="col_heading level0 col11" >1_3400</th>
#       <th id="T_62f2f_level0_col12" class="col_heading level0 col12" >2_3000</th>
#       <th id="T_62f2f_level0_col13" class="col_heading level0 col13" >2_3100</th>
#       <th id="T_62f2f_level0_col14" class="col_heading level0 col14" >2_3110</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >around</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62f2f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_62f2f_row0_col0" class="data row0 col0" >79.82</td>
#       <td id="T_62f2f_row0_col1" class="data row0 col1" >85.96</td>
#       <td id="T_62f2f_row0_col2" class="data row0 col2" >98.79</td>
#       <td id="T_62f2f_row0_col3" class="data row0 col3" >133.14</td>
#       <td id="T_62f2f_row0_col4" class="data row0 col4" >82.34</td>
#       <td id="T_62f2f_row0_col5" class="data row0 col5" >95.10</td>
#       <td id="T_62f2f_row0_col6" class="data row0 col6" >108.34</td>
#       <td id="T_62f2f_row0_col7" class="data row0 col7" >121.09</td>
#       <td id="T_62f2f_row0_col8" class="data row0 col8" >141.00</td>
#       <td id="T_62f2f_row0_col9" class="data row0 col9" >146.79</td>
#       <td id="T_62f2f_row0_col10" class="data row0 col10" >151.77</td>
#       <td id="T_62f2f_row0_col11" class="data row0 col11" >211.87</td>
#       <td id="T_62f2f_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_62f2f_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_62f2f_row0_col14" class="data row0 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_62f2f_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_62f2f_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_62f2f_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_62f2f_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_62f2f_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_62f2f_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_62f2f_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_62f2f_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_62f2f_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_62f2f_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_62f2f_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_62f2f_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_62f2f_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_62f2f_row1_col12" class="data row1 col12" >209.10</td>
#       <td id="T_62f2f_row1_col13" class="data row1 col13" >210.48</td>
#       <td id="T_62f2f_row1_col14" class="data row1 col14" >209.33</td>
#     </tr>
#   </tbody>
# </table>

# %%
# レース形状ごとの平均タイムを計算
df2_grouped = (
    df2.query("place == 6")#東京  
    .groupby(["race_type_course_len", "around"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="around",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_07d95_row0_col0, #T_07d95_row0_col1, #T_07d95_row0_col2, #T_07d95_row0_col3, #T_07d95_row0_col4, #T_07d95_row0_col5, #T_07d95_row0_col6, #T_07d95_row0_col7, #T_07d95_row0_col8, #T_07d95_row0_col9, #T_07d95_row0_col10, #T_07d95_row0_col11, #T_07d95_row0_col12, #T_07d95_row0_col13, #T_07d95_row0_col14, #T_07d95_row0_col15, #T_07d95_row0_col16, #T_07d95_row0_col17, #T_07d95_row1_col0, #T_07d95_row1_col1, #T_07d95_row1_col2, #T_07d95_row1_col3, #T_07d95_row1_col4, #T_07d95_row1_col5, #T_07d95_row1_col6, #T_07d95_row1_col7, #T_07d95_row1_col8, #T_07d95_row1_col9, #T_07d95_row1_col10, #T_07d95_row1_col11, #T_07d95_row1_col12, #T_07d95_row1_col13, #T_07d95_row1_col14, #T_07d95_row1_col15, #T_07d95_row1_col16, #T_07d95_row1_col17 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_07d95">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_07d95_level0_col0" class="col_heading level0 col0" >0_1200</th>
#       <th id="T_07d95_level0_col1" class="col_heading level0 col1" >0_1800</th>
#       <th id="T_07d95_level0_col2" class="col_heading level0 col2" >0_2400</th>
#       <th id="T_07d95_level0_col3" class="col_heading level0 col3" >0_2500</th>
#       <th id="T_07d95_level0_col4" class="col_heading level0 col4" >1_1200</th>
#       <th id="T_07d95_level0_col5" class="col_heading level0 col5" >1_1600</th>
#       <th id="T_07d95_level0_col6" class="col_heading level0 col6" >1_1800</th>
#       <th id="T_07d95_level0_col7" class="col_heading level0 col7" >1_2</th>
#       <th id="T_07d95_level0_col8" class="col_heading level0 col8" >1_2000</th>
#       <th id="T_07d95_level0_col9" class="col_heading level0 col9" >1_2200</th>
#       <th id="T_07d95_level0_col10" class="col_heading level0 col10" >1_2500</th>
#       <th id="T_07d95_level0_col11" class="col_heading level0 col11" >2_2880</th>
#       <th id="T_07d95_level0_col12" class="col_heading level0 col12" >2_3200</th>
#       <th id="T_07d95_level0_col13" class="col_heading level0 col13" >2_3210</th>
#       <th id="T_07d95_level0_col14" class="col_heading level0 col14" >2_3350</th>
#       <th id="T_07d95_level0_col15" class="col_heading level0 col15" >2_3570</th>
#       <th id="T_07d95_level0_col16" class="col_heading level0 col16" >2_4100</th>
#       <th id="T_07d95_level0_col17" class="col_heading level0 col17" >2_4250</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >around</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07d95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07d95_row0_col0" class="data row0 col0" >72.75</td>
#       <td id="T_07d95_row0_col1" class="data row0 col1" >116.33</td>
#       <td id="T_07d95_row0_col2" class="data row0 col2" >156.93</td>
#       <td id="T_07d95_row0_col3" class="data row0 col3" >164.85</td>
#       <td id="T_07d95_row0_col4" class="data row0 col4" >69.47</td>
#       <td id="T_07d95_row0_col5" class="data row0 col5" >95.81</td>
#       <td id="T_07d95_row0_col6" class="data row0 col6" >110.05</td>
#       <td id="T_07d95_row0_col7" class="data row0 col7" >228.66</td>
#       <td id="T_07d95_row0_col8" class="data row0 col8" >123.19</td>
#       <td id="T_07d95_row0_col9" class="data row0 col9" >136.31</td>
#       <td id="T_07d95_row0_col10" class="data row0 col10" >155.10</td>
#       <td id="T_07d95_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_07d95_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_07d95_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_07d95_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_07d95_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_07d95_row0_col16" class="data row0 col16" >nan</td>
#       <td id="T_07d95_row0_col17" class="data row0 col17" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_07d95_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_07d95_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_07d95_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_07d95_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_07d95_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_07d95_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_07d95_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_07d95_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_07d95_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_07d95_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_07d95_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_07d95_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_07d95_row1_col11" class="data row1 col11" >198.14</td>
#       <td id="T_07d95_row1_col12" class="data row1 col12" >216.48</td>
#       <td id="T_07d95_row1_col13" class="data row1 col13" >222.88</td>
#       <td id="T_07d95_row1_col14" class="data row1 col14" >227.37</td>
#       <td id="T_07d95_row1_col15" class="data row1 col15" >243.44</td>
#       <td id="T_07d95_row1_col16" class="data row1 col16" >286.04</td>
#       <td id="T_07d95_row1_col17" class="data row1 col17" >298.66</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 単勝オッズと相関の高い特徴量を調べる

# %%
import pandas as pd

# 数値型の列だけを抽出
numeric_df = df.select_dtypes(include=['number'])

# 必要な列名をリストとして定義
columns_to_add = [
    "race_id", "horse_id", "jockey_id", "trainer_id", "umaban", "wakuban", 
    "tansho_odds", "popularity", "impost", "sex", "age", "weight", "weight_diff", 
    "n_horses", "race_type", "around", "course_len", "weather", "ground_state", 
    "race_class", "place", "rank_2races", "rank_per_horse_2races", "prize_2races", 
    "rank_3races", "rank_per_horse_3races", "prize_3races", "rank_5races", 
    "rank_per_horse_5races", "prize_5races", "rank_10races", "rank_per_horse_10races", 
    "prize_10races", "rank_1000races", "rank_per_horse_1000races", "prize_1000races", 
    "rank_mean_1races_relative", "rank_max_1races_relative", "rank_min_1races_relative", 
    "rank_per_horse_mean_1races_relative", "rank_per_horse_max_1races_relative", 
    "rank_per_horse_min_1races_relative", "prize_mean_1races_relative", 
    "prize_max_1races_relative", "prize_min_1races_relative", "rank_diff_mean_1races_relative", 
    "rank_diff_max_1races_relative", "rank_diff_min_1races_relative", 
    "course_len_mean_1races_relative", "course_len_max_1races_relative", 
    "course_len_min_1races_relative", "race_class_mean_1races_relative", 
    "race_class_max_1races_relative", "race_class_min_1races_relative", 
    "n_horses_mean_1races_relative", "n_horses_max_1races_relative", 
    "n_horses_min_1races_relative", "nobori_mean_1races_relative", "nobori_max_1races_relative", 
    "nobori_min_1races_relative", "corner_1_per_horse_mean_1races_relative", 
    "corner_1_per_horse_max_1races_relative", "corner_1_per_horse_min_1races_relative", 
    "corner_2_per_horse_mean_1races_relative", "corner_2_per_horse_max_1races_relative", 
    "corner_2_per_horse_min_1races_relative", "corner_3_per_horse_mean_1races_relative", 
    "corner_3_per_horse_max_1races_relative", "corner_3_per_horse_min_1races_relative", 
    "corner_4_per_horse_mean_1races_relative", "corner_4_per_horse_max_1races_relative", 
    "corner_4_per_horse_min_1races_relative", "pase_1_mean_1races_relative", 
    "pase_1_max_1races_relative", "pase_1_min_1races_relative", "rank_mean_5races_relative", 
    "rank_max_5races_relative", "rank_min_5races_relative", "rank_per_horse_mean_5races_relative", 
    "rank_per_horse_max_5races_relative", "rank_per_horse_min_5races_relative", 
    "prize_mean_5races_relative", "prize_max_5races_relative", "prize_min_5races_relative", 
    "rank_diff_mean_5races_relative", "rank_diff_max_5races_relative", "rank_diff_min_5races_relative", 
    "course_len_mean_5races_relative", "course_len_max_5races_relative", 
    "course_len_min_5races_relative", "race_class_mean_5races_relative", 
    "race_class_max_5races_relative", "race_class_min_5races_relative", 
    "n_horses_mean_5races_relative", "n_horses_max_5races_relative", "n_horses_min_5races_relative", 
    "nobori_mean_5races_relative", "nobori_max_5races_relative", "nobori_min_5races_relative", 
    "corner_1_per_horse_mean_5races_relative", "corner_1_per_horse_max_5races_relative", 
    "corner_1_per_horse_min_5races_relative", "corner_2_per_horse_mean_5races_relative", 
    "corner_2_per_horse_max_5races_relative", "corner_2_per_horse_min_5races_relative", 
    "corner_3_per_horse_mean_5races_relative", "corner_3_per_horse_max_5races_relative", 
    "corner_3_per_horse_min_5races_relative", "corner_4_per_horse_mean_5races_relative", 
    "corner_4_per_horse_max_5races_relative", "corner_4_per_horse_min_5races_relative", 
    "pase_1_mean_5races_relative", "pase_1_max_5races_relative", "pase_1_min_5races_relative", 
    "pase_2_mean_5races_relative", "pase_2_max_5races_relative", "pase_2_min_5races_relative"
]

# numeric_dfに必要な列を追加
numeric_df = numeric_df[columns_to_add]

# 数値型データの相関行列を計算
correlation_matrix = numeric_df.corr()


# 単勝オッズとの相関を取得
odds_correlation = correlation_matrix["tansho_odds"].sort_values(ascending=False)

# 結果を表示
print(odds_correlation)
# Out:
# tansho_odds                   1.000000
# popularity                    0.727029
# rank_10races                  0.571281
# rank_per_horse_10races        0.568069
# rank_5races                   0.566971
#                                 ...
# prize_mean_1races_relative   -0.342665
# prize_max_1races_relative    -0.342665
# prize_min_1races_relative    -0.342665
# prize_max_5races_relative    -0.425082
# prize_mean_5races_relative   -0.440939
# Name: tansho_odds, Length: 117, dtype: float64

# %%
odds_correlation
# Out:
# tansho_odds                   1.000000
# popularity                    0.727029
# rank_10races                  0.571281
# rank_per_horse_10races        0.568069
# rank_5races                   0.566971
#                                 ...
# prize_mean_1races_relative   -0.342665
# prize_max_1races_relative    -0.342665
# prize_min_1races_relative    -0.342665
# prize_max_5races_relative    -0.425082
# prize_mean_5races_relative   -0.440939
# Name: tansho_odds, Length: 117, dtype: float64

# %%
pd.set_option('display.max_columns', None)  # 列数制限なし
pd.set_option('display.width', None)        # 幅制限なし
pd.set_option('display.max_rows', None)     # 行数制限なし

odds_correlation_df = odds_correlation.reset_index()
odds_correlation_df.columns = ['Feature', 'Correlation with Tansho Odds']

odds_correlation_df 
odds_correlation_df.to_csv('odds_correlation.csv',sep="\t", index=False)

# %%
#各レースタイプ、競馬場、距離ごとのnobori平均
# "target" 列を作成（time を整数型に変換）

df["nobori"] = df["nobori"].fillna(df["nobori"].mean())
df["target"] = df["nobori"].astype(int)

# 必要な列を選択して、データを整理
df3 = df[["race_type", "course_len", "place", "target", "race_class","weather","ground_state"]].dropna().astype(int)

# race_type と course_len の組み合わせ列を作成
df3["race_type_course_len"] = df3["race_type"].astype(str) + "_" + df3["course_len"].astype(str)

# 枠番ごとの平均タイムを計算
df3_grouped = (
    df3.query("place == 5")  # 東京
    .groupby(["race_type_course_len", "race_class"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df3_grouped.pivot(
    index="race_class",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_72073_row0_col0 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_72073_row0_col1, #T_72073_row0_col2, #T_72073_row1_col0, #T_72073_row1_col3, #T_72073_row1_col5, #T_72073_row1_col6, #T_72073_row1_col7, #T_72073_row1_col8, #T_72073_row1_col9, #T_72073_row1_col10, #T_72073_row3_col11, #T_72073_row7_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_72073_row0_col3, #T_72073_row0_col9, #T_72073_row0_col10, #T_72073_row0_col11, #T_72073_row0_col15, #T_72073_row1_col11, #T_72073_row1_col15, #T_72073_row2_col11, #T_72073_row2_col15, #T_72073_row3_col9, #T_72073_row3_col15, #T_72073_row4_col9, #T_72073_row4_col11, #T_72073_row4_col15, #T_72073_row5_col9, #T_72073_row5_col11, #T_72073_row6_col0, #T_72073_row6_col3, #T_72073_row6_col5, #T_72073_row6_col8, #T_72073_row6_col9, #T_72073_row6_col10, #T_72073_row6_col11, #T_72073_row7_col0, #T_72073_row7_col1, #T_72073_row7_col2, #T_72073_row7_col3, #T_72073_row7_col9, #T_72073_row8_col0, #T_72073_row8_col1, #T_72073_row8_col3, #T_72073_row8_col5, #T_72073_row8_col7, #T_72073_row8_col9, #T_72073_row8_col11, #T_72073_row8_col15 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_72073_row0_col4, #T_72073_row0_col12, #T_72073_row0_col13, #T_72073_row0_col14, #T_72073_row1_col4, #T_72073_row1_col12, #T_72073_row1_col13, #T_72073_row1_col14, #T_72073_row2_col4, #T_72073_row2_col9, #T_72073_row2_col12, #T_72073_row2_col13, #T_72073_row2_col14, #T_72073_row3_col4, #T_72073_row3_col8, #T_72073_row3_col12, #T_72073_row3_col13, #T_72073_row3_col14, #T_72073_row4_col4, #T_72073_row4_col6, #T_72073_row4_col12, #T_72073_row4_col13, #T_72073_row4_col14, #T_72073_row5_col0, #T_72073_row5_col3, #T_72073_row5_col4, #T_72073_row5_col10, #T_72073_row5_col12, #T_72073_row5_col13, #T_72073_row5_col14, #T_72073_row6_col1, #T_72073_row6_col4, #T_72073_row6_col12, #T_72073_row6_col13, #T_72073_row6_col14, #T_72073_row6_col15, #T_72073_row7_col4, #T_72073_row7_col5, #T_72073_row7_col7, #T_72073_row7_col11, #T_72073_row7_col12, #T_72073_row7_col13, #T_72073_row7_col14, #T_72073_row8_col2, #T_72073_row8_col4, #T_72073_row8_col12, #T_72073_row8_col13, #T_72073_row8_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_72073_row0_col5 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_72073_row0_col6 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_72073_row0_col7 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_72073_row0_col8 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_72073_row1_col1 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_72073_row1_col2 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_72073_row2_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_72073_row2_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_72073_row2_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_72073_row2_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_72073_row2_col5 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_72073_row2_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_72073_row2_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_72073_row2_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_72073_row2_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_72073_row3_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_72073_row3_col1, #T_72073_row3_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_72073_row3_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_72073_row3_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_72073_row3_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_72073_row3_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_72073_row3_col10 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_72073_row4_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_72073_row4_col1, #T_72073_row4_col2, #T_72073_row4_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_72073_row4_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_72073_row4_col7 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_72073_row4_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_72073_row4_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_72073_row5_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_72073_row5_col2, #T_72073_row7_col8 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_72073_row5_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_72073_row5_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_72073_row5_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_72073_row5_col8 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_72073_row5_col15 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_72073_row6_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_72073_row6_col6 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_72073_row6_col7 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_72073_row7_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_72073_row7_col10 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_72073_row8_col6 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_72073_row8_col8 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_72073_row8_col10 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72073">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_72073_level0_col0" class="col_heading level0 col0" >0_1300</th>
#       <th id="T_72073_level0_col1" class="col_heading level0 col1" >0_1400</th>
#       <th id="T_72073_level0_col2" class="col_heading level0 col2" >0_1600</th>
#       <th id="T_72073_level0_col3" class="col_heading level0 col3" >0_2100</th>
#       <th id="T_72073_level0_col4" class="col_heading level0 col4" >0_2400</th>
#       <th id="T_72073_level0_col5" class="col_heading level0 col5" >1_1400</th>
#       <th id="T_72073_level0_col6" class="col_heading level0 col6" >1_1600</th>
#       <th id="T_72073_level0_col7" class="col_heading level0 col7" >1_1800</th>
#       <th id="T_72073_level0_col8" class="col_heading level0 col8" >1_2000</th>
#       <th id="T_72073_level0_col9" class="col_heading level0 col9" >1_2300</th>
#       <th id="T_72073_level0_col10" class="col_heading level0 col10" >1_2400</th>
#       <th id="T_72073_level0_col11" class="col_heading level0 col11" >1_2500</th>
#       <th id="T_72073_level0_col12" class="col_heading level0 col12" >1_3400</th>
#       <th id="T_72073_level0_col13" class="col_heading level0 col13" >2_3000</th>
#       <th id="T_72073_level0_col14" class="col_heading level0 col14" >2_3100</th>
#       <th id="T_72073_level0_col15" class="col_heading level0 col15" >2_3110</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >race_class</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72073_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72073_row0_col0" class="data row0 col0" >37.49</td>
#       <td id="T_72073_row0_col1" class="data row0 col1" >38.13</td>
#       <td id="T_72073_row0_col2" class="data row0 col2" >38.45</td>
#       <td id="T_72073_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_72073_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_72073_row0_col5" class="data row0 col5" >34.80</td>
#       <td id="T_720

# %%
#各レースタイプ、競馬場、距離_rankごとのnobori平均

# %%
#芝における、天気や馬場状態の平均タイムの違いを調べる

# "target" 列を作成（time を整数型に変換）
df["target"] = df["time"].astype(int)

# 必要な列を選択して、データを整理
df2 = df[["race_type", "course_len", "place", "target", "wakuban","umaban","race_class","weather","ground_state","sex","around"]].dropna().astype(int)

# race_type と course_len の組み合わせ列を作成
df2["race_type_course_len"] = df2["race_type"].astype(str) + "_" + df2["course_len"].astype(str)

# 各組み合わせごとの数をカウント
df2["type_count"] = df2.groupby("race_type_course_len")["race_type_course_len"].transform("count")
# カウントが1000以上の行のみをフィルタリング
df2 = df2.query("type_count >= 1000")

# %%
# 馬場状態ごとの平均タイムを計算
df2_grouped = (
    df2.query("race_type == 1") 
    .groupby(["race_type_course_len", "weather"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="weather",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_0f8bd_row0_col0 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_0f8bd_row0_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_0f8bd_row0_col2, #T_0f8bd_row0_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_0f8bd_row0_col3 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_0f8bd_row0_col4 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_0f8bd_row0_col5 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_0f8bd_row0_col7 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_0f8bd_row0_col8 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_0f8bd_row0_col9 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_0f8bd_row1_col0, #T_0f8bd_row1_col2, #T_0f8bd_row1_col3, #T_0f8bd_row1_col4, #T_0f8bd_row1_col5, #T_0f8bd_row1_col6, #T_0f8bd_row1_col7, #T_0f8bd_row1_col8, #T_0f8bd_row1_col9, #T_0f8bd_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0f8bd_row1_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_0f8bd_row2_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_0f8bd_row2_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_0f8bd_row2_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_0f8bd_row2_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_0f8bd_row2_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_0f8bd_row2_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_0f8bd_row2_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_0f8bd_row2_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_0f8bd_row2_col8 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_0f8bd_row2_col9 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_0f8bd_row3_col0, #T_0f8bd_row3_col1, #T_0f8bd_row3_col2, #T_0f8bd_row3_col3, #T_0f8bd_row3_col4, #T_0f8bd_row3_col5, #T_0f8bd_row3_col7, #T_0f8bd_row3_col8, #T_0f8bd_row3_col9, #T_0f8bd_row4_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0f8bd_row3_col6 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_0f8bd_row4_col0, #T_0f8bd_row4_col2, #T_0f8bd_row4_col3, #T_0f8bd_row4_col4, #T_0f8bd_row4_col7, #T_0f8bd_row4_col8, #T_0f8bd_row5_col0, #T_0f8bd_row5_col2, #T_0f8bd_row5_col3, #T_0f8bd_row5_col4, #T_0f8bd_row5_col6, #T_0f8bd_row5_col7, #T_0f8bd_row5_col8, #T_0f8bd_row5_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_0f8bd_row4_col5 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_0f8bd_row4_col9 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_0f8bd_row5_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_0f8bd_row5_col5 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0f8bd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_0f8bd_level0_col0" class="col_heading level0 col0" >1_1000</th>
#       <th id="T_0f8bd_level0_col1" class="col_heading level0 col1" >1_1200</th>
#       <th id="T_0f8bd_level0_col2" class="col_heading level0 col2" >1_1400</th>
#       <th id="T_0f8bd_level0_col3" class="col_heading level0 col3" >1_1500</th>
#       <th id="T_0f8bd_level0_col4" class="col_heading level0 col4" >1_1600</th>
#       <th id="T_0f8bd_level0_col5" class="col_heading level0 col5" >1_1800</th>
#       <th id="T_0f8bd_level0_col6" class="col_heading level0 col6" >1_2000</th>
#       <th id="T_0f8bd_level0_col7" class="col_heading level0 col7" >1_2200</th>
#       <th id="T_0f8bd_level0_col8" class="col_heading level0 col8" >1_2400</th>
#       <th id="T_0f8bd_level0_col9" class="col_heading level0 col9" >1_2600</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >weather</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f8bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f8bd_row0_col0" class="data row0 col0" >57.18</td>
#       <td id="T_0f8bd_row0_col1" class="data row0 col1" >69.89</td>
#       <td id="T_0f8bd_row0_col2" class="data row0 col2" >82.35</td>
#       <td id="T_0f8bd_row0_col3" class="data row0 col3" >91.23</td>
#       <td id="T_0f8bd_row0_col4" class="data row0 col4" >96.06</td>
#       <td id="T_0f8bd_row0_col5" class="data row0 col5" >109.68</td>
#       <td id="T_0f8bd_row0_col6" class="data row0 col6" >122.72</td>
#       <td id="T_0f8bd_row0_col7" class="data row0 col7" >136.49</td>
#       <td id="T_0f8bd_row0_col8" class="data row0 col8" >148.75</td>
#       <td id="T_0f8bd_row0_col9" class="data row0 col9" >163.47</td>
#     </tr>
#     <tr>
#       <th id="T_0f8bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f8bd_row1_col0" class="data row1 col0" >55.88</td>
#       <td id="T_0f8bd_row1_col1" class="data row1 col1" >69.32</td>
#       <td id="T_0f8bd_row1_col2" class="data row1 col2" >81.77</td>
#       <td id="T_0f8bd_row1_col3" class="data row1 col3" >89.85</td>
#       <td id="T_0f8bd_row1_col4" class="data row1 col4" >94.74</td>
#       <td id="T_0f8bd_row1_col5" class="data row1 col5" >108.35</td>
#       <td id="T_0f8bd_row1_col6" class="data row1 col6" >121.61</td>
#       <td id="T_0f8bd_row1_col7" class="data row1 col7" >134.76</td>
#       <td id="T_0f8bd_row1_col8" class="data row1 col8" >147.12</td>
#       <td id="T_0f8bd_row1_col9" class="data row1 col9" >162.01</td>
#     </tr>
#     <tr>
#       <th id="T_0f8bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0f8bd_row2_col0" class="data row2 col0" >56.58</td>
#       <td id="T_0f8bd_row2_col1" class="data row2 col1" >69.74</td>
#       <td id="T_0f8bd_row2_col2" class="data row2 col2" >82.16</td>
#       <td id="T_0f8bd_row2_col3" class="data row2 col3" >90.25</td>
#       <td id="T_0f8bd_row2_col4" class="data row2 col4" >95.09</td>
#       <td id="T_0f8bd_row2_col5" class="data row2 col5" >109.00</td>
#       <td id="T_0f8bd_row2_col6" class="data row2 col6" >122.12</td>
#       <td id="T_0f8bd_row2_col7" class="data row2 col7" >135.13</td>
#       <td id="T_0f8bd_row2_col8" class="data row2 col8" >147.93</td>
#       <td id="T_0f8bd_row2_col9" class="data row2 col9" >163.25</td>
#     </tr>
#     <tr>
#       <th id="T_0f8bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0f8bd_row3_col0" class="data row3 col0" >57.45</td>
#       <td id="T_0f8bd_row3_col1" class="data row3 col1" >70.79</td>
#       <td id="T_0f8bd_row3_col2" class="data row3 col2" >83.63</td>
#       <td id="T_0f8bd_row3_col3" class="data row3 col3" >93.52</td>
#       <td id="T_0f8bd_row3_col4" class="data row3 col4" >96.64</td>
#       <td id="T_0f8bd_row3_col5" class="data row3 col5" >110.43</td>
#       <td id="T_0f8bd_row3_col6" class="data row3 col6" >124.97</td>
#       <td id="T_0f8bd_row3_col7" class="data row3 col7" >137.82</td>
#       <td id="T_0f8bd_row3_col8" class="data row3 col8" >150.68</td>
#       <td id="T_0f8bd_row3_col9" class="data row3 col9" >166.88</td>
#     </tr>
#     <tr>
#       <th id="T_0f8bd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0f8bd_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_0f8bd_row4_col1" class="data row4 col1" >69.18</td>
#       <td id="T_0f8bd_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_0f8bd_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_0f8bd_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_0f8bd_row4_col5" class="data row4 col5" >110.36</td>
#       <td id="T_0f8bd_row4_col6" class="data row4 col6" >125.20</td>
#       <td id="T_0f8bd_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_0f8bd_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_0f8bd_row4_col9" class="data row4 col9" >163.00</td>
#     </tr>
#     <tr>
#       <th id="T_0f8bd_level0_row5" class="row_heading

# %%
# 馬場状態ごとの平均タイムを計算
df2_grouped = (
    df2.query("race_type == 1")
    .groupby(["race_type_course_len", "ground_state"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="ground_state",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# スタイル付きのピボットテーブルを Excel に保存
with pd.ExcelWriter("pivot_table_styled_ground_state.xlsx", engine="openpyxl") as writer:
    pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm").to_excel(writer, sheet_name="Pivot Table")

# %%
# 馬場状態ごとの平均タイムを計算
df2_grouped = (
    df2.query("race_type == 1 and ground_state == 0")
    .groupby(["race_type_course_len", "weather"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="weather",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
with pd.ExcelWriter("pivot_table_styled_weather.xlsx", engine="openpyxl") as writer:
    pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm").to_excel(writer, sheet_name="Pivot Table")

# %%
# 馬場状態ごとの平均タイムを計算
df2_grouped = (
    df2.query("race_type == 1 and ground_state == 1")
    .groupby(["race_type_course_len", "weather"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="weather",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_b59a0_row0_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_b59a0_row0_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_b59a0_row0_col2, #T_b59a0_row0_col8, #T_b59a0_row3_col0, #T_b59a0_row3_col3, #T_b59a0_row3_col4, #T_b59a0_row3_col6, #T_b59a0_row3_col7, #T_b59a0_row3_col9, #T_b59a0_row4_col5, #T_b59a0_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b59a0_row0_col3, #T_b59a0_row0_col9, #T_b59a0_row1_col0, #T_b59a0_row1_col2, #T_b59a0_row1_col5, #T_b59a0_row2_col1, #T_b59a0_row2_col4, #T_b59a0_row2_col6, #T_b59a0_row2_col7, #T_b59a0_row2_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b59a0_row0_col4 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_b59a0_row0_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_b59a0_row0_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b59a0_row0_col7 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_b59a0_row1_col1, #T_b59a0_row2_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_b59a0_row1_col3, #T_b59a0_row1_col8, #T_b59a0_row1_col9, #T_b59a0_row2_col3, #T_b59a0_row4_col0, #T_b59a0_row4_col1, #T_b59a0_row4_col2, #T_b59a0_row4_col3, #T_b59a0_row4_col4, #T_b59a0_row4_col7, #T_b59a0_row4_col8, #T_b59a0_row4_col9, #T_b59a0_row5_col0, #T_b59a0_row5_col2, #T_b59a0_row5_col3, #T_b59a0_row5_col4, #T_b59a0_row5_col5, #T_b59a0_row5_col6, #T_b59a0_row5_col7, #T_b59a0_row5_col8, #T_b59a0_row5_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_b59a0_row1_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_b59a0_row1_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b59a0_row1_col7 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_b59a0_row2_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_b59a0_row2_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b59a0_row2_col9 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b59a0_row3_col1 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_b59a0_row3_col2, #T_b59a0_row3_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b59a0_row3_col5 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_b59a0_row4_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b59a0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_b59a0_level0_col0" class="col_heading level0 col0" >1_1000</th>
#       <th id="T_b59a0_level0_col1" class="col_heading level0 col1" >1_1200</th>
#       <th id="T_b59a0_level0_col2" class="col_heading level0 col2" >1_1400</th>
#       <th id="T_b59a0_level0_col3" class="col_heading level0 col3" >1_1500</th>
#       <th id="T_b59a0_level0_col4" class="col_heading level0 col4" >1_1600</th>
#       <th id="T_b59a0_level0_col5" class="col_heading level0 col5" >1_1800</th>
#       <th id="T_b59a0_level0_col6" class="col_heading level0 col6" >1_2000</th>
#       <th id="T_b59a0_level0_col7" class="col_heading level0 col7" >1_2200</th>
#       <th id="T_b59a0_level0_col8" class="col_heading level0 col8" >1_2400</th>
#       <th id="T_b59a0_level0_col9" class="col_heading level0 col9" >1_2600</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >weather</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b59a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b59a0_row0_col0" class="data row0 col0" >57.18</td>
#       <td id="T_b59a0_row0_col1" class="data row0 col1" >70.73</td>
#       <td id="T_b59a0_row0_col2" class="data row0 col2" >84.07</td>
#       <td id="T_b59a0_row0_col3" class="data row0 col3" >92.75</td>
#       <td id="T_b59a0_row0_col4" class="data row0 col4" >96.78</td>
#       <td id="T_b59a0_row0_col5" class="data row0 col5" >110.58</td>
#       <td id="T_b59a0_row0_col6" class="data row0 col6" >123.74</td>
#       <td id="T_b59a0_row0_col7" class="data row0 col7" >137.66</td>
#       <td id="T_b59a0_row0_col8" class="data row0 col8" >153.80</td>
#       <td id="T_b59a0_row0_col9" class="data row0 col9" >164.98</td>
#     </tr>
#     <tr>
#       <th id="T_b59a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b59a0_row1_col0" class="data row1 col0" >57.00</td>
#       <td id="T_b59a0_row1_col1" class="data row1 col1" >70.39</td>
#       <td id="T_b59a0_row1_col2" class="data row1 col2" >83.24</td>
#       <td id="T_b59a0_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_b59a0_row1_col4" class="data row1 col4" >96.47</td>
#       <td id="T_b59a0_row1_col5" class="data row1 col5" >110.31</td>
#       <td id="T_b59a0_row1_col6" class="data row1 col6" >123.71</td>
#       <td id="T_b59a0_row1_col7" class="data row1 col7" >137.26</td>
#       <td id="T_b59a0_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_b59a0_row1_col9" class="data row1 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b59a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b59a0_row2_col0" class="data row2 col0" >57.39</td>
#       <td id="T_b59a0_row2_col1" class="data row2 col1" >70.33</td>
#       <td id="T_b59a0_row2_col2" class="data row2 col2" >83.46</td>
#       <td id="T_b59a0_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_b59a0_row2_col4" class="data row2 col4" >96.20</td>
#       <td id="T_b59a0_row2_col5" class="data row2 col5" >110.38</td>
#       <td id="T_b59a0_row2_col6" class="data row2 col6" >123.61</td>
#       <td id="T_b59a0_row2_col7" class="data row2 col7" >134.81</td>
#       <td id="T_b59a0_row2_col8" class="data row2 col8" >149.68</td>
#       <td id="T_b59a0_row2_col9" class="data row2 col9" >165.28</td>
#     </tr>
#     <tr>
#       <th id="T_b59a0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b59a0_row3_col0" class="data row3 col0" >58.62</td>
#       <td id="T_b59a0_row3_col1" class="data row3 col1" >71.03</td>
#       <td id="T_b59a0_row3_col2" class="data row3 col2" >83.33</td>
#       <td id="T_b59a0_row3_col3" class="data row3 col3" >93.78</td>
#       <td id="T_b59a0_row3_col4" class="data row3 col4" >96.87</td>
#       <td id="T_b59a0_row3_col5" class="data row3 col5" >111.03</td>
#       <td id="T_b59a0_row3_col6" class="data row3 col6" >125.00</td>
#       <td id="T_b59a0_row3_col7" class="data row3 col7" >138.31</td>
#       <td id="T_b59a0_row3_col8" class="data row3 col8" >150.13</td>
#       <td id="T_b59a0_row3_col9" class="data row3 col9" >167.72</td>
#     </tr>
#     <tr>
#       <th id="T_b59a0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b59a0_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_b59a0_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_b59a0_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_b59a0_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_b59a0_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_b59a0_row4_col5" class="data row4 col5" >111.70</td>
#       <td id="T_b59a0_row4_col6" class="data row4 col6" >123.70</td>
#       <td id="T_b59a0_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_b59a0_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_b59a0_row4_col9" class="data row4 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b59a0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b59a0_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_b59a0_row5_col1" class="data row5 col1" >71.31</td>
#       <td id="T_b59a0_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_b59a0_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_b59a0_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_b59a0_row5_col5" class="data row5 col5" >nan</

# %%
# 馬場状態ごとの平均タイムを計算
df2_grouped = (
    df2.query("race_type == 1 and ground_state == 2")
    .groupby(["race_type_course_len", "weather"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="weather",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_3e349_row0_col0, #T_3e349_row0_col3, #T_3e349_row3_col3, #T_3e349_row4_col0, #T_3e349_row4_col1, #T_3e349_row4_col2, #T_3e349_row4_col3, #T_3e349_row4_col4, #T_3e349_row4_col5, #T_3e349_row4_col7, #T_3e349_row4_col8, #T_3e349_row4_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_3e349_row0_col1, #T_3e349_row0_col8, #T_3e349_row0_col9, #T_3e349_row1_col3, #T_3e349_row1_col7, #T_3e349_row2_col0, #T_3e349_row2_col2, #T_3e349_row2_col4, #T_3e349_row2_col5, #T_3e349_row2_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3e349_row0_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_3e349_row0_col4, #T_3e349_row0_col5, #T_3e349_row2_col3, #T_3e349_row2_col8, #T_3e349_row3_col0, #T_3e349_row3_col1, #T_3e349_row3_col2, #T_3e349_row3_col7, #T_3e349_row3_col9, #T_3e349_row4_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3e349_row0_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_3e349_row0_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_3e349_row1_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_3e349_row1_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_3e349_row1_col2 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_3e349_row1_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_3e349_row1_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_3e349_row1_col6 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_3e349_row1_col8 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_3e349_row1_col9 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_3e349_row2_col1 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_3e349_row2_col7 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_3e349_row2_col9 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_3e349_row3_col4 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_3e349_row3_col5, #T_3e349_row3_col8 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_3e349_row3_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3e349">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_3e349_level0_col0" class="col_heading level0 col0" >1_1000</th>
#       <th id="T_3e349_level0_col1" class="col_heading level0 col1" >1_1200</th>
#       <th id="T_3e349_level0_col2" class="col_heading level0 col2" >1_1400</th>
#       <th id="T_3e349_level0_col3" class="col_heading level0 col3" >1_1500</th>
#       <th id="T_3e349_level0_col4" class="col_heading level0 col4" >1_1600</th>
#       <th id="T_3e349_level0_col5" class="col_heading level0 col5" >1_1800</th>
#       <th id="T_3e349_level0_col6" class="col_heading level0 col6" >1_2000</th>
#       <th id="T_3e349_level0_col7" class="col_heading level0 col7" >1_2200</th>
#       <th id="T_3e349_level0_col8" class="col_heading level0 col8" >1_2400</th>
#       <th id="T_3e349_level0_col9" class="col_heading level0 col9" >1_2600</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >weather</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e349_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e349_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_3e349_row0_col1" class="data row0 col1" >69.86</td>
#       <td id="T_3e349_row0_col2" class="data row0 col2" >82.38</td>
#       <td id="T_3e349_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_3e349_row0_col4" class="data row0 col4" >96.48</td>
#       <td id="T_3e349_row0_col5" class="data row0 col5" >109.91</td>
#       <td id="T_3e349_row0_col6" class="data row0 col6" >122.88</td>
#       <td id="T_3e349_row0_col7" class="data row0 col7" >135.60</td>
#       <td id="T_3e349_row0_col8" class="data row0 col8" >147.95</td>
#       <td id="T_3e349_row0_col9" class="data row0 col9" >162.81</td>
#     </tr>
#     <tr>
#       <th id="T_3e349_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3e349_row1_col0" class="data row1 col0" >56.79</td>
#       <td id="T_3e349_row1_col1" class="data row1 col1" >70.07</td>
#       <td id="T_3e349_row1_col2" class="data row1 col2" >82.60</td>
#       <td id="T_3e349_row1_col3" class="data row1 col3" >91.10</td>
#       <td id="T_3e349_row1_col4" class="data row1 col4" >95.66</td>
#       <td id="T_3e349_row1_col5" class="data row1 col5" >109.75</td>
#       <td id="T_3e349_row1_col6" class="data row1 col6" >122.94</td>
#       <td id="T_3e349_row1_col7" class="data row1 col7" >135.55</td>
#       <td id="T_3e349_row1_col8" class="data row1 col8" >148.37</td>
#       <td id="T_3e349_row1_col9" class="data row1 col9" >164.32</td>
#     </tr>
#     <tr>
#       <th id="T_3e349_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3e349_row2_col0" class="data row2 col0" >56.78</td>
#       <td id="T_3e349_row2_col1" class="data row2 col1" >70.15</td>
#       <td id="T_3e349_row2_col2" class="data row2 col2" >82.34</td>
#       <td id="T_3e349_row2_col3" class="data row2 col3" >91.23</td>
#       <td id="T_3e349_row2_col4" class="data row2 col4" >95.51</td>
#       <td id="T_3e349_row2_col5" class="data row2 col5" >109.71</td>
#       <td id="T_3e349_row2_col6" class="data row2 col6" >122.77</td>
#       <td id="T_3e349_row2_col7" class="data row2 col7" >135.99</td>
#       <td id="T_3e349_row2_col8" class="data row2 col8" >149.33</td>
#       <td id="T_3e349_row2_col9" class="data row2 col9" >164.59</td>
#     </tr>
#     <tr>
#       <th id="T_3e349_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3e349_row3_col0" class="data row3 col0" >56.84</td>
#       <td id="T_3e349_row3_col1" class="data row3 col1" >70.23</td>
#       <td id="T_3e349_row3_col2" class="data row3 col2" >82.65</td>
#       <td id="T_3e349_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_3e349_row3_col4" class="data row3 col4" >95.99</td>
#       <td id="T_3e349_row3_col5" class="data row3 col5" >109.82</td>
#       <td id="T_3e349_row3_col6" class="data row3 col6" >123.53</td>
#       <td id="T_3e349_row3_col7" class="data row3 col7" >137.38</td>
#       <td id="T_3e349_row3_col8" class="data row3 col8" >148.73</td>
#       <td id="T_3e349_row3_col9" class="data row3 col9" >166.04</td>
#     </tr>
#     <tr>
#       <th id="T_3e349_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3e349_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_3e349_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_3e349_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_3e349_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_3e349_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_3e349_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_3e349_row4_col6" class="data row4 col6" >126.20</td>
#       <td id="T_3e349_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_3e349_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_3e349_row4_col9" class="data row4 col9" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 馬場状態ごとの平均タイムを計算
df2_grouped = (
    df2.query("race_type == 1 and ground_state == 3")
    .groupby(["race_type_course_len", "weather"], as_index=False)  # グループ化
    .agg({"target": "mean"})  # 平均タイムを計算
)

# ピボットテーブルを作成
pivot_table = df2_grouped.pivot(
    index="weather",   # 行：枠番
    columns="race_type_course_len", # 列：レースタイプと距離
    values="target"  # 値：平均タイム
)

# スタイリングして表示（ノートブックで見やすくする）
pivot_table.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_92d68_row0_col0, #T_92d68_row0_col7, #T_92d68_row1_col0, #T_92d68_row1_col1, #T_92d68_row1_col2, #T_92d68_row4_col0, #T_92d68_row4_col1, #T_92d68_row4_col2, #T_92d68_row4_col3, #T_92d68_row4_col5, #T_92d68_row4_col6, #T_92d68_row4_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_92d68_row0_col1, #T_92d68_row0_col6, #T_92d68_row2_col0, #T_92d68_row3_col2, #T_92d68_row3_col3, #T_92d68_row3_col4, #T_92d68_row3_col5, #T_92d68_row3_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_92d68_row0_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_92d68_row0_col3 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_92d68_row0_col4 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_92d68_row0_col5 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_92d68_row1_col3, #T_92d68_row1_col4, #T_92d68_row1_col7, #T_92d68_row2_col1, #T_92d68_row2_col2, #T_92d68_row2_col5, #T_92d68_row3_col0, #T_92d68_row3_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_92d68_row1_col5 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_92d68_row1_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_92d68_row2_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_92d68_row2_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_92d68_row2_col6 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_92d68_row2_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_92d68_row3_col1 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_92d68_row4_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# </style>
# <table id="T_92d68">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race_type_course_len</th>
#       <th id="T_92d68_level0_col0" class="col_heading level0 col0" >1_1000</th>
#       <th id="T_92d68_level0_col1" class="col_heading level0 col1" >1_1200</th>
#       <th id="T_92d68_level0_col2" class="col_heading level0 col2" >1_1400</th>
#       <th id="T_92d68_level0_col3" class="col_heading level0 col3" >1_1600</th>
#       <th id="T_92d68_level0_col4" class="col_heading level0 col4" >1_1800</th>
#       <th id="T_92d68_level0_col5" class="col_heading level0 col5" >1_2000</th>
#       <th id="T_92d68_level0_col6" class="col_heading level0 col6" >1_2200</th>
#       <th id="T_92d68_level0_col7" class="col_heading level0 col7" >1_2400</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >weather</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92d68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92d68_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_92d68_row0_col1" class="data row0 col1" >72.37</td>
#       <td id="T_92d68_row0_col2" class="data row0 col2" >84.33</td>
#       <td id="T_92d68_row0_col3" class="data row0 col3" >99.00</td>
#       <td id="T_92d68_row0_col4" class="data row0 col4" >111.81</td>
#       <td id="T_92d68_row0_col5" class="data row0 col5" >126.75</td>
#       <td id="T_92d68_row0_col6" class="data row0 col6" >142.42</td>
#       <td id="T_92d68_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_92d68_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92d68_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_92d68_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_92d68_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_92d68_row1_col3" class="data row1 col3" >96.71</td>
#       <td id="T_92d68_row1_col4" class="data row1 col4" >109.33</td>
#       <td id="T_92d68_row1_col5" class="data row1 col5" >126.20</td>
#       <td id="T_92d68_row1_col6" class="data row1 col6" >140.38</td>
#       <td id="T_92d68_row1_col7" class="data row1 col7" >149.33</td>
#     </tr>
#     <tr>
#       <th id="T_92d68_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92d68_row2_col0" class="data row2 col0" >57.56</td>
#       <td id="T_92d68_row2_col1" class="data row2 col1" >70.81</td>
#       <td id="T_92d68_row2_col2" class="data row2 col2" >83.97</td>
#       <td id="T_92d68_row2_col3" class="data row2 col3" >97.67</td>
#       <td id="T_92d68_row2_col4" class="data row2 col4" >110.20</td>
#       <td id="T_92d68_row2_col5" class="data row2 col5" >124.40</td>
#       <td id="T_92d68_row2_col6" class="data row2 col6" >141.21</td>
#       <td id="T_92d68_row2_col7" class="data row2 col7" >149.44</td>
#     </tr>
#     <tr>
#       <th id="T_92d68_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_92d68_row3_col0" class="data row3 col0" >57.38</td>
#       <td id="T_92d68_row3_col1" class="data row3 col1" >72.20</td>
#       <td id="T_92d68_row3_col2" class="data row3 col2" >85.79</td>
#       <td id="T_92d68_row3_col3" class="data row3 col3" >99.05</td>
#       <td id="T_92d68_row3_col4" class="data row3 col4" >113.68</td>
#       <td id="T_92d68_row3_col5" class="data row3 col5" >127.60</td>
#       <td id="T_92d68_row3_col6" class="data row3 col6" >139.25</td>
#       <td id="T_92d68_row3_col7" class="data row3 col7" >155.04</td>
#     </tr>
#     <tr>
#       <th id="T_92d68_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_92d68_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_92d68_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_92d68_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_92d68_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_92d68_row4_col4" class="data row4 col4" >110.62</td>
#       <td id="T_92d68_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_92d68_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_92d68_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
