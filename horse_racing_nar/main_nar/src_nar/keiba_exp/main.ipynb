# %% [markdown]
# # インポート

# %%
import create_population
import create_population_dirt_sonoda
import create_population_dirt_urawa
import create_population_dirt_saga
import create_population_dirt_ooi
import create_population_dirt_nagoya
import create_population_dirt_morioka
import create_population_dirt_monbetu
import create_population_dirt_mizusawa
import create_population_dirt_kouti
import create_population_dirt_kawasaki
import create_population_dirt_kasamatu
import create_population_dirt_kanazawa
import create_population_dirt_funabasi
import preprocessing_nar
from feature_engineering import FeatureCreator



import pandas as pd
import numpy as np

import race_grade_maker

from train_lgbm_rank_niti_cross import Trainer_lightgbm_rank_niti_cv
from train_lgbm_rank_niti_cross_in3 import Trainer_lightgbm_rank_niti_cv_in3

from train_lightgbm_time import Trainer_lightgbm_time
from train_lgbm_time_cross import Trainer_lightgbm_time_cv

from evaluation_lightgbm_time_kaiki import Evaluator_lightgbm_time_kaiki

from evaluation_shaft_time_kaiki_cross import Evaluator_lightgbm_time_kaiki_shaft

from evaluation_lgbm_rank_niti_cross import Evaluator_lightgbm_rank_niti_cross
from evaluation_shaft_rank_cross import Evaluator_lightgbm_rank_niti_shaft

from evaluation_lgbm_rank_niti_cross_ex_value import Evaluator_lightgbm_rank_niti_cross_ex_value

from evaluation_lgbm_rank_niti_cross_in3 import Evaluator_lightgbm_rank_niti_cross_in3

# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 800)

# %% [markdown]
# # 学習母集団の作成
# - ここで何年までのデータを使うか設定してください
# - 2016-01-01から、2024-11-30まではスクレイピングしてあります
# - 特徴量が多いため、あまり年月が嵩むと処理が止まる恐れがあります

# %%
population_dirt_nagoya = create_population_dirt_nagoya.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_nagoya
# Out:
#             race_id       date    horse_id
# 0      202048010101 2020-01-01  2016102293
# 1      202048010101 2020-01-01  2016103605
# 2      202048010101 2020-01-01  2016102254
# 3      202048010101 2020-01-01  2016102330
# 4      202048010101 2020-01-01  2016104199
# ...             ...        ...         ...
# 73071  202548022812 2025-02-28  2020106938
# 73072  202548022812 2025-02-28  2020101617
# 73073  202548022812 2025-02-28  2018105551
# 73074  202548022812 2025-02-28  2017103142
# 73075  202548022812 2025-02-28  2021101386
#
# [73076 rows x 3 columns]

# %%
population_all = create_population.create(from_="2020-01-01", to_="2025-02-28")
population_all
# Out:
#              race_id       date    horse_id
# 0       202045010101 2020-01-01  2017100321
# 1       202045010101 2020-01-01  2017102172
# 2       202045010101 2020-01-01  2017101060
# 3       202045010101 2020-01-01  2017104920
# 4       202045010101 2020-01-01  2017102986
# ...              ...        ...         ...
# 700185  202548022812 2025-02-28  2020106938
# 700186  202548022812 2025-02-28  2020101617
# 700187  202548022812 2025-02-28  2018105551
# 700188  202548022812 2025-02-28  2017103142
# 700189  202548022812 2025-02-28  2021101386
#
# [700190 rows x 3 columns]

# %%
population_dirt_funabasi = create_population_dirt_funabasi.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_funabasi
# Out:
#             race_id       date    horse_id
# 0      202043010701 2020-01-07  2016105249
# 1      202043010701 2020-01-07  2016106244
# 2      202043010701 2020-01-07  2016110053
# 3      202043010701 2020-01-07  2016100771
# 4      202043010701 2020-01-07  2016102836
# ...             ...        ...         ...
# 38762  202543021412 2025-02-14  2020104733
# 38763  202543021412 2025-02-14  2021101338
# 38764  202543021412 2025-02-14  2021106957
# 38765  202543021412 2025-02-14  2021100847
# 38766  202543021412 2025-02-14  2020105653
#
# [38767 rows x 3 columns]

# %%
population_dirt_sonoda = create_population_dirt_sonoda.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_sonoda
# Out:
#             race_id       date    horse_id
# 0      202050010201 2020-01-02  2015103856
# 1      202050010201 2020-01-02  2016101204
# 2      202050010201 2020-01-02  2016103711
# 3      202050010201 2020-01-02  2016105511
# 4      202050010201 2020-01-02  2015102592
# ...             ...        ...         ...
# 99227  202551022712 2025-02-27  2019105527
# 99228  202551022712 2025-02-27  2020100619
# 99229  202551022712 2025-02-27  2021101265
# 99230  202551022712 2025-02-27  2021102974
# 99231  202551022712 2025-02-27  2017106535
#
# [99232 rows x 3 columns]

# %%
population_dirt_kanazawa = create_population_dirt_kanazawa.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_kanazawa
# Out:
#             race_id       date    horse_id
# 0      202046031501 2020-03-15  2017106443
# 1      202046031501 2020-03-15  2017100514
# 2      202046031501 2020-03-15  2017106069
# 3      202046031501 2020-03-15  2017105827
# 4      202046031501 2020-03-15  2017110091
# ...             ...        ...         ...
# 43591  202446122811 2024-12-28  2019102158
# 43592  202446122811 2024-12-28  2018105954
# 43593  202446122811 2024-12-28  2021102177
# 43594  202446122811 2024-12-28  2017101928
# 43595  202446122811 2024-12-28  2020104945
#
# [43596 rows x 3 columns]

# %%
population_dirt_kasamatu = create_population_dirt_kasamatu.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_kasamatu
# Out:
#             race_id       date    horse_id
# 0      202035051701 2020-05-17  2016103780
# 1      202035051701 2020-05-17  2016104092
# 2      202035051701 2020-05-17  2013105706
# 3      202035051701 2020-05-17  2016103661
# 4      202035051701 2020-05-17  2016100654
# ...             ...        ...         ...
# 33594  202435111212 2024-11-12  2020102035
# 33595  202435111212 2024-11-12  2020104124
# 33596  202435111212 2024-11-12  2018102019
# 33597  202435111212 2024-11-12  2020105926
# 33598  202435111212 2024-11-12  2019105744
#
# [33599 rows x 3 columns]

# %%
population_dirt_kawasaki = create_population_dirt_kawasaki.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_kawasaki
# Out:
#             race_id       date    horse_id
# 0      202045010101 2020-01-01  2017100321
# 1      202045010101 2020-01-01  2017102172
# 2      202045010101 2020-01-01  2017101060
# 3      202045010101 2020-01-01  2017104920
# 4      202045010101 2020-01-01  2017102986
# ...             ...        ...         ...
# 43843  202545020812 2025-02-08  2021101536
# 43844  202545020812 2025-02-08  2019100513
# 43845  202545020812 2025-02-08  2017105088
# 43846  202545020812 2025-02-08  2020106043
# 43847  202545020812 2025-02-08  2019106634
#
# [43848 rows x 3 columns]

# %%
population_dirt_kouti = create_population_dirt_kouti.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_kouti
# Out:
#             race_id       date    horse_id
# 0      202054010101 2020-01-01  2016102561
# 1      202054010101 2020-01-01  2016105234
# 2      202054010101 2020-01-01  2016100154
# 3      202054010101 2020-01-01  2015103435
# 4      202054010101 2020-01-01  2016100245
# ...             ...        ...         ...
# 63904  202554022510 2025-02-25  2020100325
# 63905  202554022510 2025-02-25  2021103674
# 63906  202554022510 2025-02-25  2021102889
# 63907  202554022510 2025-02-25  2020104683
# 63908  202554022510 2025-02-25  2019109146
#
# [63909 rows x 3 columns]

# %%
population_dirt_mizusawa = create_population_dirt_mizusawa.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_mizusawa
# Out:
#             race_id       date    horse_id
# 0      202036010201 2020-01-02  2016110136
# 1      202036010201 2020-01-02  2016100781
# 2      202036010201 2020-01-02  2016109053
# 3      202036010201 2020-01-02  2016102629
# 4      202036010201 2020-01-02  2016104092
# ...             ...        ...         ...
# 34350  202436123112 2024-12-31  2015103452
# 34351  202436123112 2024-12-31  2018100116
# 34352  202436123112 2024-12-31  2016100846
# 34353  202436123112 2024-12-31  2017109066
# 34354  202436123112 2024-12-31  2015105502
#
# [34355 rows x 3 columns]

# %%
population_dirt_monbetu = create_population_dirt_monbetu.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_monbetu
# Out:
#             race_id       date    horse_id
# 0      202030041501 2020-04-15  2017104894
# 1      202030041501 2020-04-15  2017103560
# 2      202030041501 2020-04-15  2017102260
# 3      202030041501 2020-04-15  2017104530
# 4      202030041501 2020-04-15  2017100489
# ...             ...        ...         ...
# 47730  202430110712 2024-11-07  2014105851
# 47731  202430110712 2024-11-07  2017100630
# 47732  202430110712 2024-11-07  2018100955
# 47733  202430110712 2024-11-07  2020100492
# 47734  202430110712 2024-11-07  2021104428
#
# [47735 rows x 3 columns]

# %%
population_dirt_morioka = create_population_dirt_morioka.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_morioka
# Out:
#             race_id       date    horse_id
# 0      202035051701 2020-05-17  2016103780
# 1      202035051701 2020-05-17  2016104092
# 2      202035051701 2020-05-17  2013105706
# 3      202035051701 2020-05-17  2016103661
# 4      202035051701 2020-05-17  2016100654
# ...             ...        ...         ...
# 33594  202435111212 2024-11-12  2020102035
# 33595  202435111212 2024-11-12  2020104124
# 33596  202435111212 2024-11-12  2018102019
# 33597  202435111212 2024-11-12  2020105926
# 33598  202435111212 2024-11-12  2019105744
#
# [33599 rows x 3 columns]

# %%
population_dirt_ooi = create_population_dirt_ooi.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_ooi
# Out:
#             race_id       date    horse_id
# 0      202044012001 2020-01-20  2017101093
# 1      202044012001 2020-01-20  2017105697
# 2      202044012001 2020-01-20  2017105605
# 3      202044012001 2020-01-20  2017106156
# 4      202044012001 2020-01-20  2017103645
# ...             ...        ...         ...
# 74361  202544022112 2025-02-21  2021103631
# 74362  202544022112 2025-02-21  2020107159
# 74363  202544022112 2025-02-21  2021105206
# 74364  202544022112 2025-02-21  2021104843
# 74365  202544022112 2025-02-21  2020100449
#
# [74366 rows x 3 columns]

# %%
population_dirt_saga = create_population_dirt_saga.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_saga
# Out:
#             race_id       date    horse_id
# 0      202055010301 2020-01-03  2017106458
# 1      202055010301 2020-01-03  2017102469
# 2      202055010301 2020-01-03  2017105780
# 3      202055010301 2020-01-03  2017100532
# 4      202055010301 2020-01-03  2017102085
# ...             ...        ...         ...
# 66174  202555022311 2025-02-23  2020101339
# 66175  202555022311 2025-02-23  2021104819
# 66176  202555022311 2025-02-23  2021102289
# 66177  202555022311 2025-02-23  2020101415
# 66178  202555022311 2025-02-23  2019100882
#
# [66179 rows x 3 columns]

# %%
population_dirt_urawa = create_population_dirt_urawa.create(from_="2020-01-01", to_="2025-02-28")
population_dirt_urawa
# Out:
#             race_id       date    horse_id
# 0      202042011401 2020-01-14  2017104382
# 1      202042011401 2020-01-14  2017105808
# 2      202042011401 2020-01-14  2017104603
# 3      202042011401 2020-01-14  2017101873
# 4      202042011401 2020-01-14  2017103069
# ...             ...        ...         ...
# 38159  202542022812 2025-02-28  2021102500
# 38160  202542022812 2025-02-28  2021100930
# 38161  202542022812 2025-02-28  2017101498
# 38162  202542022812 2025-02-28  2019106220
# 38163  202542022812 2025-02-28  2021102321
#
# [38164 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 df444 = pd.read_csv(input_dir / input_filename, sep="\t")
#
# NameError: name 'input_dir' is not defined

# %% [markdown]
# # データ加工

# %%
#まとめて実行_all
# レース結果テーブルの前処理
results_preprocessed_all = preprocessing_nar.process_results(
    populaton_filename = "population_all.csv",
    output_filename = "results_all.csv",
)
# 馬の過去成績テーブルの加工
horse_results_preprocessed_all = preprocessing_nar.process_horse_results(
    populaton_filename = "population_all.csv",
    output_filename = "horse_results_all.csv",    
)
# レース情報テーブルの前処理
race_info_preprocessed_all = preprocessing_nar.process_race_info(
    populaton_filename = "population_all.csv",
    output_filename = "race_info_all_before.csv",       
)
# 騎手リーディングテーブルの前処理
# jockey_leading_preprocessed = preprocessing.process_jockey_leading()
# # 調教師リーディングテーブルの前処理
# trainer_leading_preprocessed = preprocessing.process_trainer_leading()
# 血統テーブルの前処理
# peds_preprocessed = preprocessing.process_peds(
#     populaton_filename = "population_all.csv",  
#     output_filename= "peds_all.csv",    
# )
# 払い戻しテーブルの前処理_２度目をするならcsvファイルを消さないとダメ
return_tables_preprocessed_all = preprocessing_nar.process_return_tables(
    populaton_filename = "population_all.csv",
    output_filename = "return_tables_all.pickle",    
)

# %%
# 重複チェック
results_preprocessed_all.duplicated(subset=["race_id", "horse_id"]).sum()
# Out:
# 0

# %%
# 欠損チェック
results_preprocessed_all.isnull().sum()
# Out:
# race_id                    0
# horse_id                   0
# jockey_id                  0
# trainer_id                 0
# owner_id                   0
# rank                       0
# rank_per_horse             0
# time                       0
# nobori                    96
# umaban                     0
# wakuban                    0
# tansho_odds                0
# popularity                 0
# impost                     0
# sex                        0
# age                        0
# weight                     0
# weight_diff                0
# impost_percent             0
# n_horses                   0
# corner_1_per_horse         0
# corner_2_per_horse      6543
# corner_3_per_horse    139437
# corner_4_per_horse    275111
# mean_age                   0
# median_age                 0
# mean_age_kirisute          0
# umaban_odd                 0
# corner_1                   0
# corner_2                6543
# corner_3              139437
# corner_4              275111
# ...

# %%
# 欠損チェック
horse_results_preprocessed_all.isnull().sum()
# Out:
# horse_id                                                         0
# rank_per_horse                                                   0
# date                                                             0
# rank                                                             0
# prize                                                            0
# rank_diff                                                        0
# umaban                                                           0
# wakuban                                                          0
# weather                                                          0
# race_type                                                        0
# course_len                                                       0
# impost                                                           0
# ground_state                                                     0
# race_class                                                       0
# ...

# %%
# 重複チェック
horse_results_preprocessed_all.duplicated(subset=["horse_id", "date"]).sum()
# Out:
# 0

# %%
# race_info_preprocessed_allの'race_class'列に含まれる数字（ユニークな値）の種類を確認する方法
unique_race_class_values = race_info_preprocessed_all['race_class'].unique()
print(unique_race_class_values)
# Out:
# [-12 -11 -10  -8  -6  -5 -14  -9   1  -7 -13 -15  -4   6   8   7   5  -2
#   -3  -1]

# %%
fc_grade = race_grade_maker.create_race_grade(
    poplation_filename="population_all.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all_before.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)

# %%
fc_grade
# Out:
#             race_id        date  race_type  around  course_len  weather  \
# 0      202045010101  2020-01-01          0       1        1500        1
# 1      202045010102  2020-01-01          0       1        1400        1
# 2      202045010103  2020-01-01          0       1        1400        1
# 3      202045010104  2020-01-01          0       1         900        1
# 4      202045010105  2020-01-01          0       1        1400        1
# ...             ...         ...        ...     ...         ...      ...
# 68499  202548022808  2025-02-28          0       0        1500        2
# 68500  202548022809  2025-02-28          0       0        1500        2
# 68501  202548022810  2025-02-28          0       0        1500        2
# 68502  202548022811  2025-02-28          0       0        1700        2
# 68503  202548022812  2025-02-28          0       0        1700        2
#
#        ground_state  race_class  place  season_level  season  place_season  \
# ...

# %% [markdown]
# #  特徴量作成

# %%
#_turfの特徴量作成
fc_funabasi = FeatureCreator(
    poplation_filename="population_dirt_funabasi.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_funabasi.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_funabasi = fc_funabasi.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
# 重複チェック
features_funabasi.duplicated(subset=["race_id", "horse_id"]).sum()
# Out:
# 0

# %%
#特徴量を変更した場合に実行、"config_lightgbm_niti_new.yaml"に特徴量リストが入る
list(features_turf.columns)
import yaml
feature_cols = {
    "features": features_turf.columns.drop(
        ["date","rank","rank_per_horse","time","nobori","corner_1","corner_2","corner_3","corner_4",
                        "corner_1_per_horse","corner_2_per_horse",
                        "corner_3_per_horse",
                        "corner_4_per_horse", "owner_id"]
    ).to_list()
}
print(feature_cols)
with open("config_lightgbm_niti_new.yaml","w") as file:
    yaml.dump(feature_cols,file
              )
# Out:
# {'features': ['race_id', 'horse_id', 'jockey_id', 'trainer_id', 'umaban', 'wakuban', 'tansho_odds', 'popularity', 'impost', 'sex', 'age', 'weight', 'weight_diff', 'impost_percent', 'n_horses', 'mean_age', 'median_age', 'mean_age_kirisute', 'umaban_odd', 'race_type', 'around', 'course_len', 'weather', 'ground_state', 'race_class', 'place', 'season', 'place_season', 'place_season_type', 'kaisai_race', 'kaisai_race_type', 'day', 'day_type', 'kaisai_count', 'kaisai_count_type', 'place_season_day_type', 'day_condition', 'place_season_condition_type', 'place_season_condition_type_categori_x', 'place_course_category', 'place_course_tough', 'goal_range', 'curve', 'goal_slope', 'place_season_type_course_len', 'lap_type', 'race_day_count', 'race_date_day_count', 'goal_range_100', 'course_type', 'course_len_type', 'curve_amount', 'start_point', 'start_range', 'straight_total', 'curve_total', 'curve_R12', 'curve_R34', 'height_diff', 'width', 'start_slope', 'flont_slope', 'first_curve_slope', 'la
# ...

# %%
features_funabasi.head(100)

# %%
#もしもカーネルがリセットした場合、ここからfeatureをとる
features_turf = pd.read_csv("../data/02_features/features_turf.csv", sep="\t")

# %%
#もしもカーネルがリセットした場合、ここからfeatureをとる
features_dirt = pd.read_csv("../data/02_features/features_dirt.csv", sep="\t")

# %%
#もしもカーネルがリセットした場合、ここからfeatureをとる
features_obstract = pd.read_csv("../data/02_features/features_obstract.csv", sep="\t")

# %%
features_funabasi
# Out:
#             race_id        date    horse_id jockey_id trainer_id owner_id  \
# 0      202043010701  2020-01-07  2016105249     jocke      train    owner
# 1      202043010701  2020-01-07  2016106244     jocke      train    owner
# 2      202043010701  2020-01-07  2016110053     jocke      train    owner
# 3      202043010701  2020-01-07  2016100771     jocke      train    owner
# 4      202043010701  2020-01-07  2016102836     jocke      train    owner
# ...             ...         ...         ...       ...        ...      ...
# 38096  202543021412  2025-02-14  2020104733     jocke      train    owner
# 38097  202543021412  2025-02-14  2021101338     jocke      train    owner
# 38098  202543021412  2025-02-14  2021106957     jocke      train    owner
# 38099  202543021412  2025-02-14  2021100847     jocke      train    owner
# 38100  202543021412  2025-02-14  2020105653     jocke      train    owner
#
#        rank  rank_per_horse   time  nobori  umaban  wakuban  tansho_odds  \
# ...

# %%
# rank_1races 列が None の行を抽出
none_rows = features_turf[features_turf["rank_1races"].isna()]
# none_rows の行数を確認
num_rows = none_rows.shape[0]
print(f"rank_1races が None の行数: {num_rows}")
# 表示したい列を指定
columns_to_display = ["horse_id", "date","rank_1races", "race_id"]  # 必要な列名をリストで指定
filtered_none_rows = none_rows[columns_to_display]

filtered_none_rows 
# horse_id 列をリストに変換
horse_id_list = filtered_none_rows["horse_id"].tolist()

# 結果を表示
print(horse_id_list)
# Out:
# rank_1races が None の行数: 0
# []

# %%
# rank_1races 列が None の行を抽出
none_rows = features_dirt[features_dirt["rank_1races"].isna()]
# none_rows の行数を確認
num_rows = none_rows.shape[0]
print(f"rank_1races が None の行数: {num_rows}")
# 表示したい列を指定
columns_to_display = ["horse_id", "date","rank_1races", "race_id"]  # 必要な列名をリストで指定
filtered_none_rows = none_rows[columns_to_display]

filtered_none_rows 
# horse_id 列をリストに変換
horse_id_list = filtered_none_rows["horse_id"].tolist()

# 結果を表示
print(horse_id_list)
# Out:
# rank_1races が None の行数: 268
# ...

# %%
# rank_1races 列が None の行を抽出
none_rows = features_obstract[features_obstract["rank_1races"].isna()]
# none_rows の行数を確認
num_rows = none_rows.shape[0]
print(f"rank_1races が None の行数: {num_rows}")
# 表示したい列を指定
columns_to_display = ["horse_id", "date","rank_1races", "race_id"]  # 必要な列名をリストで指定
filtered_none_rows = none_rows[columns_to_display]

filtered_none_rows 
# horse_id 列をリストに変換
horse_id_list = filtered_none_rows["horse_id"].tolist()

# 結果を表示
print(horse_id_list)
# Out:
# rank_1races が None の行数: 8
# [2010101798, 2013102275, 2016103841, 2017106471, 2017101493, 2019104410, 2017101170, 2019104437]

# %%
#_himeziの特徴量作成
fc_sonoda = FeatureCreator(
    poplation_filename="population_dirt_sonoda.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_sonoda.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_sonoda = fc_sonoda.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_kanazawaの特徴量作成
fc_kanazawa = FeatureCreator(
    poplation_filename="population_dirt_kanazawa.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_kanazawa.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_kanazawa = fc_kanazawa.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_kasamatuの特徴量作成
fc_kasamatu = FeatureCreator(
    poplation_filename="population_dirt_kasamatu.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_kasamatu.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_kasamatu = fc_kasamatu.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_kawasakiの特徴量作成
fc_kawasaki = FeatureCreator(
    poplation_filename="population_dirt_kawasaki.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_kawasaki.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_kawasaki = fc_kawasaki.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_koutiの特徴量作成
fc_kouti = FeatureCreator(
    poplation_filename="population_dirt_kouti.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_kouti.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_kouti = fc_kouti.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_mizusawaの特徴量作成
fc_mizusawa = FeatureCreator(
    poplation_filename="population_dirt_mizusawa.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_mizusawa.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_mizusawa = fc_mizusawa.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_monbetuの特徴量作成
fc_monbetu = FeatureCreator(
    poplation_filename="population_dirt_monbetu.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_monbetu.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_monbetu = fc_monbetu.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_moriokaの特徴量作成
fc_morioka = FeatureCreator(
    poplation_filename="population_dirt_morioka.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_morioka.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_morioka = fc_morioka.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_nagoyaの特徴量作成
fc_nagoya = FeatureCreator(
    poplation_filename="population_dirt_nagoya.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_nagoya.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_nagoya = fc_nagoya.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_ooiの特徴量作成
fc_ooi = FeatureCreator(
    poplation_filename="population_dirt_ooi.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_ooi.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_ooi = fc_ooi.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_sagaの特徴量作成
fc_saga = FeatureCreator(
    poplation_filename="population_dirt_saga.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_saga.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_saga = fc_saga.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %%
#_urawaの特徴量作成
fc_urawa = FeatureCreator(
    poplation_filename="population_dirt_urawa.csv",
    results_filename="results_all.csv",
    race_info_filename="race_info_all.csv",
    horse_results_filename="horse_results_all.csv",
    output_filename = "features_dirt_urawa.csv",
    # peds_filename = "peds_all.csv",
    output_filename_info = "race_info_all.csv",
)
features_urawa = fc_urawa.create_features()
# Out:
# ...
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_rank_diff ...comp
# rank_diff:   0%|          | 0/4 [00:00<?, ?it/s]
# agg_cross_time ...comp
# ...
# agg_horse_per_course_len:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features()...comp
# running agg_interval()...comp
# running cross_features_2()...comp
# agg_cross_encoded:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_3()...comp
# agg_cross_zizoku_syunpatu:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_4()...comp
# running cross_features_5()...comp
# running cross_features_6()...comp
# ...
# pace_category_win_4:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_7()...comp
# agg_pace_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_8()...comp
# agg_goal_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_9()...comp
# agg_curve_per_score:   0%|          | 0/4 [00:00<?, ?it/s]
# running cross_features_10()...comp
# ...

# %% [markdown]
# # 学習
# - 特徴量にオッズを利用したもの、利用していないもの
# - rank列を二値分類で予測したもの、回帰で予測したもの、time列を予測したもの
# - ホールドアウト法、cv(クロスバリデーション)を利用したもの
# - その他、独自の特徴量のみを利用したものなど、さまざまな学習モデルを作成する段階です
# - config_filepath="config_lightgbm_kaiki_odds_removed.yaml"の部分を変更することで、特徴量やハイパーパラメータを変更できます
# - 好きな特徴量を選んで、学習させてください（保存先のファイル名の変更も忘れずに）

# %%
# # _turfオッズありタイム回帰、クロスバリデーション
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_turf.csv", 
#     config_filepath="config_lightgbm_kaiki.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_turf",
#     model_filename="model_lightgbm_time_cv_turf.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_turf.csv",
#     final_model_filename = "model_lightgbm_time_cv_turf.pkl"
# )

# %%
# # _turfオッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション/nopast
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_turf.csv", 
#     config_filepath="config_lightgbm_kaiki_nopast.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_nopast_turf",
#     model_filename="model_lightgbm_time_cv_nopast_turf.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_nopast_turf.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_nopast_turf.pkl"
# )
# Out:
# Training fold 1/5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.387689 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 490610
# [LightGBM] [Info] Number of data points in the train set: 39887, number of used features: 1999
# [LightGBM] [Info] Start training from score 101.132825
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 9.59508
# [200]	valid_0's rmse: 3.69277
# [300]	valid_0's rmse: 1.79183
# [400]	valid_0's rmse: 1.3458
# [500]	valid_0's rmse: 1.26818
# [600]	valid_0's rmse: 1.24726
# [700]	valid_0's rmse: 1.23772
# [800]	valid_0's rmse: 1.23289
# [900]	valid_0's rmse: 1.22871
# [1000]	valid_0's rmse: 1.226
# [1100]	valid_0's rmse: 1.22443
# [1200]	valid_0's rmse: 1.22326
# [1300]	valid_0's rmse: 1.22272
# [1400]	valid_0's rmse: 1.22266
# [1500]	valid_0's rmse: 1.22245
# [1600]	valid_0's rmse: 1.22221
# [1700]	valid_0's rmse: 1.22233
# ...

# %%
# # _turfオッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション_dev（最新型を随時更新）
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_turf.csv", 
#     config_filepath="config_lightgbm_kaiki_dev.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_dev_turf",
#     model_filename="model_lightgbm_time_cv_dev_turf.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_dev_turf.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_dev_turf.pkl"
# )
# Out:
# Training fold 1/5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.220860 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 442629
# [LightGBM] [Info] Number of data points in the train set: 22416, number of used features: 1811
# [LightGBM] [Info] Start training from score 101.169477
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 10.0914
# [200]	valid_0's rmse: 3.91441
# [300]	valid_0's rmse: 1.91883
# [400]	valid_0's rmse: 1.43604
# [500]	valid_0's rmse: 1.34681
# [600]	valid_0's rmse: 1.32123
# [700]	valid_0's rmse: 1.3124
# [800]	valid_0's rmse: 1.30739
# [900]	valid_0's rmse: 1.304
# [1000]	valid_0's rmse: 1.30285
# [1100]	valid_0's rmse: 1.30146
# [1200]	valid_0's rmse: 1.30022
# [1300]	valid_0's rmse: 1.29983
# [1400]	valid_0's rmse: 1.29923
# [1500]	valid_0's rmse: 1.29928
# [1600]	valid_0's rmse: 1.29898
# [1700]	valid_0's rmse: 1.29881
# ...

# %%
# # _turfオッズと人気を特徴量から省いたindex、クロスバリデーション_dev（最新型を随時更新）
# trainer = Trainer_lightgbm_index_cv(
#     features_filename = "features_turf.csv", 
#     config_filepath="config_lightgbm_kaiki_dev.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_index_cv_dev_turf",
#     model_filename="model_lightgbm_index_cv_dev_turf.pkl",
#     evaluation_filename="evaluation_lightgbm_index_cv_dev_turf.csv",
#     final_model_filename = "model_lightgbm_index_cv_full_dev_turf.pkl"
# )
# Out:
# Training fold 1/5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.244502 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 430421
# [LightGBM] [Info] Number of data points in the train set: 22416, number of used features: 1763
# [LightGBM] [Info] Start training from score 78.928801
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 2.13565
# [200]	valid_0's rmse: 1.6025
# [300]	valid_0's rmse: 1.43423
# [400]	valid_0's rmse: 1.36772
# [500]	valid_0's rmse: 1.33621
# [600]	valid_0's rmse: 1.31597
# [700]	valid_0's rmse: 1.30449
# [800]	valid_0's rmse: 1.29722
# [900]	valid_0's rmse: 1.2926
# [1000]	valid_0's rmse: 1.2897
# [1100]	valid_0's rmse: 1.2878
# [1200]	valid_0's rmse: 1.28608
# [1300]	valid_0's rmse: 1.28539
# [1400]	valid_0's rmse: 1.2847
# [1500]	valid_0's rmse: 1.28408
# [1600]	valid_0's rmse: 1.28362
# [1700]	valid_0's rmse: 1.28334
# ...

# %%
# #_turf_newbie オッズありタイム回帰、クロスバリデーション
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_turf_newbie.csv", 
#     config_filepath="config_lightgbm_kaiki.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_turf_newbie",
#     model_filename="model_lightgbm_time_cv_turf_newbie.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_turf_newbie.csv",
#     final_model_filename = "model_lightgbm_time_cv_turf_newbie.pkl"
# )

# %%
# # _turf_newbie オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション/nopast
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_turf_newbie.csv", 
#     config_filepath="config_lightgbm_kaiki_nopast.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_nopast_turf_newbie",
#     model_filename="model_lightgbm_time_cv_nopast_turf_newbie.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_nopast_turf_newbie.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_nopast_turf_newbie.pkl"
# )

# %%
# # _turf_newbie オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション_dev（最新型を随時更新）
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_turf_newbie.csv", 
#     config_filepath="config_lightgbm_kaiki_dev.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_dev_turf_newbie",
#     model_filename="model_lightgbm_time_cv_dev_turf_newbie.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_dev_turf_newbie.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_dev_turf_newbie.pkl"
# )

# %%
# #_turf_nowin オッズありタイム回帰、クロスバリデーション
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_turf_nowin.csv", 
#     config_filepath="config_lightgbm_kaiki.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_turf_nowin",
#     model_filename="model_lightgbm_time_cv_turf_nowin.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_turf_nowin.csv",
#     final_model_filename = "model_lightgbm_time_cv_turf_nowin.pkl"
# )

# %%
# # _turf_nowin オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション/nopast
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_turf_nowin.csv", 
#     config_filepath="config_lightgbm_kaiki_nopast.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_nopast_turf_nowin",
#     model_filename="model_lightgbm_time_cv_nopast_turf_nowin.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_nopast_turf_nowin.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_nopast_turf_nowin.pkl"
# )

# %%
# # _turf_nowin オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション_dev（最新型を随時更新）
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_turf_nowin.csv", 
#     config_filepath="config_lightgbm_kaiki_dev.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_dev_turf_nowin",
#     model_filename="model_lightgbm_time_cv_dev_turf_nowin.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_dev_turf_nowin.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_dev_turf_nowin.pkl"
# )
# Out:
# Training fold 1/5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093781 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 424719
# [LightGBM] [Info] Number of data points in the train set: 12872, number of used features: 1756
# [LightGBM] [Info] Start training from score 102.434431
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 8.4528
# [200]	valid_0's rmse: 3.35594
# [300]	valid_0's rmse: 1.76338
# [400]	valid_0's rmse: 1.40944
# [500]	valid_0's rmse: 1.34377
# [600]	valid_0's rmse: 1.32975
# [700]	valid_0's rmse: 1.32687
# [800]	valid_0's rmse: 1.32508
# [900]	valid_0's rmse: 1.32439
# [1000]	valid_0's rmse: 1.32422
# Early stopping, best iteration is:
# [985]	valid_0's rmse: 1.32418
# ...

# %%
# #_dirt オッズありタイム回帰、クロスバリデーション
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_dirt.csv", 
#     config_filepath="config_lightgbm_kaiki.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_dirt",
#     model_filename="model_lightgbm_time_cv_dirt.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_dirt.csv",
#     final_model_filename = "model_lightgbm_time_cv_dirt.pkl"
# )

# %%
# # _dirt オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション/nopast
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_dirt.csv", 
#     config_filepath="config_lightgbm_kaiki_nopast.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_nopast_dirt",
#     model_filename="model_lightgbm_time_cv_nopast_dirt.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_nopast_dirt.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_nopast_dirt.pkl"
# )

# %%
# # _dirt オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション_dev（最新型を随時更新）
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_dirt.csv", 
#     config_filepath="config_lightgbm_kaiki_dev_dirt.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_dev_dirt",
#     model_filename="model_lightgbm_time_cv_dev_dirt.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_dev_dirt.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_dev_dirt.pkl"
# )
# Out:
# Training fold 1/5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.208637 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 411656
# [LightGBM] [Info] Number of data points in the train set: 22863, number of used features: 1699
# [LightGBM] [Info] Start training from score 96.011022
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 7.72464
# [200]	valid_0's rmse: 3.07654
# [300]	valid_0's rmse: 1.62792
# [400]	valid_0's rmse: 1.30888
# [500]	valid_0's rmse: 1.25944
# [600]	valid_0's rmse: 1.25385
# [700]	valid_0's rmse: 1.25227
# [800]	valid_0's rmse: 1.25042
# [900]	valid_0's rmse: 1.2501
# Early stopping, best iteration is:
# [882]	valid_0's rmse: 1.24986
# ...

# %%
# #_dirt_newbie オッズありタイム回帰、クロスバリデーション
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_dirt_newbie.csv", 
#     config_filepath="config_lightgbm_kaiki.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_dirt_newbie",
#     model_filename="model_lightgbm_time_cv_dirt_newbie.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_dirt_newbie.csv",
#     final_model_filename = "model_lightgbm_time_cv_dirt_newbie.pkl"
# )

# %%
# # _dirt_newbie オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション/nopast
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_dirt_newbie.csv", 
#     config_filepath="config_lightgbm_kaiki_nopast.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_nopast_dirt_newbie",
#     model_filename="model_lightgbm_time_cv_nopast_dirt_newbie.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_nopast_dirt_newbie.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_nopast_dirt_newbie.pkl"
# )

# %%
# # _dirt_newbie オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション_dev（最新型を随時更新）
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_dirt_newbie.csv", 
#     config_filepath="config_lightgbm_kaiki_dev_dirt.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_dev_dirt_newbie",
#     model_filename="model_lightgbm_time_cv_dev_dirt_newbie.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_dev_dirt_newbie.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_dev_dirt_newbie.pkl"
# )

# %%
# #_dirt_nowin オッズありタイム回帰、クロスバリデーション
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_dirt_nowin.csv", 
#     config_filepath="config_lightgbm_kaiki.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_dirt_nowin",
#     model_filename="model_lightgbm_time_cv_dirt_nowin.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_dirt_nowin.csv",
#     final_model_filename = "model_lightgbm_time_cv_dirt_nowin.pkl"
# )

# %%
# # _dirt_nowin オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション/nopast
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_dirt_nowin.csv", 
#     config_filepath="config_lightgbm_kaiki_nopast.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_nopast_dirt_nowin",
#     model_filename="model_lightgbm_time_cv_nopast_dirt_nowin.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_nopast_dirt_nowin.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_nopast_dirt_nowin.pkl"
# )

# %%
# # _dirt_nowin オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション_dev（最新型を随時更新）
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_dirt_nowin.csv", 
#     config_filepath="config_lightgbm_kaiki_dev_dirt.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_dev_dirt_nowin",
#     model_filename="model_lightgbm_time_cv_dev_dirt_nowin.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_dev_dirt_nowin.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_dev_dirt_nowin.pkl"
# )
# Out:
# Training fold 1/5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 106552
# [LightGBM] [Info] Number of data points in the train set: 16789, number of used features: 520
# [LightGBM] [Info] Start training from score 96.906486
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 7.52882
# [200]	valid_0's rmse: 3.24832
# [300]	valid_0's rmse: 2.01147
# [400]	valid_0's rmse: 1.75327
# [500]	valid_0's rmse: 1.69983
# [600]	valid_0's rmse: 1.68556
# [700]	valid_0's rmse: 1.68062
# [800]	valid_0's rmse: 1.678
# [900]	valid_0's rmse: 1.67505
# [1000]	valid_0's rmse: 1.67296
# [1100]	valid_0's rmse: 1.67204
# [1200]	valid_0's rmse: 1.66855
# [1300]	valid_0's rmse: 1.66818
# [1400]	valid_0's rmse: 1.66776
# Early stopping, best iteration is:
# [1364]	valid_0's rmse: 1.66741
# ...

# %%
# #_obstract オッズありタイム回帰、クロスバリデーション
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_obstract.csv", 
#     config_filepath="config_lightgbm_kaiki.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_obstract",
#     model_filename="model_lightgbm_time_cv_obstract.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_obstract.csv",
#     final_model_filename = "model_lightgbm_time_cv_obstract.pkl"
# )

# %%
# # _obstract オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション/nopast
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_obstract.csv", 
#     config_filepath="config_lightgbm_kaiki_nopast.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_time_cv_nopast_obstract",
#     model_filename="model_lightgbm_time_cv_nopast_obstract.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_nopast_obstract.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_nopast_obstract.pkl"
# )

# %%
# # _obstract オッズと人気を特徴量から省いたタイム、回帰、クロスバリデーション_dev（最新型を随時更新）
# trainer = Trainer_lightgbm_time_cv(
#     features_filename = "features_obstract.csv", 
#     config_filepath="config_lightgbm_kaiki_dev_obstract.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 3,
#     importance_filename="importance_lightgbm_time_cv_dev_obstract",
#     model_filename="model_lightgbm_time_cv_dev_obstract.pkl",
#     evaluation_filename="evaluation_lightgbm_time_cv_dev_obstract.csv",
#     final_model_filename = "model_lightgbm_time_cv_full_dev_obstract.pkl"
# )
# Out:
# Training fold 1/3...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 314283
# [LightGBM] [Info] Number of data points in the train set: 4167, number of used features: 1332
# [LightGBM] [Info] Start training from score 203.518838
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 7.5586
# [200]	valid_0's rmse: 4.2079
# [300]	valid_0's rmse: 3.51441
# [400]	valid_0's rmse: 3.40381
# [500]	valid_0's rmse: 3.3787
# [600]	valid_0's rmse: 3.36874
# [700]	valid_0's rmse: 3.3676
# Early stopping, best iteration is:
# [654]	valid_0's rmse: 3.36674
# /opt/anaconda3/envs/horse/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
# ...

# %%
missing_count = features_ooi["speed_index"].isna().sum()
print(f"speed_index の欠損数: {missing_count}")
# Out:
# speed_index の欠損数: 608

# %%
# %autoreload

# %% [markdown]
# ### スピード指数

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_time_cv(
    features_filename = "features_dirt_sonoda.csv", 
    config_filepath="config_lightgbm_kaiki_dev_dirt10.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_kaiki_cv_dev_dirt_sonoda",
    model_filename="model_lightgbm_kaikii_cv_dev_dirt_sonoda.pkl",
    evaluation_filename="evaluation_lightgbm_kaiki_cv_dev_dirt_sonoda.csv",
    final_model_filename = "model_lightgbm_kaiki_cv_full_dev_dirt_sonoda.pkl",
    final_num_boost_round = 2000
)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[158], line 6
#       1 # オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
#       2 trainer = Trainer_lightgbm_time_cv(
#       3     features_filename = "features_dirt_sonoda.csv",
#       4     config_filepath="config_lightgbm_kaiki_dev_dirt10.yaml",
#       5 )
# ----> 6 evaluation_df = trainer.run(
#       7     n_splits = 5,
#       8     importance_filename="importance_lightgbm_kaiki_cv_dev_dirt_sonoda",
#       9     model_filename="model_lightgbm_kaikii_cv_dev_dirt_sonoda.pkl",
#      10     evaluation_filename="evaluation_lightgbm_kaiki_cv_dev_dirt_sonoda.csv",
#      11     final_model_filename = "model_lightgbm_kaiki_cv_full_dev_dirt_sonoda.pkl",
#      12     final_num_boost_round = 2000
#      13 )
#
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_time_cv(
    features_filename = "features_dirt_sonoda.csv", 
    config_filepath="config_lightgbm_kaiki_dev_dirt10.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_kaiki_cv_dev_dirt_sonoda",
    model_filename="model_lightgbm_kaikii_cv_dev_dirt_sonoda.pkl",
    evaluation_filename="evaluation_lightgbm_kaiki_cv_dev_dirt_sonoda.csv",
    final_model_filename = "model_lightgbm_kaiki_cv_full_dev_dirt_sonoda.pkl",
    final_num_boost_round = 2000
)

# %%
名古屋7

笠松3

園田10


高知6

紋別５

金沢4

佐賀７

浦和４
船橋4
川崎4

多い７


盛岡３
水沢4

yamlを少ないverと多いverに分ける
4,7,10

# %% [markdown]
# ### 二値分類

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_sonoda.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt10.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_sonoda",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_sonoda.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_sonoda.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_sonoda.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.280428
# [200]	valid_0's binary_logloss: 0.27115
# [300]	valid_0's binary_logloss: 0.268517
# [400]	valid_0's binary_logloss: 0.267664
# [500]	valid_0's binary_logloss: 0.267712
# Early stopping, best iteration is:
# [446]	valid_0's binary_logloss: 0.267622
# -------------------- Metrics --------------------
# Accuracy: 0.6470
# Precision: 0.1923
# Recall: 0.8048
# F1 Score: 0.3104
# ROC AUC: 0.7985
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.265834
# [600]	valid_0's binary_logloss: 0.264307
# [700]	valid_0's binary_logloss: 0.263305
# [800]	valid_0's binary_logloss: 0.262865
# [900]	valid_0's binary_logloss: 0.262599
# [1000]	valid_0's binary_logloss: 0.262286
# [1100]	valid_0's binary_logloss: 0.262285
# Early stopping, best iteration is:
# [1026]	valid_0's binary_logloss: 0.2622
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_urawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_urawa",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_urawa.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_urawa.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_urawa.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.268276
# [200]	valid_0's binary_logloss: 0.262162
# [300]	valid_0's binary_logloss: 0.261621
# Early stopping, best iteration is:
# [269]	valid_0's binary_logloss: 0.261366
# -------------------- Metrics --------------------
# Accuracy: 0.6853
# Precision: 0.1868
# Recall: 0.7263
# F1 Score: 0.2972
# ROC AUC: 0.7805
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.275207
# [400]	valid_0's binary_logloss: 0.272998
# [500]	valid_0's binary_logloss: 0.272427
# [600]	valid_0's binary_logloss: 0.272806
# Early stopping, best iteration is:
# [540]	valid_0's binary_logloss: 0.272239
# -------------------- Metrics --------------------
# Accuracy: 0.6940
# Precision: 0.2031
# Recall: 0.7452
# F1 Score: 0.3192
# ROC AUC: 0.7795
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_saga.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_saga",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_saga.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_saga.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_saga.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.265538
# [200]	valid_0's binary_logloss: 0.254696
# [300]	valid_0's binary_logloss: 0.251951
# [400]	valid_0's binary_logloss: 0.251261
# Early stopping, best iteration is:
# [396]	valid_0's binary_logloss: 0.251233
# -------------------- Metrics --------------------
# Accuracy: 0.7181
# Precision: 0.2316
# Recall: 0.7859
# F1 Score: 0.3578
# ROC AUC: 0.8310
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.270276
# [500]	valid_0's binary_logloss: 0.267801
# [600]	valid_0's binary_logloss: 0.266917
# [700]	valid_0's binary_logloss: 0.266534
# [800]	valid_0's binary_logloss: 0.266428
# [900]	valid_0's binary_logloss: 0.266543
# Early stopping, best iteration is:
# [836]	valid_0's binary_logloss: 0.266384
# -------------------- Metrics --------------------
# Accuracy: 0.6874
# Precision: 0.2184
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_ooi.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_ooi",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_ooi.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_ooi.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_ooi.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.239419
# [200]	valid_0's binary_logloss: 0.232606
# [300]	valid_0's binary_logloss: 0.230614
# [400]	valid_0's binary_logloss: 0.230382
# Early stopping, best iteration is:
# [377]	valid_0's binary_logloss: 0.230273
# -------------------- Metrics --------------------
# Accuracy: 0.7109
# Precision: 0.1796
# Recall: 0.7530
# F1 Score: 0.2900
# ROC AUC: 0.7997
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.233649
# [500]	valid_0's binary_logloss: 0.233125
# [600]	valid_0's binary_logloss: 0.232734
# [700]	valid_0's binary_logloss: 0.232782
# Early stopping, best iteration is:
# [651]	valid_0's binary_logloss: 0.232692
# -------------------- Metrics --------------------
# Accuracy: 0.7036
# Precision: 0.1814
# Recall: 0.7589
# F1 Score: 0.2928
# ROC AUC: 0.8026
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_nagoya.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_nagoya",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_nagoya.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_nagoya.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_nagoya.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.27543
# [200]	valid_0's binary_logloss: 0.26564
# [300]	valid_0's binary_logloss: 0.263635
# [400]	valid_0's binary_logloss: 0.263943
# Early stopping, best iteration is:
# [335]	valid_0's binary_logloss: 0.263608
# -------------------- Metrics --------------------
# Accuracy: 0.6953
# Precision: 0.2182
# Recall: 0.7869
# F1 Score: 0.3416
# ROC AUC: 0.8159
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.25119
# [500]	valid_0's binary_logloss: 0.250624
# [600]	valid_0's binary_logloss: 0.250203
# [700]	valid_0's binary_logloss: 0.250292
# Early stopping, best iteration is:
# [613]	valid_0's binary_logloss: 0.250109
# -------------------- Metrics --------------------
# Accuracy: 0.7025
# Precision: 0.2094
# Recall: 0.7859
# F1 Score: 0.3307
# ROC AUC: 0.8176
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_morioka.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_morioka",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_morioka.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_morioka.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_morioka.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.29673
# [200]	valid_0's binary_logloss: 0.288965
# [300]	valid_0's binary_logloss: 0.287908
# Early stopping, best iteration is:
# [285]	valid_0's binary_logloss: 0.287723
# -------------------- Metrics --------------------
# Accuracy: 0.6617
# Precision: 0.2169
# Recall: 0.7921
# F1 Score: 0.3405
# ROC AUC: 0.7943
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.2727
# [400]	valid_0's binary_logloss: 0.270805
# [500]	valid_0's binary_logloss: 0.270835
# Early stopping, best iteration is:
# [454]	valid_0's binary_logloss: 0.270617
# -------------------- Metrics --------------------
# Accuracy: 0.6581
# Precision: 0.2117
# Recall: 0.8068
# F1 Score: 0.3354
# ROC AUC: 0.8157
# Training fold 3/5...
# Training until validation scores don't improve for 100 rounds
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_monbetu.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_monbetu",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_monbetu.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_monbetu.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_monbetu.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.27712
# [200]	valid_0's binary_logloss: 0.264497
# [300]	valid_0's binary_logloss: 0.260978
# [400]	valid_0's binary_logloss: 0.25995
# [500]	valid_0's binary_logloss: 0.260345
# Early stopping, best iteration is:
# [409]	valid_0's binary_logloss: 0.259857
# -------------------- Metrics --------------------
# Accuracy: 0.6818
# Precision: 0.2229
# Recall: 0.8268
# F1 Score: 0.3512
# ROC AUC: 0.8305
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.273066
# [600]	valid_0's binary_logloss: 0.272145
# [700]	valid_0's binary_logloss: 0.271956
# [800]	valid_0's binary_logloss: 0.271718
# [900]	valid_0's binary_logloss: 0.27185
# Early stopping, best iteration is:
# [835]	valid_0's binary_logloss: 0.271607
# -------------------- Metrics --------------------
# Accuracy: 0.6774
# Precision: 0.2242
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_mizusawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_mizusawa",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_mizusawa.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_mizusawa.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_mizusawa.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.301865
# [200]	valid_0's binary_logloss: 0.293767
# [300]	valid_0's binary_logloss: 0.291315
# [400]	valid_0's binary_logloss: 0.291868
# Early stopping, best iteration is:
# [344]	valid_0's binary_logloss: 0.290934
# -------------------- Metrics --------------------
# Accuracy: 0.6579
# Precision: 0.2052
# Recall: 0.7658
# F1 Score: 0.3236
# ROC AUC: 0.7741
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.28728
# [500]	valid_0's binary_logloss: 0.286074
# [600]	valid_0's binary_logloss: 0.286065
# Early stopping, best iteration is:
# [576]	valid_0's binary_logloss: 0.285951
# -------------------- Metrics --------------------
# Accuracy: 0.6355
# Precision: 0.1986
# Recall: 0.8053
# F1 Score: 0.3187
# ROC AUC: 0.7820
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kouti.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_kouti",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_kouti.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kouti.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_kouti.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.267247
# [200]	valid_0's binary_logloss: 0.255578
# [300]	valid_0's binary_logloss: 0.252284
# [400]	valid_0's binary_logloss: 0.251447
# [500]	valid_0's binary_logloss: 0.251814
# Early stopping, best iteration is:
# [412]	valid_0's binary_logloss: 0.251438
# -------------------- Metrics --------------------
# Accuracy: 0.7164
# Precision: 0.2361
# Recall: 0.8082
# F1 Score: 0.3655
# ROC AUC: 0.8391
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.252466
# [600]	valid_0's binary_logloss: 0.251947
# [700]	valid_0's binary_logloss: 0.251493
# [800]	valid_0's binary_logloss: 0.251336
# [900]	valid_0's binary_logloss: 0.251265
# Early stopping, best iteration is:
# [890]	valid_0's binary_logloss: 0.251223
# -------------------- Metrics --------------------
# Accuracy: 0.7106
# Precision: 0.2337
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kawasaki.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_kawasaki",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_kawasaki.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kawasaki.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_kawasaki.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.267568
# [200]	valid_0's binary_logloss: 0.260907
# [300]	valid_0's binary_logloss: 0.259905
# Early stopping, best iteration is:
# [282]	valid_0's binary_logloss: 0.259815
# -------------------- Metrics --------------------
# Accuracy: 0.6817
# Precision: 0.1817
# Recall: 0.7290
# F1 Score: 0.2909
# ROC AUC: 0.7795
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.259219
# [400]	valid_0's binary_logloss: 0.2573
# [500]	valid_0's binary_logloss: 0.256847
# [600]	valid_0's binary_logloss: 0.25672
# [700]	valid_0's binary_logloss: 0.256882
# Early stopping, best iteration is:
# [660]	valid_0's binary_logloss: 0.256602
# -------------------- Metrics --------------------
# Accuracy: 0.6843
# Precision: 0.1864
# Recall: 0.7436
# F1 Score: 0.2980
# ROC AUC: 0.7860
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kasamatu.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_kasamatu",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_kasamatu.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kasamatu.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_kasamatu.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.29673
# [200]	valid_0's binary_logloss: 0.288965
# [300]	valid_0's binary_logloss: 0.287908
# Early stopping, best iteration is:
# [285]	valid_0's binary_logloss: 0.287723
# -------------------- Metrics --------------------
# Accuracy: 0.6617
# Precision: 0.2169
# Recall: 0.7921
# F1 Score: 0.3405
# ROC AUC: 0.7943
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.2727
# [400]	valid_0's binary_logloss: 0.270805
# [500]	valid_0's binary_logloss: 0.270835
# Early stopping, best iteration is:
# [454]	valid_0's binary_logloss: 0.270617
# -------------------- Metrics --------------------
# Accuracy: 0.6581
# Precision: 0.2117
# Recall: 0.8068
# F1 Score: 0.3354
# ROC AUC: 0.8157
# Training fold 3/5...
# Training until validation scores don't improve for 100 rounds
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kanazawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_kanazawa",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_kanazawa.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kanazawa.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_kanazawa.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.289464
# [200]	valid_0's binary_logloss: 0.275802
# [300]	valid_0's binary_logloss: 0.273231
# [400]	valid_0's binary_logloss: 0.273432
# Early stopping, best iteration is:
# [355]	valid_0's binary_logloss: 0.272957
# -------------------- Metrics --------------------
# Accuracy: 0.6946
# Precision: 0.2522
# Recall: 0.8179
# F1 Score: 0.3856
# ROC AUC: 0.8375
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.28207
# [500]	valid_0's binary_logloss: 0.279436
# [600]	valid_0's binary_logloss: 0.278791
# Early stopping, best iteration is:
# [568]	valid_0's binary_logloss: 0.278651
# -------------------- Metrics --------------------
# Accuracy: 0.6792
# Precision: 0.2401
# Recall: 0.8169
# F1 Score: 0.3711
# ROC AUC: 0.8292
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_funabasi.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_funabasi",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_funabasi.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_funabasi.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_funabasi.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.268066
# [200]	valid_0's binary_logloss: 0.26088
# [300]	valid_0's binary_logloss: 0.260069
# Early stopping, best iteration is:
# [258]	valid_0's binary_logloss: 0.259961
# -------------------- Metrics --------------------
# Accuracy: 0.7072
# Precision: 0.2097
# Recall: 0.7629
# F1 Score: 0.3290
# ROC AUC: 0.8008
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.278025
# [400]	valid_0's binary_logloss: 0.276805
# [500]	valid_0's binary_logloss: 0.277135
# Early stopping, best iteration is:
# [400]	valid_0's binary_logloss: 0.276805
# -------------------- Metrics --------------------
# Accuracy: 0.6845
# Precision: 0.1953
# Recall: 0.7279
# F1 Score: 0.3080
# ROC AUC: 0.7703
# Training fold 3/5...
# Training until validation scores don't improve for 100 rounds
# ...

# %%
# #全体のレースを学習した際、最後のブースト回数よりも多いか確認
# import lightgbm as lgb
# import pickle

# from pathlib import Path
# DATA_DIR = Path("..", "data")
# INPUT_DIR = DATA_DIR / "02_features"
# OUTPUT_DIR = DATA_DIR / "03_train"

# # モデルの読み込み
# with open(OUTPUT_DIR/"model_lightgbm_rank_niti_cv_full_dev_turf.pkl", "rb") as f:
#     model = pickle.load(f)

# # ブースト回数の取得
# num_trees = model.num_trees()

# print(f"ブースト回数（num_boost_round）: {num_trees}")

# %% [markdown]
# ### 体重なし

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_sonoda.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight10.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_sonoda",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_sonoda.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_sonoda.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_sonoda.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.280348
# [200]	valid_0's binary_logloss: 0.271135
# [300]	valid_0's binary_logloss: 0.268566
# [400]	valid_0's binary_logloss: 0.26756
# [500]	valid_0's binary_logloss: 0.267259
# Early stopping, best iteration is:
# [482]	valid_0's binary_logloss: 0.267223
# -------------------- Metrics --------------------
# Accuracy: 0.6515
# Precision: 0.1944
# Recall: 0.8048
# F1 Score: 0.3131
# ROC AUC: 0.7997
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.267446
# [600]	valid_0's binary_logloss: 0.265438
# [700]	valid_0's binary_logloss: 0.264525
# [800]	valid_0's binary_logloss: 0.264078
# [900]	valid_0's binary_logloss: 0.263763
# [1000]	valid_0's binary_logloss: 0.263631
# [1100]	valid_0's binary_logloss: 0.26358
# Early stopping, best iteration is:
# [1090]	valid_0's binary_logloss: 0.263567
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_urawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_urawa",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_urawa.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_urawa.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_urawa.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.269583
# [200]	valid_0's binary_logloss: 0.264083
# [300]	valid_0's binary_logloss: 0.26413
# Early stopping, best iteration is:
# [244]	valid_0's binary_logloss: 0.263587
# -------------------- Metrics --------------------
# Accuracy: 0.6728
# Precision: 0.1807
# Recall: 0.7278
# F1 Score: 0.2895
# ROC AUC: 0.7752
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.275916
# [400]	valid_0's binary_logloss: 0.274248
# [500]	valid_0's binary_logloss: 0.27399
# Early stopping, best iteration is:
# [490]	valid_0's binary_logloss: 0.273975
# -------------------- Metrics --------------------
# Accuracy: 0.6832
# Precision: 0.1953
# Recall: 0.7341
# F1 Score: 0.3085
# ROC AUC: 0.7745
# Training fold 3/5...
# Training until validation scores don't improve for 100 rounds
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_saga.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_saga",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_saga.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_saga.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_saga.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.2655
# [200]	valid_0's binary_logloss: 0.254521
# [300]	valid_0's binary_logloss: 0.252011
# [400]	valid_0's binary_logloss: 0.251706
# [500]	valid_0's binary_logloss: 0.252106
# Early stopping, best iteration is:
# [413]	valid_0's binary_logloss: 0.251684
# -------------------- Metrics --------------------
# Accuracy: 0.7222
# Precision: 0.2342
# Recall: 0.7844
# F1 Score: 0.3607
# ROC AUC: 0.8311
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.268255
# [600]	valid_0's binary_logloss: 0.267295
# [700]	valid_0's binary_logloss: 0.266893
# [800]	valid_0's binary_logloss: 0.266868
# [900]	valid_0's binary_logloss: 0.267035
# Early stopping, best iteration is:
# [833]	valid_0's binary_logloss: 0.266793
# -------------------- Metrics --------------------
# Accuracy: 0.6941
# Precision: 0.2225
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_ooi.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_ooi",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_ooi.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_ooi.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_ooi.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.239886
# [200]	valid_0's binary_logloss: 0.233202
# [300]	valid_0's binary_logloss: 0.231806
# [400]	valid_0's binary_logloss: 0.231737
# Early stopping, best iteration is:
# [330]	valid_0's binary_logloss: 0.231645
# -------------------- Metrics --------------------
# Accuracy: 0.7050
# Precision: 0.1751
# Recall: 0.7443
# F1 Score: 0.2835
# ROC AUC: 0.7954
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.233672
# [500]	valid_0's binary_logloss: 0.233302
# [600]	valid_0's binary_logloss: 0.233315
# Early stopping, best iteration is:
# [551]	valid_0's binary_logloss: 0.233244
# -------------------- Metrics --------------------
# Accuracy: 0.7016
# Precision: 0.1798
# Recall: 0.7555
# F1 Score: 0.2905
# ROC AUC: 0.8003
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_nagoya.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_nagoya",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_nagoya.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_nagoya.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_nagoya.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.276192
# [200]	valid_0's binary_logloss: 0.266493
# [300]	valid_0's binary_logloss: 0.264361
# [400]	valid_0's binary_logloss: 0.264248
# Early stopping, best iteration is:
# [365]	valid_0's binary_logloss: 0.263986
# -------------------- Metrics --------------------
# Accuracy: 0.6986
# Precision: 0.2198
# Recall: 0.7841
# F1 Score: 0.3433
# ROC AUC: 0.8156
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.25262
# [500]	valid_0's binary_logloss: 0.251338
# [600]	valid_0's binary_logloss: 0.250967
# Early stopping, best iteration is:
# [581]	valid_0's binary_logloss: 0.250912
# -------------------- Metrics --------------------
# Accuracy: 0.6992
# Precision: 0.2076
# Recall: 0.7867
# F1 Score: 0.3285
# ROC AUC: 0.8176
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_morioka.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_morioka",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_morioka.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_morioka.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_morioka.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.297189
# [200]	valid_0's binary_logloss: 0.289999
# [300]	valid_0's binary_logloss: 0.289218
# Early stopping, best iteration is:
# [289]	valid_0's binary_logloss: 0.28905
# -------------------- Metrics --------------------
# Accuracy: 0.6632
# Precision: 0.2155
# Recall: 0.7784
# F1 Score: 0.3376
# ROC AUC: 0.7916
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.274049
# [400]	valid_0's binary_logloss: 0.272299
# [500]	valid_0's binary_logloss: 0.271648
# [600]	valid_0's binary_logloss: 0.271634
# [700]	valid_0's binary_logloss: 0.272267
# Early stopping, best iteration is:
# [626]	valid_0's binary_logloss: 0.271532
# -------------------- Metrics --------------------
# Accuracy: 0.6738
# Precision: 0.2187
# Recall: 0.7969
# F1 Score: 0.3432
# ROC AUC: 0.8159
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_monbetu.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_monbetu",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_monbetu.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_monbetu.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_monbetu.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.278491
# [200]	valid_0's binary_logloss: 0.26567
# [300]	valid_0's binary_logloss: 0.262465
# [400]	valid_0's binary_logloss: 0.261462
# Early stopping, best iteration is:
# [396]	valid_0's binary_logloss: 0.261454
# -------------------- Metrics --------------------
# Accuracy: 0.6714
# Precision: 0.2180
# Recall: 0.8330
# F1 Score: 0.3456
# ROC AUC: 0.8272
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.277328
# [500]	valid_0's binary_logloss: 0.274997
# [600]	valid_0's binary_logloss: 0.274379
# [700]	valid_0's binary_logloss: 0.27408
# [800]	valid_0's binary_logloss: 0.274095
# Early stopping, best iteration is:
# [717]	valid_0's binary_logloss: 0.273987
# -------------------- Metrics --------------------
# Accuracy: 0.6621
# Precision: 0.2159
# Recall: 0.8230
# F1 Score: 0.3421
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_mizusawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_mizusawa",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_mizusawa.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_mizusawa.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_mizusawa.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.301821
# [200]	valid_0's binary_logloss: 0.294025
# [300]	valid_0's binary_logloss: 0.291608
# [400]	valid_0's binary_logloss: 0.292484
# Early stopping, best iteration is:
# [300]	valid_0's binary_logloss: 0.291608
# -------------------- Metrics --------------------
# Accuracy: 0.6383
# Precision: 0.1981
# Recall: 0.7824
# F1 Score: 0.3162
# ROC AUC: 0.7719
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.286714
# [500]	valid_0's binary_logloss: 0.285832
# [600]	valid_0's binary_logloss: 0.285633
# Early stopping, best iteration is:
# [562]	valid_0's binary_logloss: 0.285433
# -------------------- Metrics --------------------
# Accuracy: 0.6432
# Precision: 0.2033
# Recall: 0.8122
# F1 Score: 0.3252
# ROC AUC: 0.7846
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kouti.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_kouti",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_kouti.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_kouti.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_kouti.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.267109
# [200]	valid_0's binary_logloss: 0.255588
# [300]	valid_0's binary_logloss: 0.252449
# [400]	valid_0's binary_logloss: 0.251568
# Early stopping, best iteration is:
# [399]	valid_0's binary_logloss: 0.251566
# -------------------- Metrics --------------------
# Accuracy: 0.7137
# Precision: 0.2329
# Recall: 0.7995
# F1 Score: 0.3608
# ROC AUC: 0.8382
# Training fold 2/5...
# [400]	valid_0's binary_logloss: 0.254457
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.253073
# [600]	valid_0's binary_logloss: 0.252607
# [700]	valid_0's binary_logloss: 0.2522
# [800]	valid_0's binary_logloss: 0.251918
# Early stopping, best iteration is:
# [799]	valid_0's binary_logloss: 0.251918
# -------------------- Metrics --------------------
# Accuracy: 0.7030
# Precision: 0.2277
# Recall: 0.8005
# F1 Score: 0.3546
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kawasaki.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_kawasaki",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_kawasaki.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_kawasaki.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_kawasaki.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.267684
# [200]	valid_0's binary_logloss: 0.260977
# [300]	valid_0's binary_logloss: 0.260028
# Early stopping, best iteration is:
# [278]	valid_0's binary_logloss: 0.259947
# -------------------- Metrics --------------------
# Accuracy: 0.6820
# Precision: 0.1821
# Recall: 0.7303
# F1 Score: 0.2915
# ROC AUC: 0.7793
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.258724
# [400]	valid_0's binary_logloss: 0.256841
# [500]	valid_0's binary_logloss: 0.256523
# [600]	valid_0's binary_logloss: 0.256562
# Early stopping, best iteration is:
# [548]	valid_0's binary_logloss: 0.256339
# -------------------- Metrics --------------------
# Accuracy: 0.6801
# Precision: 0.1858
# Recall: 0.7538
# F1 Score: 0.2982
# ROC AUC: 0.7861
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kasamatu.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_kasamatu",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_kasamatu.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_kasamatu.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_kasamatu.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.297189
# [200]	valid_0's binary_logloss: 0.289999
# [300]	valid_0's binary_logloss: 0.289218
# Early stopping, best iteration is:
# [289]	valid_0's binary_logloss: 0.28905
# -------------------- Metrics --------------------
# Accuracy: 0.6632
# Precision: 0.2155
# Recall: 0.7784
# F1 Score: 0.3376
# ROC AUC: 0.7916
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.274049
# [400]	valid_0's binary_logloss: 0.272299
# [500]	valid_0's binary_logloss: 0.271648
# [600]	valid_0's binary_logloss: 0.271634
# [700]	valid_0's binary_logloss: 0.272267
# Early stopping, best iteration is:
# [626]	valid_0's binary_logloss: 0.271532
# -------------------- Metrics --------------------
# Accuracy: 0.6738
# Precision: 0.2187
# Recall: 0.7969
# F1 Score: 0.3432
# ROC AUC: 0.8159
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kanazawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_kanazawa",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_kanazawa.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_kanazawa.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_kanazawa.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.290806
# [200]	valid_0's binary_logloss: 0.277084
# [300]	valid_0's binary_logloss: 0.27411
# [400]	valid_0's binary_logloss: 0.274172
# Early stopping, best iteration is:
# [343]	valid_0's binary_logloss: 0.273791
# -------------------- Metrics --------------------
# Accuracy: 0.6934
# Precision: 0.2524
# Recall: 0.8239
# F1 Score: 0.3864
# ROC AUC: 0.8368
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.282222
# [500]	valid_0's binary_logloss: 0.279827
# [600]	valid_0's binary_logloss: 0.279041
# [700]	valid_0's binary_logloss: 0.279304
# Early stopping, best iteration is:
# [609]	valid_0's binary_logloss: 0.278973
# -------------------- Metrics --------------------
# Accuracy: 0.6899
# Precision: 0.2470
# Recall: 0.8179
# F1 Score: 0.3794
# ROC AUC: 0.8295
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_funabasi.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_noweight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_noweight_funabasi",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_noweight_funabasi.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_noweight_funabasi.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_noweight_funabasi.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.268079
# [200]	valid_0's binary_logloss: 0.260616
# [300]	valid_0's binary_logloss: 0.259737
# Early stopping, best iteration is:
# [263]	valid_0's binary_logloss: 0.259639
# -------------------- Metrics --------------------
# Accuracy: 0.7088
# Precision: 0.2094
# Recall: 0.7545
# F1 Score: 0.3278
# ROC AUC: 0.8012
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.280091
# [400]	valid_0's binary_logloss: 0.279259
# Early stopping, best iteration is:
# [388]	valid_0's binary_logloss: 0.27919
# -------------------- Metrics --------------------
# Accuracy: 0.6841
# Precision: 0.1922
# Recall: 0.7102
# F1 Score: 0.3025
# ROC AUC: 0.7658
# Training fold 3/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.269441
# ...

# %%
# # オッズと人気を特徴量から省いたランク、日、クロスバリデーション
# trainer = Trainer_lightgbm_rank_niti_cv(
    
#     features_filename = "features_turf.csv", 
#     config_filepath="config_lightgbm_niti_dev_turf_only.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only",
#     model_filename="model_lightgbm_rank_niti_cv_dev_turf_only.pkl",
#     evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only.csv",
#     final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only.pkl",
#     final_num_boost_round = 1000
# )

# %%
# # オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
# evaluator = Evaluator_lightgbm_rank_niti_cross(
#     evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only.csv",
#     return_tables_filename = "return_tables_turf.pickle",
# )
# evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_turf_only.csv")
# summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_turf_only")
# summary_df_noodds_gbm

# %%
# # オッズと人気を特徴量から省いた場合_time、回帰、クロスバリデーション（最終番目）_軸
# evaluator = Evaluator_lightgbm_rank_niti_shaft(
#     evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only.csv",
#     return_tables_filename = "return_tables_turf.pickle",
# )
# evaluator.summarize_box_top_n(n=3,save_filename="shaft_summary_rank_niti_dev_top3_turf_only.csv")
# summary_df_shaft = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_turf_only")
# summary_df_shaft

# %%
# # オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
# trainer = Trainer_lightgbm_rank_niti_cv(
    
#     features_filename = "features_dirt.csv", 
#     config_filepath="config_lightgbm_niti_dev_dirt.yaml",
# )
# evaluation_df = trainer.run(
#     n_splits = 5,
#     importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt",
#     model_filename="model_lightgbm_rank_niti_cv_dev_dirt.pkl",
#     evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt.csv",
#     final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt.pkl",
#     final_num_boost_round = 1200
# )

# %%
# # オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
# evaluator = Evaluator_lightgbm_rank_niti_cross(
#     evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt.csv",
#     return_tables_filename = "return_tables_dirt.pickle",
# )
# evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt.csv")
# summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt")
# summary_df_noodds_gbm

# %% [markdown]
# ### only_tenkai

# %%
# %autoreload

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    
    features_filename = "features_dirt_sonoda.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight10.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_sonoda",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_sonoda.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_sonoda.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_sonoda.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.291957
# [200]	valid_0's binary_logloss: 0.283602
# [300]	valid_0's binary_logloss: 0.280252
# [400]	valid_0's binary_logloss: 0.278798
# [500]	valid_0's binary_logloss: 0.27805
# [600]	valid_0's binary_logloss: 0.277883
# Early stopping, best iteration is:
# [587]	valid_0's binary_logloss: 0.277854
# -------------------- Metrics --------------------
# Accuracy: 0.6242
# Precision: 0.1785
# Recall: 0.7791
# F1 Score: 0.2904
# ROC AUC: 0.7699
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.278814
# [700]	valid_0's binary_logloss: 0.277145
# [800]	valid_0's binary_logloss: 0.276379
# [900]	valid_0's binary_logloss: 0.275833
# [1000]	valid_0's binary_logloss: 0.275559
# [1100]	valid_0's binary_logloss: 0.275431
# [1200]	valid_0's binary_logloss: 0.275245
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_urawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_urawa",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_urawa.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_urawa.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_urawa.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.27908
# [200]	valid_0's binary_logloss: 0.274079
# [300]	valid_0's binary_logloss: 0.273236
# Early stopping, best iteration is:
# [295]	valid_0's binary_logloss: 0.273203
# -------------------- Metrics --------------------
# Accuracy: 0.6541
# Precision: 0.1693
# Recall: 0.7103
# F1 Score: 0.2734
# ROC AUC: 0.7456
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.284239
# [400]	valid_0's binary_logloss: 0.279289
# [500]	valid_0's binary_logloss: 0.278573
# [600]	valid_0's binary_logloss: 0.278395
# Early stopping, best iteration is:
# [559]	valid_0's binary_logloss: 0.278179
# -------------------- Metrics --------------------
# Accuracy: 0.6319
# Precision: 0.1777
# Recall: 0.7784
# F1 Score: 0.2893
# ROC AUC: 0.7633
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_saga.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_saga",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_saga.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_saga.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_saga.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.281388
# [200]	valid_0's binary_logloss: 0.271683
# [300]	valid_0's binary_logloss: 0.268214
# [400]	valid_0's binary_logloss: 0.266999
# [500]	valid_0's binary_logloss: 0.267025
# Early stopping, best iteration is:
# [429]	valid_0's binary_logloss: 0.266899
# -------------------- Metrics --------------------
# Accuracy: 0.6924
# Precision: 0.2122
# Recall: 0.7661
# F1 Score: 0.3323
# ROC AUC: 0.7989
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.284875
# [600]	valid_0's binary_logloss: 0.283348
# [700]	valid_0's binary_logloss: 0.282786
# [800]	valid_0's binary_logloss: 0.28258
# [900]	valid_0's binary_logloss: 0.282573
# Early stopping, best iteration is:
# [826]	valid_0's binary_logloss: 0.282477
# -------------------- Metrics --------------------
# Accuracy: 0.6559
# Precision: 0.1961
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_ooi.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_ooi",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_ooi.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_ooi.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_ooi.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.246594
# [200]	valid_0's binary_logloss: 0.239734
# [300]	valid_0's binary_logloss: 0.237378
# [400]	valid_0's binary_logloss: 0.236616
# Early stopping, best iteration is:
# [389]	valid_0's binary_logloss: 0.236585
# -------------------- Metrics --------------------
# Accuracy: 0.6928
# Precision: 0.1660
# Recall: 0.7252
# F1 Score: 0.2702
# ROC AUC: 0.7786
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.239902
# [500]	valid_0's binary_logloss: 0.238868
# [600]	valid_0's binary_logloss: 0.238619
# [700]	valid_0's binary_logloss: 0.238546
# [800]	valid_0's binary_logloss: 0.238533
# Early stopping, best iteration is:
# [755]	valid_0's binary_logloss: 0.23844
# -------------------- Metrics --------------------
# Accuracy: 0.6911
# Precision: 0.1714
# Recall: 0.7352
# F1 Score: 0.2780
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_nagoya.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_nagoya",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_nagoya.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_nagoya.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_nagoya.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.292022
# [200]	valid_0's binary_logloss: 0.284174
# [300]	valid_0's binary_logloss: 0.281919
# [400]	valid_0's binary_logloss: 0.281683
# Early stopping, best iteration is:
# [372]	valid_0's binary_logloss: 0.28166
# -------------------- Metrics --------------------
# Accuracy: 0.6466
# Precision: 0.1906
# Recall: 0.7759
# F1 Score: 0.3061
# ROC AUC: 0.7729
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.265756
# [500]	valid_0's binary_logloss: 0.264088
# [600]	valid_0's binary_logloss: 0.263336
# [700]	valid_0's binary_logloss: 0.262939
# [800]	valid_0's binary_logloss: 0.26263
# [900]	valid_0's binary_logloss: 0.262455
# Early stopping, best iteration is:
# [884]	valid_0's binary_logloss: 0.262402
# -------------------- Metrics --------------------
# Accuracy: 0.6708
# Precision: 0.1882
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_morioka.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_morioka",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_morioka.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_morioka.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_morioka.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.304136
# [200]	valid_0's binary_logloss: 0.297043
# [300]	valid_0's binary_logloss: 0.295872
# Early stopping, best iteration is:
# [292]	valid_0's binary_logloss: 0.295769
# -------------------- Metrics --------------------
# Accuracy: 0.6439
# Precision: 0.2017
# Recall: 0.7538
# F1 Score: 0.3182
# ROC AUC: 0.7761
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.283369
# [400]	valid_0's binary_logloss: 0.280683
# [500]	valid_0's binary_logloss: 0.280215
# [600]	valid_0's binary_logloss: 0.280107
# Early stopping, best iteration is:
# [569]	valid_0's binary_logloss: 0.279999
# -------------------- Metrics --------------------
# Accuracy: 0.6342
# Precision: 0.1992
# Recall: 0.8011
# F1 Score: 0.3190
# ROC AUC: 0.7964
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_mizusawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_mizusawa",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_mizusawa.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_mizusawa.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_mizusawa.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.309431
# [200]	valid_0's binary_logloss: 0.302381
# [300]	valid_0's binary_logloss: 0.301054
# [400]	valid_0's binary_logloss: 0.301257
# Early stopping, best iteration is:
# [340]	valid_0's binary_logloss: 0.30067
# -------------------- Metrics --------------------
# Accuracy: 0.6021
# Precision: 0.1785
# Recall: 0.7562
# F1 Score: 0.2889
# ROC AUC: 0.7443
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.299932
# [500]	valid_0's binary_logloss: 0.297866
# [600]	valid_0's binary_logloss: 0.297166
# [700]	valid_0's binary_logloss: 0.296955
# Early stopping, best iteration is:
# [685]	valid_0's binary_logloss: 0.296905
# -------------------- Metrics --------------------
# Accuracy: 0.5715
# Precision: 0.1724
# Recall: 0.8025
# F1 Score: 0.2839
# ROC AUC: 0.7484
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kouti.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight7.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kouti",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kouti.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kouti.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_kouti.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.28168
# [200]	valid_0's binary_logloss: 0.27074
# [300]	valid_0's binary_logloss: 0.266449
# [400]	valid_0's binary_logloss: 0.264845
# [500]	valid_0's binary_logloss: 0.264239
# [600]	valid_0's binary_logloss: 0.264476
# Early stopping, best iteration is:
# [507]	valid_0's binary_logloss: 0.264164
# -------------------- Metrics --------------------
# Accuracy: 0.6853
# Precision: 0.2115
# Recall: 0.7751
# F1 Score: 0.3323
# ROC AUC: 0.8067
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.267588
# [700]	valid_0's binary_logloss: 0.267248
# [800]	valid_0's binary_logloss: 0.26718
# [900]	valid_0's binary_logloss: 0.267164
# Early stopping, best iteration is:
# [848]	valid_0's binary_logloss: 0.267104
# -------------------- Metrics --------------------
# Accuracy: 0.6662
# Precision: 0.2064
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kawasaki.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kawasaki",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kawasaki.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kawasaki.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_kawasaki.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.272357
# [200]	valid_0's binary_logloss: 0.266385
# [300]	valid_0's binary_logloss: 0.264553
# [400]	valid_0's binary_logloss: 0.264537
# Early stopping, best iteration is:
# [346]	valid_0's binary_logloss: 0.264287
# -------------------- Metrics --------------------
# Accuracy: 0.6614
# Precision: 0.1700
# Recall: 0.7161
# F1 Score: 0.2748
# ROC AUC: 0.7606
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.265028
# [500]	valid_0's binary_logloss: 0.264144
# [600]	valid_0's binary_logloss: 0.264071
# Early stopping, best iteration is:
# [574]	valid_0's binary_logloss: 0.263995
# -------------------- Metrics --------------------
# Accuracy: 0.6398
# Precision: 0.1660
# Recall: 0.7449
# F1 Score: 0.2716
# ROC AUC: 0.7622
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kasamatu.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kasamatu",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kasamatu.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kasamatu.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_kasamatu.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.304136
# [200]	valid_0's binary_logloss: 0.297043
# [300]	valid_0's binary_logloss: 0.295872
# Early stopping, best iteration is:
# [292]	valid_0's binary_logloss: 0.295769
# -------------------- Metrics --------------------
# Accuracy: 0.6439
# Precision: 0.2017
# Recall: 0.7538
# F1 Score: 0.3182
# ROC AUC: 0.7761
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [300]	valid_0's binary_logloss: 0.283369
# [400]	valid_0's binary_logloss: 0.280683
# [500]	valid_0's binary_logloss: 0.280215
# [600]	valid_0's binary_logloss: 0.280107
# Early stopping, best iteration is:
# [569]	valid_0's binary_logloss: 0.279999
# -------------------- Metrics --------------------
# Accuracy: 0.6342
# Precision: 0.1992
# Recall: 0.8011
# F1 Score: 0.3190
# ROC AUC: 0.7964
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_kanazawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kanazawa",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kanazawa.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kanazawa.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_kanazawa.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.305378
# [200]	valid_0's binary_logloss: 0.290913
# [300]	valid_0's binary_logloss: 0.286235
# [400]	valid_0's binary_logloss: 0.284617
# [500]	valid_0's binary_logloss: 0.284834
# Early stopping, best iteration is:
# [464]	valid_0's binary_logloss: 0.284449
# -------------------- Metrics --------------------
# Accuracy: 0.6796
# Precision: 0.2439
# Recall: 0.8259
# F1 Score: 0.3766
# ROC AUC: 0.8244
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.292182
# [600]	valid_0's binary_logloss: 0.290701
# [700]	valid_0's binary_logloss: 0.290259
# [800]	valid_0's binary_logloss: 0.290204
# Early stopping, best iteration is:
# [765]	valid_0's binary_logloss: 0.290077
# -------------------- Metrics --------------------
# Accuracy: 0.6511
# Precision: 0.2232
# Recall: 0.8109
# F1 Score: 0.3501
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_funabasi.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_funabasi",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_funabasi.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_funabasi.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_funabasi.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.276105
# [200]	valid_0's binary_logloss: 0.269835
# [300]	valid_0's binary_logloss: 0.268447
# [400]	valid_0's binary_logloss: 0.268495
# Early stopping, best iteration is:
# [333]	valid_0's binary_logloss: 0.268258
# -------------------- Metrics --------------------
# Accuracy: 0.7035
# Precision: 0.2009
# Recall: 0.7225
# F1 Score: 0.3144
# ROC AUC: 0.7823
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.280258
# [500]	valid_0's binary_logloss: 0.27929
# [600]	valid_0's binary_logloss: 0.279059
# [700]	valid_0's binary_logloss: 0.279038
# Early stopping, best iteration is:
# [651]	valid_0's binary_logloss: 0.278887
# -------------------- Metrics --------------------
# Accuracy: 0.6642
# Precision: 0.1829
# Recall: 0.7156
# F1 Score: 0.2913
# ROC AUC: 0.7594
# Training fold 3/5...
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer = Trainer_lightgbm_rank_niti_cv(
    features_filename = "features_dirt_monbetu.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_monbetu",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_monbetu.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_monbetu.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_monbetu.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.287347
# [200]	valid_0's binary_logloss: 0.276214
# [300]	valid_0's binary_logloss: 0.2724
# [400]	valid_0's binary_logloss: 0.271313
# [500]	valid_0's binary_logloss: 0.271224
# Early stopping, best iteration is:
# [439]	valid_0's binary_logloss: 0.270961
# -------------------- Metrics --------------------
# Accuracy: 0.6457
# Precision: 0.2031
# Recall: 0.8217
# F1 Score: 0.3258
# ROC AUC: 0.8091
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.282396
# [600]	valid_0's binary_logloss: 0.281687
# [700]	valid_0's binary_logloss: 0.281347
# [800]	valid_0's binary_logloss: 0.28124
# Early stopping, best iteration is:
# [787]	valid_0's binary_logloss: 0.281153
# -------------------- Metrics --------------------
# Accuracy: 0.6362
# Precision: 0.2035
# Recall: 0.8270
# F1 Score: 0.3267
# ...

# %%
# %autoreload

# %%
#評価

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_sonoda.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_sonoda.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_sonoda")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_sonoda  \
# 0                                            0.153252
# 1                                            0.491708
# 2                                            0.170337
# 3                                            0.267274
# 4                                            0.735663
# 5                                            0.047456
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_urawa.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_urawa.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_urawa")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_urawa  \
# 0                                            0.214660
# 1                                            0.596859
# 2                                            0.308901
# 3                                            0.413613
# 4                                            0.785340
# 5                                            0.130890
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_saga.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_saga.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_saga")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_saga  \
# 0      1       単勝                                              0.175
# 1      1       複勝                                              0.600
# 2      2      ワイド                                              0.350
# 3      2       単勝                                              0.475
# 4      2       複勝                                              0.775
# 5      2       馬単                                              0.125
# 6      2       馬連                                              0.125
# 7      3      ワイド                                              0.600
# 8      3      三連単                                              0.075
# 9      3      三連複                                              0.075
# 10     3       単勝                                              0.575
# 11     3       複勝                                              0.850
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_ooi.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_ooi.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_ooi")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_ooi  \
# 0      1       単勝                                           0.237624
# 1      1       複勝                                           0.554455
# 2      2      ワイド                                           0.237624
# 3      2       単勝                                           0.356436
# 4      2       複勝                                           0.712871
# 5      2       馬単                                           0.089109
# 6      2       馬連                                           0.089109
# 7      3      ワイド                                           0.445545
# 8      3      三連単                                           0.089109
# 9      3      三連複                                           0.089109
# 10     3       単勝                                           0.495050
# 11     3       複勝                                           0.871287
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_nagoya.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_nagoya.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_nagoya")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_nagoya  \
# 0                                            0.279070
# 1                                            0.593023
# 2                                            0.313953
# 3                                            0.453488
# 4                                            0.837209
# 5                                            0.151163
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_morioka.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_morioka.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_morioka")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_morioka  \
# 0                                            0.285714
# 1                                            0.619048
# 2                                            0.238095
# 3                                            0.380952
# 4                                            0.857143
# 5                                            0.047619
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_monbetu.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_monbetu.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_monbetu")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_monbetu  \
# 0                                            0.382353
# 1                                            0.529412
# 2                                            0.470588
# 3                                            0.647059
# 4                                            0.941176
# 5                                            0.235294
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_mizusawa.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_mizusawa.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_mizusawa")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_mizusawa  \
# 0                                                0.32
# 1                                                0.56
# 2                                                0.24
# 3                                                0.56
# 4                                                0.76
# 5                                                0.08
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kouti.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_kouti.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_kouti")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_kouti  \
# 0                                             0.50000
# 1                                             0.78125
# 2                                             0.40625
# 3                                             0.62500
# 4                                             0.90625
# 5                                             0.25000
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kawasaki.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_kawasaki.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_kawasaki")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_kawasaki  \
# 0                                            0.325103
# 1                                            0.654321
# 2                                            0.267490
# 3                                            0.493827
# 4                                            0.839506
# 5                                            0.123457
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kasamatu.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_kasamatu.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_kasamatu")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_kasamatu  \
# 0                                            0.285714
# 1                                            0.619048
# 2                                            0.238095
# 3                                            0.380952
# 4                                            0.857143
# 5                                            0.047619
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kanazawa.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_kanazawa.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_kanazawa")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_kanazawa  \
# 0                                            0.448276
# 1                                            0.741379
# 2                                            0.500000
# 3                                            0.586207
# 4                                            0.879310
# 5                                            0.206897
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_funabasi.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_funabasi.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_funabasi")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_funabasi  \
# 0                                            0.453125
# 1                                            0.661417
# 2                                            0.359375
# 3                                            0.578125
# 4                                            0.826772
# 5                                            0.203125
# ...

# %% [markdown]
# ### ３位以内モデル

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_sonoda.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt10.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_sonoda_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_sonoda_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_sonoda_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_sonoda_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.530891
# [200]	valid_0's binary_logloss: 0.50964
# [300]	valid_0's binary_logloss: 0.501934
# [400]	valid_0's binary_logloss: 0.498753
# [500]	valid_0's binary_logloss: 0.4976
# [600]	valid_0's binary_logloss: 0.496949
# [700]	valid_0's binary_logloss: 0.496705
# [800]	valid_0's binary_logloss: 0.496392
# [900]	valid_0's binary_logloss: 0.496183
# [1000]	valid_0's binary_logloss: 0.496082
# [1100]	valid_0's binary_logloss: 0.496198
# Early stopping, best iteration is:
# [1004]	valid_0's binary_logloss: 0.496068
# -------------------- Metrics --------------------
# Accuracy: 0.4398
# Precision: 0.3433
# Recall: 0.9789
# F1 Score: 0.5083
# ROC AUC: 0.7816
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [1100]	valid_0's binary_logloss: 0.490383
# [1200]	valid_0's binary_logloss: 0.488525
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_urawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_urawa_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_urawa_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_urawa_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_urawa_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.512344
# [200]	valid_0's binary_logloss: 0.49557
# [300]	valid_0's binary_logloss: 0.4905
# [400]	valid_0's binary_logloss: 0.489334
# [500]	valid_0's binary_logloss: 0.489733
# Early stopping, best iteration is:
# [409]	valid_0's binary_logloss: 0.489147
# -------------------- Metrics --------------------
# Accuracy: 0.4297
# Precision: 0.3216
# Recall: 0.9704
# F1 Score: 0.4831
# ROC AUC: 0.7731
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.498955
# [600]	valid_0's binary_logloss: 0.497261
# [700]	valid_0's binary_logloss: 0.496902
# [800]	valid_0's binary_logloss: 0.496754
# [900]	valid_0's binary_logloss: 0.496695
# Early stopping, best iteration is:
# [847]	valid_0's binary_logloss: 0.496592
# -------------------- Metrics --------------------
# Accuracy: 0.4432
# Precision: 0.3372
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_saga.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt7.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_saga_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_saga_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_saga_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_saga_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.514509
# [200]	valid_0's binary_logloss: 0.492835
# [300]	valid_0's binary_logloss: 0.486084
# [400]	valid_0's binary_logloss: 0.48338
# [500]	valid_0's binary_logloss: 0.482561
# [600]	valid_0's binary_logloss: 0.4824
# Early stopping, best iteration is:
# [563]	valid_0's binary_logloss: 0.482302
# -------------------- Metrics --------------------
# Accuracy: 0.4529
# Precision: 0.3513
# Recall: 0.9733
# F1 Score: 0.5162
# ROC AUC: 0.7994
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.505584
# [700]	valid_0's binary_logloss: 0.503668
# [800]	valid_0's binary_logloss: 0.502964
# [900]	valid_0's binary_logloss: 0.502816
# [1000]	valid_0's binary_logloss: 0.50283
# Early stopping, best iteration is:
# [962]	valid_0's binary_logloss: 0.502649
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_ooi.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt7.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_ooi_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_ooi_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_ooi_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_ooi_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.471026
# [200]	valid_0's binary_logloss: 0.453902
# [300]	valid_0's binary_logloss: 0.448145
# [400]	valid_0's binary_logloss: 0.446096
# [500]	valid_0's binary_logloss: 0.445342
# [600]	valid_0's binary_logloss: 0.445168
# [700]	valid_0's binary_logloss: 0.445264
# Early stopping, best iteration is:
# [639]	valid_0's binary_logloss: 0.444988
# -------------------- Metrics --------------------
# Accuracy: 0.4659
# Precision: 0.3009
# Recall: 0.9597
# F1 Score: 0.4581
# ROC AUC: 0.7881
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [700]	valid_0's binary_logloss: 0.457187
# [800]	valid_0's binary_logloss: 0.455848
# [900]	valid_0's binary_logloss: 0.455174
# [1000]	valid_0's binary_logloss: 0.455124
# [1100]	valid_0's binary_logloss: 0.454735
# [1200]	valid_0's binary_logloss: 0.454651
# Early stopping, best iteration is:
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_nagoya.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt7.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_nagoya_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_nagoya_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_nagoya_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_nagoya_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.519169
# [200]	valid_0's binary_logloss: 0.498564
# [300]	valid_0's binary_logloss: 0.492097
# [400]	valid_0's binary_logloss: 0.489709
# [500]	valid_0's binary_logloss: 0.488957
# [600]	valid_0's binary_logloss: 0.488836
# [700]	valid_0's binary_logloss: 0.48939
# Early stopping, best iteration is:
# [600]	valid_0's binary_logloss: 0.488836
# -------------------- Metrics --------------------
# Accuracy: 0.4695
# Precision: 0.3599
# Recall: 0.9768
# F1 Score: 0.5260
# ROC AUC: 0.7950
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [700]	valid_0's binary_logloss: 0.477347
# [800]	valid_0's binary_logloss: 0.476753
# [900]	valid_0's binary_logloss: 0.476251
# [1000]	valid_0's binary_logloss: 0.476144
# [1100]	valid_0's binary_logloss: 0.476199
# Early stopping, best iteration is:
# [1007]	valid_0's binary_logloss: 0.476114
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_morioka.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_morioka_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_morioka_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_morioka_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_morioka_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.548978
# [200]	valid_0's binary_logloss: 0.52643
# [300]	valid_0's binary_logloss: 0.518917
# [400]	valid_0's binary_logloss: 0.51611
# [500]	valid_0's binary_logloss: 0.514789
# [600]	valid_0's binary_logloss: 0.515296
# Early stopping, best iteration is:
# [505]	valid_0's binary_logloss: 0.514713
# -------------------- Metrics --------------------
# Accuracy: 0.4130
# Precision: 0.3593
# Recall: 0.9909
# F1 Score: 0.5273
# ROC AUC: 0.7841
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.5047
# [700]	valid_0's binary_logloss: 0.504184
# [800]	valid_0's binary_logloss: 0.504134
# [900]	valid_0's binary_logloss: 0.504173
# Early stopping, best iteration is:
# [823]	valid_0's binary_logloss: 0.503979
# -------------------- Metrics --------------------
# Accuracy: 0.4255
# Precision: 0.3571
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_monbetu.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_monbetu_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_monbetu_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_monbetu_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_monbetu_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.521143
# [200]	valid_0's binary_logloss: 0.494404
# [300]	valid_0's binary_logloss: 0.485065
# [400]	valid_0's binary_logloss: 0.481688
# [500]	valid_0's binary_logloss: 0.480582
# [600]	valid_0's binary_logloss: 0.480636
# Early stopping, best iteration is:
# [526]	valid_0's binary_logloss: 0.480417
# -------------------- Metrics --------------------
# Accuracy: 0.4820
# Precision: 0.3740
# Recall: 0.9764
# F1 Score: 0.5409
# ROC AUC: 0.8102
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.502136
# [700]	valid_0's binary_logloss: 0.501579
# [800]	valid_0's binary_logloss: 0.501036
# [900]	valid_0's binary_logloss: 0.501179
# Early stopping, best iteration is:
# [829]	valid_0's binary_logloss: 0.500839
# -------------------- Metrics --------------------
# Accuracy: 0.4765
# Precision: 0.3769
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_mizusawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_mizusawa_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_mizusawa_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_mizusawa_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_mizusawa_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.563947
# [200]	valid_0's binary_logloss: 0.547341
# [300]	valid_0's binary_logloss: 0.540935
# [400]	valid_0's binary_logloss: 0.538443
# [500]	valid_0's binary_logloss: 0.537727
# Early stopping, best iteration is:
# [489]	valid_0's binary_logloss: 0.537494
# -------------------- Metrics --------------------
# Accuracy: 0.3848
# Precision: 0.3415
# Recall: 0.9917
# F1 Score: 0.5081
# ROC AUC: 0.7506
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.529571
# [600]	valid_0's binary_logloss: 0.525547
# [700]	valid_0's binary_logloss: 0.523845
# [800]	valid_0's binary_logloss: 0.523144
# [900]	valid_0's binary_logloss: 0.522801
# [1000]	valid_0's binary_logloss: 0.522712
# [1100]	valid_0's binary_logloss: 0.522633
# [1200]	valid_0's binary_logloss: 0.522353
# Early stopping, best iteration is:
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_kouti.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt7.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_kouti_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_kouti_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kouti_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_kouti_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.509325
# [200]	valid_0's binary_logloss: 0.483478
# [300]	valid_0's binary_logloss: 0.475154
# [400]	valid_0's binary_logloss: 0.47177
# [500]	valid_0's binary_logloss: 0.470767
# [600]	valid_0's binary_logloss: 0.470481
# [700]	valid_0's binary_logloss: 0.470271
# [800]	valid_0's binary_logloss: 0.47038
# Early stopping, best iteration is:
# [744]	valid_0's binary_logloss: 0.470156
# -------------------- Metrics --------------------
# Accuracy: 0.4997
# Precision: 0.3752
# Recall: 0.9756
# F1 Score: 0.5419
# ROC AUC: 0.8137
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [800]	valid_0's binary_logloss: 0.472325
# [900]	valid_0's binary_logloss: 0.471499
# [1000]	valid_0's binary_logloss: 0.470845
# [1100]	valid_0's binary_logloss: 0.470429
# [1200]	valid_0's binary_logloss: 0.470341
# Early stopping, best iteration is:
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_kawasaki.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_kawasaki_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_kawasaki_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kawasaki_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_kawasaki_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.510256
# [200]	valid_0's binary_logloss: 0.494392
# [300]	valid_0's binary_logloss: 0.488605
# [400]	valid_0's binary_logloss: 0.486982
# [500]	valid_0's binary_logloss: 0.486634
# Early stopping, best iteration is:
# [453]	valid_0's binary_logloss: 0.486563
# -------------------- Metrics --------------------
# Accuracy: 0.4344
# Precision: 0.3187
# Recall: 0.9724
# F1 Score: 0.4800
# ROC AUC: 0.7693
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.493249
# [600]	valid_0's binary_logloss: 0.491228
# [700]	valid_0's binary_logloss: 0.490299
# [800]	valid_0's binary_logloss: 0.489957
# [900]	valid_0's binary_logloss: 0.489827
# [1000]	valid_0's binary_logloss: 0.489899
# Early stopping, best iteration is:
# [944]	valid_0's binary_logloss: 0.489696
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_kasamatu.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_kasamatu_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_kasamatu_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kasamatu_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_kasamatu_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.548978
# [200]	valid_0's binary_logloss: 0.52643
# [300]	valid_0's binary_logloss: 0.518917
# [400]	valid_0's binary_logloss: 0.51611
# [500]	valid_0's binary_logloss: 0.514789
# [600]	valid_0's binary_logloss: 0.515296
# Early stopping, best iteration is:
# [505]	valid_0's binary_logloss: 0.514713
# -------------------- Metrics --------------------
# Accuracy: 0.4130
# Precision: 0.3593
# Recall: 0.9909
# F1 Score: 0.5273
# ROC AUC: 0.7841
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.5047
# [700]	valid_0's binary_logloss: 0.504184
# [800]	valid_0's binary_logloss: 0.504134
# [900]	valid_0's binary_logloss: 0.504173
# Early stopping, best iteration is:
# [823]	valid_0's binary_logloss: 0.503979
# -------------------- Metrics --------------------
# Accuracy: 0.4255
# Precision: 0.3571
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_kanazawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_kanazawa_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_kanazawa_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kanazawa_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_kanazawa_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.54537
# [200]	valid_0's binary_logloss: 0.518732
# [300]	valid_0's binary_logloss: 0.509792
# [400]	valid_0's binary_logloss: 0.506294
# [500]	valid_0's binary_logloss: 0.504939
# [600]	valid_0's binary_logloss: 0.505249
# Early stopping, best iteration is:
# [561]	valid_0's binary_logloss: 0.504908
# -------------------- Metrics --------------------
# Accuracy: 0.4824
# Precision: 0.4024
# Recall: 0.9814
# F1 Score: 0.5708
# ROC AUC: 0.8028
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.52022
# [700]	valid_0's binary_logloss: 0.516735
# [800]	valid_0's binary_logloss: 0.516292
# [900]	valid_0's binary_logloss: 0.515867
# Early stopping, best iteration is:
# [883]	valid_0's binary_logloss: 0.515681
# -------------------- Metrics --------------------
# Accuracy: 0.4654
# Precision: 0.3927
# ...

# %%
# オッズと人気を特徴量から省いたランク、芝、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_funabasi.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_dirt_funabasi_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_dirt_funabasi_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_funabasi_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_dirt_funabasi_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.513848
# [200]	valid_0's binary_logloss: 0.495269
# [300]	valid_0's binary_logloss: 0.489931
# [400]	valid_0's binary_logloss: 0.488639
# [500]	valid_0's binary_logloss: 0.489008
# Early stopping, best iteration is:
# [401]	valid_0's binary_logloss: 0.488625
# -------------------- Metrics --------------------
# Accuracy: 0.4206
# Precision: 0.3252
# Recall: 0.9795
# F1 Score: 0.4882
# ROC AUC: 0.7811
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.50373
# [600]	valid_0's binary_logloss: 0.502562
# [700]	valid_0's binary_logloss: 0.502129
# [800]	valid_0's binary_logloss: 0.502079
# [900]	valid_0's binary_logloss: 0.50199
# Early stopping, best iteration is:
# [880]	valid_0's binary_logloss: 0.501744
# -------------------- Metrics --------------------
# Accuracy: 0.4360
# Precision: 0.3363
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_sonoda.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight10.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_sonoda_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_sonoda_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_sonoda_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_sonoda_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.552476
# [200]	valid_0's binary_logloss: 0.534235
# [300]	valid_0's binary_logloss: 0.526386
# [400]	valid_0's binary_logloss: 0.522124
# [500]	valid_0's binary_logloss: 0.519721
# [600]	valid_0's binary_logloss: 0.518485
# [700]	valid_0's binary_logloss: 0.517835
# [800]	valid_0's binary_logloss: 0.517599
# [900]	valid_0's binary_logloss: 0.517584
# Early stopping, best iteration is:
# [893]	valid_0's binary_logloss: 0.517521
# -------------------- Metrics --------------------
# Accuracy: 0.3831
# Precision: 0.3229
# Recall: 0.9899
# F1 Score: 0.4870
# ROC AUC: 0.7546
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [900]	valid_0's binary_logloss: 0.517817
# [1000]	valid_0's binary_logloss: 0.515392
# [1100]	valid_0's binary_logloss: 0.513985
# [1200]	valid_0's binary_logloss: 0.51301
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_urawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_urawa_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_urawa_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_urawa_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_urawa_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.530853
# [200]	valid_0's binary_logloss: 0.515694
# [300]	valid_0's binary_logloss: 0.50984
# [400]	valid_0's binary_logloss: 0.507145
# [500]	valid_0's binary_logloss: 0.506487
# [600]	valid_0's binary_logloss: 0.506869
# Early stopping, best iteration is:
# [525]	valid_0's binary_logloss: 0.506345
# -------------------- Metrics --------------------
# Accuracy: 0.3832
# Precision: 0.3060
# Recall: 0.9825
# F1 Score: 0.4667
# ROC AUC: 0.7511
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.511078
# [700]	valid_0's binary_logloss: 0.509343
# [800]	valid_0's binary_logloss: 0.508772
# [900]	valid_0's binary_logloss: 0.508829
# Early stopping, best iteration is:
# [834]	valid_0's binary_logloss: 0.508573
# -------------------- Metrics --------------------
# Accuracy: 0.3957
# Precision: 0.3205
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_saga.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight7.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_saga_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_saga_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_saga_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_saga_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.54238
# [200]	valid_0's binary_logloss: 0.523233
# [300]	valid_0's binary_logloss: 0.515362
# [400]	valid_0's binary_logloss: 0.511263
# [500]	valid_0's binary_logloss: 0.509265
# [600]	valid_0's binary_logloss: 0.508302
# [700]	valid_0's binary_logloss: 0.508114
# Early stopping, best iteration is:
# [688]	valid_0's binary_logloss: 0.507976
# -------------------- Metrics --------------------
# Accuracy: 0.3738
# Precision: 0.3224
# Recall: 0.9878
# F1 Score: 0.4861
# ROC AUC: 0.7696
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [700]	valid_0's binary_logloss: 0.531061
# [800]	valid_0's binary_logloss: 0.528615
# [900]	valid_0's binary_logloss: 0.527596
# [1000]	valid_0's binary_logloss: 0.527099
# [1100]	valid_0's binary_logloss: 0.526999
# Early stopping, best iteration is:
# [1056]	valid_0's binary_logloss: 0.526849
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_ooi.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight7.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_ooi_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_ooi_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_ooi_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_ooi_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.487011
# [200]	valid_0's binary_logloss: 0.469151
# [300]	valid_0's binary_logloss: 0.462482
# [400]	valid_0's binary_logloss: 0.45919
# [500]	valid_0's binary_logloss: 0.457984
# [600]	valid_0's binary_logloss: 0.4574
# [700]	valid_0's binary_logloss: 0.457472
# Early stopping, best iteration is:
# [618]	valid_0's binary_logloss: 0.45733
# -------------------- Metrics --------------------
# Accuracy: 0.3991
# Precision: 0.2785
# Recall: 0.9774
# F1 Score: 0.4335
# ROC AUC: 0.7714
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [700]	valid_0's binary_logloss: 0.466353
# [800]	valid_0's binary_logloss: 0.465489
# [900]	valid_0's binary_logloss: 0.465111
# [1000]	valid_0's binary_logloss: 0.46488
# [1100]	valid_0's binary_logloss: 0.464745
# [1200]	valid_0's binary_logloss: 0.464774
# Early stopping, best iteration is:
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_nagoya.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight7.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_nagoya_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_nagoya_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_nagoya_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_nagoya_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.550997
# [200]	valid_0's binary_logloss: 0.531382
# [300]	valid_0's binary_logloss: 0.522986
# [400]	valid_0's binary_logloss: 0.519102
# [500]	valid_0's binary_logloss: 0.517289
# [600]	valid_0's binary_logloss: 0.516994
# [700]	valid_0's binary_logloss: 0.517303
# Early stopping, best iteration is:
# [618]	valid_0's binary_logloss: 0.516923
# -------------------- Metrics --------------------
# Accuracy: 0.3835
# Precision: 0.3275
# Recall: 0.9922
# F1 Score: 0.4924
# ROC AUC: 0.7618
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [700]	valid_0's binary_logloss: 0.49941
# [800]	valid_0's binary_logloss: 0.498478
# [900]	valid_0's binary_logloss: 0.497905
# [1000]	valid_0's binary_logloss: 0.497729
# [1100]	valid_0's binary_logloss: 0.497902
# Early stopping, best iteration is:
# [1003]	valid_0's binary_logloss: 0.4977
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_morioka.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_morioka_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_morioka_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_morioka_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_morioka_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.563659
# [200]	valid_0's binary_logloss: 0.54335
# [300]	valid_0's binary_logloss: 0.535476
# [400]	valid_0's binary_logloss: 0.532041
# [500]	valid_0's binary_logloss: 0.53046
# [600]	valid_0's binary_logloss: 0.530657
# Early stopping, best iteration is:
# [524]	valid_0's binary_logloss: 0.530288
# -------------------- Metrics --------------------
# Accuracy: 0.3837
# Precision: 0.3486
# Recall: 0.9959
# F1 Score: 0.5164
# ROC AUC: 0.7640
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.522824
# [700]	valid_0's binary_logloss: 0.52153
# [800]	valid_0's binary_logloss: 0.521601
# Early stopping, best iteration is:
# [742]	valid_0's binary_logloss: 0.521226
# -------------------- Metrics --------------------
# Accuracy: 0.3869
# Precision: 0.3428
# Recall: 0.9915
# F1 Score: 0.5095
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_monbetu.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_monbetu_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_monbetu_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_monbetu_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_monbetu_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.537279
# [200]	valid_0's binary_logloss: 0.512192
# [300]	valid_0's binary_logloss: 0.502474
# [400]	valid_0's binary_logloss: 0.498539
# [500]	valid_0's binary_logloss: 0.497031
# [600]	valid_0's binary_logloss: 0.496923
# Early stopping, best iteration is:
# [584]	valid_0's binary_logloss: 0.496748
# -------------------- Metrics --------------------
# Accuracy: 0.4423
# Precision: 0.3575
# Recall: 0.9846
# F1 Score: 0.5246
# ROC AUC: 0.7930
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.520788
# [700]	valid_0's binary_logloss: 0.519919
# [800]	valid_0's binary_logloss: 0.51958
# [900]	valid_0's binary_logloss: 0.5192
# [1000]	valid_0's binary_logloss: 0.519473
# Early stopping, best iteration is:
# [904]	valid_0's binary_logloss: 0.519193
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_mizusawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_mizusawa_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_mizusawa_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_mizusawa_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_mizusawa_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.577632
# [200]	valid_0's binary_logloss: 0.564618
# [300]	valid_0's binary_logloss: 0.559941
# [400]	valid_0's binary_logloss: 0.558203
# [500]	valid_0's binary_logloss: 0.557644
# Early stopping, best iteration is:
# [457]	valid_0's binary_logloss: 0.557477
# -------------------- Metrics --------------------
# Accuracy: 0.3486
# Precision: 0.3293
# Recall: 0.9972
# F1 Score: 0.4952
# ROC AUC: 0.7231
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.55008
# [600]	valid_0's binary_logloss: 0.547214
# [700]	valid_0's binary_logloss: 0.546036
# [800]	valid_0's binary_logloss: 0.54576
# [900]	valid_0's binary_logloss: 0.545776
# [1000]	valid_0's binary_logloss: 0.545782
# Early stopping, best iteration is:
# [930]	valid_0's binary_logloss: 0.545638
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_kouti.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight7.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kouti_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kouti_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kouti_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_kouti_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.538651
# [200]	valid_0's binary_logloss: 0.516039
# [300]	valid_0's binary_logloss: 0.506276
# [400]	valid_0's binary_logloss: 0.500989
# [500]	valid_0's binary_logloss: 0.498126
# [600]	valid_0's binary_logloss: 0.496763
# [700]	valid_0's binary_logloss: 0.495737
# [800]	valid_0's binary_logloss: 0.495221
# [900]	valid_0's binary_logloss: 0.495216
# Early stopping, best iteration is:
# [829]	valid_0's binary_logloss: 0.495092
# -------------------- Metrics --------------------
# Accuracy: 0.4162
# Precision: 0.3406
# Recall: 0.9874
# F1 Score: 0.5064
# ROC AUC: 0.7883
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [900]	valid_0's binary_logloss: 0.499847
# [1000]	valid_0's binary_logloss: 0.498828
# [1100]	valid_0's binary_logloss: 0.498225
# [1200]	valid_0's binary_logloss: 0.497775
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_kawasaki.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kawasaki_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kawasaki_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kawasaki_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_kawasaki_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.522344
# [200]	valid_0's binary_logloss: 0.506305
# [300]	valid_0's binary_logloss: 0.499929
# [400]	valid_0's binary_logloss: 0.49759
# [500]	valid_0's binary_logloss: 0.496909
# [600]	valid_0's binary_logloss: 0.496847
# Early stopping, best iteration is:
# [533]	valid_0's binary_logloss: 0.496678
# -------------------- Metrics --------------------
# Accuracy: 0.3850
# Precision: 0.3017
# Recall: 0.9819
# F1 Score: 0.4616
# ROC AUC: 0.7551
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.501682
# [700]	valid_0's binary_logloss: 0.501153
# [800]	valid_0's binary_logloss: 0.500883
# [900]	valid_0's binary_logloss: 0.50072
# Early stopping, best iteration is:
# [883]	valid_0's binary_logloss: 0.500687
# -------------------- Metrics --------------------
# Accuracy: 0.3929
# Precision: 0.3064
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_kasamatu.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kasamatu_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kasamatu_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kasamatu_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_kasamatu_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.563659
# [200]	valid_0's binary_logloss: 0.54335
# [300]	valid_0's binary_logloss: 0.535476
# [400]	valid_0's binary_logloss: 0.532041
# [500]	valid_0's binary_logloss: 0.53046
# [600]	valid_0's binary_logloss: 0.530657
# Early stopping, best iteration is:
# [524]	valid_0's binary_logloss: 0.530288
# -------------------- Metrics --------------------
# Accuracy: 0.3837
# Precision: 0.3486
# Recall: 0.9959
# F1 Score: 0.5164
# ROC AUC: 0.7640
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [600]	valid_0's binary_logloss: 0.522824
# [700]	valid_0's binary_logloss: 0.52153
# [800]	valid_0's binary_logloss: 0.521601
# Early stopping, best iteration is:
# [742]	valid_0's binary_logloss: 0.521226
# -------------------- Metrics --------------------
# Accuracy: 0.3869
# Precision: 0.3428
# Recall: 0.9915
# F1 Score: 0.5095
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_kanazawa.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kanazawa_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kanazawa_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kanazawa_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_kanazawa_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.570881
# [200]	valid_0's binary_logloss: 0.545863
# [300]	valid_0's binary_logloss: 0.535447
# [400]	valid_0's binary_logloss: 0.531216
# [500]	valid_0's binary_logloss: 0.529398
# [600]	valid_0's binary_logloss: 0.5292
# [700]	valid_0's binary_logloss: 0.528927
# Early stopping, best iteration is:
# [690]	valid_0's binary_logloss: 0.528922
# -------------------- Metrics --------------------
# Accuracy: 0.4303
# Precision: 0.3801
# Recall: 0.9900
# F1 Score: 0.5493
# ROC AUC: 0.7787
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [700]	valid_0's binary_logloss: 0.541192
# [800]	valid_0's binary_logloss: 0.537058
# [900]	valid_0's binary_logloss: 0.535259
# [1000]	valid_0's binary_logloss: 0.534614
# [1100]	valid_0's binary_logloss: 0.534269
# [1200]	valid_0's binary_logloss: 0.534257
# Early stopping, best iteration is:
# ...

# %%
# オッズと人気を特徴量から省いたランク、日、クロスバリデーション
trainer_in3 = Trainer_lightgbm_rank_niti_cv_in3(
    features_filename = "features_dirt_funabasi.csv", 
    config_filepath="config_lightgbm_niti_dev_dirt_only_tenkai_weight4.yaml",
)
evaluation_df = trainer_in3.run(
    n_splits = 5,
    importance_filename="importance_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_funabasi_in3",
    model_filename="model_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_funabasi_in3.pkl",
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_funabasi_in3.csv",
    final_model_filename = "model_lightgbm_rank_niti_cv_full_dev_turf_only_tenkai_weight_funabasi_in3.pkl",
    final_num_boost_round = 1000
)
# Out:
# Training fold 1/5...
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's binary_logloss: 0.527388
# [200]	valid_0's binary_logloss: 0.509087
# [300]	valid_0's binary_logloss: 0.502492
# [400]	valid_0's binary_logloss: 0.500589
# [500]	valid_0's binary_logloss: 0.500612
# Early stopping, best iteration is:
# [414]	valid_0's binary_logloss: 0.5003
# -------------------- Metrics --------------------
# Accuracy: 0.3675
# Precision: 0.3072
# Recall: 0.9893
# F1 Score: 0.4688
# ROC AUC: 0.7667
# Training fold 2/5...
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's binary_logloss: 0.512373
# [600]	valid_0's binary_logloss: 0.51121
# [700]	valid_0's binary_logloss: 0.510643
# [800]	valid_0's binary_logloss: 0.510465
# [900]	valid_0's binary_logloss: 0.510557
# Early stopping, best iteration is:
# [826]	valid_0's binary_logloss: 0.51044
# -------------------- Metrics --------------------
# Accuracy: 0.3940
# Precision: 0.3212
# ...

# %%
#評価

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_sonoda_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_sonoda_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_sonoda_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_sonoda_in3  \
# 0      1       単勝                                           0.346154
# 1      1       複勝                                           0.769231
# 2      2      ワイド                                           0.576923
# 3      2       単勝                                           0.538462
# 4      2       複勝                                           0.923077
# 5      2       馬単                                           0.384615
# 6      2       馬連                                           0.384615
# 7      3      ワイド                                           0.807692
# 8      3      三連単                                           0.115385
# 9      3      三連複                                           0.115385
# 10     3       単勝                                           0.692308
# 11     3       複勝                                           1.000000
# 12     3       馬単                                           0.538462
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_urawa_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_urawa_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_urawa_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_urawa_in3  \
# 0      1       単勝                                           0.235602
# 1      1       複勝                                           0.560209
# 2      2      ワイド                                           0.308901
# 3      2       単勝                                           0.424084
# 4      2       複勝                                           0.759162
# 5      2       馬単                                           0.125654
# 6      2       馬連                                           0.125654
# 7      3      ワイド                                           0.507853
# 8      3      三連単                                           0.120419
# 9      3      三連複                                           0.120419
# 10     3       単勝                                           0.528796
# 11     3       複勝                                           0.900524
# 12     3       馬単                                           0.293194
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_saga_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_saga_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_saga_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_saga_in3  \
# 0      1       単勝                                              0.275
# 1      1       複勝                                              0.750
# 2      2      ワイド                                              0.425
# 3      2       単勝                                              0.525
# 4      2       複勝                                              0.825
# 5      2       馬単                                              0.225
# 6      2       馬連                                              0.225
# 7      3      ワイド                                              0.650
# 8      3      三連単                                              0.075
# 9      3      三連複                                              0.075
# 10     3       単勝                                              0.675
# 11     3       複勝                                              0.975
# 12     3       馬単                                              0.350
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_ooi_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_ooi_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_ooi_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_ooi_in3  \
# 0      1       単勝                                           0.316832
# 1      1       複勝                                           0.633663
# 2      2      ワイド                                           0.326733
# 3      2       単勝                                           0.435644
# 4      2       複勝                                           0.811881
# 5      2       馬単                                           0.148515
# 6      2       馬連                                           0.148515
# 7      3      ワイド                                           0.564356
# 8      3      三連単                                           0.148515
# 9      3      三連複                                           0.148515
# 10     3       単勝                                           0.603960
# 11     3       複勝                                           0.930693
# 12     3       馬単                                           0.366337
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_nagoya_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_nagoya_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_nagoya_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_nagoya_in3  \
# 0      1       単勝                                           0.372093
# 1      1       複勝                                           0.662791
# 2      2      ワイド                                           0.406977
# 3      2       単勝                                           0.558140
# 4      2       複勝                                           0.872093
# 5      2       馬単                                           0.209302
# 6      2       馬連                                           0.209302
# 7      3      ワイド                                           0.581395
# 8      3      三連単                                           0.174419
# 9      3      三連複                                           0.174419
# 10     3       単勝                                           0.639535
# 11     3       複勝                                           0.965116
# 12     3       馬単                                           0.383721
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_morioka_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_morioka_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_morioka_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_morioka_in3  \
# 0      1       単勝                                           0.380952
# 1      1       複勝                                           0.666667
# 2      2      ワイド                                           0.333333
# 3      2       単勝                                           0.523810
# 4      2       複勝                                           0.809524
# 5      2       馬単                                           0.238095
# 6      2       馬連                                           0.238095
# 7      3      ワイド                                           0.380952
# 8      3      三連単                                           0.095238
# 9      3      三連複                                           0.095238
# 10     3       単勝                                           0.619048
# 11     3       複勝                                           0.952381
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_monbetu_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_monbetu_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_monbetu_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_monbetu_in3  \
# 0      1       単勝                                           0.500000
# 1      1       複勝                                           0.764706
# 2      2      ワイド                                           0.500000
# 3      2       単勝                                           0.676471
# 4      2       複勝                                           1.000000
# 5      2       馬単                                           0.205882
# 6      2       馬連                                           0.205882
# 7      3      ワイド                                           0.852941
# 8      3      三連単                                           0.205882
# 9      3      三連複                                           0.205882
# 10     3       単勝                                           0.823529
# 11     3       複勝                                           1.000000
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_mizusawa_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_mizusawa_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_mizusawa_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_mizusawa_in3  \
# 0      1       単勝                                               0.28
# 1      1       複勝                                               0.68
# 2      2      ワイド                                               0.36
# 3      2       単勝                                               0.64
# 4      2       複勝                                               0.92
# 5      2       馬単                                               0.24
# 6      2       馬連                                               0.24
# 7      3      ワイド                                               0.68
# 8      3      三連単                                               0.12
# 9      3      三連複                                               0.12
# 10     3       単勝                                               0.72
# 11     3       複勝                                               1.00
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kouti_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_kouti_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_kouti_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_kouti_in3  \
# 0      1       単勝                                            0.43750
# 1      1       複勝                                            0.71875
# 2      2      ワイド                                            0.31250
# 3      2       単勝                                            0.59375
# 4      2       複勝                                            0.84375
# 5      2       馬単                                            0.18750
# 6      2       馬連                                            0.18750
# 7      3      ワイド                                            0.59375
# 8      3      三連単                                            0.15625
# 9      3      三連複                                            0.15625
# 10     3       単勝                                            0.78125
# 11     3       複勝                                            0.96875
# 12     3       馬単                                            0.31250
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kawasaki_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_kawasaki_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_kawasaki_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_kawasaki_in3  \
# 0      1       単勝                                           0.345679
# 1      1       複勝                                           0.650206
# 2      2      ワイド                                           0.279835
# 3      2       単勝                                           0.502058
# 4      2       複勝                                           0.851852
# 5      2       馬単                                           0.123457
# 6      2       馬連                                           0.123457
# 7      3      ワイド                                           0.572016
# 8      3      三連単                                           0.082305
# 9      3      三連複                                           0.082305
# 10     3       単勝                                           0.621399
# 11     3       複勝                                           0.934156
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kasamatu_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_kasamatu_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_kasamatu_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_kasamatu_in3  \
# 0      1       単勝                                           0.380952
# 1      1       複勝                                           0.666667
# 2      2      ワイド                                           0.333333
# 3      2       単勝                                           0.523810
# 4      2       複勝                                           0.809524
# 5      2       馬単                                           0.238095
# 6      2       馬連                                           0.238095
# 7      3      ワイド                                           0.380952
# 8      3      三連単                                           0.095238
# 9      3      三連複                                           0.095238
# 10     3       単勝                                           0.619048
# 11     3       複勝                                           0.952381
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kanazawa_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_kanazawa_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_kanazawa_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_kanazawa_in3  \
# 0      1       単勝                                           0.431034
# 1      1       複勝                                           0.672414
# 2      2      ワイド                                           0.465517
# 3      2       単勝                                           0.724138
# 4      2       複勝                                           0.879310
# 5      2       馬単                                           0.310345
# 6      2       馬連                                           0.310345
# 7      3      ワイド                                           0.793103
# 8      3      三連単                                           0.189655
# 9      3      三連複                                           0.189655
# 10     3       単勝                                           0.810345
# 11     3       複勝                                           0.965517
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_funabasi_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_funabasi_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_funabasi_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_funabasi_in3  \
# 0      1       単勝                                           0.335938
# 1      1       複勝                                           0.622047
# 2      2      ワイド                                           0.367188
# 3      2       単勝                                           0.500000
# 4      2       複勝                                           0.850394
# 5      2       馬単                                           0.148438
# 6      2       馬連                                           0.148438
# 7      3      ワイド                                           0.601562
# 8      3      三連単                                           0.117188
# 9      3      三連複                                           0.117188
# 10     3       単勝                                           0.648438
# 11     3       複勝                                           0.897638
# ...

# %%
#展開

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_sonoda_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_sonoda_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_sonoda_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_sonoda_in3  \
# 0                                            0.307692
# 1                                            0.653846
# 2                                            0.384615
# 3                                            0.500000
# 4                                            0.884615
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_urawa_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_urawa_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_urawa_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_urawa_in3  \
# 0                                            0.251309
# 1                                            0.586387
# 2                                            0.329843
# 3                                            0.434555
# 4                                            0.806283
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_saga_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_saga_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_saga_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_saga_in3  \
# 0                                               0.300
# 1                                               0.700
# 2                                               0.325
# 3                                               0.475
# 4                                               0.850
# 5                                               0.125
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_ooi_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_ooi_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_ooi_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_ooi_in3  \
# 0                                            0.247525
# 1                                            0.603960
# 2                                            0.306931
# 3                                            0.366337
# 4                                            0.772277
# 5                                            0.099010
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_nagoya_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_nagoya_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_nagoya_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_nagoya_in3  \
# 0                                            0.406977
# 1                                            0.639535
# 2                                            0.360465
# 3                                            0.523256
# 4                                            0.790698
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_morioka_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_morioka_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_morioka_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_morioka_in3  \
# 0                                            0.190476
# 1                                            0.523810
# 2                                            0.333333
# 3                                            0.380952
# 4                                            0.761905
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_monbetu_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_monbetu_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_monbetu_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_monbetu_in3  \
# 0                                            0.500000
# 1                                            0.676471
# 2                                            0.470588
# 3                                            0.676471
# 4                                            0.970588
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_mizusawa_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_mizusawa_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_mizusawa_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_mizusawa_in3  \
# 0                                                0.28
# 1                                                0.64
# 2                                                0.32
# 3                                                0.48
# 4                                                0.92
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kouti_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_kouti_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_kouti_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_kouti_in3  \
# 0                                             0.31250
# 1                                             0.62500
# 2                                             0.40625
# 3                                             0.53125
# 4                                             0.81250
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kawasaki_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_kawasaki_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_kawasaki_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_kawasaki_in3  \
# 0                                            0.312757
# 1                                            0.621399
# 2                                            0.296296
# 3                                            0.473251
# 4                                            0.818930
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kasamatu_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_kasamatu_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_kasamatu_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_kasamatu_in3  \
# 0                                            0.190476
# 1                                            0.523810
# 2                                            0.333333
# 3                                            0.380952
# 4                                            0.761905
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_kanazawa_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_kanazawa_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_kanazawa_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_kanazawa_in3  \
# 0                                            0.448276
# 1                                            0.758621
# 2                                            0.534483
# 3                                            0.620690
# 4                                            0.879310
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_turf_only_tenkai_weight_funabasi_in3.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_only_tenkai_weight_funabasi_in3.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_funabasi_in3")
summary_df_noodds_gbm
# Out:
#     topn bet_type  \
# 0      1       単勝
# 1      1       複勝
# 2      2      ワイド
# 3      2       単勝
# 4      2       複勝
# 5      2       馬単
# 6      2       馬連
# 7      3      ワイド
# 8      3      三連単
# 9      3      三連複
# 10     3       単勝
# 11     3       複勝
# 12     3       馬単
# 13     3       馬連
# 14     4      ワイド
# 15     4      三連単
# 16     4      三連複
# 17     4       単勝
# 18     4       複勝
# 19     4       馬単
# 20     4       馬連
# 21     5      ワイド
# 22     5      三連単
# 23     5      三連複
# 24     5       単勝
# 25     5       複勝
# 26     5       馬単
# 27     5       馬連
#
#     hitrate_lightgbm_rank_niti_cross_dev_dirt_only_tenkai_weight_funabasi_in3  \
# 0                                            0.375000
# 1                                            0.574803
# 2                                            0.375000
# 3                                            0.578125
# 4                                            0.850394
# ...

# %% [markdown]
# ###　状況

# %% [markdown]
# # 精度評価
# - popは人気列にかけた場合の回収率、的中率です
# - topnはそのモデルが評価した上からn番目にかけた場合の的中回収です
# - 例えばtop4の馬単にかけた場合上から4つの馬をかけた、4*3=12通りの的中率、回収率を計算します
# - なので、馬単と馬連などの的中率は同じになりますが、回収率は変わります

# %%
# %autoreload

# %% [markdown]
# ### 二値分類

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_sonoda.csv",
    return_tables_filename = "return_tables_all.pickle",
)


evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_sonoda.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_sonoda")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_sonoda  \
# 0      1       単勝                                          0.359684
# 1      1       複勝                                          0.671937
# 2      2      ワイド                                          0.430830
# 3      2       単勝                                          0.616601
# 4      2       複勝                                          0.885375
# 5      2       馬単                                          0.252964
# 6      2       馬連                                          0.252964
# 7      3      ワイド                                          0.683794
# 8      3      三連単                                          0.162055
# 9      3      三連複                                          0.162055
# 10     3       単勝                                          0.754941
# 11     3       複勝                                          0.972332
# 12     3       馬単                                          0.458498
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_urawa.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_urawa.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_urawa")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_urawa  \
# 0      1       単勝                                         0.219895
# 1      1       複勝                                         0.544503
# 2      2      ワイド                                         0.287958
# 3      2       単勝                                         0.397906
# 4      2       複勝                                         0.748691
# 5      2       馬単                                         0.136126
# 6      2       馬連                                         0.136126
# 7      3      ワイド                                         0.492147
# 8      3      三連単                                         0.109948
# 9      3      三連複                                         0.109948
# 10     3       単勝                                         0.513089
# 11     3       複勝                                         0.879581
# 12     3       馬単                                         0.251309
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_saga.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_saga.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_saga")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_saga  \
# 0      1       単勝                                           0.300
# 1      1       複勝                                           0.650
# 2      2      ワイド                                           0.400
# 3      2       単勝                                           0.550
# 4      2       複勝                                           0.800
# 5      2       馬単                                           0.200
# 6      2       馬連                                           0.200
# 7      3      ワイド                                           0.600
# 8      3      三連単                                           0.150
# 9      3      三連複                                           0.150
# 10     3       単勝                                           0.675
# 11     3       複勝                                           0.900
# 12     3       馬単                                           0.375
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_ooi.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_ooi.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_ooi")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_ooi  \
# 0      1       単勝                                       0.267327
# 1      1       複勝                                       0.564356
# 2      2      ワイド                                       0.366337
# 3      2       単勝                                       0.485149
# 4      2       複勝                                       0.841584
# 5      2       馬単                                       0.168317
# 6      2       馬連                                       0.168317
# 7      3      ワイド                                       0.574257
# 8      3      三連単                                       0.079208
# 9      3      三連複                                       0.079208
# 10     3       単勝                                       0.603960
# 11     3       複勝                                       0.920792
# 12     3       馬単                                       0.316832
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_nagoya.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_nagoya.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_nagoya")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_nagoya  \
# 0      1       単勝                                          0.395349
# 1      1       複勝                                          0.674419
# 2      2      ワイド                                          0.395349
# 3      2       単勝                                          0.593023
# 4      2       複勝                                          0.906977
# 5      2       馬単                                          0.220930
# 6      2       馬連                                          0.220930
# 7      3      ワイド                                          0.604651
# 8      3      三連単                                          0.197674
# 9      3      三連複                                          0.197674
# 10     3       単勝                                          0.697674
# 11     3       複勝                                          0.965116
# 12     3       馬単                                          0.418605
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_morioka.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_morioka.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_morioka")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_morioka  \
# 0      1       単勝                                           0.333333
# 1      1       複勝                                           0.571429
# 2      2      ワイド                                           0.285714
# 3      2       単勝                                           0.476190
# 4      2       複勝                                           0.809524
# 5      2       馬単                                           0.142857
# 6      2       馬連                                           0.142857
# 7      3      ワイド                                           0.476190
# 8      3      三連単                                           0.047619
# 9      3      三連複                                           0.047619
# 10     3       単勝                                           0.523810
# 11     3       複勝                                           0.904762
# 12     3       馬単                                           0.285714
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_monbetu.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_monbetu.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_monbetu")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_monbetu  \
# 0      1       単勝                                           0.529412
# 1      1       複勝                                           0.764706
# 2      2      ワイド                                           0.558824
# 3      2       単勝                                           0.823529
# 4      2       複勝                                           1.000000
# 5      2       馬単                                           0.294118
# 6      2       馬連                                           0.294118
# 7      3      ワイド                                           0.911765
# 8      3      三連単                                           0.352941
# 9      3      三連複                                           0.352941
# 10     3       単勝                                           0.941176
# 11     3       複勝                                           1.000000
# 12     3       馬単                                           0.676471
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_mizusawa.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_mizusawa.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_mizusawa")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_mizusawa  \
# 0      1       単勝                                               0.40
# 1      1       複勝                                               0.72
# 2      2      ワイド                                               0.40
# 3      2       単勝                                               0.52
# 4      2       複勝                                               0.84
# 5      2       馬単                                               0.20
# 6      2       馬連                                               0.20
# 7      3      ワイド                                               0.60
# 8      3      三連単                                               0.04
# 9      3      三連複                                               0.04
# 10     3       単勝                                               0.72
# 11     3       複勝                                               0.96
# 12     3       馬単                                               0.28
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kouti.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_kouti.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_kouti")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_kouti  \
# 0      1       単勝                                          0.53125
# 1      1       複勝                                          0.84375
# 2      2      ワイド                                          0.40625
# 3      2       単勝                                          0.75000
# 4      2       複勝                                          0.93750
# 5      2       馬単                                          0.25000
# 6      2       馬連                                          0.25000
# 7      3      ワイド                                          0.62500
# 8      3      三連単                                          0.15625
# 9      3      三連複                                          0.15625
# 10     3       単勝                                          0.78125
# 11     3       複勝                                          0.96875
# 12     3       馬単                                          0.43750
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kawasaki.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_kawasaki.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_kawasaki")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_kawasaki  \
# 0      1       単勝                                           0.329218
# 1      1       複勝                                           0.637860
# 2      2      ワイド                                           0.283951
# 3      2       単勝                                           0.522634
# 4      2       複勝                                           0.847737
# 5      2       馬単                                           0.156379
# 6      2       馬連                                           0.156379
# 7      3      ワイド                                           0.547325
# 8      3      三連単                                           0.078189
# 9      3      三連複                                           0.078189
# 10     3       単勝                                           0.658436
# 11     3       複勝                                           0.930041
# 12     3       馬単                                           0.329218
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kasamatu.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_kasamatu.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_kasamatu")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_kasamatu  \
# 0      1       単勝                                           0.333333
# 1      1       複勝                                           0.571429
# 2      2      ワイド                                           0.285714
# 3      2       単勝                                           0.476190
# 4      2       複勝                                           0.809524
# 5      2       馬単                                           0.142857
# 6      2       馬連                                           0.142857
# 7      3      ワイド                                           0.476190
# 8      3      三連単                                           0.047619
# 9      3      三連複                                           0.047619
# 10     3       単勝                                           0.523810
# 11     3       複勝                                           0.904762
# 12     3       馬単                                           0.285714
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_kanazawa.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_kanazawa.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_kanazawa")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_kanazawa  \
# 0      1       単勝                                           0.413793
# 1      1       複勝                                           0.689655
# 2      2      ワイド                                           0.500000
# 3      2       単勝                                           0.655172
# 4      2       複勝                                           0.879310
# 5      2       馬単                                           0.258621
# 6      2       馬連                                           0.258621
# 7      3      ワイド                                           0.758621
# 8      3      三連単                                           0.137931
# 9      3      三連複                                           0.137931
# 10     3       単勝                                           0.758621
# 11     3       複勝                                           0.965517
# 12     3       馬単                                           0.465517
# ...

# %%
# オッズと人気を特徴量から省いた場合_ランク、二値、クロスバリデーション（最終番目）
evaluator = Evaluator_lightgbm_rank_niti_cross(
    evaluation_filename="evaluation_lightgbm_rank_niti_cv_dev_dirt_funabasi.csv",
    return_tables_filename = "return_tables_all.pickle",
)
evaluator.summarize_box_top_n(n=3,save_filename="box_summary_rank_niti_cross_dev_dirt_funabasi.csv")
summary_df_noodds_gbm = evaluator.summarize_box_exp(exp_name="lightgbm_rank_niti_cross_dev_dirt_funabasi")
summary_df_noodds_gbm
# Out:
#     topn bet_type  hitrate_lightgbm_rank_niti_cross_dev_dirt_funabasi  \
# 0      1       単勝                                           0.335938
# 1      1       複勝                                           0.637795
# 2      2      ワイド                                           0.328125
# 3      2       単勝                                           0.507812
# 4      2       複勝                                           0.866142
# 5      2       馬単                                           0.195312
# 6      2       馬連                                           0.195312
# 7      3      ワイド                                           0.609375
# 8      3      三連単                                           0.109375
# 9      3      三連複                                           0.109375
# 10     3       単勝                                           0.664062
# 11     3       複勝                                           0.905512
# 12     3       馬単                                           0.351562
# ...

# %% [markdown]
# # 予測当日の処理

# %% [markdown]
# ## 事前準備
# **当日出走馬が確定した時点**で実行できる

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
# 当日出走馬の過去成績テーブルの前処理_そのままで使えない未加工のデータを加工する
horse_results_preprocessed = preprocessing.process_horse_results(
    input_filename="horse_results_prediction.csv",
    output_filename="horse_results_prediction.csv"
)
horse_results_preprocessed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[272], line 2
#       1 # 当日出走馬の過去成績テーブルの前処理_そのままで使えない未加工のデータを加工する
# ----> 2 horse_results_preprocessed = preprocessing.process_horse_results(
#       3     input_filename="horse_results_prediction.csv",
#       4     output_filename="horse_results_prediction.csv"
#       5 )
#       6 horse_results_preprocessed
#
# NameError: name 'preprocessing' is not defined

# %%
population = create_population.create(from_="2016-01-01", to_="2024-11-31")

# %%
# 当日出走馬の血統テーブルの前処理
peds_preprocessed = preprocessing.process_peds(
    input_filename="peds_prediction.csv",
    output_filename="peds_prediction.csv"
)
peds_preprocessed

# %%
pfc = PredictionFeatureCreator()
# 過去成績集計は事前に行うことができる
pfc.create_baselog()
pfc.agg_horse_n_races()
pfc.agg_horse_n_races_relative()
pfc.agg_horse_n_races_df

# %%
# レース結果テーブルの前処理
results_preprocessed = condition_prediction.process_results()
# レース情報テーブルの前処理
race_info_preprocessed = condition_prediction.process_race_info()
create_race_grade_preprocessed = condition_prediction.create_race_grade()

# %% [markdown]
# ## 当日の予測処理
# レース直前出走直前に実行する

# %%
#当日にやらないと、天気や馬場状態がわからないので、当日に実行してください、
# 特徴量の更新
features = pfc.create_features(
    race_id="202408060411",  # 予測するレースidを指定
    date_content_a = "2024年11月10日", #"%Y年%m月%d日"形式で該当レース当日の日付を入れてください    
    skip_agg_horse=True  # 事前に集計した場合はスキップできる
)

# %%
pfc.results

# %%
pfc.race_info

# %% [markdown]
# ### pred列は全て降順（大きい順）で表示されます
# ### 二値予測のrankはpred列が大きい順で評価がよく、回帰のrankとtimeは小さい順で評価が良いです
# ### 順番が逆になっているので気をつけてください

# %%
# オッズ除外モデルでの予測、time、クロスバリデーション
prediction.predict(
    features,
    model_filename="model_lightgbm_time_cv_full_odds_removed.pkl",
    config_filepath="config_lightgbm_kaiki_odds_removed.yaml"
)
